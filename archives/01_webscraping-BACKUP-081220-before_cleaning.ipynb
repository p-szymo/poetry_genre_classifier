# %% [markdown]
# # Webscraping
#
# ## Using Selenium and BeautifulSoup
#
# - This notebook details my process for scraping genre-labeled poetry from [PoetryFoundation.org](https://www.poetryfoundation.org/).
#
# #### Important note
# Due to the imperfection and idiosyncracies of scraping text from images, a lot of rescraping was necessary, sometimes in a manner that is best described, rather unfortunately, as nonprogrammatic. As a result, this notebook is extremely messy, which is not a reflection on the other notebooks for this project.
#
# Thank you for understanding :)
#
# ## Table of contents
#
# 1. [Import necessary packages](#Import-necessary-packages)
# 2. [Initial scrape](#Initial-scrape)
#
#     - [Text poems](#Text-poems)
#     - [Scanned poems](#Scanned-poems)
#     - [March](#March)
#         - [First half](#First-half)
#         - [Second half](#Second-half)
#     - [April](#April)
#     - [May](#May)
# 3. [Combine DataFrames](#Combine-DataFrames)
#
#     - [Save](#Save)
#
# ## Import necessary packages
#
# [[go back to the top](#Webscraping)]

# %%
# custom functions for webscraping
from functions_webscraping import *

# standard dataframe packages
import pandas as pd
import numpy as np

# # string manipulation libraries
# import re
# from unicodedata import normalize
# from ast import literal_eval

# # webscraping libraries
# import requests as rq
# from bs4 import BeautifulSoup as bs
# from selenium import webdriver

# timekeeping/progress packages
import time
from tqdm import tqdm

# saving packages
import gzip
import pickle

# reload functions/libraries when edited
# %load_ext autoreload
# %autoreload 2

# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# increase column width of dataframe
pd.set_option('max_colwidth', 150)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# - **Manually create dictionary with URL codes for each genre.**

# %% [markdown]
# ## Initial scrape
#
# [[go back to the top](#Webscraping)]
#
# - Load URL codes for each genre.
# - Create dictionary of URLs to poets' pages within each genre.
#     - *NOTE: The function for this process uses Selenium, which will open dummy browser windows, so to speak.*
# - Scrape URLs to poems' pages within each genre, separating into two groups:
#     - Poems known to be in text format on the site.
#     - Poem suspected to be within scanned images.
# - Attempt to scrape each variety of poem.

# %%
# dictionary of genre codes found in poetryfoundation.org urls
genre_codes = load_genre_codes()
genre_codes
# Out:
# {'augustan': 149,
#  'beat': 150,
#  'black_arts_movement': 304,
#  'black_mountain': 151,
#  'confessional': 152,
#  'fugitive': 153,
#  'georgian': 154,
#  'harlem_renaissance': 155,
#  'imagist': 156,
#  'language_poetry': 157,
#  'middle_english': 158,
#  'modern': 159,
#  'new_york_school': 160,
#  'new_york_school_2nd_generation': 161,
#  'objectivist': 162,
#  'renaissance': 163,
#  'romantic': 164,
#  'victorian': 165}

# %% [markdown]
# - Run function in a loop to create dictionary of poet urls.

# %%
# dictionary creation using custom function
poet_urls = {genre: poet_urls_by_genre(genre_code, 3) for genre, genre_code in genre_codes.items()}

# check a genre
poet_urls['augustan']

# %% [markdown]
# - Selenium can be finicky, so the loop only partially worked.
# - I'll re-run sections in which some URLs are missing.

# %%
# re-run on genre
poet_urls['black_arts_movement'] = poet_urls_by_genre(genre_codes['black_arts_movement'])

# %%
# re-run on genre
poet_urls['modern'] = poet_urls_by_genre(genre_codes['modern'])

# %%
# re-run on genre
poet_urls['renaissance'] = poet_urls_by_genre(genre_codes['renaissance'])

# %%
# re-run on genre
poet_urls['romantic'] = poet_urls_by_genre(genre_codes['romantic'])

# %%
# re-run on genre
poet_urls['victorian'] = poet_urls_by_genre(genre_codes['victorian'])

# %%
# confirm all urls have been grabbed
url_lens = {k:len(v) for k,v in poet_urls.items()}
url_lens
# Out:
# {'augustan': 23,
#  'beat': 13,
#  'black_arts_movement': 23,
#  'black_mountain': 10,
#  'confessional': 7,
#  'fugitive': 7,
#  'georgian': 22,
#  'harlem_renaissance': 17,
#  'imagist': 6,
#  'language_poetry': 18,
#  'middle_english': 3,
#  'modern': 54,
#  'new_york_school': 9,
#  'new_york_school_2nd_generation': 16,
#  'objectivist': 5,
#  'renaissance': 41,
#  'romantic': 51,
#  'victorian': 55}

# %% [markdown]
# - Ezra Pound and Richard Aldington both appear in two genres: Imagist and Modern.
# - Since Modern has so many poets within it, and Imagist so few, I'll give them to the Imagists.

# %%
# remove urls that appear in two genres
poet_urls['modern'] = [url for url in poet_urls['modern'] \
                        if url not in \
                        ['https://www.poetryfoundation.org/poets/richard-aldington', 
                         'https://www.poetryfoundation.org/poets/ezra-pound']]

# %%
# confirm drop
url_lens = {k:len(v) for k,v in poet_urls.items()}
url_lens['modern']
# Out:
# 52

# %% [markdown]
# #### 💾 Save/Load poet URLs dictionary

# %%
# # uncomment to save
# with gzip.open('data/poet_url_dict.pkl', 'wb') as goodbye:
#     pickle.dump(poet_urls, goodbye, protocol=pickle.HIGHEST_PROTOCOL)

# # uncomment to load
# with gzip.open('data/poet_url_dict.pkl', 'rb') as hello:
#     poet_url_dict = pickle.load(hello)

# %% [markdown]
# - Scrape poem URLs.

# %%
# %%time

# loop over keys and values of dictionary
for genre, poet_urls in poet_url_dict.items():
    # scrape poem urls (text and scan poems) for each poet in each genre
    # now each poet's url with be a key and
    # the value will be a tuple of their text poems' urls and their scan poems' urls 
    poet_url_dict[genre] = [{poet_url: poem_url_scraper(poet_url)} for poet_url in poet_urls]
# Out:
# CPU times: user 41.1 s, sys: 699 ms, total: 41.8 s
# Wall time: 9min 32s

# %% [markdown]
# - Simplify the structure of the dictionary.

# %%
# instantiate dictionaries of text and scan urls in each genre
poem_url_dict = {genre:{'text_urls':[],'scan_urls':[]} for genre in poet_url_dict}

# fill in empty lists with each type of url
for genre, poets in poet_url_dict.items():
    for poet in poets:
        for poet_url, poems in poet.items():
            poem_url_dict[genre]['text_urls'].extend(poems[0])
            poem_url_dict[genre]['scan_urls'].extend(poems[1])

# %%
#-------DATA STRUCTURE--------#
#
# genre ==> 'text_urls' ==> list of urls known to be text-based
#    \
#     ==> 'scan_urls' ==> list of urls thought to be scanned images

# %% [markdown]
# #### 💾 Save/Load poem URLs dictionary

# %%
# # uncomment to save
# with gzip.open('data/poem_url_dict.pkl', 'wb') as goodbye:
#     pickle.dump(poem_url_dict, goodbye, protocol=pickle.HIGHEST_PROTOCOL)

# # uncomment to load
# with gzip.open('data/poem_url_dict.pkl', 'rb') as hello:
#     poem_url_dict = pickle.load(hello)

# %%
# confirm everything's there
poem_url_dict.keys()
# Out:
# dict_keys(['augustan', 'beat', 'black_arts_movement', 'black_mountain', 'confessional', 'fugitive', 'georgian', 'harlem_renaissance', 'imagist', 'language_poetry', 'middle_english', 'modern', 'new_york_school', 'new_york_school_2nd_generation', 'objectivist', 'renaissance', 'romantic', 'victorian'])

# %%
# %%time

poem_dicts = []
error_poems = []
for genre in tqdm(poem_url_dict.keys()):
    for text_url in poem_url_dict[genre]['text_urls']:
        poem = text_poem_scraper(text_url)
        poem['genre'] = genre
        poem['poem_url'] = text_url
        poem_dicts.append(poem)
        time.sleep(0.01)
        
    for scan_url in poem_url_dict[genre]['scan_urls']:
        try:
            poem = text_poem_scraper(scan_url)
            poem['genre'] = genre
            poem['poem_url'] = scan_url
            poem_dicts.append(poem)
            poem_url_dict[genre]['text_urls'].append(scan_url)
            poem_url_dict[genre]['scan_urls'].remove(scan_url)
            time.sleep(0.01)
        except:
            try:
                poem = scan_poem_scraper(scan_url)
                poem['genre'] = genre
                poem['poem_url'] = scan_url
                poem_dicts.append(poem)
                time.sleep(0.01)
            except:
                error_poems.append(scan_url)
# Out:
# 100%|██████████| 18/18 [4:52:18<00:00, 974.35s/it]
# CPU times: user 15min 58s, sys: 1min 56s, total: 17min 54s
# Wall time: 4h 52min 18s

# %%
len(poem_dicts), len(error_poems)
# Out:
# (4923, 80)

# %%
poems = pd.DataFrame(poem_dicts)
poems.head()
# Out:
#               poet  \
# 0      Mary Barber
# 1  Susanna Blamire
# 2  Susanna Blamire
# 3  Susanna Blamire
# 4      Henry Carey
#
#                                                                         poem_url  \
# 0     https://www.poetryfoundation.org/poems/50523/advice-to-her-son-on-marriage
# 1                 https://www.poetryfoundation.org/poems/50534/auld-robin-forbes
# 2      https://www.poetryfoundation.org/poems/50533/o-donald-ye-are-just-the-man
# 3                  https://www.poetryfoundation.org/poems/50532/the-siller-croun
# 4  https://www.poetryfoundation.org/poems/43884/the-ballad-of-sally-in-our-alley
#
#                               title  \
# 0     Advice to Her Son on Marriage
# 1                 Auld Robin Forbes
# 2     O Donald! Ye Are Just the Man
# 3                  The Siller Croun
# 4  The Ballad of Sally in our Alley
#
#                                                                                                                                               poem_lines  \
# 0  [When you gain her Affection, take care to preserve it;, Lest others persuade her, you do not deserve it., Still study to heighten the Joys of her...
# 1  [And auld Robin Forbes hes gien tem a dance,, I pat on my speckets to see them aw prance;, I thout o’ the days when I was but fifteen,, And skipp’...
# 2  [O Donald! ye are just the man, Who, when he’s got a wife,, Begins to fratch— nae notice ta’en—, They’re strangers a’ their life., The fan may dro...
# 3  [And ye shall walk in silk attire,, And siller hae to spare,, Gin ye’ll consent to be his bride,, Nor think o’ Donald mair., O wha wad buy a silke...
# 4  [Of all the Girls that are so smart, There’s none like pretty SALLY,, She is the Darling of my Heart,, And she lives in our Alley., There is no La...
#
#                                                                                                                                              poem_string  \
# 0  When you gain her Affection, take care to preserve it;\nLest others persuade her, you do not deserve it.\nStill study to heighten the Joys of her ...
# 1  And auld Robin Forbes hes gien tem a dance,\nI pat on my speckets to see them aw prance;\nI thout o’ the days when I was but fifteen,\nAnd skipp’d...
# 2  O Donald! ye are just the man\nWho, when he’s got a wife,\nBegins to fratch— nae notice ta’en—\nThey’re strangers a’ their life.\nThe fan may drop...
# 3  And ye shall walk in silk attire,\nAnd siller hae to spare,\nGin ye’ll consent to be his bride,\nNor think o’ Donald mair.\nO wha wad buy a silken...
# 4  Of all the Girls that are so smart\nThere’s none like pretty SALLY,\nShe is the Darling of my Heart,\nAnd she lives in our Alley.\nThere is no Lad...
#
#       genre
# 0  augustan
# 1  augustan
# 2  augustan
# 3  augustan
# 4  augustan

# %%
poems.to_csv('data/poems_v2.csv')

# %%
poems = pd.read_csv('data/poems_v2.csv', index_col=0)

# %%
# %%time

text_poems = []
for genre in tqdm(poem_url_dict.keys()):
    for text_url in poem_url_dict[genre]['text_urls']:
        poem = text_poem_scraper(text_url)
        poem['genre'] = genre
        poem['poem_url'] = text_url
        text_poems.append(poem)
        time.sleep(0.01)
# Out:
# 100%|██████████| 18/18 [1:26:33<00:00, 288.51s/it]
# CPU times: user 5min 46s, sys: 38.3 s, total: 6min 25s
# Wall time: 1h 26min 33s

# %%
text_poems_df = pd.DataFrame(text_poems)
text_poems_df.shape
# Out:
# (3261, 6)

# %%
text_poems_df[text_poems_df.poem_string == '']
# Out:
#                          poet  \
# 154            Allen Ginsberg
# 166               Bob Kaufman
# 210     Lawrence Ferlinghetti
# 268               Henry Dumas
# 288            Nikki Giovanni
# 290            Nikki Giovanni
# 298          Etheridge Knight
# 401             Robert Duncan
# 505               Anne Sexton
# 683          W. E. B. Du Bois
# 720   Georgia Douglas Johnson
# 802                Amy Lowell
# 803                Amy Lowell
# 807                Amy Lowell
# 843   William Carlos Williams
# 853   William Carlos Williams
# 854   William Carlos Williams
# 863   William Carlos Williams
# 865   William Carlos Williams
# 890            Rae Armantrout
# 928              Lyn Hejinian
# 930              Lyn Hejinian
# 942                Fanny Howe
# 945                Fanny Howe
# 952                Susan Howe
# 977          Bernadette Mayer
# 994              Ron Silliman
# 995              Ron Silliman
# 1131              T. S. Eliot
# 1207       Archibald MacLeish
# 1322           Gertrude Stein
# 1324           Gertrude Stein
# 1325           Gertrude Stein
# 1330           Gertrude Stein
# 1331           Gertrude Stein
# 1339           Gertrude Stein
# 1341           Gertrude Stein
# 1388             Dylan Thomas
# 1522             John Ashbery
# 1540            Barbara Guest
# 1580           Arthur Rimbaud
# 1586           Arthur Rimbaud
# 1594           Arthur Rimbaud
# 1603             Frank O'Hara
# 1636                Tom Clark
# 1676              Ron Padgett
# 2093      William Shakespeare
# 2617      Friedrich Hölderlin
# 2895             Emma Lazarus
#
#                                                                                                                         poem_url  \
# 154                                                     https://www.poetryfoundation.org/poems/47660/a-supermarket-in-california
# 166                                                       https://www.poetryfoundation.org/poems/55713/a-terror-is-more-certain-
# 210                                    https://www.poetryfoundation.org/poetrymagazine/poems/58150/beatitudes-visuales-mexicanas
# 268                                                                          https://www.poetryfoundation.org/poems/53477/kef-21
# 288                                                                   https://www.poetryfoundation.org/poems/90181/no-complaints
# 290                                                                      https://www.poetryfoundation.org/poems/90180/rosa-parks
# 298                                                           https://www.poetryfoundation.org/poems/51371/a-fable-56d22f0fa5920
# 401                                          https://www.poetryfoundation.org/poems/46316/a-poem-beginning-with-a-line-by-pindar
# 505                                                                   https://www.poetryfoundation.org/poems/152252/o-ye-tongues
# 683                                                          https://www.poetryfoundation.org/poems/43026/my-country-tis-of-thee
://www.poetryfoundation.org/poems/46791/by-the-waters-of-babylon
#
#                                                                                title  \
# 154                                                      A Supermarket in California
# 166                                                   A Terror is More Certain . . .
# 210                                                    Beatitudes Visuales Mexicanas
# 268                                                                           Kef 21
# 288                                                                    No Complaints
# 290                                                                       Rosa Parks
# 298                                                                          A Fable
# 401                                           A Poem Beginning with a Line by Pindar
# 505                                                                     O Ye Tongues
# 683                                                          My Country ’Tis of Thee
# 720                                                                 My Little Dreams
# 802                                                                  Towns in Colour
# 803                                                                             Bath
# 807                                                                       Spring Day
# 843                                                  Kora in Hell: Improvisations II
# 853                                                Kora in Hell: Improvisations XI﻿V
# 854                                                Kora in Hell: Improvisations XXII
# 863                                               Kora in Hell: Improvisations XXVII
# 865                                                  Kora in Hell: Improvisations XI
# 890                                                                           Covers
# 928                                     My Life: A name trimmed with colored ribbons
# 930                       My Life: Reason looks for two, then arranges it from there
# 942   You Can’t Warm Your Hands in Front of a Book but You Can Warm Your Hopes There
# 945                                                              Everything’s a Fake
# 952                                                               My Emily Dickinson
# 977                                                     Incandescent War Poem Sonnet
# 994                                                                    You, part XII
# 995                                                                      You, part I
# 1131                                                                        Hysteria
# 1207                                                     Definition of the Frontiers
# 1322                                                 A Carafe, that is a Blind Glass
# 1324                                                                           Sugar
# 1325                                                        A Substance in a Cushion
# 1330                                                         A Little Called Pauline
# 1331                                 Idem the Same: A Valentine to Sherwood Anderson
# 1339                                                              Hotel François 1er
# 1341                                                                         Matisse
# 1388                                             Poem on His Birthday [Facs. drafts]
# 1522                                              If You Said You Would Come With Me
# 1540                                                                   Imagined Room
# 1580                                                          Morning of Drunkenness
# 1586                                                                         Royalty
# 1594                                                                           Genie
# 1603                                                     Meditations in an Emergency
# 1636                                                                        Eternity
# 1676                                              Prose Poem ("The morning coffee.")
# 2093                                                          Speech: Bottom's Dream
# 2617                                                                  In Lovely Blue
# 2895                                                        By the Waters of Babylon
#
#      poem_lines poem_string                           genre
# 154          []                                        beat
# 166          []                                        beat
# 210          []                                        beat
# 268          []                         black_arts_movement
# 288          []                         black_arts_movement
# 290          []                         black_arts_movement
# 298          []                         black_arts_movement
# 401          []                              black_mountain
# 505          []                                confessional
# 683          []                          harlem_renaissance
# 720          []                          harlem_renaissance
# 802          []                                     imagist
# 803          []                                     imagist
# 807          []                                     imagist
# 843          []                                     imagist
# 853          []                                     imagist
# 854          []                                     imagist
# 863          []                                     imagist
# 865          []                                     imagist
# 890          []                             language_poetry
# 928          []                             language_poetry
# 930          []                             language_poetry
# 942          []                             language_poetry
# 945          []                             language_poetry
# 952          []                             language_poetry
# 977          []                             language_poetry
# 994          []                             language_poetry
# 995          []                             language_poetry
# 1131         []                                      modern
# 1207         []                                      modern
# 1322         []                                      modern
# 1324         []                                      modern
# 1325         []                                      modern
# 1330         []                                      modern
# 1331         []                                      modern
# 1339         []                                      modern
# 1341         []                                      modern
# 1388         []                                      modern
# 1522         []                             new_york_school
# 1540         []                             new_york_school
# 1580         []                             new_york_school
# 1586         []                             new_york_school
# 1594         []                             new_york_school
# 1603         []                             new_york_school
# 1636         []              new_york_school_2nd_generation
# 1676         []              new_york_school_2nd_generation
# 2093         []                                 renaissance
# 2617         []                                    romantic
# 2895         []                                   victorian

# %%
for index in text_poems_df[text_poems_df.poem_string == ''].index:
    try:
        text_poems_df.loc[index,'poem_lines'] = PoemView_rescraper(text_poems_df.loc[index,'poem_url'])[0]
        text_poems_df.loc[index,'poem_string'] = PoemView_rescraper(text_poems_df.loc[index,'poem_url'])[1]
    except:
        print(index)

# %%
text_poems_df[text_poems_df.poem_string == '']
# Out:
#                poet  \
# 1388   Dylan Thomas
# 1540  Barbara Guest
#
#                                                                            poem_url  \
# 1388  https://www.poetryfoundation.org/poems/26804/poem-on-his-birthday-facs-drafts
# 1540                     https://www.poetryfoundation.org/poems/49367/imagined-room
#
#                                     title poem_lines poem_string  \
# 1388  Poem on His Birthday [Facs. drafts]         []
# 1540                        Imagined Room         []
#
#                 genre
# 1388           modern
# 1540  new_york_school

# %%
text_df = text_poems_df[text_poems_df.poem_string != '']
text_df.shape
# Out:
# (3259, 6)

# %%
text_df.to_csv('data/text_poems_df.csv')

# %%
# %%time

scan_poem_dicts = []
need_to_rescrape = []
for genre in tqdm(poem_url_dict.keys()):
    for scan_url in poem_url_dict[genre]['scan_urls']:
        try:
            poem = scan_poem_scraper(scan_url)
            poem['genre'] = genre
            poem['poem_url'] = scan_url
            scan_poem_dicts.append(poem)
        except:
            need_to_rescrape.append(scan_url)
# Out:
# 100%|██████████| 18/18 [3:25:25<00:00, 684.77s/it]
# CPU times: user 7min 49s, sys: 5min 10s, total: 12min 59s
# Wall time: 3h 25min 25s

# %%
len(scan_poem_dicts), len(need_to_rescrape)
# Out:
# (1775, 161)

# %%
scan_poem_df = pd.DataFrame(scan_poem_dicts)
scan_poem_df.head()
# Out:
#                 poet  \
# 0  Richard Brautigan
# 1    William Everson
# 2    William Everson
# 3     Allen Ginsberg
# 4     Jack Hirschman
#
#                                                                                           poem_url  \
# 0                                 https://www.poetryfoundation.org/poetrymagazine/poems/31338/wood
# 1                   https://www.poetryfoundation.org/poetrymagazine/poems/21676/dust-and-the-glory
# 2                     https://www.poetryfoundation.org/poetrymagazine/poems/21675/we-in-the-fields
# 3  https://www.poetryfoundation.org/poetrymagazine/poems/36505/written-in-my-dream-by-w-c-williams
# 4                    https://www.poetryfoundation.org/poetrymagazine/poems/30162/the-baseball-poem
#
#                                  title  \
# 0                                 Wood
# 1                   Dust And The Glory
# 2                     We In The Fields
# 3  Written In My Dream By W C Williams
# 4                    The Baseball Poem
#
#                                                                                                                                               poem_lines  \
# 0  [We age in darkness like wood, and watch our phantoms change, eir clothes, of shingles and boards, for a purpose that can only be, described as wo...
# 1  [On a low Lorrainian knoll a leaning peasant sinking a pit, Meets rotted rock and a slab., The slab cracks and is split, the old grave opened,, Hi...
# 2  [Dawn and a high film, the sun burned it,, But noon had a thick sheet, and the clouds coming,, The low rain-bringers, trooping in from the north,,...
# 3  [“As Is, you're bearing, a common, Truth, Commonly known, as desire, No need, to dress, it up, as beauty, No need, to distort, what’s not, standar...
# 4  [A wrist (to repeat, with a shift, of ac-, cent, mood, of emphasis, attentive to) now, needed, The wrist I lost, hold of, of, what was most, loved...
#
#                                                                                                                                              poem_string  \
# 40  [When I rode the zebra past your door,, wearing nothing but my diamonds, I expected to hear bells, and see your face behind the thin curtain:, But...
# 41  [I carry it on my keychain, which itself, is a big brass ring, large enough for my wrist,, holding keys for safe deposit box,, friends’ apartments...
# 42  [The rain of summer thunders down past the sweet peas, trailing up the staves, of my balcony,, and I,, just returned from a journey,, am sitting a...
# 43  [A girl sits in a black room., She is so, the plums have fallen off the trees outside., Icy winds blow geese, into her hair., The room is black, b...
# 44  [Smudging is the term used for lighting small oil fires in the orange, groves at night when the temperatures are too low, to keep the leaves, and ...
#
#                                                                                                                                               poem_string  \
# 35  Let me celebrate you. I\nHave never known anyone\nMore beautiful than you. I,\nWalking beside you, watching\nYou move beside me, watching\nThat st...
# 36  Profound stillness in the greystone\nRomanesque chapel, the rus\nOf wheels beyond the door only\nUnderlines the silence. The wheels\nOf life turn ...
# 37  All night I lay awake beside you,\nLeaning on my elbow, watching your\nSleeping face, that face whose purity\nNever ceases to astonish me.\nI coul...
# 38  To think of you surcharged with\nLoneliness. To hear your voice\nOver the recorder say,\n“Loneliness.” The word, the voice,\nSo full of it, and I,...
# 39  He jumped out of a window.\nOr did he shoot himself?\nWas there a gun?\nOr was it pills?\nDid anyone see blood?\nWas he holding water in his lungs...
# 40  When I rode the zebra past your door,\nwearing nothing but my diamonds, I expected to hear bells\nand see your face behind the thin curtain:\nBut ...
# 41  I carry it on my keychain, which itself\nis a big brass ring\nlarge enough for my wrist,\nholding keys for safe deposit box,\nfriends’ apartments,...
# 42  The rain of summer thunders down past the sweet peas\ntrailing up the staves\nof my balcony,\nand I,\njust returned from a journey,\nam sitting am...
# 43  A girl sits in a black room.\nShe is so\nthe plums have fallen off the trees outside.\nIcy winds blow geese\ninto her hair.\nThe room is black\nbu...
# 44  Smudging is the term used for lighting small oil fires in the orange\ngroves at night when the temperatures are too low, to keep the leaves\nand f...
#
#    genre
# 35  beat
# 36  beat
# 37  beat
# 38  beat
# 39  beat
# 40  beat
# 41  beat
# 42  beat
# 43  beat
# 44  beat

# %% [markdown]
# ## Individual rescrapes pt. I

# %%
scan_poem_df[scan_poem_df.poem_string == '']
# Out:
#                          poet  \
# 6             Michael McClure
# 23            Kenneth Patchen
# 606   William Carlos Williams
# 723     Guillaume Apollinaire
# 775            Malcolm Cowley
# 778                Hart Crane
# 779                Hart Crane
# 780                Hart Crane
# 782                Hart Crane
# 1170          Stephen Spender
# 1486     William Butler Yeats
# 1594             Frank O'Hara
# 1666                Tom Clark
#
#                                                                                                                           poem_url  \
# 6                                               https://www.poetryfoundation.org/poetrymagazine/poems/26838/2-for-theodore-roethke
# 23                                                          https://www.poetryfoundation.org/poetrymagazine/poems/27128/poemscapes
# 606   https://www.poetryfoundation.org/poetrymagazine/poems/27969/some-simple-measures-in-the-american-idiom-and-the-variable-foot
# 723                                https://www.poetryfoundation.org/poetrymagazine/poems/25655/toward-the-south-tr-by-harry-duncan
# 775                                            https://www.poetryfoundation.org/poetrymagazine/poems/30954/a-countryside-1918-1968
# 778                                      https://www.poetryfoundation.org/poetrymagazine/poems/19926/the-urn-enrich-my-resignation
# 779                                                 https://www.poetryfoundation.org/poetrymagazine/poems/19916/the-urn-purgatorio
# 780                                                      https://www.poetryfoundation.org/poetrymagazine/poems/19922/the-urn-reply
# 782                                             https://www.poetryfoundation.org/poetrymagazine/poems/19920/the-urn-the-sad-indian
# 1170                                          https://www.poetryfoundation.org/poetrymagazine/poems/22310/poem-after-the-wrestling
# 1486                                              https://www.poetryfoundation.org/poetrymagazine/poems/20737/a-full-moon-in-march
# 1594                                         https://www.poetryfoundation.org/poetrymagazine/poems/31123/places-for-oscar-salvador
# 1666                                                             https://www.poetryfoundation.org/poetrymagazine/poems/30773/fig-1
#
#                                                                  title  \
# 6                                               2 For Theodore Roethke
# 23                                                          Poemscapes
# 606   Some Simple Measures In The American Idiom And The Variable Foot
# 723                                Toward The South Tr By Harry Duncan
# 775                                            A Countryside 1918 1968
# 778                                      The Urn Enrich My Resignation
# 779                                                 The Urn Purgatorio
# 780                                                      The Urn Reply
# 782                                             The Urn The Sad Indian
# 1170                                          Poem After The Wrestling
# 1486                                              A Full Moon In March
# 1594                                         Places For Oscar Salvador
# 1666                                                             Fig 1
#
#      poem_lines poem_string                           genre
# 6            []                                        beat
# 23           []                                        beat
# 606          []                                     imagist
# 723          []                                      modern
# 775          []                                      modern
# 778          []                                      modern
# 779          []                                      modern
# 780          []                                      modern
# 782          []                                      modern
# 1170         []                                      modern
# 1486         []                                      modern
# 1594         []                             new_york_school
# 1666         []              new_york_school_2nd_generation

# %%
rescrapes = []

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/26838/2-for-theodore-roethke'
rescrape = scan_poem_scraper(url, input_poet='Michael McClure', input_title='2 For Theodore Roethke: Premonition')
rescrape['poem_url'] = url
rescrape['genre'] = 'beat'
rescrapes.append(rescrape)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=87&issue=4&page=28'
rescrape = scan_poem_scraper(url, input_poet='Michael McClure', input_title='2 For Theodore Roethke: 2')
rescrape['poem_url'] = url
rescrape['genre'] = 'beat'
rescrapes.append(rescrape)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/30954/a-countryside-1918-1968'
rescrape = scan_poem_scraper(url, input_poet='Malcolm Cowley', input_title='A Countryside 1918 1968: Boy in Sunlight')
rescrape['poem_url'] = url
rescrape['genre'] = 'modern'
rescrapes.append(rescrape)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/27969/some-simple-measures-in-the-american-idiom-and-the-variable-foot'
rescrape = scan_poem_scraper(url, 
                             input_poet='William Carlos Williams',
                             input_title='Some Simple Measures In The American Idiom And The Variable Foot',
                             first_pattern='.*((?:\r?\n.*)*)',
                             next_pattern='\n((?:\r?\n(?!COMMENT).*)*)')
rescrape['poem_url'] = url
rescrape['genre'] = 'imagist'
rescrapes.append(rescrape)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/27128/poemscapes'
rescrape = scan_poem_scraper(url, 
                             input_poet='Kenneth Patchen',
                             first_pattern='.*((?:\r?\n.*)*)',
                             next_pattern='\n((?:\r?\n(?!comment).*)*)')
rescrape['poem_url'] = url
rescrape['genre'] = 'beat'
rescrapes.append(rescrape)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/19915/the-urn-reliquary'
rescrape = scan_poem_scraper(url, input_poet='Hart Crane')
rescrape['poem_url'] = url
rescrape['genre'] = 'modern'
rescrapes.append(rescrape)

# %%
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=41&issue=4&page=2'
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/19916/the-urn-purgatorio'
rescrape = scan_poem_scraper(actual_url, input_poet='Hart Crane', input_title='The Urn: Purgatorio')
rescrape['poem_url'] = url
rescrape['genre'] = 'modern'
rescrapes.append(rescrape)

# %%
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=41&issue=4&page=6'
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/19920/the-urn-the-sad-indian'
rescrape = scan_poem_scraper(actual_url, input_poet='Hart Crane', input_title='The Urn: The Sad Indian')
rescrape['poem_url'] = url
rescrape['genre'] = 'modern'
rescrapes.append(rescrape)

# %%
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=41&issue=4&page=7'
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/19922/the-urn-reply'
rescrape = scan_poem_scraper(actual_url, input_poet='Hart Crane', input_title='The Urn: Reply')
rescrape['poem_url'] = url
rescrape['genre'] = 'modern'
rescrapes.append(rescrape)

# %%
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=41&issue=4&page=10'
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/19922/the-urn-reply'
rescrape = scan_poem_scraper(actual_url, input_poet='Hart Crane', input_title='The Urn: Enrich My Resignation')
rescrape['poem_url'] = url
rescrape['genre'] = 'modern'
rescrapes.append(rescrape)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/31123/places-for-oscar-salvador'
rescrape = scan_poem_scraper(url, 
                             input_poet="Frank O'Hara",
                             input_title='Places for Oscar Salvador',
                             first_pattern='.*((?:\r?\n.*)*)',
                             next_pattern='\n((?:\r?\n(?!SUDDEN SNOW).*)*)')
rescrape['poem_url'] = url
rescrape['genre'] = 'new_york_school'
rescrapes.append(rescrape)

# %%
rescrapes_pt1 = pd.DataFrame(rescrapes)
rescrapes_pt1
# Out:
#                        poet  \
# 0           Michael McClure
# 1           Michael McClure
# 2            Malcolm Cowley
# 3   William Carlos Williams
# 4           Kenneth Patchen
# 5                Hart Crane
# 6                Hart Crane
# 7                Hart Crane
# 8                Hart Crane
# 9                Hart Crane
# 10             Frank O'Hara
#
#                                                                                                                         poem_url  \
# 0                                             https://www.poetryfoundation.org/poetrymagazine/poems/26838/2-for-theodore-roethke
#
',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/19682/part-of-a-novel-part-of-a-poem-part-of-a-play-the-hero',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/12845/lost',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/24848/number-man',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/56415/doors-56d238e3affca',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/15533/lenvoi',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/17874/discus-thrower',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/12858/september-midnight',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/20683/conjunctions',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/58857/people-behaving-badly-a-concern',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/33626/syringa',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/57376/bunch-of-stuff',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/57377/by-guess-and-by-gosh',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/54557/to-a-reason',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/41038/town-hall-fifteenth-arrondissement',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29206/angelica-an-opera-act-ii',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/40750/to-my-fathers-business',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/33672/poem-green-things-are-flowers',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/53039/destitute-peru',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/53034/sweet-romanian-tongue',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/57008/first-thing',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30246/poem-to-simply-talk',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30549/poem-like-musical-instruments',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30775/sonnet-five-am-on-east-fourteenth',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/58492/epicedium-to-potters-field',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/58493/juarez',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/58497/bright-blue-self-portrait',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/58241/from-my-forehead',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/58240/license',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/58234/this-fire',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/58235/the-elements-56d23c6f1d3ce',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/58237/stalker',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/149708/clocked',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/149707/ticking-and-tocking',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/58341/the-seasons-56d23ca091a25',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/56418/poem-56d238e5159dc',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30723/jungle-56d21432117a5',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/56845/history-will-decide',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30140/spring-stood-there',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30139/march-56d213a2b802b',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29475/now-in-one-year',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30141/the-park-a-darling-walk',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30138/consider-at-the-outset',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30790/smile-to-see-the-lake',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29449/psalm-56d212ff620c5',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29745/giovannis-rape-of-the-sabine-women-at-wildensteins',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/19125/1930s',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/19940/along-the-flat-roofs',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/31024/a-21-rudens-act-iii',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/32643/a-22-an-era-any-time',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28076/brucio-e-limminenza-lombra-che-sale-riconosco',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/36501/a-trenta-sei-of-the-pleasure-we-take-in-the-early-death-of-keats']

# %%
error_rescrapes = []
still_errors = need_to_rescrape.copy()

# %%
# %%time

for url in tqdm(still_errors):
    try:
        rescrape = text_poem_scraper(url)
        error_rescrapes.append(rescrape)
        still_errors.remove(url)
    except:
        continue
# Out:
#  72%|███████▏  | 106/148 [07:49<03:05,  4.43s/it]
# CPU times: user 55.4 s, sys: 1min 40s, total: 2min 35s
# Wall time: 7min 49s

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/29416/mad-sonnet-we-shall-be-free'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=102&issue=3&page=18'
rescrape = scan_poem_scraper(actual_url, input_poet='Michael McClure', input_title='Mad Sonnet: We Shall Be Free')
rescrape['poem_url'] = url
rescrape['genre'] = 'beat'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/29415/mad-sonnet-when-spirit-has-no-edge'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=102&issue=3&page=17'
rescrape = scan_poem_scraper(actual_url, input_poet='Michael McClure', input_title='Mad Sonnet: When Spirit Has No Edge')
rescrape['poem_url'] = url
rescrape['genre'] = 'beat'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/30530/song-how-simply-for-another'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=109&issue=5&page=6'
rescrape = scan_poem_scraper(actual_url, input_poet='Robert Creeley', input_title='Enough: Left After That')
rescrape['poem_url'] = url
rescrape['genre'] = 'black_mountain'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/29779/walking-56d2134a84892'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=104&issue=3&page=19'
rescrape = scan_poem_scraper(actual_url, input_poet='Robert Creeley', input_title='Walking: In My Head')
rescrape['poem_url'] = url
rescrape['genre'] = 'black_mountain'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/14358/epitaph-an-old-willow'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=13&issue=6&page=13'
rescrape = scan_poem_scraper(actual_url, input_poet='William Carlos Williams', input_title='Epitaph')
rescrape['poem_url'] = url
rescrape['genre'] = 'imagist'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/28310/elaine'
rescrape = scan_poem_scraper(url, input_poet='William Carlos Williams', input_title='Elainb')
rescrape['poem_url'] = url
rescrape['genre'] = 'imagist'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/28312/emily'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=95&issue=6&page=3'
rescrape = scan_poem_scraper(actual_url, input_poet='William Carlos Williams', input_title='Emily')
rescrape['poem_url'] = url
rescrape['genre'] = 'imagist'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/28311/erica'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=95&issue=6&page=2'
rescrape = scan_poem_scraper(actual_url, input_poet='William Carlos Williams', input_title='Erica')
rescrape['poem_url'] = url
rescrape['genre'] = 'imagist'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/18899/poem-as-the-cat'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=36&issue=4&page=22'
rescrape = scan_poem_scraper(actual_url, input_poet='William Carlos Williams', input_title='Poem: As the cat')
rescrape['poem_url'] = url
rescrape['genre'] = 'imagist'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/13202/from-discordants-iv'
rescrape = scan_poem_scraper(url, input_poet='Conrad Aiken', input_title='Discordants')
rescrape['poem_url'] = url
rescrape['genre'] = 'modern'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/13202/from-discordants-iv'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=6&issue=6&page=22'
rescrape = scan_poem_scraper(actual_url, input_poet='Conrad Aiken', input_title='Discordants IV')
rescrape['poem_url'] = url
rescrape['genre'] = 'modern'
error_rescrapes.append(rescrape)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/25512/jacks-white-horseup'
rescrape = scan_poem_scraper(url, input_poet='E. E. Cummings', input_title="jack's white")
rescrape['poem_url'] = url
rescrape['genre'] = 'modern'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/25263/imc-a-tmo'
rescrape = scan_poem_scraper(url, input_poet='E. E. Cummings', input_title='E. E. Cummings')
rescrape['poem_url'] = url
rescrape['genre'] = 'modern'
rescrape['title'] = 'Untitled [5]'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/29577/valery-as-dictator'
rescrape = text_poem_scraper(url)
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/30270/ritual-ix'
rescrape = scan_poem_scraper(url, input_poet='Paul Blackburn', input_title='Ritual IX: Gathering Winter Fuel')
rescrape['poem_url'] = url
rescrape['genre'] = 'black_mountain'
rescrape['poem_lines'].extend(temp_rescrape_lines)
rescrape['poem_string'] = ' '.join(rescrape['poem_lines'])
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
temp_rescrape = scan_poem_scraper('https://www.poetryfoundation.org/poetrymagazine/browse?volume=108&issue=1&page=42',
                  input_poet='Paul Blackburn', input_title='the same barrels')
temp_rescrape_lines = [temp_rescrape['title']]
temp_rescrape_lines.extend(temp_rescrape['poem_lines'])
temp_rescrape_lines
# Out:
# ['the same barrels',
#  '& cans & older men in long',
#  'overcoats from the mission,',
#  '& here, the scene unabated, 20-odd years later',
#  'the fruit & vegetable market, First Ave. & Ninth, using',
#  'wood from crates',
#  'New Jersey, Delaware, Cali-',
#  'for-ni-yay,',
#  'Florida, New Mexico, Georgia, Louisiana, Texas, all',
#  'e same fire, how',
#  'reunite the South & North, the West & East',
#  'IN SUNLIGHT YOU NEVER SEE Ir, ry just walking by &',
#  'feel the warmth e.',
#  'Fire in a barrel, burning',
#  'the hands,',
#  'the hands / the italian',
#  'bakery next door is still discreet,',
#  'but the kosher butcher shop next to',
#  'that comes out for a word or two, the',
#  'gesture',
#  'palms stiff out at arms’ length, passing',
#  'the time of day, their magic hands',
#  'reddened & liverspotted maybe,',
#  'no peyis or beard, sti',
#  'here at First Ave. & Ninth St. it’s',
#  'the jews uniting the world, the country, the city,',
#  'mankind down geological time perhaps,',
#  'to keep their hands warm']

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/30550/the-sundering-up-tracks'
rescrape = scan_poem_scraper(url, 
                             input_poet='Edward Dorn', 
                             input_title='The Sundering U.P. Tracks: The End of the North Atlantic Turbine Poem')
rescrape['poem_url'] = url
rescrape['genre'] = 'black_mountain'
rescrape['poem_lines'].extend(temp_rescrape_lines)
rescrape['poem_string'] = ' '.join(rescrape['poem_lines'])
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
temp_rescrape = scan_poem_scraper('https://www.poetryfoundation.org/poetrymagazine/browse?volume=109&issue=6&page=8',
                  input_poet='Edward Dorn', input_title='"Compared to the majestic legal thievery')
temp_rescrape_lines = [temp_rescrape['title']]
temp_rescrape_lines.extend(temp_rescrape['poem_lines'])
temp_rescrape_lines
# Out:
# ['"Compared to the majestic legal thievery',
#  'of Commodore Vanderbilt men like Jay G Gould',
#  'and Jim Fisk were second-story workers .',
#  'Each side of the shining double knife',
#  'from Chicago to Fri',
#  'to Denver, the Cheyenne cutoff',
#  'the Right of Way they called it',
#  'and still it runs that way',
#  'right through the heart',
#  'the Union Pacific rails run also to Portland.',
#  'Even through the heart of the blue beech',
#  'hard as it is.',
#  'each hamlet',
#  'the winter sanctuar',
#  'of the rare Jailbird',
#  'and the Ishmaelite',
#  'the esoteric summer firebombs',
#  'of Chicago',
#  'the same scar tissue',
#  'I saw in Pocatello',
#  'made',
#  'by the rapacious geo-economic',
#  'surgery of Harriman, the old isolator',
#  'that ambassador-at-large',
#  'You talk of color?',
#  'Ob cosmological america, how well',
#  'and with what geometry',
#  'you teach your citizens']

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/30551/the-first-note'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=109&issue=6&page=9'
rescrape = scan_poem_scraper(actual_url, 
                             input_poet='Edward Dorn', 
                             input_title='The First Note: From London')
rescrape['poem_url'] = url
rescrape['genre'] = 'black_mountain'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/30225/song-i-wouldnt-embarrass-you'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=107&issue=5&page=46'
rescrape = scan_poem_scraper(actual_url, 
                             input_poet='Robert Creeley', 
                             input_title='Song')
rescrape['poem_url'] = url
rescrape['genre'] = 'black_mountain'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/28862/the-law'
rescrape = scan_poem_scraper(url, 
                             input_poet='Robert Duncan', 
                             input_title='The Law: A Series in Variation')

rescrape['poem_url'] = url
rescrape['genre'] = 'black_mountain'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/28862/the-law'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=99&issue=3&page=33'
rescrape = scan_poem_scraper(actual_url, 
                             input_poet='Robert Duncan', 
                             input_title="The Law: Song's Fateful Crime")

rescrape['poem_url'] = url
rescrape['genre'] = 'black_mountain'
error_rescrapes.append(rescrape)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/28862/the-law'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=99&issue=3&page=34'
rescrape = scan_poem_scraper(actual_url, 
                             input_poet='Robert Duncan', 
                             input_title="The Law: Cursed be he that")

rescrape['poem_url'] = url
rescrape['genre'] = 'black_mountain'
error_rescrapes.append(rescrape)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/28862/the-law'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=99&issue=3&page=35'
rescrape = scan_poem_scraper(actual_url, 
                             input_poet='Robert Duncan', 
                             input_title="The Law: No! Took an Other way as its law")

rescrape['poem_url'] = url
rescrape['genre'] = 'black_mountain'
error_rescrapes.append(rescrape)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/27415/poem-when-the-immortal-blond'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=90&issue=6&page=20'
rescrape = scan_poem_scraper(actual_url, 
                             input_poet='Robert Duncan', 
                             input_title="Poem")

rescrape['poem_url'] = url
rescrape['genre'] = 'black_mountain'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
# shrug, should've worked in earlier loop
error_rescrapes.append(text_poem_scraper('https://www.poetryfoundation.org/poetrymagazine/poems/55733/what-next'))

# %%
# shrug, should've worked in earlier loop
error_rescrapes.append(text_poem_scraper('https://www.poetryfoundation.org/poetrymagazine/poems/41677/pacemaker'))

# %%
# shrug, should've worked in earlier loop
error_rescrapes.append(text_poem_scraper('https://www.poetryfoundation.org/poetrymagazine/poems/13075/the-dead'))

# %%
# shrug, should've worked in earlier loop
error_rescrapes.append(text_poem_scraper('https://www.poetryfoundation.org/poetrymagazine/poems/55313/god-56d236c65624c'))

# %%
# shrug, should've worked in earlier loop
error_rescrapes.append(text_poem_scraper('https://www.poetryfoundation.org/poetrymagazine/poems/55537/and'))

# %%
remove_list = [
    'https://www.poetryfoundation.org/poetrymagazine/poems/55733/what-next',
    'https://www.poetryfoundation.org/poetrymagazine/poems/41677/pacemaker',
    'https://www.poetryfoundation.org/poetrymagazine/poems/13075/the-dead',
    'https://www.poetryfoundation.org/poetrymagazine/poems/55313/god-56d236c65624c',
    'https://www.poetryfoundation.org/poetrymagazine/poems/55537/and'
]

for item in remove_list:
    still_errors.remove(item)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/54278/accounts'
error_rescrapes.append(text_poem_scraper(url))
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/150946/elsewhere-5d70274a8beed'
error_rescrapes.append(text_poem_scraper(url))
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/53487/paragraph'
error_rescrapes.append(text_poem_scraper(url))
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/89349/object-permanence'
error_rescrapes.append(text_poem_scraper(url))
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/92669/natural-histories'
error_rescrapes.append(text_poem_scraper(url))
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/144605/my-house-59df845fd8d77'
error_rescrapes.append(text_poem_scraper(url))
still_errors.remove(url)

# %%
# %%time

for url in tqdm(still_errors[20:]):
    try:
        rescrape = text_poem_scraper(url)
        error_rescrapes.append(rescrape)
        still_errors.remove(url)
    except:
        continue
# Out:
# 100%|██████████| 54/54 [00:52<00:00,  1.02it/s]
# CPU times: user 4.2 s, sys: 248 ms, total: 4.45 s
# Wall time: 52.8 s

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/28835/pity-his-how-illimitable-plight'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=99&issue=2&page=9'
rescrape = scan_poem_scraper(actual_url, input_poet='E. E. Cummings', input_title='pity his how illimitable plight')
rescrape['poem_url'] = url
rescrape['genre'] = 'modern'
rescrape['poem_lines'].extend(temp_rescrape_lines)
rescrape['poem_lines'].extend(temp_rescrape_lines2)
rescrape['poem_string'] = ' '.join(rescrape['poem_lines'])
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
temp_rescrape = scan_poem_scraper('https://www.poetryfoundation.org/poetrymagazine/browse?volume=99&issue=2&page=10',
                  input_poet='E. E. Cummings', input_title='without the mercy of')
temp_rescrape_lines = [temp_rescrape['title']]
temp_rescrape_lines.extend(temp_rescrape['poem_lines'])
temp_rescrape_lines
# Out:
# ['without the mercy of',
#  'your eyes your',
#  'voice your',
#  'ways (o very most my shining love)',
#  'how more than dark i am,',
#  'no song (no',
#  'thing) no',
#  'silence ever told; it has no name—',
#  'but should this namelessness',
#  '(completely',
#  'fleetly',
#  'vanish, at the infinite precise',
#  'thrill of your beauty, then',
#  'my lost my',
#  'my',
#  'whereful selves they put on here again',
#  '—to livingest one star',
#  'as small these',
#  'all these',
#  'thankful (hark) birds singing wholly are']

# %%
temp_rescrape2 = scan_poem_scraper('https://www.poetryfoundation.org/poetrymagazine/browse?volume=99&issue=2&page=11',
                  input_poet='E. E. Cummings', input_title='annie died the other day')
temp_rescrape_lines2 = [temp_rescrape2['title']]
temp_rescrape_lines2.extend(temp_rescrape2['poem_lines'])
temp_rescrape_lines2
# Out:
# ['annie died the other day',
#  'never was there such a lay—',
#  'whom, among her dollies, dad',
#  'first (“don’t tell your mother”) had;',
#  'making annie slightly mad',
#  'but very wonderful in bed',
#  '—-saints and satyrs, go your way',
#  'youths and maidens: let us pray']

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/22223/six'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=53&issue=4&page=5'
rescrape = scan_poem_scraper(actual_url, input_poet='E. E. Cummings', input_title='six')
rescrape['poem_url'] = url
rescrape['genre'] = 'modern'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/25960/springmay0151'
rescrape = scan_poem_scraper(url, input_poet='E. E. Cummings', input_title='spring! may')
rescrape['poem_url'] = url
rescrape['genre'] = 'modern'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/25513/-oroundmoonhow'
rescrape = scan_poem_scraper(url, input_poet='E. E. Cummings', input_title='o(rounD)moon, how')
rescrape['poem_url'] = url
rescrape['genre'] = 'modern'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/28566/why-dont-be'
rescrape = scan_poem_scraper(url, input_poet='E. E. Cummings', input_title="why don't be sil ly o no in deed; money")
rescrape['poem_url'] = url
rescrape['genre'] = 'modern'
error_rescrapes.append(rescrape)
still_errors.remove(url)
# rescrape

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/24807/thislets-rememberday'
rescrape = scan_poem_scraper(url, input_poet='E. E. Cummings', input_title="this(let's remember)day died again and")
rescrape['poem_url'] = url
rescrape['genre'] = 'modern'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/28834/for-any-ruffian-of-the-sky'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=99&issue=2&page=8'
rescrape = scan_poem_scraper(actual_url, input_poet='E. E. Cummings', input_title="for any ruffian of the sky")
rescrape['poem_url'] = url
rescrape['genre'] = 'modern'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/28833/if-seventy-were-young'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=99&issue=2&page=7'
rescrape = scan_poem_scraper(actual_url, input_poet='E. E. Cummings', input_title="if seventy were young")
rescrape['poem_url'] = url
rescrape['genre'] = 'modern'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/26048/rosetreerosetree'
rescrape = scan_poem_scraper(url, input_poet='E. E. Cummings', input_title="rosetree, rosetree")
rescrape['poem_url'] = url
rescrape['genre'] = 'modern'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/15533/lenvoi'
rescrape = scan_poem_scraper(url, input_poet='Marion Strobel', input_title="envoi")
rescrape['poem_url'] = url
rescrape['genre'] = 'modern'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/17874/discus-thrower'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=31&issue=5&page=3'
rescrape = scan_poem_scraper(actual_url, input_poet='Marion Strobel', input_title="Discus-Thrower",
                            next_pattern='\n((?:\r?\n(?!SURF-BOARDING).*)*)')
rescrape['poem_url'] = url
rescrape['genre'] = 'modern'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/33672/poem-green-things-are-flowers'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=130&issue=2&page=10'
rescrape = scan_poem_scraper(actual_url, input_poet="Frank O'Hara", input_title="Poem")
rescrape['poem_url'] = url
rescrape['genre'] = 'new_york_school'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/30246/poem-to-simply-talk'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=107&issue=6&page=10'
rescrape = scan_poem_scraper(actual_url, input_poet="Tom Clark", input_title="Poem")
rescrape['poem_url'] = url
rescrape['genre'] = 'new_york_school_2nd_generation'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/30549/poem-like-musical-instruments'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=109&issue=6&page=14'
rescrape = scan_poem_scraper(actual_url, input_poet="Tom Clark", input_title="Poem")
rescrape['poem_url'] = url
rescrape['genre'] = 'new_york_school_2nd_generation'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/30775/sonnet-five-am-on-east-fourteenth'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=111&issue=3&page=8'
rescrape = scan_poem_scraper(actual_url, input_poet="Tom Clark", input_title="Sonnet")
rescrape['poem_url'] = url
rescrape['genre'] = 'new_york_school_2nd_generation'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
# i've truly lost my mind
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/30723/jungle-56d21432117a5'
rescrape = scan_poem_scraper(url, input_poet="Aram Saroyan", input_title="saroyan")
rescrape['poem_url'] = url
rescrape['genre'] = 'new_york_school_2nd_generation'
rescrape['poem_lines'] = ['j;u;n;g;l;e']
rescrape['poem_string'] = ' '.join(rescrape['poem_lines'])
rescrape['title'] = 'Untitled'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/30140/spring-stood-there'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=106&issue=5&page=29'
rescrape = scan_poem_scraper(actual_url, input_poet='Lorine Niedecker', input_title="Spring")
rescrape['poem_url'] = url
rescrape['genre'] = 'objectivist'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/30139/march-56d213a2b802b'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=106&issue=5&page=28'
rescrape = scan_poem_scraper(actual_url, input_poet='Lorine Niedecker', input_title="March")
rescrape['poem_url'] = url
rescrape['genre'] = 'objectivist'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/29475/now-in-one-year'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=102&issue=5&page=27'
rescrape = scan_poem_scraper(actual_url, input_poet='Lorine Niedecker', input_title="Now in one year")
rescrape['poem_url'] = url
rescrape['genre'] = 'objectivist'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/30141/the-park-a-darling-walk'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=106&issue=5&page=30'
rescrape = scan_poem_scraper(actual_url, input_poet='Lorine Niedecker', input_title="The park")
rescrape['poem_url'] = url
rescrape['genre'] = 'objectivist'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/30138/consider-at-the-outset'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=106&issue=5&page=28'
rescrape = scan_poem_scraper(actual_url, input_poet='Lorine Niedecker', input_title="Consider at the outset")
rescrape['poem_url'] = url
rescrape['genre'] = 'objectivist'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/30790/smile-to-see-the-lake'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=111&issue=3&page=22'
rescrape = scan_poem_scraper(actual_url, input_poet='Lorine Niedecker', input_title="Smile")
rescrape['poem_url'] = url
rescrape['genre'] = 'objectivist'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/29745/giovannis-rape-of-the-sabine-women-at-wildensteins'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?contentId=29745'
rescrape = scan_poem_scraper(actual_url, input_poet='George Oppen', input_title="Giovanni's Rape of the Sabine Women at Wildenstein")
rescrape['poem_url'] = url
rescrape['genre'] = 'objectivist'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/19125/1930s'
rescrape = scan_poem_scraper(url, input_poet='George Oppen', input_title="1930")
rescrape['poem_url'] = url
rescrape['genre'] = 'objectivist'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/19940/along-the-flat-roofs'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=41&issue=4&page=17'
rescrape = scan_poem_scraper(actual_url, input_poet='Charles Reznikoff', input_title="Along the flat roofs beneath our window")
rescrape['poem_url'] = url
rescrape['genre'] = 'objectivist'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/31024/a-21-rudens-act-iii'
rescrape = scan_poem_scraper(url, input_poet='Louis Zukofsky', input_title='"A"21: Rudens, Dads')
rescrape['poem_url'] = url
rescrape['genre'] = 'objectivist'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/32643/a-22-an-era-any-time'
rescrape = scan_poem_scraper(url, input_poet='Louis Zukofsky', input_title='"A"22: An Era Any Time Of Year')
rescrape['poem_url'] = url
rescrape['genre'] = 'objectivist'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
rescrape
# Out:
# {'poet': 'Louis Zukofsky',
#  'poem_url': 'https://www.poetryfoundation.org/poetrymagazine/poems/32643/a-22-an-era-any-time',
#  'title': '"A"22: An Era Any Time Of Year',
#  'poem_lines': ['Others letters a sum owed',
#   'ages account years each year',
#   'out of old fields, permute',
#   'blow blue up against yellow',
#   '—scapes welcome young birds—initial',
#   'transmutes itself, swim near and',
#   'read a weed’s reward—grain',
#   'an omen a good omen',
#   'the chill mists greet woods',
#   'ice, flowers—their soul’s return',
#   'let me live here ever,',
#   'sweet now, silence foison to',
#   'on top of the weather',
#   'it has said it before',
#   'why that was you that',
#   'is how you weather division',
#   'a peacocks grammar perching—and',
#   'perhaps think that they see',
#   'or they fly thru a',
#   'window not knowing it there'],
#  'poem_string': 'Others letters a sum owed\nages account years each year\nout of old fields, permute\nblow blue up against yellow\n—scapes welcome young birds—initial\ntransmutes itself, swim near and\nread a weed’s reward—grain\nan omen a good omen\nthe chill mists greet woods\nice, flowers—their soul’s return\nlet me live here ever,\nsweet now, silence foison to\non top of the weather\nit has said it before\nwhy that was you that\nis how you weather division\na peacocks grammar perching—and\nperhaps think that they see\nor they fly thru a\nwindow not knowing it there',
#  'genre': 'objectivist'}

# %%
scan_poem_df[scan_poem_df.poet == 'Lorine Niedecker']
# Out:
#                   poet  \
# 1694  Lorine Niedecker
# 1695  Lorine Niedecker
# 1696  Lorine Niedecker
# 1697  Lorine Niedecker
# 1698  Lorine Niedecker
# 1699  Lorine Niedecker
# 1700  Lorine Niedecker
# 1701  Lorine Niedecker
# 1702  Lorine Niedecker
# 1703  Lorine Niedecker
# 1704  Lorine Niedecker
#
#                                                                                       poem_url  \
# 1694            https://www.poetryfoundation.org/poetrymagazine/poems/30789/fall-56d21442f2ddc
# 1695     https://www.poetryfoundation.org/poetrymagazine/poems/29472/three-poems-56d21304a5f2d
# 1696          https://www.poetryfoundation.org/poetrymagazine/poems/30787/young-in-fall-i-said
# 1697  https://www.poetryfoundation.org/poetrymagazine/poems/20187/promise-of-brilliant-funeral
# 1698      https://www.poetryfoundation.org/poetrymagazine/poems/30136/five-poems-56d213a21e011
# 1699          https://www.poetryfoundation.org/poetrymagazine/poems/30788/we-are-what-the-seas
# 1700  https://www.poetryfoundation.org/poetrymagazine/poems/20188/when-ecstasy-is-inconvenient
# 1701          https://www.poetryfoundation.org/poetrymagazine/poems/30137/to-my-pres-sure-pump
# 1702            https://www.poetryfoundation.org/poetrymagazine/poems/29473/river-marsh-drowse
# 1703         https://www.poetryfoundation.org/poetrymagazine/poems/29474/prosperity-is-poverty
# 1704      https://www.poetryfoundation.org/poetrymagazine/poems/30786/four-poems-56d2144172721
#
#                              title  \
# 1694                          Fall
# 1695                   Three Poems
# 1696          Young In Fall I Said
# 1697  Promise Of Brilliant Funeral
# 1698                    Five Poems
# 1699          We Are What The Seas
# 1700  When Ecstasy Is Inconvenient
# 1701          To My Pres Sure Pump
# 1702            River Marsh Drowse
# 1703         Prosperity Is Poverty
# 1704                    Four Poems
# 1695  objectivist
# 1696  objectivist
# 1697  objectivist
# 1698  objectivist
# 1699  objectivist
# 1700  objectivist
# 1701  objectivist
# 1702  objectivist
# 1703  objectivist
# 1704  objectivist

# %%
scan_poem_df.loc[1695, 'poem_string']
# Out:
# 'I\nRiver-marsh-drowse\nand in flood\nof no land.\nThey fish, a man\ntakes his wife to town\nwith his rowboat’s 1o-horse\nships his voice\nto the herons.\nSure they drink\n—full foamy folk—\ntill asleep.\nThe place is asleep\non one leg in the weeds.\nProsperity is poverty—\nI’ve foreclosed.\nI own again\nthese walls thin\nas the back\nof my writing tablet.'

# %%
scan_poem_df[scan_poem_df.title == 'God']
# Out:
# Empty DataFrame
# Columns: [poet, poem_url, title, poem_lines, poem_string, genre]
# Index: []

# %%
still_errors
# Out:
# ['https://www.poetryfoundation.org/poetrymagazine/poems/48292/road-56d22969928f0',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/19645/persons-seen',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/32401/sonnets-of-the-blood',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14312/calligraphy-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14296/on-seeing-the-portrait-of-a-beautiful-concubine-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14316/on-the-classic-of-the-hills-and-sea-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14321/the-inn-at-the-western-lake-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14313/one-goes-a-journey-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14315/the-palace-blossoms-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14310/an-evening-meeting-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14322/the-emperors-return-from-a-journey-to-the-south-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14314/from-the-straw-hut-among-the-seven-peaks-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14320/a-recluse-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14311/after-how-many-years-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/13065/exiles-letter-tr-by-ezra-pound',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/13497/paganis',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/12926/amities',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/12663/contemporania',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/32405/proof-of-immortality-56d215f13b354',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/21476/to-an-elder-poet',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/22220/nouns-to-nouns',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/25510/dim-i-nu-tiv',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28836/without-the-mercy-of',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/22222/up-into-the-silence-the-green',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28837/annie-died-the-other-day',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/22221/when-what-hugs-stopping-earth',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/40222/honeymoon-tr-by-barry-goldensohn',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/15885/wanderings-champs-dhonneur-56d20918e2c28',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/15867/wanderings-champs-dhonneur',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/22372/slow-blue',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/34682/project-for-an-aesthetic',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/34678/five-poems-from-the-1920s',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/12960/ollie-mgee',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/21466/walking-sticks-and-paperweights-and-watermarks',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/19682/part-of-a-novel-part-of-a-poem-part-of-a-play-the-hero',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/20683/conjunctions',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29206/angelica-an-opera-act-ii',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30246/poem-to-simply-talk',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30549/poem-like-musical-instruments',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30775/sonnet-five-am-on-east-fourteenth',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30723/jungle-56d21432117a5',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30140/spring-stood-there',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30139/march-56d213a2b802b',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29475/now-in-one-year',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30141/the-park-a-darling-walk',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30138/consider-at-the-outset',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30790/smile-to-see-the-lake',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29745/giovannis-rape-of-the-sabine-women-at-wildensteins',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/19125/1930s',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/19940/along-the-flat-roofs',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/31024/a-21-rudens-act-iii',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/32643/a-22-an-era-any-time',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28076/brucio-e-limminenza-lombra-che-sale-riconosco']

# %%
scan_poem_scraper(url, 
                             input_poet="Frank O'Hara",
                             input_title='Places for Oscar Salvador',
                             first_pattern='.*((?:\r?\n.*)*)',
                             next_pattern='\n((?:\r?\n(?!SUDDEN SNOW).*)*)')

# %%
text = pytesseract.image_to_string('data/temp.png')
text
# Out:
# "E. E. CUMMINGS\n\nmoney\ncan’t do(never\ndid &\n\nnever will)any\n\ncfar\n\nfrom it;you\nre wrong,my friend. But\nwhat does\n\n0,\nhas always done\n\nwill do alw\n\n-ays something\n\nis(guess)yes\n‘ou're\n\nright:my enemy\n\n. Love"

# %%
https://www.poetryfoundation.org/poetrymagazine/browse?volume=99&issue=2&page=9

# %%
rescrapes_pt2 = pd.DataFrame(error_rescrapes)
rescrapes_pt2
# Out:
#                         poet  \
# 0            Michael McClure
# 1            Michael McClure
# 2             Robert Creeley
# 3             Robert Creeley
# 4    William Carlos Williams
# ..                       ...
# 122             George Oppen
# 123             George Oppen
# 124        Charles Reznikoff
# 125           Louis Zukofsky
# 126           Louis Zukofsky
#
#                                                                                                            poem_url  \
# 0                           https://www.poetryfoundation.org/poetrymagazine/poems/29416/mad-sonnet-we-shall-be-free
# 1                    https://www.poetryfoundation.org/poetrymagazine/poems/29415/mad-sonnet-when-spirit-has-no-edge
# 2                           https://www.poetryfoundation.org/poetrymagazine/poems/30530/song-how-simply-for-another
# 3                                 https://www.poetryfoundation.org/poetrymagazine/poems/29779/walking-56d2134a84892
# 4                                 https://www.poetryfoundation.org/poetrymagazine/poems/14358/epitaph-an-old-willow
# ..                                                                                                              ...
# 122  https://www.poetryfoundation.org/poetrymagazine/poems/29745/giovannis-rape-of-the-sabine-women-at-wildensteins
# 123                                               https://www.poetryfoundation.org/poetrymagazine/poems/19125/1930s
# 124                                https://www.poetryfoundation.org/poetrymagazine/poems/19940/along-the-flat-roofs
# 125                                 https://www.poetryfoundation.org/poetrymagazine/poems/31024/a-21-rudens-act-i
# 4           imagist
# ..              ...
# 122     objectivist
# 123     objectivist
# 124     objectivist
# 125     objectivist
# 126     objectivist
#
# [127 rows x 6 columns]

# %%
rescrapes_pt2.to_csv('data/temp_rescrapes_pt2.csv')

# %%
text_poems_df.shape, scan_poem_df.shape, rescrapes_pt1.shape, rescrapes_pt2.shape
# Out:
# ((3261, 6), (1774, 6), (11, 6), (124, 6))

# %%
df = pd.concat([text_poems_df, scan_poem_df, rescrapes_pt1, rescrapes_pt2], axis=0, ignore_index=True)
df.shape
# Out:
# (5170, 6)

# %%
df.iloc[3255:3270]
# Out:
#                          poet  \
# 3255  John Greenleaf Whittier
# 3256  John Greenleaf Whittier
# 3257  John Greenleaf Whittier
# 3258  John Greenleaf Whittier
# 3259              Oscar Wilde
# 3260            A. E. Housman
# 3261        Richard Brautigan
# 3262          William Everson
# 3263          William Everson
# 3264           Allen Ginsberg
# 3265           Jack Hirschman
# 3266           Jack Hirschman
# 3267          Michael McClure
# 3268          Michael McClure
# 3269          Kenneth Patchen
#
#                                                                                                                    poem_url  \
# 3255                                                          https://www.poetryfoundation.org/poems/45491/telling-the-bees
# 3256                                                               https://www.poetryfoundation.org/poems/53105/the-pumpkin
# 3257                                                              https://www.poetryfoundation.org/poems/45482/an-autograph
# 3258                                                       https://www.poetryfoundation.org/poems/45492/what-the-birds-said
# 3259                                                https://www.poetryfoundation.org/poems/45495/the-ballad-of-reading-gaol
# 3260  https://www.poetryfoundation.org/poetrymagazine/poems/55409/to-my-comrade-moses-j-jackson-scoffer-at-this-scholarship
# 3261                                                       https://www.poetryfoundation.org/poetrymagazine/poems/31338/wood
# 3262                                         https://www.poetryfoundation.org/poetrymagazine/poems/21676/dust-and-the-glory
# 3263                                           https://www.poetryfoundation.org/poetrymagazine/poems/21675/we-in-the-fields
# 3264                        https://www.poetryfoundation.org/poetrymagazine/poems/36505/written-in-my-dream-by-w-c-williams
# 3265                                          https://www.poetryfoundation.org/poetrymagazine/poems/30162/the-baseball-poem
# 3266                           https://www.poetryfoundation.org/poetrymagazine/poems/29383/from-one-finger-from-the-seasons
# 3267                                     https://www.poetryfoundation.org/poetrymagazine/poems/26838/2-for-theodore-roethke
# 3268                                                  https://www.poetryfoundation.org/poetrymagazine/poems/29414/the-child
# 3269                                                https://www.poetryfoundation.org/poetrymagazine/poems/26193/all-is-safe
#
#                                                              title  \
# 3255                                              Telling the Bees
# 3256                                                   The Pumpkin
# 3257                                                  An Autograph
# 3258                                           What the Birds Said
# 3259                                    The Ballad of Reading Gaol
# 3260  To my Comrade, Moses J. Jackson, Scoffer at this Scholarship
# 3261                                                          Wood
# 3262                                            Dust And The Glory
# 3263                                              We In The Fields
# 3264                           Written In My Dream By W C Williams
# 3265                                             The Baseball Poem
# 3266                              From One Finger From The Seasons
# 3267                                        2 For Theodore Roethke
# 3268                                                     The Child
# 3269                                                   All Is Safe
#
#                                                                                                                                                  poem_lines  \
# 3255  [Here is the place; right over the hill, Runs the path I took;, You can see the gap in the old wall still,, And the stepping-stones in the shallow...
# 3256  [Oh, greenly and fair in the lands of the sun,, The vines of the gourd and the rich melon run,, And the rock and the tree and the cottage enfold,,...
# 3257  [I write my name as one,, On sands by waves o’errun, Or winter’s frosted pane,, Traces a record vain., Oblivion’s blankness claims, Wiser and bett...
# 3267
# 3268  Who were the Lion Men who walked in my dreams\nwhen I was a fat and sleeping babe\nin a room whose walls were miracles?\nWho were the lion men wit...
# 3269  Flow, water, the blue water\nLittle birds of foam\nSinging on thee\nO flow, water, blue water\nLittle stars falling asleep\nTo thy tossing\nO flow...
#
#           genre
# 3255  victorian
# 3256  victorian
# 3257  victorian
# 3258  victorian
# 3259  victorian
# 3260  victorian
# 3261       beat
# 3262       beat
# 3263       beat
# 3264       beat
# 3265       beat
# 3266       beat
# 3267       beat
# 3268       beat
# 3269       beat

# %%
df.sort_values(by=['genre', 'poet', 'title'], inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#              poet  \
# 0  Alexander Pope
# 1  Alexander Pope
# 2  Alexander Pope
# 3  Alexander Pope
# 4  Alexander Pope
#
#                                                                     poem_url  \
# 0  https://www.poetryfoundation.org/poems/44896/an-essay-on-criticism-part-1
# 1  https://www.poetryfoundation.org/poems/44897/an-essay-on-criticism-part-2
# 2  https://www.poetryfoundation.org/poems/44898/an-essay-on-criticism-part-3
# 3     https://www.poetryfoundation.org/poems/44899/an-essay-on-man-epistle-i
# 4    https://www.poetryfoundation.org/poems/44900/an-essay-on-man-epistle-ii
#
#                            title  \
# 0  An Essay on Criticism: Part 1
# 1  An Essay on Criticism: Part 2
# 2  An Essay on Criticism: Part 3
# 3     An Essay on Man: Epistle I
# 4    An Essay on Man: Epistle II
#
#                                                                                                                                               poem_lines  \
# 0  [PART 1, 'Tis hard to say, if greater want of skill, Appear in writing or in judging ill;, But, of the two, less dang'rous is th' offence, To tire...
# 1  [Of all the causes which conspire to blind, Man's erring judgment, and misguide the mind,, What the weak head with strongest bias rules,, Is pride...
# 2  [Learn then what morals critics ought to show,, For 'tis but half a judge's task, to know., 'Tis not enough, taste, judgment, learning, join;, In ...
# 3  [Awake, my St. John! leave all meaner things, To low ambition, and the pride of kings., Let us (since life can little more supply, Than just to lo...
# 4  [I., Know then thyself, presume not God to scan;, The proper study of mankind is man., Plac'd on this isthmus of a middle state,, A being darkly w...
#
#                                                                                                                                              poem_string  \
# 0  PART 1\n'Tis hard to say, if greater want of skill\nAppear in writing or in judging ill;\nBut, of the two, less dang'rous is th' offence\nTo tire ...
# 1  Of all the causes which conspire to blind\nMan's erring judgment, and misguide the mind,\nWhat the weak head with strongest bias rules,\nIs pride,...
# 2  Learn then what morals critics ought to show,\nFor 'tis but half a judge's task, to know.\n'Tis not enough, taste, judgment, learning, join;\nIn a...
# 3  Awake, my St. John! leave all meaner things\nTo low ambition, and the pride of kings.\nLet us (since life can little more supply\nThan just to loo...
# 4  I.\nKnow then thyself, presume not God to scan;\nThe proper study of mankind is man.\nPlac'd on this isthmus of a middle state,\nA being darkly wi...
#
#       genre
# 0  augustan
# 1  augustan
# 2  augustan
# 3  augustan
# 4  augustan

# %%
df.tail()
# Out:
#                              poet  \
# 5165               William Barnes
# 5166               William Barnes
# 5167        William Ernest Henley
# 5168  William Makepeace Thackeray
# 5169               William Miller
#
#                                                                       poem_url  \
# 5165                       https://www.poetryfoundation.org/poems/52365/tokens
# 5166                      https://www.poetryfoundation.org/poems/52362/zun-zet
# 5167                     https://www.poetryfoundation.org/poems/51642/invictus
# 5168       https://www.poetryfoundation.org/poems/52711/the-cane-bottomd-chair
# 5169  https://www.poetryfoundation.org/poems/46949/willie-winkie-56d2271169ef7
#
#                         title  \
# 5165                   Tokens
# 5166                  Zun-zet
# 5167                 Invictus
# 5168  The Cane-Bottom’d Chair
# 5169            Willie Winkie
#
#                                                                                                                                                  poem_lines  \
# 5165  [Green mwold on zummer bars do show, That they’ve a-dripp’d in winter wet;, The hoof-worn ring o’ groun’ below, The tree, do tell o’ storms or het...
# 5166  [Where the western zun, unclouded,, Up above the grey hill-tops,, Did sheen drough ashes, lofty sh’ouded,, On the turf beside the copse,, In zumme...
# 5167  [Out of the night that covers me,, Black as the pit from pole to pole,, I thank whatever gods may be, For my unconquerable soul., In the fell clut...
# 5168  [In tattered old slippers that toast at the bars,, And a ragged old jacket perfumed with cigars,, Away from the world and its toils and its cares,...
# 5169  [Wee Willie Winkie, Rins through the toun,, Up stairs and doun stairs, In his nicht-gown,, Tirling at the window,, Crying at the lock,, “Are the w...
#
#                                                                                                                                                 poem_string  \
# 5165  Green mwold on zummer bars do show\nThat they’ve a-dripp’d in winter wet;\nThe hoof-worn ring o’ groun’ below\nThe tree, do tell o’ storms or het;...
# 5166  Where the western zun, unclouded,\nUp above the grey hill-tops,\nDid sheen drough ashes, lofty sh’ouded,\nOn the turf beside the copse,\nIn zummer...
# 5167  Out of the night that covers me,\nBlack as the pit from pole to pole,\nI thank whatever gods may be\nFor my unconquerable soul.\nIn the fell clutc...
# 5168  In tattered old slippers that toast at the bars,\nAnd a ragged old jacket perfumed with cigars,\nAway from the world and its toils and its cares,\...
# 5169  Wee Willie Winkie\nRins through the toun,\nUp stairs and doun stairs\nIn his nicht-gown,\nTirling at the window,\nCrying at the lock,\n“Are the we...
#
#           genre
# 5165  victorian
# 5166  victorian
# 5167  victorian
# 5168  victorian
# 5169  victorian

# %%
df.to_csv('data/poems_df_pre_clean.csv')

# %%
scan_poem_df.loc[4, 'poem_string']
# Out:
# 'A wrist (to repeat\nwith a shift\nof ac-\ncent, mood, of emphasis\nattentive to) now\nneeded\nThe wrist I lost\nhold of, of\nwhat was most\nloved as a kid\nin the swing of\nTed Williams,\nthe effortlessly\nbreaking as\nof the curved\nway true to the\nmark, of the stuff of Prince\nal,\nthe poem ought to be,\nas love is\na style she holds\nout to me\nto perch on the pulse of,\naristo-\ncratically, as I am not so but can\nat will flop for,\nsloppily,\nto please the crowd\nFor the game (the\njugglery,\nevasion\nthat’s the invasion of\nprivacy in, say\nyes,\nsay it, him, and by\nall means\nempathetically)\nCharlie Chaplin)\nis as it must be\ndrawing\nto the close of its\nnight now,\none is 30,\nhaving learned control,\nhow to pick the spots,\nand sits\nhigh up in the tiers\ninstead o\nthe lobsterbacked\nbleachers faraway close,\nand knows no wrist of a\nrare kid’s form\nwill bring down\nthat bird with the sun in its beak to break all records.'

# %%
scan_poem_scraper(scan_poem_df.loc[4, 'poem_url'])
# Out:
# {'poet': 'Jack Hirschman',
#  'poem_url': 'https://www.poetryfoundation.org/poetrymagazine/poems/30162/the-baseball-poem',
#  'title': 'The Baseball Poem',
#  'poem_lines': ['A wrist (to repeat',
#   'with a shift',
#   'of ac-',
#   'cent, mood, of emphasis',
#   'attentive to) now',
#   'needed',
#   'The wrist I lost',
#   'hold of, of',
#   'what was most',
#   'loved as a kid',
#   'in the swing of',
#   'Ted Williams,',
#   'the effortlessly',
#   'breaking as',
#   'of the curved',
#   'way true to the',
#   'mark, of the stuff of Prince',
#   'al,',
#   'the poem ought to be,',
#   'as love is',
#   'a style she holds',
#   'out to me',
#   'to perch on the pulse of,',
#   'aristo-',
#   'cratically, as I am not so but can',
#   'at will flop for,',
#   'sloppily,',
#   'to please the crowd'],
#  'poem_string': 'A wrist (to repeat\nwith a shift\nof ac-\ncent, mood, of emphasis\nattentive to) now\nneeded\nThe wrist I lost\nhold of, of\nwhat was most\nloved as a kid\nin the swing of\nTed Williams,\nthe effortlessly\nbreaking as\nof the curved\nway true to the\nmark, of the stuff of Prince\nal,\nthe poem ought to be,\nas love is\na style she holds\nout to me\nto perch on the pulse of,\naristo-\ncratically, as I am not so but can\nat will flop for,\nsloppily,\nto please the crowd'}

# %%
page = rq.get('https://www.poetryfoundation.org/poetrymagazine/browse?volume=50&issue=3&page=12')
soup = bs(page.content, 'html.parser')
img_link = soup.find('img', src=re.compile('.*/jstor/.*'))['src']
img_data = rq.get(img_link).content
with open('data/temp.png', 'wb') as handle:
    handle.write(img_data)

# %%
text = pytesseract.image_to_string('data/temp.png')
text
# Out:
# 'POETRY\n\nA MAGAZINE OF VERSE\n\nVOL. LIIIL NO. IV\n\nJANUARY 1939\n\nSEVEN POEMS\n\nI\nmortals)\nclimbi\nng i\nnto eachness begi\nn\ndizzily\nswingthings\nof speeds of\ntrapeze gush somersaults\nopen ing\nhes shes\n[169]'

# %%
re.match('[\[\(\{]?\s?[\d]+\s?[\]\)\}]?', text)

# %%
re.match('^[A-HJ-Z][A-HJ-Z ][A-Z ]+\n', text)

# %%
scan_pattern = '\n\n((?:\r?\n?(?![A-HJ-Z][A-HJ-Z ][A-Z ]+$).*)*)'
lines = re.search(scan_pattern, text, re.MULTILINE).group(1).splitlines()
lines
# Out:
# ['Though words are littered to my hand',
#  'nothing they build can house my need.',
#  'Though words, a masked bedizened band,',
#  'surround me, mock — assail — evade —',
#  '',
#  'though words come flowing from afar',
#  'having from ancient hills their red',
#  '',
#  'and from this sky their cloud, their star,',
#  'still thirsty, mute, I bow my head.',
#  '',
#  'For I am caught here needing speech,',
#  'sick with a lovely song unsung.',
#  '‘Waves broken on a desolate beach,',
#  'O not your strange confusing tongue',
#  '',
#  'but rather the enchanted beat,',
#  '',
#  'the deep eternal surge and sway —',
#  '',
#  'silence, then running rapturous feet —',
#  '',
#  'comes nearer what my heart would say.',
#  'Grace Fallow Norton',
#  '',
#  '[133]']

# %%
poems.shape
# Out:
# (4923, 6)

# %%
poems.head()
# Out:
#               poet  \
# 0      Mary Barber
# 1  Susanna Blamire
# 2  Susanna Blamire
# 3  Susanna Blamire
# 4      Henry Carey
#
#                                                                         poem_url  \
# 0     https://www.poetryfoundation.org/poems/50523/advice-to-her-son-on-marri
# 3748         []         NaN                     renaissance
# 4279         []         NaN                        romantic
# 4557         []         NaN                       victorian

# %%
# %%time

for index in poems[poems.poem_string.isna()].index:
    try:
        poems.loc[index,'poem_lines'] = PoemView_rescraper(poems.loc[index,'poem_url'])[0]
        poems.loc[index,'poem_string'] = PoemView_rescraper(poems.loc[index,'poem_url'])[1]
    except:
        print(index)
# Out:
# 215
# 232
# 1461
# 2141
# 2196
# 2199
# 2200
# 2201
# 2203
# 2910
# 3099
# CPU times: user 8.18 s, sys: 269 ms, total: 8.44 s
# Wall time: 22.3 s

# %%
poems[poems.poem_string == '']
# Out:
#                          poet  \
# 215           Michael McClure
# 232           Kenneth Patchen
# 1461  William Carlos Williams
# 2053             Dylan Thomas
# 2141    Guillaume Apollinaire
# 2196           Malcolm Cowley
# 2199               Hart Crane
# 2200               Hart Crane
# 2201               Hart Crane
# 2203               Hart Crane
# 2910     William Butler Yeats
# 2949            Barbara Guest
# 3099             Frank O'Hara
#
#                                                                                                                           poem_url  \
# 215                                             https://www.poetryfoundation.org/poetrymagazine/poems/26838/2-for-theodore-roethke
# 232                                                         https://www.poetryfoundation.org/poetrymagazine/poems/27128/poemscapes
# 1461  https://www.poetryfoundation.org/poetrymagazine/poems/27969/some-simple-measures-in-the-american-idiom-and-the-variable-foot
# 2053                                                 https://www.poetryfoundation.org/poems/26804/poem-on-his-birthday-facs-drafts
# 2141                               https://www.poetryfoundation.org/poetrymagazine/poems/25655/toward-the-south-tr-by-harry-duncan
# 2196                                           https://www.poetryfoundation.org/poetrymagazine/poems/30954/a-countryside-1918-1968
# 2199                                     https://www.poetryfoundation.org/poetrymagazine/poems/19926/the-urn-enrich-my-resignation
# 2200                                                https://www.poetryfoundation.org/poetrymagazine/poems/19916/the-urn-purgatorio
# 2201                                                     https://www.poetryfoundation.org/poetrymagazine/poems/19922/the-urn-reply
# 2203                                            https://www.poetryfoundation.org/poetrymagazine/poems/19920/the-urn-the-sad-indian
# 2910                                              https://www.poetryfoundation.org/poetrymagazine/poems/20737/a-full-moon-in-march
# 2949                                                                    https://www.poetryfoundation.org/poems/49367/imagined-room
# 3099                                         https://www.poetryfoundation.org/poetrymagazine/poems/31123/places-for-oscar-salvador
#
#                                                                  title  \
# 215                                             2 For Theodore Roethke
# 232                                                         Poemscapes
# 1461  Some Simple Measures In The American Idiom And The Variable Foot
# 2053                               Poem on His Birthday [Facs. drafts]
# 2141                               Toward The South Tr By Harry Duncan
# 2196                                           A Countryside 1918 1968
# 2199                                     The Urn Enrich My Resignation
# 2200                                                The Urn Purgatorio
# 2201                                                     The Urn Reply
# 2203                                            The Urn The Sad Indian
# 2910                                              A Full Moon In March
# 2949                                                     Imagined Room
# 3099                                         Places For Oscar Salvador
#
#      poem_lines poem_string            genre
# 215          []                         beat
# 232          []                         beat
# 1461         []                      imagist
# 2053         []                       modern
# 2141         []                       modern
# 2196         []                       modern
# 2199         []                       modern
# 2200         []                       modern
# 2201         []                       modern
# 2203         []                       modern
# 2910         []                       modern
# 2949         []              new_york_school
# 3099         []              new_york_school

# %%
poems = poems[poems.poem_string != '']
poems.shape
# Out:
# (4910, 6)

# %%
error_rescrapes = []
still_errors = error_poems.copy()

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/29416/mad-sonnet-we-shall-be-free'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=102&issue=3&page=18'
rescrape = scan_poem_scraper(actual_url, input_poet='Michael McClure', input_title='Mad Sonnet: We Shall Be Free')
rescrape['poem_url'] = url
rescrape['genre'] = 'beat'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/29415/mad-sonnet-when-spirit-has-no-edge'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=102&issue=3&page=17'
rescrape = scan_poem_scraper(actual_url, input_poet='Michael McClure', input_title='Mad Sonnet: When Spirit Has No Edge')
rescrape['poem_url'] = url
rescrape['genre'] = 'beat'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/30530/song-how-simply-for-another'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=109&issue=5&page=6'
rescrape = scan_poem_scraper(actual_url, input_poet='Robert Creeley', input_title='Enough: Left After That')
rescrape['poem_url'] = url
rescrape['genre'] = 'black_mountain'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/29779/walking-56d2134a84892'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=104&issue=3&page=19'
rescrape = scan_poem_scraper(actual_url, input_poet='Robert Creeley', input_title='Walking: In My Head')
rescrape['poem_url'] = url
rescrape['genre'] = 'black_mountain'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/14358/epitaph-an-old-willow'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=13&issue=6&page=13'
rescrape = scan_poem_scraper(actual_url, input_poet='William Carlos Williams', input_title='Epitaph')
rescrape['poem_url'] = url
rescrape['genre'] = 'imagist'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/28310/elaine'
rescrape = scan_poem_scraper(url, input_poet='William Carlos Williams', input_title='Elainb')
rescrape['poem_url'] = url
rescrape['genre'] = 'imagist'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/28312/emily'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=95&issue=6&page=3'
rescrape = scan_poem_scraper(actual_url, input_poet='William Carlos Williams', input_title='Emily')
rescrape['poem_url'] = url
rescrape['genre'] = 'imagist'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/28311/erica'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=95&issue=6&page=2'
rescrape = scan_poem_scraper(actual_url, input_poet='William Carlos Williams', input_title='Erica')
rescrape['poem_url'] = url
rescrape['genre'] = 'imagist'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/18899/poem-as-the-cat'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=36&issue=4&page=22'
rescrape = scan_poem_scraper(actual_url, input_poet='William Carlos Williams', input_title='Poem: As the cat')
rescrape['poem_url'] = url
rescrape['genre'] = 'imagist'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/13202/from-discordants-iv'
rescrape = scan_poem_scraper(url, input_poet='Conrad Aiken', input_title='Discordants')
rescrape['poem_url'] = url
rescrape['genre'] = 'modern'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/13202/from-discordants-iv'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=6&issue=6&page=22'
rescrape = scan_poem_scraper(actual_url, input_poet='Conrad Aiken', input_title='Discordants IV')
rescrape['poem_url'] = url
rescrape['genre'] = 'modern'
error_rescrapes.append(rescrape)

# %%
error_poems
# Out:
# ['https://www.poetryfoundation.org/poetrymagazine/poems/29415/mad-sonnet-when-spirit-has-no-edge',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29416/mad-sonnet-we-shall-be-free',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30270/ritual-ix',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30225/song-i-wouldnt-embarrass-you',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29779/walking-56d2134a84892',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30530/song-how-simply-for-another',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30550/the-sundering-up-tracks',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30551/the-first-note',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28862/the-law',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/27415/poem-when-the-immortal-blond',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/19645/persons-seen',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/32401/sonnets-of-the-blood',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14433/compensation-56d20832b37a3',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14312/calligraphy-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14296/on-seeing-the-portrait-of-a-beautiful-concubine-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14321/the-inn-at-the-western-lake-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14315/the-palace-blossoms-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14310/an-evening-meeting-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14322/the-emperors-return-from-a-journey-to-the-south-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14320/a-recluse-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14311/after-how-many-years-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/13065/exiles-letter-tr-by-ezra-pound',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/13497/paganis',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/12926/amities',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/12663/contemporania',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28310/elaine',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/18899/poem-as-the-cat',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/32405/proof-of-immortality-56d215f13b354',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28312/emily',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14358/epitaph-an-old-willow',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28311/erica',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/21476/to-an-elder-poet',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/13202/from-discordants-iv',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/25512/jacks-white-horseup',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/25263/imc-a-tmo',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/22220/nouns-to-nouns',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28835/pity-his-how-illimitable-plight',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/25510/dim-i-nu-tiv',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/22223/six',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/25960/springmay0151',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/25513/-oroundmoonhow',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28566/why-dont-be',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28836/without-the-mercy-of',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/22222/up-into-the-silence-the-green',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28837/annie-died-the-other-day',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/24807/thislets-rememberday',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28834/for-any-ruffian-of-the-sky',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28833/if-seventy-were-young',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/26048/rosetreerosetree',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28838/o-the-sun-comes-up-up-up',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/40222/honeymoon-tr-by-barry-goldensohn',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/15885/wanderings-champs-dhonneur-56d20918e2c28',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/15867/wanderings-champs-dhonneur',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/22372/slow-blue',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/34682/project-for-an-aesthetic',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/34678/five-poems-from-the-1920s',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/12960/ollie-mgee',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/21466/walking-sticks-and-paperweights-and-watermarks',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/19682/part-of-a-novel-part-of-a-poem-part-of-a-play-the-hero',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/22310/poem-after-the-wrestling',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/15533/lenvoi',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/17874/discus-thrower',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/20683/conjunctions',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29206/angelica-an-opera-act-ii',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/33672/poem-green-things-are-flowers',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30549/poem-like-musical-instruments',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30775/sonnet-five-am-on-east-fourteenth',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30723/jungle-56d21432117a5',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30140/spring-stood-there',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30139/march-56d213a2b802b',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29475/now-in-one-year',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30141/the-park-a-darling-walk',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30138/consider-at-the-outset',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30790/smile-to-see-the-lake',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29745/giovannis-rape-of-the-sabine-women-at-wildensteins',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/19125/1930s',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/19940/along-the-flat-roofs',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/32643/a-22-an-era-any-time',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/26578/je-faisois-ces-sonnets-tr-by-george-dillon',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28076/brucio-e-limminenza-lombra-che-sale-riconosco']

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/25512/jacks-white-horseup'
rescrape = scan_poem_scraper(url, input_poet='E. E. Cummings', input_title="jack's white")
rescrape['poem_url'] = url
rescrape['genre'] = 'modern'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
rescrapes_v2 = pd.DataFrame(error_rescrapes)

# %%
rescrapes_v2.to_csv('data/temp_rescrapes_2.csv')

# %%
poems.loc[2247, 'poem_string']
# Out:
# 'climbi\nng i\nnto eachness begi\ndizzily\nswingthings\nof speeds of\ntrapeze gush somersaults\nopen ing\nhes shes\n&meet &\nswoop\nfully is are ex\nquisite theys of re\nfall which now drop who all dreamlike\nim)\nJanuary 1939'

# %%
poems[poems.poet == 'E. E. Cummings']
# Out:
#                 poet  \
# 1755  E. E. Cummings
# 1756  E. E. Cummings
# 1757  E. E. Cummings
# 1758  E. E. Cummings
# 1759  E. E. Cummings
# 1760  E. E. Cummings
# 1761  E. E. Cummings
# 1762  E. E. Cummings
# 1763  E. E. Cummings
# 1764  E. E. Cummings
# 1765  E. E. Cummings
# 1766  E. E. Cummings
# 1767  E. E. Cummings
# 2212  E. E. Cummings
# 2213  E. E. Cummings
# 2214  E. E. Cummings
# 2215  E. E. Cummings
# 2216  E. E. Cummings
# 2217  E. E. Cummings
# 2218  E. E. Cummings
# 2219  E. E. Cummings
# 2220  E. E. Cummings
# 2221  E. E. Cummings
# 2222  E. E. Cummings
# 2223  E. E. Cummings
# 2224  E. E. Cummings
# 2225  E. E. Cummings
# 2222                   Possibly Thrice We Glimpsed0151
# 2223                  Now All The Fingers Of This Tree
# 2224                             Whose Are Thesewraith
# 2225                  All Nearness Pauses While A Star
# 2226                    If The Lovestar Grows Most Big
# 2227        [i carry your heart with me(i carry it in]
# 2228                                          Timeless
# 2229               [anyone lived in a pretty how town]
# 2230                 You Which Could Grin Three Smiles
# 2231                                    Crazy Jay Blue
# 2232                                    A Pretty A Day
# 2233                                     Neither Awake
# 2234                         What If A Much Of A Which
# 2235                   If Everything Happens That Cant
# 2236                           Though Your Sorrows Not
# 2237                                 In Spring Comesno
# 2238                                 This Is A Rubbish
# 2239                [love is more thicker than forget]
# 2240                                   Spirit Colossal
# 2241                                 Ones Not Half Two
# 2242                     Iftouched By Loves Own Secret
# 2243                  Might These Be Thrushes Climbing
# 2244              If A Cheerfulest Elephantangel Child
# 2245                          Infinite Jukethrob Smoke
# 2246                                 Open His Headbaby
# 2247                             Seven Poems I Mortals
# 2248                                     2 Little Whos
# 2249                       Unloves The Heavenless Hell
#
#                                                                                                                                                  poem_lines  \
# 1755  ['"kitty". sixteen,5\'1",white,prostitute.', 'ducking always the touch of must and shall,', "whose slippery body is Death's littlest pal,", 'skill...
# 1756  ['the bigness of cannon', 'is skilful,', 'but i have seen', 'death’s clever enormous voice', 'which hides in a fragility', 'of poppies. . . .', 'i...
# 1757  ['O sweet spontaneous', 'earth how often have', 'the', 'doting', 'fingers of', 'prurient philosophers pinched', 'and', 'poked', 'thee', ',has the ...
# 1758  ['in Just-', 'spring          when the world is mud-', 'luscious the little', 'lame balloonman', 'whistles          far          and wee', 'and ed...
# 1759  ['little tree', 'little silent Christmas tree', 'you are so little', 'you are more like a flower', 'who found you in the green forest', 'and were ...
# 1760  ['the Cambridge ladies who live in furnished souls', 'are unbeautiful and have comfortable minds', "(also, with the church's protestant blessings"...
# 1761  ['Buffalo Bill ’s', 'defunct', 'who used to', 'ride a watersmooth-silver', 'stallion', 'and break onetwothreefourfive pigeonsjustlikethat', 'Jesus...
# 1762  ['what if a much of a which of a wind', "gives truth to the summer's lie;", 'bloodies with dizzying leaves the sun', 'and yanks immortal stars awr...
# 1763  ['into the strenuous briefness', 'Life:', 'handorgans and April', 'darkness,friends', 'i charge laughing.', 'Into the hair-thin tints', 'of yellow...
# 1764  ['All in green went my love riding', 'on a great horse of gold', 'into the silver dawn.', 'four lean hounds crouched low and smiling', 'the merry ...
# 1765  ['hist      whist', 'little ghostthings', 'tip-toe', 'twinkle-toe', 'little twitchy', 'witches and tingling', 'goblins', 'hob-a-nob     hob-a-nob'...
# 1766  ['somewhere i have never travelled,gladly beyond', 'any experience,your eyes have their silence:', 'in your most frail gesture are things which en...
# 1767  ['as freedom is a breakfastfood', 'or truth can live with right and wrong', 'or molehills are from mountains made', '—long enough and just so long...
# 2212  ['while possibly not(at a guess)quite half way down', 'to the earth are leapandswooping tinily birds', 'whose magical gaiety makes your beautiful ...
# 2213  ['climbi', 'ng i', 'nto eachness begi', 'n', 'dizzily', 'swingthings', 'of speeds of', 'trapeze gush somersaults', 'open ing', 'hes shes', '&meet&...
# 2214  ['sam done', 'the best he kin', 'till they digged his hole', ':Sam was a man', 'stout as a bridge', 'tugged as a bear', 'slickern a weazel', 'how ...
# 2215  ['minute by second and most by more—', 'if death is the loser and life is the winner', '(and beggars are rich but misers are poor)', '—let’s touch...
# 2216                                                                                         ['how many centuries)these more than eyes', 'troll d 11 d, ;']
# 2217  ['and from all selfsubtracting hugely doom', 'treasures of reeking innocence are born.', 'Then, with not credible the anywhere', 'eclipsing of a s...
# 2218  ['n', 'd', 'fall which now drop who all dreamlike', 'im)', 'Il', 'these children singing in stone a', 'silence of stone these', 'little children w...
# 2219  ['dive for dreams', 'or a slogan may topple you', '(trees are their roots', 'and wind is wind )', 'trust your heart', 'if the seas catch fire', '(...
# 2220  ['can hold a you', 'shall see the not', 'stood within his steam be-', 'ginning and', 'began to sing all', 'here is hands machine no', 'good too qu...
# 2221  ['smoke and we aint got', 'nothing to smoke: come on kid', '~ Iet’s go to sleep', 'if you can’t smoke you got to', 'Sing and we aint got', 'nothin...
# 2222  ['more likely twice', 'that(once crammed into someone’s kitchenette)', 'wheezing bulgily world of genial plac', '-idity (plus,out of much its misb...
# 2223  ['hands,and all the hands have people;and', 'more each particular person is(my love)', 'alive than every world can understand', "and now you are a...
# 2224  ['ghosts drowning in supreme thunder?ours', '(over you reels and me a moon;beneath,', 'bombed the by ocean earth bigly shudders)', 'never was deat...
# 2225  ['all nearness pauses, while a star can grow', 'all distance breathes a final dream of bells;', 'perfectly outlined against afterglow', 'are all a...
# 2226  ['a voice comes out of some dreaming tree', '(and how ill stand more still than still)', "and what he'll sing and sing to me", 'and while this dre...
# 2227  ['i carry your heart with me(i carry it in', 'my heart)i am never without it(anywhere', 'i go you go,my dear;and whatever is done', 'by only me is...
# 2228                           ['ly this', '(merely and whose', 'not', 'numerable leaves are', 'fall', 'i', 'ng)he', '* Copyright 1961 by E. E. Cummings.']
# 2229  ['anyone lived in a pretty how town', '(with up so floating many bells down)', 'spring summer autumn winter', 'he sang his didn’t he danced his di...
# 2230  ['house clutch between eyes emptiness toss one', 'at nobody shoulder and thick stickingly un', 'stride after glide massacre monday did', 'more) as...
# 2231  ['demon laughshriek', 'ing at me', 'your scorn of easily', 'hatred of timid', '& loathing foe( call all', 'regular righteo', 'comfortable yunworld...
# 2232  ['(and every fades)', 'is here and away', '(but born are maids', 'to flower an hour', 'in allall)', 'until so blithe', 'a doer a wooer', 'some lim...
# 2233  ['(there’s your general', 'yas buy gad)', 'nor asleep', 'booted & spurred', 'with an apish grin', '(extremely like', 'but quite absurd', 'gloved f...
# 2234  ["gives the truth to summer's lie;", 'bloodies with dizzying leaves the sun', 'and yanks immortal stars awry?', 'Blow king to beggar and queen to ...
# 2235  ['(and anything’s righter', 'ooks', 'could plan)', 'the stupidest teacher will almost guess', '(with a run', 'skip', 'around we go yes)', 'there’s...
# 2236  ['any tongue may name,', 'three i’ll give you sweet', 'joys for each of them', 'But it must be your”', 'whispers that flower', 'murmurs eager this...
# 2232  (and every fades)\nis here and away\n(but born are maids\nto flower an hour\nin allall)\nuntil so blithe\na doer a wooer\nsome limber and lithe\ns...
# 2233  (there’s your general\nyas buy gad)\nnor asleep\nbooted & spurred\nwith an apish grin\n(extremely like\nbut quite absurd\ngloved fist on hip\n& th...
# 2234  gives the truth to summer's lie;\nbloodies with dizzying leaves the sun\nand yanks immortal stars awry?\nBlow king to beggar and queen to seem\n(b...
# 2235  (and anything’s righter\nooks\ncould plan)\nthe stupidest teacher will almost guess\n(with a run\nskip\naround we go yes)\nthere’s nothing as some...
# 2236  any tongue may name,\nthree i’ll give you sweet\njoys for each of them\nBut it must be your”\nwhispers that flower\nmurmurs eager this\n“4 will gi...
# 2237  Spring comes(no-\nasks his name)\na mender\nof things\nwith eager\nfingers (with\npatient\neyes )re\n-new-\ning remaking what\nother\n-wise we sho...
# 2238  with a photograph\nclutched in the half\nof a hand and the word\nlove underlined\nthis is a girl who died in her mind\nwith a warm thick scream\na...
# 2239  love is more thicker than forget\nmore thinner than recall\nmore seldom than a wave is wet\nmore frequent than to fail\nit is most mad and moonly\...
# 2240  (& daunted by always\nnothing )you darling\ndiminutive person\njovial ego(&\nmischievous tenderly\nphoebeing alter)\nclown of an angel\neverywhere...
# 2241  which halves reintegrating, shall occur\nno death and any quantity; but than\nall numerable mosts the actual more\nminds ignorant of stern miracul...
# 2242  through welcoming sweet miracles of air\n(and joyfully all truths of wing resuming)\nselves,into infinite tomorrow steer\n—souls under whom flow( ...
# 2243  beautifully wandering in merciful\nmiracles wonderingly celebrate day\nand welcome earth’s arrival with a soul)\nsunlight? yes\n(always we have he...
# 2244  (holding a red candle over his head\nby a finger of trunk,and singing out of a red\nbook)on a proud round cloud in a white high night\nwhere his h...
# 2245  gorge)\na sulky gob with entirely white\neyes of elsewhere\njabber while (infinite\nfog & puking jukepulse hug) large less\nthan more magnetic pin...
# 2246  & you'll find a heart in it\n(cracked )\nopen that heart,mabel\n& you'll find a bed in it\n(fact)\nopen this bed,sibyl\n& you'll find a tart in it...
# 2247  climbi\nng i\nnto eachness begi\ndizzily\nswingthings\nof speeds of\ntrapeze gush somersaults\nopen ing\nhes shes\n&meet &\nswoop\nfully is are ex...
# 2248  (he and she)\nunder are this\nwonderful tree\nsmiling stand\n(all realms of where\nand when beyond)\nnow and here\n(fr from a grown\n-up i&you-\nf...
# 2249  unlove’s the heavenless hell and homeless home\nof knowledgeable shadows (quick to seize\neach nothing which all soulless wraiths proclaim\nsubsta...
#
#        genre
# 1755  modern
# 1756  modern
# 1757  modern
# 1758  modern
# 1759  modern
# 1760  modern
# 1761  modern
# 1762  modern
# 1763  modern
# 1764  modern
# 1765  modern
# 1766  modern
# 1767  modern
# 2212  modern
# 2213  modern
# 2214  modern
# 2215  modern
# 2216  modern
# 2217  modern
# 2218  modern
# 2219  modern
# 2220  modern
# 2221  modern
# 2222  modern
# 2223  modern
# 2224  modern
# 2225  modern
# 2226  modern
# 2227  modern
# 2228  modern
# 2229  modern
# 2230  modern
# 2231  modern
# 2232  modern
# 2233  modern
# 2234  modern
# 2235  modern
# 2236  modern
# 2237  modern
# 2238  modern
# 2239  modern
# 2240  modern
# 2241  modern
# 2242  modern
# 2243  modern
# 2244  modern
# 2245  modern
# 2246  modern
# 2247  modern
# 2248  modern
# 2249  modern

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/25263/imc-a-tmo'
rescrape = scan_poem_scraper(url, input_poet='E. E. Cummings', input_title="(im)c-a-t(mo)")
rescrape['poem_url'] = url
rescrape['genre'] = 'modern'
rescrape
# error_rescrapes.append(rescrape)
# still_errors.remove(url)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/Documents/flatiron/projects/mod5/poetry_genre_classifier/functions_webscraping.py in process_image(poem_url, first, poet, title, first_pattern, next_pattern)
#     304             scan_pattern = fr'{title.split()[-1].upper()}{first_pattern}'
# --> 305             lines = re.search(scan_pattern, text, re.MULTILINE).group(1).splitlines()
#     306         except:
#
# AttributeError: 'NoneType' object has no attribute 'group'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/Documents/flatiron/projects/mod5/poetry_genre_classifier/functions_webscraping.py in process_image(poem_url, first, poet, title, first_pattern, next_pattern)
#     309                 scan_pattern = fr'{title.split()[-1]}{first_pattern}'
# --> 310                 lines = re.search(scan_pattern, text, re.MULTILINE).group(1).splitlines()
#     311             except:
#
# AttributeError: 'NoneType' object has no attribute 'group'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/Documents/flatiron/projects/mod5/poetry_genre_classifier/functions_webscraping.py in process_image(poem_url, first, poet, title, first_pattern, next_pattern)
#     314                     scan_pattern = fr'{title.split()[-1].lower()}{first_pattern}'
# --> 315                     lines = re.search(scan_pattern, text, re.MULTILINE).group(1).splitlines()
#     316                 except:
#
# AttributeError: 'NoneType' object has no attribute 'group'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/Documents/flatiron/projects/mod5/poetry_genre_classifier/functions_webscraping.py in process_image(poem_url, first, poet, title, first_pattern, next_pattern)
#     319                         scan_pattern = fr'{title.split()[0].upper()}{first_pattern}'
# --> 320                         lines = re.search(scan_pattern, text, re.MULTILINE).group(1).splitlines()
#     321                     except:
#
# AttributeError: 'NoneType' object has no attribute 'group'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/Documents/flatiron/projects/mod5/poetry_genre_classifier/functions_webscraping.py in process_image(poem_url, first, poet, title, first_pattern, next_pattern)
#     324                             scan_pattern = fr'{title.split()[0]}{first_pattern}'
# --> 325                             lines = re.search(scan_pattern, text, re.MULTILINE).group(1).splitlines()
#     326                         except:
#
# AttributeError: 'NoneType' object has no attribute 'group'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-174-c5c7077946f6> in <module>
#       1 url = 'https://www.poetryfoundation.org/poetrymagazine/poems/25263/imc-a-tmo'
# ----> 2 rescrape = scan_poem_scraper(url, input_poet='E.E. Cummings', input_title="(im)c-a-t(mo)")
#       3 rescrape['poem_url'] = url
#       4 rescrape['genre'] = 'modern'
#       5 rescrape
#
# ~/Documents/flatiron/projects/mod5/poetry_genre_classifier/functions_webscraping.py in scan_poem_scraper(poem_url, input_poet, input_title, first_pattern, next_pattern)
#     354                                                   title=input_title,
#     355                                                   first_pattern=first_pattern,
# --> 356                                                   next_pattern=next_pattern)
#     357
#     358     while re.match(r'[\[\(]?\s?[\d]+\s?[\]\)]?', lines[-1]):
#
# ~/Documents/flatiron/projects/mod5/poetry_genre_classifier/functions_webscraping.py in process_image(poem_url, first, poet, title, first_pattern, next_pattern)
#     327                             # if all lowercase, first word
#     328                             scan_pattern = fr'{title.split()[0].lower()}{first_pattern}'
# --> 329                             lines = re.search(scan_pattern, text, re.MULTILINE).group(1).splitlines()
#     330
#     331     else:
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
poems[poems.contains('cummings')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-178-7a8e1d1e41a3> in <module>
# ----> 1 poems[poems.contains('cummings')]
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'contains'

# %%
title = 'HEY'

# %%
pattern=r'\b.*((?:\r?\n(?![A-HJ-Z][A-HJ-Z ][A-Z ]+$).*)*)'
f'{title}' + pattern
# Out:
# 'HEY\\b.*((?:\\r?\\n(?![A-HJ-Z][A-HJ-Z ][A-Z ]+$).*)*)'

# %%
re.match(r'[\[\(]?\s?[\d]+\s?[\]\)]?', process_image(actual_url, poet='William Carlos Williams', title='Erica')[0][-1])
# Out:
# <_sre.SRE_Match object; span=(0, 3), match='326'>

# %%
rescrape['poem_lines']
# Out:
# ['the melody line is',
#  'everything',
#  'in this composition',
#  'when I first witnessed',
#  'your hea',
#  'and held it',
#  'admiringly between',
#  'in approval',
#  'at the Scandinavian',
#  'name they’d',
#  'given you Erica after',
#  'your father’s',
#  'forebears',
#  'the rest remains a',
#  'mystery',
#  'your snub nose spinning']

# %%
process_image('https://www.poetryfoundation.org/poetrymagazine/browse?volume=95&issue=6&page=3', first=False)
# Out:
# ([],
#  'https://www.poetryfoundation.org/poetrymagazine/browse?volume=95&issue=6&page=4')

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/28309/3-stances'
rescrape = scan_poem_scraper(url, 
                             input_poet='William Carlos Williams',
                             input_title='3 Stances',
                             first_pattern='.*((?:\r?\n.*)*)',
                             next_pattern='\n((?:\r?\n(?!THEODORE HOLMES).*)*)')
rescrape['poem_url'] = url
rescrape['genre'] = 'imagist'
rescrape
# Out:
# {'poet': 'William Carlos Williams',
#  'poem_url': 'https://www.poetryfoundation.org/poetrymagazine/poems/28309/3-stances',
#  'title': '3 Stances',
#  'poem_lines': ['I',
#   'ELAINB',
#   'poised for the leap she',
#   'is not yet ready for',
#   '—-save in her eyes',
#   'her bare toes',
#   'starting over the clipt',
#   'lawn where she may',
#   'not go emphasize summer',
#   'and the curl',
#   'of her blond hair'],
#  'poem_string': 'I\nELAINB\npoised for the leap she\nis not yet ready for\n—-save in her eyes\nher bare toes\nstarting over the clipt\nlawn where she may\nnot go emphasize summer\nand the curl\nof her blond hair',
#  'genre': 'imagist'}

# %%
poems.loc[1505, 'poem_string']
# Out:
# 'I\nWhen a man had gone\nin Russia from a small\ntown\nto the University\nhe\nreturned a hero—\npeople\nbowed down to him—\nhis\nego, nourished by this,\nmount-\ned to notable works.\nHere\nin the streets the kids\nsay\nHello Pete! to me\nWhat\ncan one be or\nimagine?\nNothing is reverenced\nnothing\nlooked up to. Nothing\ncan\ncome of that sort of\nis-\nrespect for the under-\nstanding'

# %%
poems[poems.title == 'The Unfrocked Priest']
# Out:
#                          poet  \
# 1505  William Carlos Williams
#
#                                                                               poem_url  \
# 1505  https://www.poetryfoundation.org/poetrymagazine/poems/18898/the-unfrocked-priest
#
#                      title  \
# 1505  The Unfrocked Priest
#
#                                                                                                                                                  poem_lines  \
# 1505  [I, When a man had gone, in Russia from a small, town, to the University, he, returned a hero—, people, bowed down to him—, his, ego, nourished by...
#
#                                                                                                                                                 poem_string  \
# 1505  I\nWhen a man had gone\nin Russia from a small\ntown\nto the University\nhe\nreturned a hero—\npeople\nbowed down to him—\nhis\nego, nourished by ...
#
#         genre
# 1505  imagist

# %%
poems = poems[poems.title != '3 Stances']
poems.iloc[1489:1492]
# Out:
#                          poet  \
# 1493  William Carlos Williams
# 1494  William Carlos Williams
# 1495  William Carlos Williams
#
#                                                                                        poem_url  \
# 1493  https://www.poetryfoundation.org/poetrymagazine/poems/22755/the-world-narrowed-to-a-point
# 1494                       https://www.poetryfoundation.org/poetrymagazine/poems/13515/marriage
# 1495                         https://www.poetryfoundation.org/poetrymagazine/poems/15467/spouts
#
#                               title  \
# 1493  The World Narrowed To A Point
# 1494                       Marriage
# 1495                         Spouts
#
#                                                                                                                                                  poem_lines  \
# 1493  [Liquor and love, when the mind is dull, focus the wit, on a world of form, The eye awakes, perfumes are defined, inflections, ride the quick ear,...
# 1494                                                                               [So different, this man, And this woman:, A stream flowing, In a field.]
# 1495  [In this world of, as fine a pair of breasts, as ever I saw,, the fountain in, Madison Square, spouts up of water, a white tree,, that dies and li...
#
#                                                                                                                                                 poem_string  \
# 1493  Liquor and love\nwhen the mind is dull\nfocus the wit\non a world of form\nThe eye awakes\nperfumes are defined\ninflections\nride the quick ear\n...
# 1494                                                                                 So different, this man\nAnd this woman:\nA stream flowing\nIn a field.
# 1495  In this world of\nas fine a pair of breasts\nas ever I saw,\nthe fountain in\nMadison Square\nspouts up of water\na white tree,\nthat dies and liv...
#
#         genre
# 1493  imagist
# 1494  imagist
# 1495  imagist

# %%
error_rescrapes[-1]
# Out:
# {'poet': 'Robert Creeley',
#  'poem_url': 'https://www.poetryfoundation.org/poetrymagazine/poems/29779/walking-56d2134a84892',
#  'title': 'Walking: In My Head',
#  'poem_lines': ['is there to walk,',
#   'not thought of, is',
#   'the road itself more',
#   'than seen. I think',
#   'it might be, feel',
#   'as my feet do, and',
#   'continue, and',
#   'at last reach, slowly,',
#   'one end of my intention.'],
#  'poem_string': 'is there to walk,\nnot thought of, is\nthe road itself more\nthan seen. I think\nit might be, feel\nas my feet do, and\ncontinue, and\nat last reach, slowly,\none end of my intention.',
#  'genre': 'black_mountain'}

# %%
text = pytesseract.image_to_string('data/temp.png')
text
# Out:
# 'POETRY: 4 Magazine of Verse\nTWO LADIES\n\nEPITAPH FOR TABITHA\nThief at her left and whore at her right,\nPause and pity Tabitha’s plight!\n\nPoor old kindly Tabitha who\n\nShunned the devil and all his crew;\n\nSqueezed the shillings and pinched the groats,\nKept the heathen in petticoats;\n\nTook her heart when she felt it prod,\nSalted it down like a frisky cod.\n\nGood old proper Tabitha Tubb,\nMeasuring bones with Beelzebub,\n\nCovered with daisies and chagrin,\nHere she lies where they heeled her in-\n\nThief at her left and whore at her right,\nPause and pity Tabitha’s plight.\nLOCAL COLOR\n\nMrs. Leander came to town,\nOgled us deftly up and down;\nPaused at Mrs. O’Reilly’s door,\nComplimented her sycamore;\n\n[196]'

# %%
lines = re.search('WILLIAM CARLOS WILLIAMS\n((?:\r?\n(?![A-HJ-Z][A-HJ-Z ][A-Z ]+$).*)*)', text, re.MULTILINE).group(1).splitlines()
lines
# Out:
# []

# %%
text = 'William Carlos Williams\n\nEPITAPH\n\nAn old willow with hollow branches\nSlowly swayed his few high bright tendrils\nAnd sang:\n\n“Love is a young green willow\nShimmering at the bare wood’s edge.”\n\nSPIRIT\n\nO my grey hairs!\nYou are truly white as plum blossoms.\n\nSTROLLER\n\nI have seen the hills blue,\n\nI have seen them purple;\n\nAnd it is as hard to know\n\nThe words of a woman\n\nAs to straighten the crumpled branch\nOf an old willow.\n\nMEMORY OF APRIL\n\nYou say love is this, love is that:\nPoplar tassels, willow tendrils\n\nThe wind and the rain comb,\nTinkle and drip, tinkle and drip—\nBranches drifting apart. Hagh!\nLove has not even visited this country.\n\n[303]'

# %%
title = 'Epitaph'
scan_pattern = fr'{title.split()[-1].upper()}\b.*((?:\r?\n(?![A-HJ-Z][A-HJ-Z ][A-Z ]+$).*)*)'
lines = re.search(scan_pattern, text, re.MULTILINE).group(1).splitlines()
lines
# Out:
# ['',
#  '',
#  'An old willow with hollow branches',
#  'Slowly swayed his few high bright tendrils',
#  'And sang:',
#  '',
#  '“Love is a young green willow',
#  'Shimmering at the bare wood’s edge.”']

# %%
poems.to_csv('data/poems_df.csv')

# %%
poems.loc[550:600, 'poem_string']
# Out:
# 550    Don’t ste}\nso lightly. Break\nyour back, missed\nthe step. Don’t go\naway mad, lady in\nthe nightmare. You\nare central,\neven necessary.\nI will...
# 551    Remember the way you\nhunched up the first\ntimes in bed, all your\nbody as you walked\nseemed centered\nin your breasts. It\nwas watching the wor...
# 552    Thinking of you asleep on a\nbed on a pillow, on a\nbed—the ground or space\nyou lie on. That’s enough to\ntalk to now I got space and\ntime like ...
# 553    For fear I want\nto make myself again\nunder the thumb\nof old love, old time\nsubservience\nand pain, bent\ninto a nail that will\nnot come out.\...
# 554    For Robert Duncan\nIt is hard going to the door\ncut so small in the wall where\nthe vision which echoes loneliness\nbrings a scent of wild flower...
# 555    For whatever, it could\nbe done, simply\nremove it, cut the\noffending member. Once\nin a photograph by\nFrederick Sommer a leg\nlay on what was a...
# 556    Say that you’re\nlonely—and want\nsomething to\nplace you—\ngoing around groping\neither by mind\nor hand—but behind\nthe pun is a\ndoor you keep ...
# 557    Of a few years\ncome into focus—\npeace and understanding,\nthe uneasy virtues.\nOf a mist.\nA night’s peace\nwaking to sullenness,\nuneasy compan...
# 558    With a quick\njump he caught\nthe edge of\nher eye and\nit tore, down,\nripping. She\nshuddered,\nwith the unexpected\nassault, but\nto his vantag...
# 559    Harry has written\nall he knows,\nMiriam tells\nher thought, Peter\nsays, again,\nhis mind. Robert and John,\nWilliam, Tom,\nand Helen, Ethel,\nth...
# 560    ess\nsomething small\nbut infinite\nand quiet.\nThere are senses\nmake an object\nin their simple\nfeeling for one.\nTHE FLOWER\nRemember the way ...
# 561    All the grass\ndies\nin front of us.\nflares out.\nThe night\nsuch a large\nplace. Stars\nthe points,\nbut like\nplaces no\ndepth, I see\na\na pla...
# 562    He thinks\nalways things\nwill be simpler,\nwith face\nof a clown\nso that the mouth\nrolls down, then\nthe eye shuts\nas a fist\nto hold patience...
# 563    The eye I look out of\nor hands I use,\nfeet walking,\nthey stay particular.\nI wanted\none place to be\nwhere I was\nalways.\nI wanted you\nsomeh...
# 564    Each gesture\nis a common one, a\nblack dog, crying, a\nman, crying.\nAll alike, people\nor things grow\nfixed with what\nhappens to them.\nI thro...
# 565    When they came near,\nthe one, two, three, four,\nall five of us sat\nin the broken seat.\nOh glad to see,\noh glad to be,\nwhere company\nis so d...
# 566    I keep to myself such\nmeasures as I care for,\ndaily the rocks\naccumulate position.\nThere is nothing\nbut what thinking makes\nit less tangible...
# 567    There is a lake of clear water.\nThere are forms of things despite us.\nPope said, “A little learning,”\nand, and, and, and—the same.\nWhy don’t y...
# 568                                                                                             Happy the man who loves what\nhe has and worked for it also.
# 569    I'm going to roll up\na monkey and smoke it, put\nan elephant in the pot. I’m going out\nand never come back.\nWhat's better than that.\nLying on ...
# 570    Who\nam I—\nidentity\nsinging.\nPlace\na lake\non ground, water\nfinds a form.\nSmoke\non the air\ngoes higher\nto fade.\nSun bright,\ntrees dark ...
# 571    By location, e.g., where\nor here—or what words in\ntime make of things. Space,\nthey say, and think a several\ndimensioned locus. Mr.\nWarner cam...
# 596    The bland electricity, light blue wash\nair . . . colonies of the sun:\nPicasso’s Antibes\nimagine a new element.\nOutcasts! we are. But the smoot...
# 597    For the Good,\nil ben dell’ intelletto, the good of the people,\nthe soul’s good.\nI put aside\nwhatever I once served of the poet, master\nof enc...
# 598    John Adams, marginalia to Court de Gébelin’s Monde Primitif:\n“We see not the End. We can foresee no end\nof the weakness,\n“gnor{ance and corrupt...
# 599    like a woman\nbrought to childbirth—\ninexorable love. It is the necessity\nthat defies pleasure\nor caring. A destiny in all that we love,\na ble...
# 600    neither\nsky nor earth, without horizon it’s\na-\nnother tossing, continually in-\nreaking\nghosts of blackness or verdure\nthat here are\ndark wh...
# Name: poem_string, dtype: object

# %%
poems[poems.title == 'A Boat']
# Out:
#                   poet  \
# 116  Richard Brautigan
# 209  Richard Brautigan
#
#                                                                              poem_url  \
# 116                               https://www.poetryfoundation.org/poems/48576/a-boat
# 209  https://www.poetryfoundation.org/poetrymagazine/poems/56423/a-boat-56d238e754f45
#
#       title  \
# 116  A Boat
# 209  A Boat
#
#                                                                                                                                                 poem_lines  \
# 116  [O beautiful, was the werewolf, in his evil forest., We took him, to the carnival, and he started, crying, when he saw, the Ferris wheel., Electri...
# 209  [O beautiful, was the werewolf, in his evil forest., We took him, to the carnival, and he started, crying, when he saw, the Ferris wheel., Electri...
#
#                                                                                                                                                poem_string  \
# 116  O beautiful\nwas the werewolf\nin his evil forest.\nWe took him\nto the carnival\nand he started\ncrying\nwhen he saw\nthe Ferris wheel.\nElectric...
# 209  O beautiful\nwas the werewolf\nin his evil forest.\nWe took him\nto the carnival\nand he started\ncrying\nwhen he saw\nthe Ferris wheel.\nElectric...
#
#     genre
# 116  beat
# 209  beat

# %%
poems[poems.duplicated(subset=['poet', 'poem_string', 'genre'], keep=False)]
# Out:
#                     poet  \
# 116    Richard Brautigan
# 154       Allen Ginsberg
# 183       Allen Ginsberg
# 209    Richard Brautigan
# 589          Edward Dorn
# 590          Edward Dorn
# 2095     Wallace Stevens
# 2105     Wallace Stevens
# 2237     Wallace Stevens
# 2350          Hart Crane
# 2351          Hart Crane
# 2354          Hart Crane
# 2359          Hart Crane
# 2600   Edgar Lee Masters
# 2601   Edgar Lee Masters
# 2621      Marianne Moore
# 2625      Marianne Moore
# 2629      Marianne Moore
# 2836     Wallace Stevens
# 4386  William Wordsworth
# 4460  William Wordsworth
#
#                                                                                                                                                    poem_url  \
# 116                                                                                                     https://www.poetryfoundation.org/poems/48576/a-boat
# 154                                                                                                       https://www.poetryfoundation.org/poems/49303/howl
# 183                                                                                                       https://www.poetryfoundation.org/poems/49303/howl
# 209                                                                        https://www.poetryfoundation.org/poetrymagazine/poems/56423/a-boat-56d238e754f45
# 589                                                                              https://www.poetryfoundation.org/poetrymagazine/poems/30551/the-first-note
# 590                                                                     https://www.poetryfoundation.org/poetrymagazine/poems/30550/the-sundering-up-tracks
# 2095                                                                                https://www.poetryfoundation.org/poems/45235/the-snow-man-56d224a6d4e90
# 2105                                                                         https://www.poetryfoundation.org/poems/51648/anecdote-of-the-jar-56d22f87dc64f
# 2237                                                                        https://www.poetryfoundation.org/poetrymagazine/poems/14575/anecdote-of-the-jar
# 2350                                                                              https://www.poetryfoundation.org/poetrymagazine/poems/19922/the-urn-reply
# 
# 2625  Take all that is there and forfeit increment,\nIs a truth too clear for argument\nIn the old fairytale in which golden eggs were laid,\nOne a day....
# 2629  Take all that is there and forfeit increment,\nIs a truth too clear for argument\nIn the old fairytale in which golden eggs were laid,\nOne a day....
# 2836  One must have a mind of winter\nTo regard the frost and the boughs\nOf the pine-trees crusted with snow;\nAnd have been cold a long time\nTo behol...
# 4386  Five years have past; five summers, with the length\nOf five long winters! and again I hear\nThese waters, rolling from their mountain-springs\nWi...
# 4460  Five years have past; five summers, with the length\nOf five long winters! and again I hear\nThese waters, rolling from their mountain-springs\nWi...
#
#                genre
# 116             beat
# 154             beat
# 183             beat
# 209             beat
# 589   black_mountain
# 590   black_mountain
# 2095          modern
# 2105          modern
# 2237          modern
# 2350          modern
# 2351          modern
# 2354          modern
# 2359          modern
# 2600          modern
# 2601          modern
# 2621          modern
# 2625          modern
# 2629          modern
# 2836          modern
# 4386        romantic
# 4460        romantic

# %%
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=109&issue=6&page=9'

poems.loc[589,'poem_lines'] = scan_poem_scraper(actual_url, input_poet=poems.loc[589,'poet'], 
                                                input_title=poems.loc[589,'title'])['poem_lines']

poems.loc[589,'poem_string'] = scan_poem_scraper(actual_url, input_poet=poems.loc[589,'poet'], 
                                                input_title=poems.loc[589,'title'])['poem_string']

# %%
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=41&issue=4&page=7'

poems.loc[2350,'poem_lines'] = scan_poem_scraper(actual_url, input_poet=poems.loc[2350,'poet'], 
                                                input_title=poems.loc[2350,'title'])['poem_lines']

poems.loc[2350,'poem_string'] = scan_poem_scraper(actual_url, input_poet=poems.loc[2350,'poet'], 
                                                input_title=poems.loc[2350,'title'])['poem_string']

# %%
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=41&issue=4&page=6'

poems.loc[2351,'poem_lines'] = scan_poem_scraper(actual_url, input_poet=poems.loc[2351,'poet'], 
                                                input_title=poems.loc[2351,'title'])['poem_lines']

poems.loc[2351,'poem_string'] = scan_poem_scraper(actual_url, input_poet=poems.loc[2351,'poet'], 
                                                input_title=poems.loc[2351,'title'])['poem_string']

# %%
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=41&issue=4&page=2'

poems.loc[2354,'poem_lines'] = scan_poem_scraper(actual_url, input_poet=poems.loc[2354,'poet'], 
                                                input_title=poems.loc[2354,'title'])['poem_lines']

poems.loc[2354,'poem_string'] = scan_poem_scraper(actual_url, input_poet=poems.loc[2354,'poet'], 
                                                input_title=poems.loc[2354,'title'])['poem_string']

# %%
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=41&issue=4&page=10'

poems.loc[2359,'poem_lines'] = scan_poem_scraper(actual_url, input_poet=poems.loc[2359,'poet'], 
                                                input_title=poems.loc[2359,'title'])['poem_lines']

poems.loc[2359,'poem_string'] = scan_poem_scraper(actual_url, input_poet=poems.loc[2359,'poet'], 
                                                input_title=poems.loc[2359,'title'])['poem_string']

# %%
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=83&issue=6&page=2'

poems.loc[2621,'poem_lines'] = scan_poem_scraper(actual_url, input_poet=poems.loc[2621,'poet'], 
                                                input_title=poems.loc[2621,'title'])['poem_lines']

poems.loc[2621,'poem_string'] = scan_poem_scraper(actual_url, input_poet=poems.loc[2621,'poet'], 
                                                input_title=poems.loc[2621,'title'])['poem_string']

# %%
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=83&issue=6&page=3'

poems.loc[2629,'poem_lines'] = scan_poem_scraper(actual_url, input_poet=poems.loc[2629,'poet'], 
                                                input_title=poems.loc[2629,'title'])['poem_lines']

poems.loc[2629,'poem_string'] = scan_poem_scraper(actual_url, input_poet=poems.loc[2629,'poet'], 
                                                input_title=poems.loc[2629,'title'])['poem_string']

# %%
poems.drop_duplicates(subset=['poet', 'poem_string', 'genre'], inplace=True)

# %%
poempara_rescraper('https://www.poetryfoundation.org/poems/57369/the-send-off')
# Out:
# (['Down the close, darkening lanes they sang their way',
#   'To the siding-shed,',
#   'And lined the train with faces grimly gay.',
#   '',
#   'Their breasts were stuck all white with wreath and spray',
#   "As men's are, dead.",
#   '',
#   'Dull porters watched them, and a casual tramp',
#   'Stood staring hard,',
#   'Sorry to miss them from the upland camp.',
#   'Then, unmoved, signals nodded, and a lamp',
#   'Winked to the guard.',
#   '',
#   'So secretly, like wrongs hushed-up, they went.',
#   'They were not ours:',
#   'We never heard to which front these were sent.',
#   '',
#   'Nor there if they yet mock what women meant',
#   'Who gave them flowers.',
#   '',
#   'Shall they return to beatings of great bells',
#   'In wild trainloads?',
#   'A few, a few, too few for drums and yells,',
#   'May creep back, silent, to still village wells',
#   'Up half-known roads.'],
#  "Down the close, darkening lanes they sang their way\nTo the siding-shed,\nAnd lined the train with faces grimly gay.\n\nTheir breasts were stuck all white with wreath and spray\nAs men's are, dead.\n\nDull porters watched them, and a casual tramp\nStood staring hard,\nSorry to miss them from the upland camp.\nThen, unmoved, signals nodded, and a lamp\nWinked to the guard.\n\nSo secretly, like wrongs hushed-up, they went.\nThey were not ours:\nWe never heard to which front these were sent.\n\nNor there if they yet mock what women meant\nWho gave them flowers.\n\nShall they return to beatings of great bells\nIn wild trainloads?\nA few, a few, too few for drums and yells,\nMay creep back, silent, to still village wells\nUp half-known roads.")

# %%
poems[poems.duplicated(subset=['poet', 'poem_string'], keep=False)].head(20)
# Out:
#                    poet  \
# 743     W. D. Snodgrass
# 1231  Richard Aldington
# 1270         Ezra Pound
# 1271         Ezra Pound
# 1272         Ezra Pound
# 1273         Ezra Pound
# 1274         Ezra Pound
# 1275         Ezra Pound
# 1276         Ezra Pound
# 1277         Ezra Pound
# 1278         Ezra Pound
# 1279         Ezra Pound
# 1280         Ezra Pound
# 1281         Ezra Pound
# 1282         Ezra Pound
# 1283         Ezra Pound
# 1284         Ezra Pound
# 1285             Li Bai
# 1286         Ezra Pound
# 1287         Ezra Pound
#
#                                                                                           poem_url  \
# 743                                https://www.poetryfoundation.org/poems/52643/song-56d2314775fcc
# 1231                                        https://www.poetryfoundation.org/poems/53969/le-maudit
# 1270                                          https://www.poetryfoundation.org/poems/54314/canto-i
# 1271                                 https://www.poetryfoundation.org/poems/52318/cantico-del-sole
# 1272                          https://www.poetryfoundation.org/poems/54317/canto-xvi-56d234860e2a1
# 1273                                   https://www.poetryfoundation.org/poems/54321/from-canto-cxv
# 1274                     https://www.poetryfoundation.org/poems/44915/hugh-selwyn-mauberley-part-i
# 1275                          https://www.poetryfoundation.org/poems/54315/canto-iii-56d234851afde
# 1276                    https://www.poetryfoundation.org/poems/57353/hugh-selwyn-mauberley-part-ii
# 1277                                      https://www.poetryfoundation.org/poems/54320/canto-lxxxi
# 1278                                      https://www.poetryfoundation.org/poems/54318/canto-xxxvi
# 1279                                       https://www.poetryfoundation.org/poems/46478/a-virginal
# 1280                              https://www.poetryfoundation.org/poems/44914/envoi-56d2243243e40
# 1281                                     https://www.poetryfoundation.org/poems/44917/the-seafarer
# 1282                                        https://www.poetryfoundation.org/poems/54319/canto-xlv
# 1283                               https://www.poetryfoundation.org/poems/51550/paganis-november-8
# 1284                                https://www.poetryfoundation.org/poems/53967/sestina-altaforte
# 1285                       https://www.poetryfoundation.org/poems/48687/the-jewel-stairs-grievance
# 1286  https://www.poetryfoundation.org/poems/47692/the-river-merchants-wife-a-letter-56d22853677f9
# 1287                              https://www.poetryfoundation.org/poems/44916/portrait-dune-femme
#
#                                     title  \
# 743                                  Song
# 1231                            Le Maudit
# 1270                              Canto I
# 1271                     Cantico del Sole
# 1286       imagist
# 1287       imagist

# %%
poems_double_backup = poems.copy()

# %%
poems.shape
# Out:
# (5151, 6)

# %%
rial_mod_ind = list(poems[(poems.poet == 'Richard Aldington') & (poems.genre == 'modern')].index)

poems.drop(rial_mod_ind, inplace=True)

poems.shape
# Out:
# (5048, 6)

# %%
poems[poems.poet == 'Li Bai']
# Out:
#         poet  \
# 1285  Li Bai
# 2003  Li Bai
#
#                                                                      poem_url  \
# 1285  https://www.poetryfoundation.org/poems/48687/the-jewel-stairs-grievance
# 2003  https://www.poetryfoundation.org/poems/48687/the-jewel-stairs-grievance
#
#                             title  \
# 1285  The Jewel Stairs’ Grievance
# 2003  The Jewel Stairs’ Grievance
#
#                                                                                                                                                  poem_lines  \
# 1285  [The jewelled steps are already quite white with dew,, It is so late that the dew soaks my gauze stockings,, And I let down the crystal curtain, A...
# 2003  [The jewelled steps are already quite white with dew,, It is so late that the dew soaks my gauze stockings,, And I let down the crystal curtain, A...
#
#                                                                                                                                                 poem_string  \
# 1285  The jewelled steps are already quite white with dew,\nIt is so late that the dew soaks my gauze stockings,\nAnd I let down the crystal curtain\nAn...
# 2003  The jewelled steps are already quite white with dew,\nIt is so late that the dew soaks my gauze stockings,\nAnd I let down the crystal curtain\nAn...
#
#         genre
# 1285  imagist
# 2003   modern

# %%
poems[poems.duplicated(subset=['poet', 'poem_string'], keep=False)].head(20)
# Out:
#                             poet  \
# 743              W. D. Snodgrass
# 1285                      Li Bai
# 2003                      Li Bai
# 2133  Henry Wadsworth Longfellow
# 2196       Guillaume Apollinaire
# 2197       Guillaume Apollinaire
# 2292       Guillaume Apollinaire
# 3478       Guillaume Apollinaire
# 3480       Guillaume Apollinaire
# 3529       Guillaume Apollinaire
# 4815  Henry Wadsworth Longfellow
# 4976             W. D. Snodgrass
#
#                                                                                    poem_url  \
# 743                         https://www.poetryfoundation.org/poems/52643/song-56d2314775fcc
# 1285                https://www.poetryfoundation.org/poems/48687/the-jewel-stairs-grievance
# 2003                https://www.poetryfoundation.org/poems/48687/the-jewel-stairs-grievance
# 2133      https://www.poetryfoundation.org/poems/44637/the-landlords-tale-paul-reveres-ride
# 2196             https://www.poetryfoundation.org/poetrymagazine/poems/58343/ocean-of-earth
# 2197                   https://www.poetryfoundation.org/poetrymagazine/poems/58342/the-lady
# 2292  https://www.poetryfoundation.org/poetrymagazine/poems/58341/the-seasons-56d23ca091a25
# 3478             https://www.poetryfoundation.org/poetrymagazine/poems/58343/ocean-of-earth
# 3480                   https://www.poetryfoundation.org/poetrymagazine/poems/58342/the-lady
# 3529  https://www.poetryfoundation.org/poetrymagazine/poems/58341/the-seasons-56d23ca091a25
# 4815      https://www.poetryfoundation.org/poems/44637/the-landlords-tale-paul-reveres-ride
# 4976                        https://www.poetryfoundation.org/poems/52643/song-56d2314775fc
# 4976  Sweet beast, I have gone prowling,\na proud rejected man\nwho lived along the edges\ncatch as catch can;\nin darkness and in hedges\nI sang my sou...
#
#                                genre
# 743                     confessional
# 1285                         imagist
# 2003                          modern
# 2133                          modern
# 2196                          modern
# 2197                          modern
# 2292                          modern
# 3478  new_york_school_2nd_generation
# 3480  new_york_school_2nd_generation
# 3529  new_york_school_2nd_generation
# 4815                       victorian
# 4976                       victorian

# %%
poems.drop([2003, 2133, 3478, 3480, 3529, 4976], inplace=True)

poems.shape
# Out:
# (5042, 6)

# %%
poems[poems.duplicated(subset=['poem_string'], keep=False)]
# Out:
#                  poet  \
# 4754    A. E. Housman
# 5142  Katharine Tynan
#
#                                                                                           poem_url  \
# 4754  https://www.poetryfoundation.org/poems/58269/a-shropshire-lad-52-far-in-a-western-brookland-
# 5142                           https://www.poetryfoundation.org/poems/57349/a-lament-56d23ac7ae84a
#
#                                                 title poem_lines poem_string  \
# 4754  A Shropshire Lad 52: Far in a western brookland        [ ]
# 5142                                         A Lament        [ ]
#
#           genre
# 4754  victorian
# 5142  victorian

# %%
poems.loc[988,'poem_lines'] = poempara_rescraper(poems.loc[988,'poem_url'])[0]
poems.loc[988,'poem_string'] = poempara_rescraper(poems.loc[988,'poem_url'])[1]

poems.loc[4754,'poem_lines'] = poempara_rescraper(poems.loc[4754,'poem_url'])[0]
poems.loc[4754,'poem_string'] = poempara_rescraper(poems.loc[4754,'poem_url'])[1]

poems.loc[5142,'poem_lines'] = poempara_rescraper(poems.loc[5142,'poem_url'])[0]
poems.loc[5142,'poem_string'] = poempara_rescraper(poems.loc[5142,'poem_url'])[1]

# %%
poems.to_csv('data/poems_df.csv')

# %%
poems_backup = poems.copy()

# %%
# uncomment to save
with gzip.open('data/poems_df.pkl', 'wb') as goodbye:
    pickle.dump(poems, goodbye, protocol=pickle.HIGHEST_PROTOCOL)

# uncomment to load
with gzip.open('data/poems_df.pkl', 'rb') as hello:
    poems_df = pickle.load(hello)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-559-ade99e464b71> in <module>
#       1 # uncomment to save
#       2 with gzip.open('data/poems_df.pkl', 'wb') as goodbye:
# ----> 3     pickle.dump(poems, goodbye, protocol=pickle.HIGHEST_PROTOCOL)
#       4
#       5 # uncomment to load
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/bs4/element.py in __getnewargs__(self)
#     633
#     634     def __getnewargs__(self):
# --> 635         return (str(self),)
#     636
#     637     def __getattr__(self, attr):
#
# RecursionError: maximum recursion depth exceeded while getting the str of an object

# %%
error_poems = error_poems_orig.copy()
len(error_poems)
# Out:
# 223

# %%
poems[poems.poet == 'Michael McClure']
# Out:
#                 poet  \
# 169  Michael McClure
# 170  Michael McClure
# 171  Michael McClure
# 172  Michael McClure
# 218  Michael McClure
# 219  Michael McClure
#
#                                                                                poem_url  \
# 169      https://www.poetryfoundation.org/poems/54613/dream-the-night-of-december-23rd-
# 170                            https://www.poetryfoundation.org/poems/54612/the-chamber
# 171       https://www.poetryfoundation.org/poems/54614/mexico-seen-from-the-moving-car-
# 172                https://www.poetryfoundation.org/poems/54611/the-mystery-of-the-hunt
# 218  https://www.poetryfoundation.org/poetrymagazine/poems/26838/2-for-theodore-roethke
# 219               https://www.poetryfoundation.org/poetrymagazine/poems/29414/the-child
#
#                                    title  \
# 169  Dream: The Night of December 23rd ﻿
# 170                          The Chamber
# 171    Mexico Seen from the Moving Car ﻿
# 172              The Mystery of the Hunt
# 218               2 For Theodore Roethke
# 219                            The Child
#
#                                                                                                                                                 poem_lines  \
# 169  [—ALL  HUGE LIKE GIANT FLIGHTLESS KIWIS TWICE THE, SIZE OF OSTRICHES,, they turned and walked away from us, and you were there Jane and you were t...
# 170  [IN LIGHT ROOM IN DARK HELL IN UMBER IN CHROME,, I sit feeling the swell of the cloud made about by movement, of arm leg and tongue. In reflection...
# 171  [THERE ARE HILLS LIKE SHARKFINS, and clods of mud., The mind drifts through, in the shape of a museum,, in the guise of a museum, dreaming dead fr...
# 172  [It’s the mystery of the hunt that intrigues me,, That drives us like lemmings, but cautiously—, The search for a bright square cloud—the scent of...
# 218  [PREMONITION, My bones ascend by arsenics of sight., Where noise is all the sound there is to hear,, Beginning in the heart I work towards light.,...
# 219  [Who were the Lion Men who walked in my dreams, when I was a fat and sleeping babe, in a room whose walls were miracles?, Who were the lion men wi...
#
#                                                                                                                                                poem_string  \
# 169  —ALL  HUGE LIKE GIANT FLIGHTLESS KIWIS TWICE THE\nSIZE OF OSTRICHES,\nthey turned and walked away from us\nand you were there Jane and you were tw...
# 170  IN LIGHT ROOM IN DARK HELL IN UMBER IN CHROME,\nI sit feeling the swell of the cloud made about by movement\nof arm leg and tongue. In reflections...
# 171  THERE ARE HILLS LIKE SHARKFINS\nand clods of mud.\nThe mind drifts through\nin the shape of a museum,\nin the guise of a museum\ndreaming dead fri...
# 172  It’s the mystery of the hunt that intrigues me,\nThat drives us like lemmings, but cautiously—\nThe search for a bright square cloud—the scent of ...
# 218  PREMONITION\nMy bones ascend by arsenics of sight.\nWhere noise is all the sound there is to hear,\nBeginning in the heart I work towards light.\n...
# 219  Who were the Lion Men who walked in my dreams\nwhen I was a fat and sleeping babe\nin a room whose walls were miracles?\nWho were the lion men wit...
#
#     genre
# 169  beat
# 170  beat
# 171  beat
# 172  beat
# 218  beat
# 219  beat

# %%
poems.loc[574, 'poem_string']
# Out:
# 'I\nIt is possible, in words, to speak\nof what has happened—a sense\nof there and here, now\nand then. It is some other\nway of being, prized enough,\nthat it makes a common\nground. Once\nyou were\nalone and I\nmet you. It was late\nat night.\nT never'

# %%
scan_poem_scraper(poems.loc[574, 'poem_url'])
# Out:
# {'poet': 'Robert Creeley',
#  'poem_url': 'https://www.poetryfoundation.org/poetrymagazine/poems/30524/enough-56d214013c576',
#  'title': 'Enough',
#  'poem_lines': ['I',
#   'It is possible, in words, to speak',
#   'of what has happened—a sense',
#   'of there and here, now',
#   'and then. It is some other',
#   'way of being, prized enough,',
#   'that it makes a common',
#   'ground. Once',
#   'you were',
#   'alone and I',
#   'met you. It was late',
#   'at night.',
#   'T never'],
#  'poem_string': 'I\nIt is possible, in words, to speak\nof what has happened—a sense\nof there and here, now\nand then. It is some other\nway of being, prized enough,\nthat it makes a common\nground. Once\nyou were\nalone and I\nmet you. It was late\nat night.\nT never'}

# %%
text = pytesseract.image_to_string('data/temp.png')
text

#  'https://www.poetryfoundation.org/poetrymagazine/poems/12960/ollie-mgee',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/21466/walking-sticks-and-paperweights-and-watermarks',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14339/shades-of-callimachus',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/13065/exiles-letter-tr-by-ezra-pound',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/13497/paganis',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/12926/amities',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/22310/poem-after-the-wrestling',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/15533/lenvoi',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/17874/discus-thrower',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/20683/conjunctions',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/27246/to-redoute',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/33672/poem-green-things-are-flowers',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30246/poem-to-simply-talk',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30775/sonnet-five-am-on-east-fourteenth',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30549/poem-like-musical-instruments',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30723/jungle-56d21432117a5',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30789/fall-56d21442f2ddc',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30138/consider-at-the-outset',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30790/smile-to-see-the-lake',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29475/now-in-one-year',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30140/spring-stood-there',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30139/march-56d213a2b802b',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30141/the-park-a-darling-walk',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29745/giovannis-rape-of-the-sabine-women-at-wildensteins',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/19125/1930s',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/19941/the-squads-platoons',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/19940/along-the-flat-roofs',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/31024/a-21-rudens-act-iii',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/19141/a0151seventh-movement',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30768/a-19',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/26578/je-faisois-ces-sonnets-tr-by-george-dillon',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28076/brucio-e-limminenza-lombra-che-sale-riconosco']

# %%
# %%time

simple_rescrapes = []
still_errors = []
for url in tqdm(error_poems):
    try:
        info = scan_poem_scraper(url)
        info['poem_url'] = url
        info['genre'] = ''
        simple_rescrapes.append(info)
    except:
        still_errors.append(url)
# Out:
# 100%|██████████| 102/102 [05:06<00:00,  3.00s/it]
# CPU times: user 14.6 s, sys: 45.9 s, total: 1min
# Wall time: 5min 6s

# %%
simple_rescrapes
# Out:
# [{'poet': 'John Berryman',
#   'poem_url': 'https://www.poetryfoundation.org/poetrymagazine/poems/29169/spellbound-held-subtle-henry',
#   'title': 'Spellbound Held Subtle Henry',
#   'poem_lines': ['the little people spread, & did friendly things;',
#    'then he was glad.',
#    'Pleased, at the worst, except with man, he shook',
#    'the brightest winter sun.',
#    'All the green lives',
#    'of the great delta, hours, hurt his migrant heart',
#    'in a safety of the steady plane. Please, please',
#    'come.',
#    "My friends,—he has been known to mourn,—I'll die;",
#    'live you, in the most wild, kindly, green',
#    'partly forgiving wood,',
#    'sort of forever and all those human sings',
#    'close not your better ears to, while good Spring',
#    'returns with a dance and a sigh.',
#    'i',
#    'Henry’s pelt was put on sundry walls',
#    'where it did much resemble Henry and',
#    'them persons was delighted.'],
#   'poem_string': "the little people spread, & did friendly things;\nthen he was glad.\nPleased, at the worst, except with man, he shook\nthe brightest winter sun.\nAll the green lives\nof the great delta, hours, hurt his migrant heart\nin a safety of the steady plane. Please, please\ncome.\nMy friends,—he has been known to mourn,—I'll die;\nlive you, in the most wild, kindly, green\npartly forgiving wood,\nsort of forever and all those human sings\nclose not your better ears to, while good Spring\nreturns with a dance and a sigh.\ni\nHenry’s pelt was put on sundry walls\nwhere it did much resemble Henry and\nthem persons was delighted.",
#   'genre': ''},
#  {'poet': 'John Berryman',
#   'poem_url': 'https://www.poetryfoundation.org/poetrymagazine/poems/29525/viii-he-yelled-at-me-in-greek',
#   'title': 'Viii He Yelled At Me In Greek',
#   'poem_lines': ['my God!—It’s not his language',
#    'and I’m no good at—his is Aramaic,',
#    'was—I am a monoglot of English',
#    '(American version) and, say pieces from',
#    'a baker’s dozen others: where’s the bread?',
#    'but rising in the Second Gospel, pal:',
#    'seed goes down, god dies,',
#    'a rising happens,',
#    'some crust, and then occurs an eating. He said so,',
#    'a Greek idea,',
#    'troublesome to imaginary Jews,',
#    'like bitter Henry, full of the death of love,',
#    'Cawdor-uneasy, disambitious, mourning',
#    'the whole implausible necessary thing.',
#    'He dropped his voice & sybilled of',
#    'the death of the death of love.',
#    'I dught to get going.'],
#   'poem_string': 'my God!—It’s not his language\nand I’m no good at—his is Aramaic,\nwas—I am a monoglot of English\n(American version) and, say pieces from\na baker’s dozen others: where’s the bread?\nbut rising in the Second Gospel, pal:\nseed goes down, god dies,\na rising happens,\nsome crust, and then occurs an eating. He said so,\na Greek idea,\ntroublesome to imaginary Jews,\nlike bitter Henry, full of the death of love,\nCawdor-uneasy, disambitious, mourning\nthe whole implausible necessary thing.\nHe dropped his voice & sybilled of\nthe death of the death of love.\nI dught to get going.',
#   'genre': ''},
#  {'poet': 'John Berryman',
#   'poem_url': 'https://www.poetryfoundation.org/poetrymagazine/poems/29166/the-greens-of-the-ganges',
#   'title': 'The Greens Of The Ganges',
#   'poem_lines': ['Of heartless youth made late aware he pled:',
#    'Brownies, please come.',
#    'To Henry in his sparest times sometimes',
#    'the little people spread, & did friendly things;',
#    'then he was glad.',
#    'Pleased, at the worst, except with man, he shook',
#    'the brightest winter sun.',
#    'All the green lives',
#    'of the great delta, hours, hurt his migrant heart',
#    'in a safety of the steady plane. Please, please',
#    'come.',
#    "My friends,—he has been known to mourn,—I'll die;",
#    'live you, in the most wild, kindly, green',
#    'partly forgiving wood,',
#    'sort of forever and all those human sings',
#    'close not your better ears to, while good Spring',
#    'returns with a dance and a sigh.',
#    'i',
#    'Henry’s pelt was put on sundry walls',
#    'where it did much resemble Henry and',
#    'them persons was delighted.'],
#   'poem_string': "Of heartless youth made late aware he pled:\nBrownies, please come.\nTo Henry in his sparest times sometimes\nthe little people spread, & did friendly things;\nthen he was glad.\nPleased, at the worst, except with man, he shook\nthe brightest winter sun.\nAll the green lives\nof the great delta, hours, hurt his migrant heart\nin a safety of the steady plane. Please, please\ncome.\nMy friends,—he has been known to mourn,—I'll die;\nlive you, in the most wild, kindly, green\npartly forgiving wood,\nsort of forever and all those human sings\nclose not your better ears to, while good Spring\nreturns with a dance and a sigh.\ni\nHenry’s pelt was put on sundry walls\nwhere it did much resemble Henry and\nthem persons was delighted.",
#   'genre': ''},
#  {'poet': 'Robert Lowell',
#   'poem_url': 'https://www.poetryfoundation.org/poetrymagazine/poems/29552/you-search-in-rome-for-rome',
#   'title': 'You Search In Rome For Rome',
#   'poem_lines': ['You search in Rome for Rome? Oh traveller!',
#    'In Rome itself there is no room for Rome,',
#    'a corpse is all its churches put on show,',
#    'the Aventine is its own mound and tomb.',
#    'There, where the Palatifle once towered and reigned,',
#    'are medals ruined by the hands of time,',
#    'they show how more was lost to chance and time',
#    'than Hannibal or Caesar could consume.',
#    'The Tiber flows still, but its current guards',
#    'a city that has fallen in its grave—',
#    'each wave’s a woman tearing at her breast.',
#    'Oh Rome! From all your beauty, all your grandeur,',
#    'whatever once was firm has fled . . . what once',
#    'was fugitive maintains its permanence.'],
#   'poem_string': 'You search in Rome for Rome? Oh traveller!\nIn Rome itself there is no room for Rome,\na corpse is all its churches put on show,\nthe Aventine is its own mound and tomb.\nThere, where the Palatifle once towered and reigned,\nare medals ruined by the hands of time,\nthey show how more was lost to chance and time\nthan Hannibal or Caesar could consume.\nThe Tiber flows still, but its current guards\na city that has fallen in its grave—\neach wave’s a woman tearing at her breast.\nOh Rome! From all your beauty, all your grandeur,\nwhatever once was firm has fled . . . what once\nwas fugitive maintains its permanence.',
#   'genre': ''},
#  {'poet': 'Allen Tate',
#   'poem_url': 'https://www.poetryfoundation.org/poetrymagazine/poems/19715/in-ukraine',
#   'title': 'In Ukraine',
#   'poem_lines': ['Double Dealer appeared some translations by him of',
#    'Laforgue, which seemed to me very fine; I looked up pre-',
#    'vious numbers of the magazine, and found Black Tam-',
#    'bourine, an early poem that contained some of the char-',
#    'acteristic features of his later and mature style. I had',
#    'seen nothing like it in Anglo-American poetry. From that',
#    'time until his death one could trace the development of a',
#    'poetry which, though similar in some technical respects to',
#    'French Symbolism, is now a distinct contribution to',
#    'American literature. It is a poetry that could have been',
#    'written only in this country and in this age.',
#    'Crane committed suicide on April 28, 1932, by jumping',
#    'off the S. S. Orizaba bound from Vera Cruz to New York.',
#    'Why he did it no one will ever know. He had recently',
#    'heard that his father’s estate in Cleveland, from which he',
#    'derived an income, was bankrupt: a year ago he told a',
#    'friend in New York that his work was at anend. In the',
#    'summer of 1930 he wrote to me that he feared his most',
#    'ambitious work, The Bridge, was not quite perfectly',
#    'realized, that probably his soundest work was in the',
#    'shorter pieces of White Buildings, but that his mind being',
#    'committed to the larger undertaking could never return to',
#    'the purely lyrical and more fragmentary vision. He had',
#    'an extraordinary insight into the foundations of his work,',
#    'and I think this judgment of it will never be refuted.',
#    'If he had lived another month my acquaintance with',
#    'him would have covered exactly ten years. In most of',
#    'that time I was either in frequent correspondence with him',
#    'or lived near him in New York; from 1922 to 1928, when I',
#    'went abroad and saw him and heard from him irregularly',
#    'until his death, I could observe the development of his',
#    'style from poem to poem; and his letters—always written',
#    'in a pure and lucid prose—provide a valuable commentary',
#    'on his career. This is not the time to bring all this',
#    'material together for judgment. As I look back upon his',
#    'work and its relation to the life he lived, a general state-',
#    'ment about it occurs to me, which may throw some light',
#    'on the dissatisfaction that he felt with his career.',
#    'The Bridge is presumably an epic. How early he had',
#    'conceived the idea of the poem, and the leading symbol-',
#    'ism, it is difficult to know; probably early in 1924. Up to',
#    'that time, with the exception of For the Marriage of',
#    'Faustus and Helen (1922), he had written only short poems,',
#    'but most of them—Praise for an Urn, Black Tambourine,',
#    'Paraphrase, and Emblems of Conduct, are among his finest',
#    'works. It is a mistake to suppose that all of White Build-',
#    'ings is early experimental writing; a large portion of that',
#    'volume, and perhaps the least successful part of it, is',
#    'made up of poems written after The Bridge was begun.',
#    'Praise for an Urn was written in the spring of 1922—one of',
#    'the finest elegies ever written by an American poet—and',
#    'although his later development gave us a poetry that the',
#    'period would be much the less rich for not having, he never',
#    'again had such perfect mastery of his subject. And I think',
#    'this was because he never afterwards knew precisely what',
#    'his subject was. That is why The Bridge is such a magnifi-',
#    'cent failure: a great talent is engaged upon the problem',
#    'of stating a position that is fundamentally incapable of',
#    'definition.',
#    'Readers familiar with For the Marriage of Faustus and',
#    'Helen have always admired it by passages, but the whole',
#    'conception of the poem, logically speaking, is an abstrac-',
#    'tion empty of any well-defined experience, and in its',
#    'verbal properties it is a conventional revival of the kind',
#    'of symbolism that a young poet picks up in his first read-',
#    'ing. Crane, I believe, felt that this was so; and he became',
#    'so dissatisfied, not only with the style of the poem, which',
#    'is heavily influenced by Eliot and Laforgue, but with the',
#    '“literary” character of the symbolism, that he set about',
#    'the greater task of writing The Bridge. He looked upon',
#    'his Faustus and Helen as an answer to the historical',
#    'pessimism of the school of Eliot, and The Bridge was to be',
#    'an even more complete answer.',
#    'There was a fundamental mistake in Crane’s diagnosis',
#    'of Eliot’s problem. Eliot’s “‘pessimism” grows out of an',
#    'awareness of the decay of the individual consciousness and',
#    'its fixed relations to the world; but Crane thought that it',
#    'was due to something like pure “orneryness,” an unwilling-',
#    'ness “‘to share with us the breath released,” a new kind of',
#    'freedom which he identified emotionally with the age of',
#    'the machine. This vagueness of purpose, in spite of the',
#    'apparently concrete character of the Brooklyn Bridge,',
#    'which became the symbol of his epic, he never succeeded in',
#    'correcting. The “bridge” stands for no well-defined',
#    'experience; it differs from the Helen and Faust symbols',
#    'only in its unliterary origin. I think Crane was deceived',
#    'by this, and by the fact that Brooklyn Bridge is “modern”',
#    'anda fine piece of “mechanics.” His more ambitious later',
#    'project permitted him no greater degree of self-definition',
#    'than the more literary symbolism of his youth.',
#    'It has always seemed to me that by testing out his',
#    'capacity to construct a great objective piece of work, in',
#    'which his own definition of himself should have been per-',
#    'fectly articulated, he brought his work to anend. I think',
#    'he knew that the framework of The Bridge was finally',
#    'incoherent, and for that reason—as I have said—he could',
#    'no longer believe in even his lyrical powers; he could not',
#    'return to the early work and take it up where he had left',
#    'off. Far from “refuting” Eliot, his whole career is a',
#    'vindication of Eliot’s major premise—that the integrity of',
#    'the individual consciousness has broken down. In the final',
#    'analysis, Crane had, in his later work, no individual con-',
#    'sciousness: the hard firm style of Praise for an Urn, which',
#    'is based upon a clear-cut definition of personal relations,',
#    'and the ultimate inviolability of persons, begins to dis-',
#    'appear when the poet goes out into the world and finds',
#    'that the simplicity of his early world has no universal',
#    'sanction. From then on, instead of the effort to define',
#    'himself in the midst of overwhelming complications—a',
#    'situation that might have produced a tragic poet—we',
#    'that he falls back upon the intensity of consciousness,',
#    'rather than the clarity, for his center of writing; and this',
#    'is simply romanticism.',
#    'His world had no center, and the compensatory action',
#    'that he took is responsible for the fragmentary quality of',
#    'his most ambitious work. This action took two forms—',
#    'the blind assertion of the will, and the blind desire for self-',
#    'destruction. In either case, the poet will not face his first',
#    'problem, which is to define the limits of his personality and',
#    'to discover its moral properties in an appropriate symbol-',
#    'ism. He can only assert a quality of will against the world,',
#    'and at each successive failure of the will he can only turn',
#    'upon himself. In the failure of understanding—and under-',
#    'standing, for Dante, was a way of love—the romantic',
#    'modern poet of the age of science attempts to impose his',
#    'will upon experience and to possess the world.',
#    'It is this impulse of the modern period that has given us',
#    'the greatest romantic poetry: Crane instinctively con-',
#    'tinued the conception of the will that was the deliberate',
#    'discovery of Rimbaud. A poetry of the will is a poetry of',
#    'sensation, for the poet surrenders to his sensations of the',
#    'object i in his effort to identify himself with it, and to own',
#    'it. Some of Crane’s finest lyrics—those written in the',
#    'period of The Bridge—carry the modern impulse as far as',
#    'you will find it anywhere in the French romantics.',
#    'Lachrymae Christi and Passage, for example, though on the',
#    'surface pure imagery without “philosophical” meaning of',
#    'the explicit sort in The Bridge, are the lyrical equivalents',
#    'of the epic: it is the same mechanism of the sensibility; the',
#    'one defines the other. The implicit grasp of his material',
#    'that we find in Praise for an Urn, the poet has exchanged',
#    'for an external random symbol that has no possibility of',
#    'definition. It is an irrational symbol of the will, of con-',
#    'quest, of blind ack Passage,',
#    'whose lack of symbolism shows the poetry of the will on',
#    'the plane of sensation, which is the self-destructive return',
#    'of the will upon it:',
#    'In the last generation American criticism has had much',
#    'to say of the frustration of American writers. The',
#    'assumption seems always to be that their defeat has been',
#    'due to failure to accept American life. If there is any',
#    'American life distinct from the main idea of western',
#    'civilization, their failure has been due to their accepting it',
#    'too fully. It is a heresy that rises in a revolt against the',
#    'traditional organization of the consciousness—for which',
#    'the only substitute offered is the assertion of the will. We',
#    'hear that Americans are not rooted in the soil, that they',
#    'must get rid of the European past before they can be',
#    'rooted. That is untrue: the only Americans who have ever',
#    'been rooted in the American soil have lived on the',
#    'European system, socially and spiritually.',
#    'Crane was the archetype of the modern American poet,',
#    'whose fundamental mistake lay in thinking that an',
#    'irrational surrender of the intellect to the will would be the',
#    'basis of a new mentality. His life and his work could have',
#    'been lived and written only in modern times, particularly',
#    'since 1870. All the accidental features of his career, his',
#    'early life, his education, fitted him for the réle. His sensa-',
#    'tional death was morally appropriate, and I think it has',
#    'some significance as a symbol of the “American” mind.',
#    'Those who knew Hart long and well will remember an un-',
#    'searchable integrity of purpose in his craft. His devotion',
#    'to it was so perfect that no one need be surprised at the',
#    'courage with which he brought his work to its logical con-',
#    'clusion of personal violence. After he had lost the instinct',
#    'for self-definition, and later, after the exploration of his',
#    'symbol of the will had brought him back upon himself, he',
#    'might have continued to breathe, but he would no longer',
#    'have been alive. Allen Tate'],
#   'poem_string': 'Double Dealer appeared some translations by him of\nLaforgue, which seemed to me very fine; I looked up pre-\nvious numbers of the magazine, and found Black Tam-\nbourine, an early poem that contained some of the char-\nacteristic features of his later and mature style. I had\nseen nothing like it in Anglo-American poetry. From that\ntime until his death one could trace the development of a\npoetry which, though similar in some technical respects to\nFrench Symbolism, is now a distinct contribution to\nAmerican literature. It is a poetry that could have been\nwritten only in this country and in this age.\nCrane committed suicide on April 28, 1932, by jumping\noff the S. S. Orizaba bound from Vera Cruz to New York.\nWhy he did it no one will ever know. He had recently\nheard that his father’s estate in Cleveland, from which he\nderived an income, was bankrupt: a year ago he told a\nfriend in New York that his work was at anend. In the\nsummer of 1930 he wrote to me that he feared his most\nambitious work, The Bridge, was not quite perfectly\nrealized, that probably his soundest work was in the\nshorter pieces of White Buildings, but that his mind being\ncommitted to the larger undertaking could never return to\nthe purely lyrical and more fragmentary vision. He had\nan extraordinary insight into the foundations of his work,\nand I think this judgment of it will never be refuted.\nIf he had lived another month my acquaintance with\nhim would have covered exactly ten years. In most of\nthat time I was either in frequent correspondence with him\nor lived near him in New York; from 1922 to 1928, when I\nwent abroad and saw him and heard from him irregularly\nuntil his death, I could observe the development of his\nstyle from poem to poem; and his letters—always written\nin a pure and lucid prose—provide a valuable commentary\non his career. This is not the time to bring all this\nmaterial together for judgment. As I look back upon his\nwork and its relation to the life he lived, a general state-\nment about it occurs to me, which may throw some light\non the dissatisfaction that he felt with his career.\nThe Bridge is presumably an epic. How early he had\nconceived the idea of the poem, and the leading symbol-\nism, it is difficult to know; probably early in 1924. Up to\nthat time, with the exception of For the Marriage of\nFaustus and Helen (1922), he had written only short poems,\nbut most of them—Praise for an Urn, Black Tambourine,\nParaphrase, and Emblems of Conduct, are among his finest\nworks. It is a mistake to suppose that all of White Build-\nings is early experimental writing; a large portion of that\nvolume, and perhaps the least successful part of it, is\nmade up of poems written after The Bridge was begun.\nPraise for an Urn was written in the spring of 1922—one of\nthe finest elegies ever written by an American poet—and\nalthough his later development gave us a poetry that the\nperiod would be much the less rich for not having, he never\nagain had such perfect mastery of his subject. And I think\nthis was because he never afterwards knew precisely what\nhis subject was. That is why The Bridge is such a magnifi-\ncent failure: a great talent is engaged upon the problem\nof stating a position that is fundamentally incapable of\ndefinition.\nReaders familiar with For the Marriage of Faustus and\nHelen have always admired it by passages, but the whole\nconception of the poem, logically speaking, is an abstrac-\ntion empty of any well-defined experience, and in its\nverbal properties it is a conventional revival of the kind\nof symbolism that a young poet picks up in his first read-\ning. Crane, I believe, felt that this was so; and he became\nso dissatisfied, not only with the style of the poem, which\nis heavily influenced by Eliot and Laforgue, but with the\n“literary” character of the symbolism, that he set about\nthe greater task of writing The Bridge. He looked upon\nhis Faustus and Helen as an ans ...
#   'genre': ''},
#  {'poet': 'Allen Tate',
#   'poem_url': 'https://www.poetryfoundation.org/poetrymagazine/poems/34386/the-swimmers-56d217cb70e3f',
#   'title': 'The Swimmers',
#   'poem_lines': ['To waters under the bs Kentucky sun,',
#    'His little friends ie an him, seeing',
#    '£3. shadows of, the grapevine wriggle and run',
#    'Over the ‘Eee “swirl; mujlein under the ear',
#    "B. Soft as Nausicaa's eweet—ee fun",
#    "childhood's thin harmonious tear:",
#    'EO',
#    'Replenish me the cause of love and fear',
#    'And give me back the eye to see it jn',
#    'As yin the',
#    'Pige~,. ies of the moccasin.',
#    'Tit',
#    ' ',
#    'Borg H, tuk KRorowd ws',
#    'nt hin open vy 4b',
#    'Ace Xokinn, ela tay lek , tee, Vr Fre',
#    'Ki hme, AerA, Marry Late aclu ployd',
#    'TA, Far, ued? TOG tt, log writ, bog hain',
#    ' ',
#    'een:',
#    ' '],
#   'poem_string': "To waters under the bs Kentucky sun,\nHis little friends ie an him, seeing\n£3. shadows of, the grapevine wriggle and run\nOver the ‘Eee “swirl; mujlein under the ear\nB. Soft as Nausicaa's eweet—ee fun\nchildhood's thin harmonious tear:\nEO\nReplenish me the cause of love and fear\nAnd give me back the eye to see it jn\nAs yin the\nPige~,. ies of the moccasin.\nTit\n \nBorg H, tuk KRorowd ws\nnt hin open vy 4b\nAce Xokinn, ela tay lek , tee, Vr Fre\nKi hme, AerA, Marry Late aclu ployd\nTA, Far, ued? TOG tt, log writ, bog hain\n \neen:\n ",
#   'genre': ''},
#  {'poet': 'Langston Hughes',
#   'poem_url': 'https://www.poetryfoundation.org/poetrymagazine/poems/19426/god-56d20b580c612',
#   'title': 'God',
#   'poem_lines': ['Without one friend,',
#    'Alone in my purity',
#    'World without end.',
#    'Below me young lovers',
#    'Tread the sweet ground—',
#    'But I am God—',
#    'T cannot come down.',
#    'Spring!',
#    'Life is love!',
#    'Love is life only!',
#    'Better to be human',
#    'Than God—and lonely.',
#    'Langston Hughes'],
#   'poem_string': 'Without one friend,\nAlone in my purity\nWorld without end.\nBelow me young lovers\nTread the sweet ground—\nBut I am God—\nT cannot come down.\nSpring!\nLife is love!\nLove is life only!\nBetter to be human\nThan God—and lonely.\nLangston Hughes',
#   'genre': ''},
#  {'poet': 'H. D.',
#   'poem_url': 'https://www.poetryfoundation.org/poetrymagazine/poems/15346/song-you-are-as-gold',
#   'title': 'Song You Are As Gold',
#   'poem_lines': ['Is love’s gift loveliest?',
#    'I know not what to do,',
#    'Now sleep has pressed',
#    'Weight on your eyelids.',
#    'Shall I break your rest,',
#    'Devouring, eager?',
#    'Is love’s gift best ?—',
#    'Nay, song’s the loveliest.',
#    'Yet, were you lost,',
#    'What.rapture could I take from song?—',
#    'What song were left?',
#    'I know not what to do:',
#    'To turn and slake',
#    'The rage that burns,',
#    'With my breath burn',
#    'And trouble your cool breath—',
#    'So shall I turn and take',
#    'Snow in my arms,',
#    '(Is love’s gift best?)',
#    'Of snow were comfortless,',
#    'Did you lie wondering,',
#    'Wakened yet unawake.',
#    'Shall I turn and take',
#    'Comfortless snow within my arms,',
#    'Press lips to lips that answer not,',
#    'Press lips to flesh',
#    'That shudders not nor breaks?',
#    'Is love’s gift best?—',
#    'Shall I turn and slake',
#    'All the wild longing?',
#    'Oh, I am eager for you!',
#    'As the Pleiads shake',
#    'White light in whiter water,',
#    'So shall I take you?',
#    'My mind is quite divided;',
#    'My minds hesitate,',
#    'So perfect matched',
#    'I know not what to do.',
#    'Each strives with each:',
#    'As two white wrestlers,',
#    'Standing for a match,',
#    'Ready to turn and clutch,',
#    'Yet never shake',
#    'Muscle or nerve or tendon;',
#    'So my mind waits',
#    'To grapple with my mind—',
#    'Yet I am quiet,',
#    'I would seem at rest.',
#    'I know not what to do.',
#    'Strain upon strain,',
#    'Sound surging upon sound,',
#    'Makes my brain blind;',
#    'As a wave line may wait to fall,',
#    'Yet waiting for its falling',
#    'Still the wind may take,',
#    'From off its crest,',
#    'White flake on flake of foam,',
#    'That rises',
#    'Seeming to dart and pulse',
#    'And rend the light,',
#    'So my mind hesitates',
#    'Above the passion',
#    'Quivering yet to break,',
#    'So my mind hesitates above my mind',
#    'Listening to song’s delight.',
#    'I know not what to do.',
#    'Will the sound break,',
#    'Rending the night',
#    'With rift on rift of rose',
#    'And scattered light?',
#    'Will the sound break at last',
#    'As the wave hesitant,',
#    'Or will the whole night pass',
#    'And I lie listening awake?'],
#   'poem_string': 'Is love’s gift loveliest?\nI know not what to do,\nNow sleep has pressed\nWeight on your eyelids.\nShall I break your rest,\nDevouring, eager?\nIs love’s gift best ?—\nNay, song’s the loveliest.\nYet, were you lost,\nWhat.rapture could I take from song?—\nWhat song were left?\nI know not what to do:\nTo turn and slake\nThe rage that burns,\nWith my breath burn\nAnd trouble your cool breath—\nSo shall I turn and take\nSnow in my arms,\n(Is love’s gift best?)\nOf snow were comfortless,\nDid you lie wondering,\nWakened yet unawake.\nShall I turn and take\nComfortless snow within my arms,\nPress lips to lips that answer not,\nPress lips to flesh\nThat shudders not nor breaks?\nIs love’s gift best?—\nShall I turn and slake\nAll the wild longing?\nOh, I am eager for you!\nAs the Pleiads shake\nWhite light in whiter water,\nSo shall I take you?\nMy mind is quite divided;\nMy minds hesitate,\nSo perfect matched\nI know not what to do.\nEach strives with each:\nAs two white wrestlers,\nStanding for a match,\nReady to turn and clutch,\nYet never shake\nMuscle or nerve or tendon;\nSo my mind waits\nTo grapple with my mind—\nYet I am quiet,\nI would seem at rest.\nI know not what to do.\nStrain upon strain,\nSound surging upon sound,\nMakes my brain blind;\nAs a wave line may wait to fall,\nYet waiting for its falling\nStill the wind may take,\nFrom off its crest,\nWhite flake on flake of foam,\nThat rises\nSeeming to dart and pulse\nAnd rend the light,\nSo my mind hesitates\nAbove the passion\nQuivering yet to break,\nSo my mind hesitates above my mind\nListening to song’s delight.\nI know not what to do.\nWill the sound break,\nRending the night\nWith rift on rift of rose\nAnd scattered light?\nWill the sound break at last\nAs the wave hesitant,\nOr will the whole night pass\nAnd I lie listening awake?',
#   'genre': ''},
#  {'poet': 'Amy Lowell',
#   'poem_url': 'https://www.poetryfoundation.org/poetrymagazine/poems/14533/good-gracious',
#   'title': 'Good Gracious',
#   'poem_lines': ['They say there is a fairy in every streak’d tulip.',
#    'I have rows and rows of them beside my door.',
#    'Hoop-la! Come out, Brownie,',
#    'And I will give you an emerald ear-ring!',
#    'You had better come out,',
#    'For to-morrow may be stormy,',
#    'And I could never bring myself to part with my emerald',
#    'ear-rings',
#    'Unless there was a moon.',
#    'Amy Lowell'],
#   'poem_string': 'They say there is a fairy in every streak’d tulip.\nI have rows and rows of them beside my door.\nHoop-la! Come out, Brownie,\nAnd I will give you an emerald ear-ring!\nYou had better come out,\nFor to-morrow may be stormy,\nAnd I could never bring myself to part with my emerald\near-rings\nUnless there was a moon.\nAmy Lowell',
#   'genre': ''},
#  {'poet': 'Ezra Pound',
#   'poem_url': 'https://www.poetryfoundation.org/poetrymagazine/poems/14339/shades-of-callimachus',
#   'title': 'Shades Of Callimachus',
#   'poem_lines': ['It is in your grove I would walk—',
#    'I who come first from the clear font,',
#    'Bringing the Grecian orgies into Italy,',
#    'and the dance into Italy.',
#    'Who hath taught you so subtle a measure,',
#    'in what hall have you heard it;',
#    'What foot beat out your time-bar,',
#    'what water has mellowed your whistles?',
#    'Out-weariers of Apollo will, as we know, continue their',
#    'Martian generalities.',
#    'ave kept our erasers in order.',
#    'A new-fangled chariot follows the flower-hung horses;',
#    'A young Muse, with young loves clustered about her,',
#    'ascends with me into the ether, .. .',
#    'And there is no high road to the Muses.',
#    'Annalists will continue to record Roman reputations,',
#    'Celebrities from the Trans-Caucasus will belaud Roman',
#    'celebrities',
#    'And expound the distentions of empire.',
#    'But for something to read in normal circumstances?',
#    'For a few pages brought down from the forked hill un-',
#    'sullied ?',
#    'I ask a wreath which will not crush my head.',
#    'And there is no hurry about it;',
#    'I shall have, doubtless, a boom after my funeral,',
#    'Seeing that long standing increases all things,',
#    'regardless of quality.',
#    'And who would have known the towers',
#    'pulled down by a deal-wood horse,',
#    'Or of Achilles withstaying waters by Simois,',
#    'Or of Hector spattering wheel-rims,',
#    'Or of Polydamas, by Scamander, or Helenus and Dei-',
#    'phobus?',
#    'Their door-yard would scarcely know them, or Paris;',
#    'Small talk, O Ilion, and O Troad,',
#    'twice taken by Oetaan gods,',
#    'If Homer had not stated your case!',
#    'And I also among the later nephews of this city',
#    's ave my dog’s day',
#    'With no stone upon my contemptible sepulchre,',
#    'My vote coming from the temple of Phoebus in Lycia, at',
#    'atara.',
#    'And in the mean time my songs will travel,',
#    'And the devirginated young ladies will enjoy them',
#    'when they have got over the strangeness;',
#    'For Orpheus tamed the wild beasts—',
#    'and held up the Threician river;',
#    'And Citharaon shook up the rocks by Thebes',
#    'and danced them into a bulwark at his pleasure;',
#    'And you, O Polyphemus?—did harsh Galatea almost',
#    'Turn to your dripping horses, because of a tune, under',
#    'Aetna?',
#    'We must look into the matter. Bacchus and Apollo in favor',
#    'of it,',
#    'There will be a crowd of young women doing homage to',
#    'my palaver.',
#    '‘Though my house is not propped up by Taenarian columns',
#    'From Laconia (associated with Neptune and Cerberus),',
#    'Though it is not stretched upon gilded beams;',
#    'My orchards do not lie level and wide',
#    'as the forests of Phzacia,',
#    'the luxurious and Ionian,',
#    'Nor are my caverns stuffed stiff with a Marcian vintage—',
#    'my cellar does not date from Numa Pompilius,',
#    'Nor bristle with wine jars) :',
#    'Yet the companions of the Muses will keep their collective',
#    'nose in my books,',
#    'And, weary with historical data, they will turn to my dance',
#    'tune.',
#    'Happy who are mentioned in my pamphlets',
#    'The songs shall be a fine tomb-stone over theis beauty.',
#    'But against this?',
#    'Neither expensive pyramids scraping the stars in their route,',
#    'Nor houses modelled upon that of Jove in East Elis.',
#    'Nor the monumental effigies of Mausolus,',
#    'are a complete elucidation of death.',
#    'Flame burns, rain sinks into the cracks,',
#    'And they all go to rack ruin beneath the thud of the years.',
#    'Stands Genius a deathless adornment,',
#    'a name not to be worn out with the years.',
#    'Il',
#    'I had been seen in the shade, recumbent on cushioned Helicon,',
#    'The water dripping from Bellerophon’s horse.',
#    'Alba, your kings, and the realm your folk have constructed',
#    'with such industry,',
#    'Shall be yawned out on my lyre—with such industry.',
#    'My little mouth shall gobble in such great fountains',
#    '“Whereof father Ennius, sitting before I came, hath drunk.”',
#    'I had rehearsed the Curian brothers, and made remarks on',
#    'the Horatian javelin',
#    '(Near Q. H. Flaccus’ book-stall).',
#    '“Of” royal Aemilia, drawn on the memorial raft,',
#    '“Of” the victorious delay of Fabius, and the left-handed',
#    'battle at Cannae,',
#    'Of lares fleeing the “Roman seat” .. .',
#    'had sung of all these',
#    'And of Hannibal,',
#    'and of Jove protected by geese.',
#    'And Phoebus, looking upon me from the Castalian tree,',
#    'Said then, “You idiot! What are you doing with that',
#    'water—',
#    'Who has ordered a book about heroes?',
#    'You need, Propertius, not think',
#    'About acquiring that sort of a reputation!',
#    'Soft fields must be worn by small wheels,',
#    'Your pamphlets will be thrown, thrown often, into a chair',
#    'Where a girl waits alone for her man.',
#    'y wrench your page out of its course?',
#    'No keel will sink with your genius—',
#    'et another oar churn the water,',
#    'Another wheel, the arena: mid-crowd is as bad as mid-sea.”',
#    'He had spoken and pointed me a place with his plectrum.',
#    'Orgies of vintages, an earthen image of Silenus',
#    'Strengthened with rushes, Tegean Pan,',
#    'The small birds of the Cytherean mother,',
#    'their Punic faces dyed in the Gorgon’s lake;',
#    'Nine girls, from as many countrysides,',
#    'earing her offerings in their unhardened hands:',
#    'Such my cohort and setting. And she bound ivy to his',
#    'thyrsos,',
#    'Fitted songs to the strings,',
#    'roses twined in her hands.',
#    'And one among them looked at me with face offended—',
#    'Calliope:',
#    '“Content ever to move with white swans!',
#    'Nor will the noise of high horses lead you ever to battle;',
#    'Nor will the public criers ever have your name',
#    'in their classic horns;',
#    'Nor Mars shout you in the wood at Aeonium,',
#    'nor where Rome ruins German riches,',
#    'Nor where the Rhine flows with barbarous blood,',
#    'and flood carries wounded Suevi.',
#    'Obviously, crowned lovers at unknown doors,',
#    'Night dogs, the marks of a drunken scurry—',
#    'These are your images, and from you the sorcerizing',
#    'of shut-in young ladies,',
#    'The wounding of austere men by chicane.”',
#    'Thus Mistress Calliope,',
#    'Dabbling her hands in the fount, thus she',
#    'Stiffened our face with the backwash of Philetas the Coan.',
#    'Il',
#    'Midnight, and a letter comes to me from our mistress',
#    'Telling me to come to Tibur “At once!”',
#    'Bright tips reach up from twin towers,',
#    'Anienan spring-water falls into flat-spread pools.',
#    'What is to be done about it?',
#    'Shall I entrust myself to entangled shadows',
#    'Where bold hands may do violence to my person?',
#    'Yet if I postpone my obedience,',
#    'because of this respectable terror,',
#    'I shall be prey to lamentations worse than a nocturnal as-',
#    'sailant.',
#    'And I shall be in the wrong,',
#    'and it will last a twelve-month,',
#    'For her hands have no kindness me-ward,',
#    'Nor is there anyone to whom lovers are not sacred at mid-',
#    'night',
#    'And in the Via Sciro,',
#    'If any man would be a lover',
#    'e may walk on the Scythian coast:',
#    'No barbarism would go to the extent of doing him harm,',
#    'The moon will carry his candle,',
#    'he stars will point out the stumbles,',
#    'Cupid will carry lighted torches before him',
#    'and keep mad dogs off his ankles.',
#    'Thus all roads are perfectly safe',
#    'and at any hour;',
#    'Who so indecorous as to shed the pure gore of a suitor?',
#    'Cypris is his cicerone.',
#    'What if undertakers follow my track—',
#    'such a death is worth dying.',
#    'She would bring frankincense and wreaths to my tomb,',
#    'he would sit like an ornament on my pyre.',
#    'Gods’ aid, let not my bones lie in a public location',
#    'With crowds too assiduous in their crossing of it;',
#    'For thus are tombs of lovers most desecrated.',
#    'May a woody and sequestered place cover me with its foliage',
#    'Or may I inter beneath the hummock',
#    'me as yet uncatalogued sand;',
#    'At any rate I shall not have my epitaph in a high-road.',
#    'Iv',
#    'When, when, and whenever death closes our eyelids,',
#    'Moving naked over Acheron',
#    'Upon the one raft, victor and conquered together,',
#    'Marius and Jugurtha together,',
#    'ne tangle of shadows.',
#    'Caesar plots against India—',
#    'Tigris and Euphrates shall from now on flow at his bidding,',
#    'Tibet shall be full of Roman policemen,',
#    'The Parthians shall get used to our statuary',
#    'and acquire a Roman religion:',
#    'One raft on the veiled flood of Acheron,',
#    'Marius and Jugurtha together.',
#    'Nor at my funeral either will there be any long trail,',
#    'earing ancestral lares and images;',
#    'No trumpets filled with my emptiness;',
#    'Nor shall it be on an Attalic bed.',
#    'The perfumed cloths shall be absent.',
#    'A small plebeian procession—',
#    'Enough, enough, and in plenty.',
#    'There will be three books at my obsequies',
#    'Which I take, my not unworthy gift, to Persephone.',
#    'You will follow the bare scarified breast;',
#    'Nor will you be weary of calling my name, nor too weary',
#    'To place the last kiss on my. lips',
#    'When the Syrian onyx is broken.',
#    '“He who is now vacant dust',
#    'Was once the slave ‘of one passion” —',
#    'Give that much inscription—',
#    '“Death, why tardily come?”',
#    'You, sometime, will lament a lost friend,',
#    'for it is a custom—',
#    'This care for past men—',
#    'Since Adonis was gored in Idalia, and the Cytherean',
#    'Ran crying with out-spread hair.',
#    'In vain you call back the shade;',
#    'In vain, Cynthia, vain call to unanswering shadow—',
#    'small talk comes from small bones.',
#    'Ezra Pound'],
#   'poem_string': 'It is in your grove I would walk—\nI who come first from the clear font,\nBringing the Grecian orgies into Italy,\nand the dance into Italy.\nWho hath taught you so subtle a measure,\nin what hall have you heard it;\nWhat foot beat out your time-bar,\nwhat water has mellowed your whistles?\nOut-weariers of Apollo will, as we know, continue their\nMartian generalities.\nave kept our erasers in order.\nA new-fangled chariot follows the flower-hung horses;\nA young Muse, with young loves clustered about her,\nascends with me into the ether, .. .\nAnd there is no high road to the Muses.\nAnnalists will continue to record Roman reputations,\nCelebrities from the Trans-Caucasus will belaud Roman\ncelebrities\nAnd expound the distentions of empire.\nBut for something to read in normal circumstances?\nFor a few pages brought down from the forked hill un-\nsullied ?\nI ask a wreath which will not crush my head.\nAnd there is no hurry about it;\nI shall have, doubtless, a boom after my funeral,\nSeeing that long standing increases all things,\nregardless of quality.\nAnd who would have known the towers\npulled down by a deal-wood horse,\nOr of Achilles withstaying waters by Simois,\nOr of Hector spattering wheel-rims,\nOr of Polydamas, by Scamander, or Helenus and Dei-\nphobus?\nTheir door-yard would scarcely know them, or Paris;\nSmall talk, O Ilion, and O Troad,\ntwice taken by Oetaan gods,\nIf Homer had not stated your case!\nAnd I also among the later nephews of this city\ns ave my dog’s day\nWith no stone upon my contemptible sepulchre,\nMy vote coming from the temple of Phoebus in Lycia, at\natara.\nAnd in the mean time my songs will travel,\nAnd the devirginated young ladies will enjoy them\nwhen they have got over the strangeness;\nFor Orpheus tamed the wild beasts—\nand held up the Threician river;\nAnd Citharaon shook up the rocks by Thebes\nand danced them into a bulwark at his pleasure;\nAnd you, O Polyphemus?—did harsh Galatea almost\nTurn to your dripping horses, because of a tune, under\nAetna?\nWe must look into the matter. Bacchus and Apollo in favor\nof it,\nThere will be a crowd of young women doing homage to\nmy palaver.\n‘Though my house is not propped up by Taenarian columns\nFrom Laconia (associated with Neptune and Cerberus),\nThough it is not stretched upon gilded beams;\nMy orchards

#   'poem_url': 'https://www.poetryfoundation.org/poetrymagazine/poems/49515/design-56d22baceda5f',
#   'title': 'Design',
#   'poem_lines': ['for Jean-Michel Rabaté',
#    'I saw the sign',
#    'on its hooks',
#    'grappling with',
#    'the being of its',
#    'having become &',
#    'gone, in a flash',
#    'just like the',
#    'returned to its holster',
#    'or the prairie dog',
#    'howling with',
#    'homesickness',
#    'even at home.',
#    'The consciousness of',
#    'consciousness lapses',
#    'into intermittent',
#    'power outages &',
#    'salt water taffy.',
#    'History will end',
#    '& the sooner',
#    'the better',
#    'as long as',
#    'I have my',
#    'season pass.',
#    'CHARLES BERNSTEIN 193'],
#   'poem_string': 'for Jean-Michel Rabaté\nI saw the sign\non its hooks\ngrappling with\nthe being of its\nhaving become &\ngone, in a flash\njust like the\nreturned to its holster\nor the prairie dog\nhowling with\nhomesickness\neven at home.\nThe consciousness of\nconsciousness lapses\ninto intermittent\npower outages &\nsalt water taffy.\nHistory will end\n& the sooner\nthe better\nas long as\nI have my\nseason pass.\nCHARLES BERNSTEIN 193',
#   'genre': ''},
#  {'poet': 'E. E. Cummings',
#   'poem_url': 'https://www.poetryfoundation.org/poetrymagazine/poems/23584/if-everything-happens-that-cant',
#   'title': 'If Everything Happens That Cant',
#   'poem_lines': ['(and anything’s righter',
#    'ooks',
#    'could plan)',
#    'the stupidest teacher will almost guess',
#    '(with a run',
#    'skip',
#    'around we go yes)',
#    'there’s nothing as something as one',
#    'one hasn’t a why or because or although',
#    '(and buds know better',
#    'than books',
#    'don’t grow)',
#    'one’s anything old being everything new',
#    '(with a what',
#    'which',
#    'around we come who)',
#    'one’s everyanything so',
#    'so world is a leaf so tree is a bough',
#    '(and birds sing sweeter',
#    'than books',
#    'tell how)',
#    'so here is away and so your is a my',
#    '(with a down',
#    'up',
#    'around again fly)',
#    'forever was never till now',
#    'now i love you and you love me',
#    '(and books are shuter',
#    'than books',
#    'can be)',
#    'and deep in the high that does nothing but fall',
#    '(with a shout',
#    'ch',
#    'around we go all)',
#    'there’s somebody calling who’s we',
#    "we're anything brighter than even the sun",
#    "(we're everything greater",
#    'than books',
#    'might mean )',
#    "we're everyanything more than believe",
#    '(with a spin',
#    'leay',
#    "alive we're alive)",
#    "we're wonderful one times one",
#    'E. E. Cummings'],
# ...
#    'He wears a white suit, carries a white newspaper and apple, his',
#    'hands and face are white;',
#    'The clouds sneer but go sailing into the white sky.'],
#   'poem_string': 'The caves, blind fists,\nGreen seaweed on the black and blue water\nAnd the friends’ precision with excitement,\n“The man who sees a cloud in Schenectady\nAffects someone he does not know on the other side of the globe,\nwho wants him\nAnd we shall have that rose, Dutch work apart.”\nBlue towers, squeals, the blind roses go by.\nTherefore we have these few things.\nTt was a summer afternoon or night, glory was in the gondola\nOn the percussive honeymoon.\nBut he thought of the nights the ruined homes\nThe gold tears shed for him.\nTherefore we have these white bricks.\nThe bride wore white...\nHe wears a white suit, carries a white newspaper and apple, his\nhands and face are white;\nThe clouds sneer but go sailing into the white sky.',
#   'genre': ''},
#  {'poet': 'Lorine Niedecker',
#   'poem_url': 'https://www.poetryfoundation.org/poetrymagazine/poems/30789/fall-56d21442f2ddc',
#   'title': 'Fall',
#   'poem_lines': ['are at their highest thoughts',
#    'of leaving',
#    'Middle life said nothing—',
#    'grounde',
#    'to a livelihood',
#    'Old age—a high gabbling gathering',
#    'before goodbye',
#    'of all we know',
#    'We are what the seas',
#    'have made us',
#    'longingly immense',
#    'the very veery',
#    'on the fence',
#    'Fall',
#    'We must pull',
#    'the curtains—',
#    'we haven’t any',
#    'leaves',
#    'Smile',
#    'to see the lake',
#    'ay',
#    'the still sky',
#    'And',
#    'out for an easy',
#    'k',
#    'make',
#    'the dragonfly'],
#   'poem_string': 'are at their highest thoughts\nof leaving\nMiddle life said nothing—\ngrounde\nto a livelihood\nOld age—a high gabbling gathering\nbefore goodbye\nof all we know\nWe are what the seas\nhave made us\nlongingly immense\nthe very veery\non the fence\nFall\nWe must pull\nthe curtains—\nwe haven’t any\nleaves\nSmile\nto see the lake\nay\nthe still sky\nAnd\nout for an easy\nk\nmake\nthe dragonfly',
#   'genre': ''},
#  {'poet': 'Charles Reznikoff',
#   'poem_url': 'https://www.poetryfoundation.org/poetrymagazine/poems/19941/the-squads-platoons',
#   'title': 'The Squads Platoons',
#   'poem_lines': ['that intricate shrub',
#    'of nerves, veins, arteries—',
#    'myself—uncurls',
#    'its knotted leaves',
#    'to the shining air.',
#    'Upon this wooded hillside,',
#    'pied with snow, I hear',
#    'only the melting snow',
#    'drop from the twigs.',
#    'II SUBWAY',
#    'In steel clouds',
#    'to the sound of thunder',
#    'like the ancient gods:',
#    'our sky, cement;',
#    'the earth, cement;',
#    'our trees, steel;',
#    'instead of sunshine,',
#    'a light that has no twilight,',
#    'neither morning nor evening, «',
#    'only noon.',
#    'Coming up the subway stairs, I thought the moon',
#    'only another street-light—',
#    'a little crooked.',
#    'Ill',
#    'From the middle of the pool',
#    'in the concrete pavement a fountain',
#    'in neat jets; the wind scatters it',
#    'upon the water. The untidy trees',
#    'drop their leaves upon the pavement.',
#    'Iv',
#    'Along the flat roofs beneath our window,',
#    'in the morning sunshine',
#    'I read the signature of last night’s rain.',
#    'v',
#    'The squads, platoons, and regiments',
#    'of lighted windows,',
#    'ephemeral under the evening star—',
#    'feast, you who cross the bridge',
#    'this cold twilight',
#    'on these honeycombs of light, the buildings of Manhattan.',
#    'Charles Reznikoff'],
#   'poem_string': 'that intricate shrub\nof nerves, veins, arteries—\nmyself—uncurls\nits knotted leaves\nto the shining air.\nUpon this wooded hillside,\npied with snow, I hear\nonly the melting snow\ndrop from the twigs.\nII SUBWAY\nIn steel clouds\nto the sound of thunder\nlike the ancient gods:\nour sky, cement;\nthe earth, cement;\nour trees, steel;\ninstead of sunshine,\na light that has no twilight,\nneither morning nor evening, «\nonly noon.\nComing up the subway stairs, I thought the moon\nonly another street-light—\na little crooked.\nIll\nFrom the middle of the pool\nin the concrete pavement a fountain\nin neat jets; the wind scatters it\nupon the water. The untidy trees\ndrop their leaves upon the pavement.\nIv\nAlong the flat roofs beneath our window,\nin the morning sunshine\nI read the signature of last night’s rain.\nv\nThe squads, platoons, and regiments\nof lighted windows,\nephemeral under the evening star—\nfeast, you who cross the bridge\nthis cold twilight\non these honeycombs of light, the buildings of Manhattan.\nCharles Reznikoff',
#   'genre': ''},
#  {'poet': 'Louis Zukofsky',
#   'poem_url': 'https://www.poetryfoundation.org/poetrymagazine/poems/31024/a-21-rudens-act-iii',
#   'title': 'A 21 Rudens Act Iii',
#   'poem_lines': ['climbing to molest could not',
#    'grip what was in it,',
#    'then came down to me',
#    'asked to borrow a ladder.',
#    'I responded “by their example',
#    'Philomela and Procne engendered swallows” —',
#    'pleading “don’t hurt my populace.”',
#    'And the monkey fired ferociously',
#    'threatening all kind of evil',
#    'invoking justice. Somehow angered I',
#    'gripped her middle and looped',
#    'the monkey with her tail.',
#    'How’m I to divine this',
#    'dream—I’ve conjectured all day.',
#    '(Voice off)',
#    "middle summer's spring and regret",
#    'will with passing regret less'],
#   'poem_string': "climbing to molest could not\ngrip what was in it,\nthen came down to me\nasked to borrow a ladder.\nI responded “by their example\nPhilomela and Procne engendered swallows” —\npleading “don’t hurt my populace.”\nAnd the monkey fired ferociously\nthreatening all kind of evil\ninvoking justice. Somehow angered I\ngripped her middle and looped\nthe monkey with her tail.\nHow’m I to divine this\ndream—I’ve conjectured all day.\n(Voice off)\nmiddle summer's spring and regret\nwill with passing regret less",
#   'genre': ''},
#  {'poet': 'Louis Zukofsky',
#   'poem_url': 'https://www.poetryfoundation.org/poetrymagazine/poems/19141/a0151seventh-movement',
#   'title': 'A0151Seventh Movement',
#   'poem_lines': ['Horses: who will do it? out of manes? Words',
#    'Will do it, out of manes, out of airs, but',
#    'They have no manes, so there are no airs, birds',
#    'Of words, from me to them no singing gut.',
#    'For they have no eyes, for their legs are wood,',
#    'For their stomachs are logs with print on them,',
#    'Blood-red, red lamps hang from necks or where could',
#    'Be necks, two legs stand A, four together M.',
#    '“Street Closed” is what print says on their stomachs;',
#    'That cuts out everybody but the diggers;',
#    'You’re cut out, and she’s cut out, and the jiggers',
#    'Are cut out, No! we can’t have such nor bucks',
#    'As won’t, tho they’re not here pass thru a hoop',
#    'Strayed on a manhole—me? Am on a stoop.',
#    'Am on a stoop to sit here tho no one',
#    'Asked me, nor asked you because you’re not here,',
#    'A sign creaks LAUNDRY TO-LET (creaks—wind—)—',
#    'SUN—',
#    '(Nights?) the sun’s, bro’, what month’s rent in arrear?)',
#    'Aighuh—and no manes and horses’ trot? butt, butt',
#    'Of earth, birds spreading harps, two manes a pair',
#    'Of birds, each bird a word, a streaming gut',
#    'Trot, trot—? No horse is here, no horse is there?',
#    "Says you! Then I—fellow me, airs! we'll make",
#    'Wood horse, and recognise it with our words—',
#    'Not it—nine less two!—as many as take',
#    'To make a dead man purple in the face,',
#    'Full dress to rise and circle thru a',
#    'Trained horses—in latticed orchards, \\ewitch !) birds.',
#    'Just what I said—Birds!—See Him! Whom? The Son',
#    'Of Man, grave-turf on taxi, taxi gone',
#    'Who blabbed of orchards, strides one leg here, one',
#    'Leg there—wooden horses? give them manes!—(was on',
#    'A stoop, He found them sleeping, don’t you see?',
#    'See him! How? Against wood his body close;',
#    'Speaks: My face at where its forehead might be,',
#    'The plank’s end’s a forehead waving a rose—',
#    'Birds—birds—nozzle of horse, washed plank in air . . .',
#    'For they had no manes we would give them manes,',
#    'For their wood was dead the wood would move—bare',
#    'But for the print on it—for diggers gone, trains’',
#    'Run, light lights in air where the dead reposed—',
#    'As many as take liveforever, “Street Closed.”',
#    "“Closed”? then fellow me airs, we'll open ruts",
#    'For the wood-grain skin laundered to pass thru,',
#    'Switch is a whip which never has been, cuts',
#    'Winds for words—Turf streams words, airs untraced—',
#    'New',
#    'The night, and orchards were here? Horses passed ?—',
#    'There were no diggers, bro’, no horses there,',
#    'But the graves were turfed and the horses grassed—',
#    'Two voices:—Airs? No birds. Taxi? No air—',
#    'Says one! Then I—Are logs?! Two legs stand ““A”—',
#    'Pace them! in revolution are the same!',
#    'Switch! See! we can have such and bucks tho they',
#    'Are not here, nor were there, pass thru a hoo',
#    '(Tho their legs are wood and their necks ’ave no name)',
#    'Strayed on a manhole— See! Am on a stoop!',
#    'See! For me these jiggers, these dancing bucks:',
#    'Bum pump a-dumb, the pump is neither bum',
#    'Nor dumb, dumb pump uh! hum, bum pump o! shucks!',
#    '(Whose clavicembalo? bum? bum? te-hum .. .)',
#    'Not in the say but in the sound’s—hey-hey—',
#    'The way today, Die, die, die, die, tap, slow,',
#    'Die, wake up, up! up! O Saviour, today!',
#    'Choose Jews’ shoes or whose: anyway Choose! Go!',
#    'But they had no eyes, and their legs were wood!',
#    'But their stomachs were logs with print on them!',
#    'Blood-red, red lamps hung from necks or where could',
#    'Be necks, two legs stood A, four together M—',
#    'They had no manes so there were no airs, but—',
#    'Butt ... butt... from me to pit no singing gut!',
#    'Says you! Then I, Singing, It is not the sea',
#    'But what floats over: hang from necks or where could',
#    'Be necks, blood-red, red lamps (Night), Launder me,',
#    'Mary! Sea of horses that once were wood.',
#    'Green and, and leaf on leaf, and dancing bucks,',
#    'Who take liveforever! Taken a pum',
#    'And shaped a flower. “Street Closed” on their stomachs.',
#    'But the street has moved; at each block a stump',
#    'That blossoms red. And I sat there, no one',
#    'Asked me, nor asked you. Whom? You were not there.',
#    'A sign creaked—LAUNDRY TO-LET—(creaked—wind)',
#    '—SUN—',
#    '(Nights?) the sun’s, bro’, no month’s rent in arrear—',
#    'Bum pump a-dum, no one’s cut out, pump a-',
#    'Ricky, bro’, Shimaunu-San, yours is the',
#    'Clavicembalo—Nine less two, Seven',
#    'Were the diggers, seven sang, danced, the paces',
#    'Seven, Seven Saviours went to heaven—',
#    'Their tongues, hands, feet, eyes, ears and hearts, each face',
#    'as',
#    'Of a Sea looking Outward (Rose the Glass',
#    'Broken), Each a reflection of the other,',
#    'Just for the fun of it.. And ’t came to pass',
#    '(Open, O fierce flaming pit!)',
#    'three said: “Bother,',
#    'Brother, we want a meal, different techniques.”',
#    'Two ways, my two voices. . . . Offal and what',
#    'The imagination, . . . And the seven came',
#    'To horses seven (of wood—Who will?—kissed their',
#    'stomachs',
#    'Bent knees as these rose around them—trot—trot—',
#    'Spoke: words, words, we are words, horses, manes, words.',
#    'Louis Zukofsky',
#    'Note: Quotations the sources of which are not detailed in the context',
#    'are based on the text of Bach’s Saint Matthew Passion, and are in italics'],
poem_url': 'https://www.poetryfoundation.org/poetrymagazine/poems/30768/a-19',
#   'title': 'A 19',
#   'poem_lines': ['door snow',
#    'flakes drift',
#    'down up',
#    'thru and',
#    'past turn',
#    'over under',
#    'on froth',
#    'pine needles',
#    'frost tomorrow’s',
#    'sun better',
#    'than any'],
#   'poem_string': 'door snow\nflakes drift\ndown up\nthru and\npast turn\nover under\non froth\npine needles\nfrost tomorrow’s\nsun better\nthan any',
#   'genre': ''}]

# %%
still_errors
# Out:
# ['https://www.poetryfoundation.org/poetrymagazine/poems/29416/mad-sonnet-we-shall-be-free',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29415/mad-sonnet-when-spirit-has-no-edge',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30530/song-how-simply-for-another',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30225/song-i-wouldnt-embarrass-you',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29779/walking-56d2134a84892',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/27415/poem-when-the-immortal-blond',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/48292/road-56d22969928f0',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/19645/persons-seen',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/32401/sonnets-of-the-blood',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14310/an-evening-meeting-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14321/the-inn-at-the-western-lake-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14312/calligraphy-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14320/a-recluse-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14316/on-the-classic-of-the-hills-and-sea-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14315/the-palace-blossoms-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14313/one-goes-a-journey-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14311/after-how-many-years-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14296/on-seeing-the-portrait-of-a-beautiful-concubine-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14314/from-the-straw-hut-among-the-seven-peaks-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14322/the-emperors-return-from-a-journey-to-the-south-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/13065/exiles-letter-tr-by-ezra-pound',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/13497/paganis',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/12926/amities',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14358/epitaph-an-old-willow',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28310/elaine',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/32405/proof-of-immortality-56d215f13b354',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/18899/poem-as-the-cat',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28312/emily',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28311/erica',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/21476/to-an-elder-poet',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/13202/from-discordants-iv',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/22222/up-into-the-silence-the-green',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28566/why-dont-be',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/25510/dim-i-nu-tiv',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/25513/-oroundmoonhow',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/24807/thislets-rememberday',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28833/if-seventy-were-young',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/22220/nouns-to-nouns',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28837/annie-died-the-other-day',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28836/without-the-mercy-of',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28834/for-any-ruffian-of-the-sky',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28838/o-the-sun-comes-up-up-up',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28835/pity-his-how-illimitable-plight',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/25960/springmay0151',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/25263/imc-a-tmo',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/26048/rosetreerosetree',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/22223/six',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/25512/jacks-white-horseup',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/22221/when-what-hugs-stopping-earth',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/15885/wanderings-champs-dhonneur-56d20918e2c28',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/15867/wanderings-champs-dhonneur',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/34682/project-for-an-aesthetic',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/12960/ollie-mgee',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/21466/walking-sticks-and-paperweights-and-watermarks',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/13065/exiles-letter-tr-by-ezra-pound',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/13497/paganis',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/12926/amities',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/22310/poem-after-the-wrestling',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/15533/lenvoi',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/17874/discus-thrower',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/20683/conjunctions',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/33672/poem-green-things-are-flowers',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30246/poem-to-simply-talk',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30775/sonnet-five-am-on-east-fourteenth',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30549/poem-like-musical-instruments',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30723/jungle-56d21432117a5',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30138/consider-at-the-outset',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30790/smile-to-see-the-lake',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29475/now-in-one-year',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30140/spring-stood-there',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30139/march-56d213a2b802b',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30141/the-park-a-darling-walk',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29745/giovannis-rape-of-the-sabine-women-at-wildensteins',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/19125/1930s',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/19940/along-the-flat-roofs',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/26578/je-faisois-ces-sonnets-tr-by-george-dillon',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28076/brucio-e-limminenza-lombra-che-sale-riconosco']

# %%
poems[poems.poet == 'William Carlos Williams']
# Out:
#                          poet  \
# 1289  William Carlos Williams
# 1290  William Carlos Williams
# 1291  William Carlos Williams
# 1292  William Carlos Williams
# 1293  William Carlos Williams
# ...                       ...
# 1571  William Carlos Williams
# 1572  William Carlos Williams
# 1573  William Carlos Williams
# 1574  William Carlos Williams
# 1575  William Carlos Williams
#
#                                                                                           poem_url  \
# 1289  https://www.poetryfoundation.org/poems/148460/spring-and-all-chapter-xiii-thus-weary-of-life
# 1290                              https://www.poetryfoundation.org/poems/56159/this-is-just-to-say
# 1291       https://www.poetryfoundation.org/poems/148462/spring-and-all-xi-in-passing-with-my-mind
# 1292                 https://www.poetryfoundation.org/poems/53078/flowers-by-the-sea-56d23210587cf
# 1293                                    https://www.poetryfoundation.org/poems/49849/between-walls
# ...                                                                                            ...
# 1571                      https://www.poetryfoundation.org/poetrymagazine/poems/14364/the-dark-day
# 1572                       https://www.poetryfoundation.org/poetrymagazine/poems/13517/summer-song
# 1573                https://www.poetryfoundation.org/poetrymagazine/poems/22430/the-forgotten-city
# 1574              https://www.poetryfoundation.org/poetrymagazine/poems/18898/the-unfrocked-priest
# 1575            https://www.poetryfoundation.org/poetrymagazine/poems/19139/the-botticellian-trees
#
#                                                    title  \
# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/29416/mad-sonnet-we-shall-be-free'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=102&issue=3&page=18'
rescrape = scan_poem_scraper(actual_url, input_poet='Michael McClure', input_title='Mad Sonnet: We Shall Be Free')
rescrape['poem_url'] = url
rescrape['genre'] = 'beat'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/29415/mad-sonnet-when-spirit-has-no-edge'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=102&issue=3&page=17'
rescrape = scan_poem_scraper(actual_url, input_poet='Michael McClure', input_title='Mad Sonnet: When Spirit Has No Edge')
rescrape['poem_url'] = url
rescrape['genre'] = 'beat'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/30530/song-how-simply-for-another'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=109&issue=5&page=6'
rescrape = scan_poem_scraper(actual_url, input_poet='Robert Creeley', input_title='Enough: Left After That')
rescrape['poem_url'] = url
rescrape['genre'] = 'black_mountain'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/29779/walking-56d2134a84892'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=104&issue=3&page=19'
rescrape = scan_poem_scraper(actual_url, input_poet='Robert Creeley', input_title='Walking: In My Head')
rescrape['poem_url'] = url
rescrape['genre'] = 'black_mountain'
error_rescrapes.append(rescrape)
still_errors.remove(url)

# %%
img_data = rq.get('https://static.poetryfoundation.org/jstor/i20572016/pages/13.png').content
with open('data/temp.png', 'wb') as handle:
    handle.write(img_data)
text = pytesseract.image_to_string('data/temp.png')
text
# Out:
# 'William Carlos Williams\n\nEPITAPH\n\nAn old willow with hollow branches\nSlowly swayed his few high bright tendrils\nAnd sang:\n\n“Love is a young green willow\nShimmering at the bare wood’s edge.”\n\nSPRING\n\nO my grey hairs!\nYou are truly white as plum blossoms.\n\nSTROLLER\n\nI have seen the hills blue,\n\nI have seen them purple;\n\nAnd it is as hard to know\n\nThe words of a woman\n\nAs to straighten the crumpled branch\nOf an old willow.\n\nMEMORY OF APRIL\n\nYou say love is this, love is that:\nPoplar tassels, willow tendrils\n\nThe wind and the rain comb,\nTinkle and drip, tinkle and drip—\nBranches drifting apart. Hagh!\nLove has not even visited this country.\n\n[303]'

# %%
text = 'William Carlos Williams\n\nEPITAPH\n\nAn old willow with hollow branches\nSlowly swayed his few high bright tendrils\nAnd sang:\n\n“Love is a young green willow\nShimmering at the bare wood’s edge.”\n\nSPIRIT\n\nO my grey hairs!\nYou are truly white as plum blossoms.\n\nSTROLLER\n\nI have seen the hills blue,\n\nI have seen them purple;\n\nAnd it is as hard to know\n\nThe words of a woman\n\nAs to straighten the crumpled branch\nOf an old willow.\n\nMEMORY OF APRIL\n\nYou say love is this, love is that:\nPoplar tassels, willow tendrils\n\nThe wind and the rain comb,\nTinkle and drip, tinkle and drip—\nBranches drifting apart. Hagh!\nLove has not even visited this country.\n\n[303]'

# %%
title = 'Epitaph'
scan_pattern = fr'{title.split()[-1].upper()}\b.*((?:\r?\n(?![A-HJ-Z][A-HJ-Z ][A-Z ]+$).*)*)'
lines = re.search(scan_pattern, text, re.MULTILINE).group(1).splitlines()
lines
# Out:
# ['',
#  '',
#  'An old willow with hollow branches',
#  'Slowly swayed his few high bright tendrils',
#  'And sang:',
#  '',
#  '“Love is a young green willow',
#  'Shimmering at the bare wood’s edge.”']

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/14358/epitaph-an-old-willow'
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=13&issue=6&page=13'
rescrape = scan_poem_scraper(actual_url, input_poet='William Carlos Williams', input_title='Epitaph')
rescrape['poem_url'] = url
rescrape['genre'] = 'imagist'
rescrape
# error_rescrapes.append(rescrape)
# Out:
# {'poet': 'William Carlos Williams',
#  'poem_url': 'https://www.poetryfoundation.org/poetrymagazine/poems/14358/epitaph-an-old-willow',
#  'title': 'Epitaph',
#  'poem_lines': ['An old willow with hollow branches',
#   'Slowly swayed his few high bright tendrils',
#   'And sang:',
#   '“Love is a young green willow',
#   'Shimmering at the bare wood’s edge.”'],
#  'poem_string': 'An old willow with hollow branches\nSlowly swayed his few high bright tendrils\nAnd sang:\n“Love is a young green willow\nShimmering at the bare wood’s edge.”',
#  'genre': 'imagist'}

# %%
from tqdm import tqdm

# %%
# %%time

rescraped = []
for url in tqdm(error_poems):
    try:
        poem = scan_poem_rescrape(url)
        rescraped.append(poem)
        error_poems.remove(url)
    except:
        continue
# Out:
#  65%|██████▌   | 145/223 [06:41<03:36,  2.77s/it]
# CPU times: user 28 s, sys: 52.3 s, total: 1min 20s
# Wall time: 6min 41s

# %%
len(error_poems)
# Out:
# 145

# %%
pd.DataFrame(rescraped)[pd.DataFrame(rescraped).poet == 'Kenneth Rexroth']
# Out:
# Empty DataFrame
# Columns: [poet, poem_url, title, poem_lines, poem_string]
# Index: []

# %%
error_poems
# Out:
# ['https://www.poetryfoundation.org/poetrymagazine/poems/29416/mad-sonnet-we-shall-be-free',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29415/mad-sonnet-when-spirit-has-no-edge',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/27130/in-my-childhood-when-i-first',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30530/song-how-simply-for-another',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30225/song-i-wouldnt-embarrass-you',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29779/walking-56d2134a84892',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/27415/poem-when-the-immortal-blond',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29522/v-tell-it-to-the-forest-fire',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29169/spellbound-held-subtle-henry',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29525/viii-he-yelled-at-me-in-greek',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29166/the-greens-of-the-ganges',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29168/the-high-ones-die-die',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29526/ix-he-stared-at-ruin',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29523/vi-to-mark-van-doren-all-virtues-enter',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29551/i-saw-the-musty-shingles',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29552/you-search-in-rome-for-rome',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29553/this-structure-you-admire',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/19645/persons-seen',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/19715/in-ukraine',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/34386/the-swimmers-56d217cb70e3f',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/32402/vii-the-fire-i-praise',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/32401/sonnets-of-the-blood',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/19426/god-56d20b580c612',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/15345/fragment-xxxvi-i-know-not-what',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/15346/song-you-are-as-gold',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14310/an-evening-meeting-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14321/the-inn-at-the-western-lake-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14312/calligraphy-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14320/a-recluse-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14316/on-the-classic-of-the-hills-and-sea-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14315/the-palace-blossoms-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14313/one-goes-a-journey-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14311/after-how-many-years-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14296/on-seeing-the-portrait-of-a-beautiful-concubine-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14314/from-the-straw-hut-among-the-seven-peaks-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14322/the-emperors-return-from-a-journey-to-the-south-tr-by-amy-lowell-and-florence-ayscough',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/13067/image-from-dorleans',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14339/shades-of-callimachus',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/13065/exiles-letter-tr-by-ezra-pound',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/13497/paganis',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14342/when-when-and-whenever',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/12926/amities',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14340/i-had-been-seen-in-the-shade',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14358/epitaph-an-old-willow',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14356/to-be-closely-written',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28310/elaine',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/32405/proof-of-immortality-56d215f13b354',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/18899/poem-as-the-cat',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28312/emily',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28311/erica',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/21476/to-an-elder-poet',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/17625/broad-on-the-sunburnt-hill',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/13202/from-discordants-iv',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/12802/i-have-drifted-along-this-river',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/32378/poem-o-who-can-ever-praise',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/22702/poem-he-watched-with-all-his',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/19922/the-urn-reply',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/19916/the-urn-purgatorio',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/22222/up-into-the-silence-the-green',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28566/why-dont-be',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/25510/dim-i-nu-tiv',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/23584/if-everything-happens-that-cant',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/24810/jake-hates',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/25513/-oroundmoonhow',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/24807/thislets-rememberday',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28833/if-seventy-were-young',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/22220/nouns-to-nouns',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28837/annie-died-the-other-day',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/24812/this-is-a-rubbish',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28836/without-the-mercy-of',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28834/for-any-ruffian-of-the-sky',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/25264/in-spring-comesno',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/25957/all-nearness-pauses-while-a-star',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28838/o-the-sun-comes-up-up-up',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/25262/possibly-thrice-we-glimpsed0151',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28565/though-your-sorrows-not',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28835/pity-his-how-illimitable-plight',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/25960/springmay0151',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/25263/imc-a-tmo',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/26048/rosetreerosetree',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28832/timeless',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/25515/crazy-jay-blue',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/22223/six',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/25512/jacks-white-horseup',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/25261/open-his-headbaby',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/25514/if-the-lovestar-grows-most-big',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/25958/unloves-the-heavenless-hell',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/23583/might-these-be-thrushes-climbing',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/25516/if-ups-the-word',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/22655/a-pretty-a-day',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/22221/when-what-hugs-stopping-earth',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/24808/neither-awake',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/19567/buckshee-vi-viii',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/15885/wanderings-champs-dhonneur-56d20918e2c28',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/15867/wanderings-champs-dhonneur',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/25637/fire-56d20fb904f96',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/34682/project-for-an-aesthetic',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/12960/ollie-mgee',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/21466/walking-sticks-and-paperweights-and-watermarks',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/26389/the-woods-and-the-woodman',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/21512/poem-o-i-have-seen-the-heaven',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/13067/image-from-dorleans',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14339/shades-of-callimachus',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/13065/exiles-letter-tr-by-ezra-pound',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/13497/paganis',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14342/when-when-and-whenever',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/12926/amities',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14340/i-had-been-seen-in-the-shade',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/22750/as-i-sit-staring',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/22310/poem-after-the-wrestling',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/15533/lenvoi',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/17874/discus-thrower',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/14542/song-let-it-be-forgotten',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/22110/o-make-me-a-mask-and-a-wall',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/22111/not-from-this-anger',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/20683/conjunctions',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/27246/to-redoute',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/33672/poem-green-things-are-flowers',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/27317/poem-instant-coffee-with',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30246/poem-to-simply-talk',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30775/sonnet-five-am-on-east-fourteenth',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30549/poem-like-musical-instruments',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30720/i-crazy',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30725/seek-air',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29721/bad-dreams-come-often',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30718/sky-56d214310e84b',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29724/talking-to-you',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29720/i-have-spent-a-year',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30789/fall-56d21442f2ddc',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30138/consider-at-the-outset',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30790/smile-to-see-the-lake',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29473/river-marsh-drowse',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29475/now-in-one-year',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30140/spring-stood-there',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30139/march-56d213a2b802b',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30141/the-park-a-darling-walk',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/29745/giovannis-rape-of-the-sabine-women-at-wildensteins',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/19941/the-squads-platoons',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/19940/along-the-flat-roofs',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/31024/a-21-rudens-act-iii',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/19141/a0151seventh-movement',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/30768/a-19',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/32828/a-22-part-ii-centuries',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/26578/je-faisois-ces-sonnets-tr-by-george-dillon',
#  'https://www.poetryfoundation.org/poetrymagazine/poems/28076/brucio-e-limminenza-lombra-che-sale-riconosco']

# %%
poem_url = 'https://www.poetryfoundation.org/poetrymagazine/poems/29779/walking-56d2134a84892'

jumble_pattern = r'-[0-9]+[a-z][0-9a-z]*$'
clean_url = re.sub(jumble_pattern, '', poem_url)
# try:
#     title = soup.find('h1').contents[-1].strip()
# except:
title_pattern = r'[a-z0-9\-]*$'
title = re.search(
    title_pattern,
    clean_url,
    re.I).group().replace(
    '-',
    ' ').title()
    
title
# Out:
# 'Walking'

# %%
title.split()[-1].upper()
# Out:
# 'WALKING'

# %%
scan_poem_rescrape('https://www.poetryfoundation.org/poetrymagazine/poems/29779/walking-56d2134a84892')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-401-2868a4927961> in process_image_rescrape(poem_url, first)
#      22             scan_pattern = fr'{title.split()[-1].upper()}\b.*((\r?\n(?![A-Z][A-Z ]{3,}$).*)*)'
# ---> 23             lines = re.search(scan_pattern, text, re.MULTILINE).group(1).splitlines()
#      24         except:
#
# AttributeError: 'NoneType' object has no attribute 'group'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-401-2868a4927961> in process_image_rescrape(poem_url, first)
#      26                 scan_pattern = fr'{title.split()[0].upper()}\b.*((\r?\n(?![A-Z][A-Z ]{3,}$).*)*)'
# ---> 27                 lines = re.search(scan_pattern, text, re.MULTILINE).group(1).splitlines()
#      28             except:
#
# AttributeError: 'NoneType' object has no attribute 'group'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-402-9ec16f8e3256> in <module>
# ----> 1 scan_poem_rescrape('https://www.poetryfoundation.org/poetrymagazine/poems/29779/walking-56d2134a84892')
#
# <ipython-input-401-2868a4927961> in scan_poem_rescrape(poem_url)
#      44
#      45 def scan_poem_rescrape(poem_url):
# ---> 46     lines, poet, title, next_page = process_image_rescrape(poem_url)
#      47     while re.match(r'[\[\(]?[\d]+[\]\)]?', lines[-1]):
#      48         add_lines, next_page = process_image_rescrape(next_page, first=False)
#
# <ipython-input-401-2868a4927961> in process_image_rescrape(poem_url, first)
#      28             except:
#      29                 scan_pattern = fr'{title.split()[-1].lower()}\b.*((\r?\n(?![A-Z][A-Z ]{3,}$).*)*)'
# ---> 30                 lines = re.search(scan_pattern, text, re.MULTILINE).group(1).splitlines()
#      31
#      32     else:
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
type(poems.loc[157,'poem_lines'])
# Out:
# list

# %%
# rescrape poem based on index from above 
poems.loc[157,'poem_lines'] = PoemView_rescraper(poems.loc[157,'poem_url'])[0]
poems.loc[157,'poem_string'] = PoemView_rescraper(poems.loc[157,'poem_url'])[1]

# %%
# rescrape poem based on index from above 
poems.loc[157,'poem_lines'] = PoemView_rescraper(poems.loc[157,'poem_url'])[0]
poems.loc[157,'poem_string'] = PoemView_rescraper(poems.loc[157,'poem_url'])[1]

poems.loc[165,'poem_lines'] = PoemView_rescraper(poems.loc[165,'poem_url'])[0]
poems.loc[165,'poem_string'] = PoemView_rescraper(poems.loc[165,'poem_url'])[1]

poems.loc[210,'poem_lines'] = PoemView_rescraper(poems.loc[210,'poem_url'])[0]
poems.loc[210,'poem_string'] = PoemView_rescraper(poems.loc[210,'poem_url'])[1]

df_trim.loc[165,'poem_lines'] = str(PoemView_rescraper(df_trim.loc[703,'poem_url'])[0])
df_trim.loc[703,'poem_string'] = PoemView_rescraper(df_trim.loc[703,'poem_url'])[1]

df_trim.loc[952,'poem_lines'] = str(poempara_rescraper(df_trim.loc[952,'poem_url'])[0])
df_trim.loc[952,'poem_string'] = poempara_rescraper(df_trim.loc[952,'poem_url'])[1]

df_trim.loc[953,'poem_lines'] = str(modified_regular_rescraper(df_trim.loc[953,'poem_url'])[0])
df_trim.loc[953,'poem_string'] = modified_regular_rescraper(df_trim.loc[953,'poem_url'])[1]

df_trim.loc[1231,'poem_lines'] = str(justify_rescraper(df_trim.loc[1231,'poem_url'])[0])
df_trim.loc[1231,'poem_string'] = justify_rescraper(df_trim.loc[1231,'poem_url'])[1]

df_trim.loc[1234,'poem_lines'] = str(justify_rescraper(df_trim.loc[1234,'poem_url'])[0])
df_trim.loc[1234,'poem_string'] = justify_rescraper(df_trim.loc[1234,'poem_url'])[1]

df_trim.loc[1389,'poem_lines'] = str(PoemView_rescraper(df_trim.loc[1389,'poem_url'])[0])
df_trim.loc[1389,'poem_string'] = PoemView_rescraper(df_trim.loc[1389,'poem_url'])[1]

df_trim.loc[1603,'poem_lines'] = str(PoemView_rescraper(df_trim.loc[1603,'poem_url'])[0])
df_trim.loc[1603,'poem_string'] = PoemView_rescraper(df_trim.loc[1603,'poem_url'])[1]

df_trim.loc[2514,'poem_lines'] = str(PoemView_rescraper(df_trim.loc[2514,'poem_url'])[0])
df_trim.loc[2514,'poem_string'] = PoemView_rescraper(df_trim.loc[2514,'poem_url'])[1]

df_trim.loc[2517,'poem_lines'] = str(PoemView_rescraper(df_trim.loc[2517,'poem_url'])[0])
df_trim.loc[2517,'poem_string'] = PoemView_rescraper(df_trim.loc[2517,'poem_url'])[1]

df_trim.loc[3335,'poem_lines'] = str(ranged_rescraper(df_trim.loc[3335,'poem_url'])[0])
df_trim.loc[3335,'poem_string'] = ranged_rescraper(df_trim.loc[3335,'poem_url'])[1]

df_trim.loc[3418,'poem_lines'] = str(center_rescraper(df_trim.loc[3418,'poem_url'])[0])
df_trim.loc[3418,'poem_string'] = center_rescraper(df_trim.loc[3418,'poem_url'])[1]

df_trim.loc[3421,'poem_lines'] = str(justify_rescraper(df_trim.loc[3421,'poem_url'])[0])
df_trim.loc[3421,'poem_string'] = justify_rescraper(df_trim.loc[3421,'poem_url'])[1]

df_trim.loc[4217,'poem_lines'] = str(poempara_rescraper(df_trim.loc[4217,'poem_url'])[0])
df_trim.loc[4217,'poem_string'] = poempara_rescraper(df_trim.loc[4217,'poem_url'])[1]

df_trim.loc[4611,'poem_lines'] = str(poempara_rescraper(df_trim.loc[4611,'poem_url'])[0])
df_trim.loc[4611,'poem_string'] = poempara_rescraper(df_trim.loc[4611,'poem_url'])[1]

# %%
PoemView_rescraper('https://www.poetryfoundation.org/poems/54566/kora-in-hell-improvisations-xiv')
# Out:
# (['XIV1',
#   'The brutal Lord of All will rip us from each other—leave the one to suffer here alone. No need belief in god or hell to postulate that much. The dance: hands touching, leaves touching—eyes looking, clouds rising—lips touching, cheeks touching, arm about . . . Sleep. Heavy head, heavy arm, heavy dream—: Of Ymir’s flesh the earth was made and of his thoughts were all the gloomy clouds created. Oya!  ________________',
#   'Out of bitterness itself the clear wine of the imagination will be pressed and the dance prosper thereby.  2',
#   'To you! whoever you are, wherever you are! (But I know where you are!) There’s Dürer’s “Nemesis” naked on her sphere over the little town by the river—except she’s too old. There’s a dancing burgess by Tenier and Villon’s maitresse—after he’d gone bald and was skin pocked and toothless: she that had him ducked in the sewage drain. Then there’s that miller’s daughter of “buttocks broad and breastes high.” Something of Nietzsche, something of the good Samaritan, something of the devil himself,—can cut a caper of a fashion, my fashion! Hey you, the dance! Squat. leap. Hips to the left. Chin—ha!—sideways! Stand up, stand up ma bonne! you’ll break my backbone. So again!—and so forth till we’re sweat soaked.  ________________',
#   'Some fools once were listening to a poet reading his poem. It so happened that the words of the thing spoke of gross matters of the everyday world such as are never much hidden from a quick eye. Out of these semblances, and borrowing certain members from fitting masterpieces of antiquity, the poet began piping up his music, simple fellow, thinking to please his listeners. But they getting the whole matter sadly muddled in their minds made such a confused business of listening that not only were they not pleased at the poet’s exertions but no sooner had he done than they burst out against him with violent imprecations.  3',
#   'It’s all one. Richard worked years to conquer the descending cadence, idiotic sentimentalist. Ha, for happiness! This tore the dress in ribbons from her maid’s back and not spared the nails either; wild anger spit from her pinched eyes! This is the better part. Or a child under a table to be dragged out coughing and biting, eyes glittering evilly. I’ll have it my way! Nothing is any pleasure but misery and brokenness. THIS is the only up-cadence. This is where the secret rolls over and opens its eyes. Bitter words spoken to a child ripple in morning light! Boredom from a bedroom doorway thrills with anticipation! The complaints of an old man dying piecemeal are starling chirrups. Coughs go singing on springtime paths across a field; corruption picks strawberries and slow warping of the mind, blacking the deadly walls—counted and recounted—rolls in the grass and shouts ecstatically. All is solved! The moaning and dull sobbing of infants sets blood tingling and eyes ablaze to listen. Speed sings in the heels at long nights tossing on coarse sheets with bruning sockets staring into the black. Dance! Sing! Coil and uncoil! Whip yourselves about! Shout the deliverance! An old woman has infected her blossomy grand-daughter with a blood illness that every two weeks drives the mother into hidden songs of agony, the pad-footed mirage of creeping death for music. The face muscles keep pace. Then a darting about the compass in a tarantelle that wears flesh from bones. Here is dancing! The mind in tatters. And so the music wistfully takes the lead. Ay de mí, Juana la Loca, reina de España, esa está tu canta, reina mía!'],
—counted and recounted—rolls in the grass and shouts ecstatically. All is solved! The moaning and dull sobbing of infants sets blood tingling and eyes ablaze to listen. Speed sings in the heels at long nights tossing on coarse sheets with bruning sockets staring into the black. Dance! Sing! Coil and uncoil! Whip yourselves about! Shout the deliverance! An old woman has infected her blossomy grand-daughter with a blood illness that every two weeks drives the mother into hidden songs of agony, the pad-footed mirage of creeping death for music. The face muscles keep pace. Then a darting about the compass in a tarantelle that wears flesh from bones. Here is dancing! The mind in tatters. And so the music wistfully takes the lead. Ay de mí\ufeff, Juana la Loca, reina de Españ\ufeffa, esa está\ufeff tu canta, reina mí\ufeffa!\ufeff\n']

# %%
page = rq.get(poem_url)
soup = bs(page.content, 'html.parser')

# %%
text_poems = text_poems[text_poems.poem_string != ''].reset_index(drop=True)
text_poems.shape
# Out:
# (3082, 6)

# %%
text_poems.to_csv('data/text_poems.csv')

# %%
text_poems[text_poems.poet == 'William Carlos Williams']
# Out:
#                         poet  \
# 810  William Carlos Williams
# 811  William Carlos Williams
# 812  William Carlos Williams
# 813  William Carlos Williams
# 814  William Carlos Williams
# 815  William Carlos Williams
# 816  William Carlos Williams
# 817  William Carlos Williams
# 818  William Carlos Williams
# 819  William Carlos Williams
# 820  William Carlos Williams
# 821  William Carlos Williams
# 822  William Carlos Williams
# 823  William Carlos Williams
# 824  William Carlos Williams
# 825  William Carlos Williams
# 826  William Carlos Williams
# 827  William Carlos Williams
# 828  William Carlos Williams
# 829  William Carlos Williams
# 830  William Carlos Williams
# 831  William Carlos Williams
# 832  William Carlos Williams
# 833  William Carlos Williams
# 834  William Carlos Williams
# 835  William Carlos Williams
# 836  William Carlos Williams
# 837  William Carlos Williams
# 838  William Carlos Williams
# 839  William Carlos Williams
#
#                                                                                               poem_url  \
# 810       https://www.poetryfoundation.org/poems/148460/spring-and-all-chapter-xiii-thus-weary-of-life
# 811                                   https://www.poetryfoundation.org/poems/56159/this-is-just-to-say
# 812            https://www.poetryfoundation.org/poems/148462/spring-and-all-xi-in-passing-with-my-mind
# 813                      https://www.poetryfoundation.org/poems/53078/flowers-by-the-sea-56d23210587cf
# 814                                         https://www.poetryfoundation.org/poems/49849/between-walls
# 815                       https://www.poetryfoundation.org/poems/54566/kora-in-hell-improvisations-xiv
# 816                                              https://www.poetryfoundation.org/poems/46485/to-elsie
# 817                     https://www.poetryfoundation.org/poems/54564/kora-in-hell-improvisations-xxvii
# 818                               https://www.poetryfoundation.org/poems/54326/love-song-56d2348bab385
# 819                                      https://www.poetryfoundation.org/poems/46484/queen-annes-lace
# 820        https://www.poetryfoundation.org/poems/148461/spring-and-all-iii-the-farmer-in-deep-thought
# 821                    https://www.poetryfoundation.org/poems/45497/complete-destruction-56d22520b4800
# 822                            https://www.poetryfoundation.org/poems/45498/the-crowd-at-the-ball-game
# 823                       https://www.poetryfoundation.org/poems/45499/dedication-for-a-plot-of-ground
# 824                                                 https://www.poetryfoundation.org/poems/45503/tract
# 825                         https://www.poetryfoundation.org/poems/57325/sonnet-in-search-of-an-author
# 838  Somebody dies every four minutes\nin New York State —\nTo hell with you and your poetry —\nYou will rot and be blown\nthrough the next solar syste...
# 839  Snow: years of anger following hours that float idly down — the blizzard drifts its weight deeper and deeper for three days or sixty years, eh? Th...
#
#        genre
# 810  imagist
# 811  imagist
# 812  imagist
# 813  imagist
# 814  imagist
# 815  imagist
# 816  imagist
# 817  imagist
# 818  imagist
# 819  imagist
# 820  imagist
# 821  imagist
# 822  imagist
# 823  imagist
# 824  imagist
# 825  imagist
# 826  imagist
# 827  imagist
# 828  imagist
# 829  imagist
# 830  imagist
# 831  imagist
# 832  imagist
# 833  imagist
# 834  imagist
# 835  imagist
# 836  imagist
# 837  imagist
# 838  imagist
# 839  imagist

# %%
poet_poems_url_dict
# Out:
# {'augustan': [{'https://www.poetryfoundation.org/poets/mary-barber': (['https://www.poetryfoundation.org/poems/50523/advice-to-her-son-on-marriage'],
#     [])},
#   {'https://www.poetryfoundation.org/poets/susanna-blamire': (['https://www.poetryfoundation.org/poems/50534/auld-robin-forbes',
#      'https://www.poetryfoundation.org/poems/50532/the-siller-croun',
#      'https://www.poetryfoundation.org/poems/50533/o-donald-ye-are-just-the-man'],
#     [])},
#   {'https://www.poetryfoundation.org/poets/henry-carey': (['https://www.poetryfoundation.org/poems/43884/the-ballad-of-sally-in-our-alley'],
#     [])},
#   {'https://www.poetryfoundation.org/poets/thomas-chatterton': (['https://www.poetryfoundation.org/poems/43925/an-excelente-balade-of-charitie',
#      'https://www.poetryfoundation.org/poems/43924/aella-a-tragical-interlude'],
#     [])},
#   {'https://www.poetryfoundation.org/poets/william-collins': (['https://www.poetryfoundation.org/poems/44003/ode-to-evening',
#      'https://www.poetryfoundation.org/poems/44002/an-ode-on-the-popular-superstitions-of-the-highlands-of-scotland-considered-as-the-subject-of-poetry',
#      'https://www.poetryfoundation.org/poems/52293/eclogue-the-second-hassan-or-the-camel-driver',
#      'https://www.poetryfoundation.org/poems/44001/ode-on-the-poetical-character'],
#     [])},
#   {'https://www.poetryfoundation.org/poets/william-cowper': (['https://www.poetryfoundation.org/poems/44035/the-task-book-i-the-sofa',
#      'https://www.poetryfoundation.org/poems/44034/sonnet-to-william-wilberforce-esq',
#      'https://www.poetryfoundation.org/poems/50600/hatred-and-vengeance-my-eternal-portion',
#      'https://www.poetryfoundation.org/poems/44029/on-the-loss-of-the-royal-george',
#      'https://www.poetryfoundation.org/poems/44028/light-shining-out-of-darkness',
#      'https://www.poetryfoundation.org/poems/50599/epitaph-on-a-hare',
#      'https://www.poetryfoundation.org/poems/44036/the-task-book-ii-the-time-piece',
#      'https://www.poetryfoundation.org/poems/44031/on-receipt-of-my-mothers-picture',
#      'https://www.poetryfoundation.org/poems/44033/the-shrubbery',
#      'https://www.poetryfoundation.org/poems/44039/the-task-book-vi-the-winter-walk-at-noon',
#      'https://www.poetryfoundation.org/poems/44027/the-castaway',
#      'https://www.poetryfoundation.org/poems/44037/the-task-book-iv-the-winter-evening',
#      'https://www.poetryfoundation.org/poems/44038/the-task-book-v-the-winter-morning-walk'],
#     [])},
#   {'https://www.poetryfoundation.org/poets/daniel-defoe': (['https://www.poetryfoundation.org/poems/44081/the-true-born-englishman'],
#     [])},
#   {'https://www.poetryfoundation.org/poets/anne-finch': (['https://www.poetryfoundation.org/poems/50574/the-answer-56d22dc3e6ea0',
#      'https://www.poetryfoundation.org/poems/50566/adam-posed-56d22dc0cdf52',
#      'https://www.poetryfoundation.org/poems/50575/on-myself',
#      'https://www.poetryfoundation.org/poems/50564/the-introduction',
#      'https://www.poetryfoundation.org/poems/50560/a-song-56d22dbe9ef8e',
#      'https://www.poetryfoundation.org/poems/47656/to-the-nightingale',

#      'https://www.poetryfoundation.org/poetrymagazine/poems/21676/dust-and-the-glory'])},
#   {'https://www.poetryfoundation.org/poets/lawrence-ferlinghetti': (['https://www.poetryfoundation.org/poems/42869/i-am-waiting-56d22183d718a',
#      'https://www.poetryfoundation.org/poems/42865/queens-cemetery-setting-sun',
#      'https://www.poetryfoundation.org/poems/42862/dont-let-that-horse-',
#      'https://www.poetryfoundation.org/poems/42863/in-golden-gate-park-that-day-',
#      'https://www.poetryfoundation.org/poems/42858/retired-ballerinas-central-park-west',
#      'https://www.poetryfoundation.org/poems/42867/away-above-a-harborful-',
#      'https://www.poetryfoundation.org/poems/42860/sometime-during-eternity-',
#      'https://www.poetryfoundation.org/poems/52319/constantly-risking-absurdity-15',
#      'https://www.poetryfoundation.org/poems/42861/in-goyas-greatest-scenes-we-seem-to-see-',
#      'https://www.poetryfoundation.org/poems/42871/underwear',
#      'https://www.poetryfoundation.org/poems/42868/london-crossfigured',
#      'https://www.poetryfoundation.org/poems/42859/people-getting-divorced',
#      'https://www.poetryfoundation.org/poems/42870/autobiography-56d221842ab9d',
#      'https://www.poetryfoundation.org/poems/42866/the-canticle-of-jack-kerouac',
#      'https://www.poetryfoundation.org/poems/53076/dog-56d2320f90631',
#      'https://www.poetryfoundation.org/poems/42864/i-genitori-perduti'],
#     ['https://www.poetryfoundation.org/poetrymagazine/poems/58150/beatitudes-visuales-mexicanas'])},
#   {'https://www.poetryfoundation.org/poets/allen-ginsberg': (['https://www.poetryfoundation.org/poems/49303/howl',
#      'https://www.poetryfoundation.org/poems/49304/sunflower-sutra',
#      'https://www.poetryfoundation.org/poems/49313/kaddish',
#      'https://www.poetryfoundation.org/poems/47660/a-supermarket-in-california',
#      'https://www.poetryfoundation.org/poems/49310/mugging-i',
#      'https://www.poetryfoundation.org/poems/50123/new-stanzas-for-amazing-grace',
#      'https://www.poetryfoundation.org/poems/54163/footnote-to-howl',
#      'https://www.poetryfoundation.org/poems/49305/america-56d22b41f119f',
#      'https://www.poetryfoundation.org/poems/49307/my-sad-self',
#      'https://www.poetryfoundation.org/poems/49311/homework-56d22b44cb0bd'],
#     ['https://www.poetryfoundation.org/poetrymagazine/poems/36505/written-in-my-dream-by-w-c-williams'])},
#   {'https://www.poetryfoundation.org/poets/jack-hirschman': ([],
#     ['https://www.poetryfoundation.org/poetrymagazine/poems/30162/the-baseball-poem',
#      'https://www.poetryfoundation.org/poetrymagazine/poems/29383/from-one-finger-from-the-seasons'])},
#   {'https://www.poetryfoundation.org/poets/bob-kaufman': (['https://www.poetryfoundation.org/poems/55714/believe-believe',
#      'https://www.poetryfoundation.org/poems/55713/a-terror-is-more-certain-',
#      'https://www.poetryfoundation.org/poems/55967/the-night-that-lorca-comes',
#      'https://www.poetryfoundation.org/poems/55966/walking-parker-home',
#      'https://www.poetryfoundation.org/poems/55715/o-jazz-o-war-memoir-jazz-dont-listen-to-it-at-your-own-risk'],
#     [])},
#   {'https://www.poetryfoundation.org/poets/michael-mcclure': (['https://www.poetryfoundation.org/poems/54613/dream-the-night-of-december-23rd-',
#      'https://www.poetryfoundation.org/poems/54612/the-chamber',
#      'https://www.poetryfoundation.org/poems/54614/mexico-seen-from-the-moving-car-',
#      'https://www.poetryfoundation.org/poems/54611/the-mystery-of-the-hunt'],
#     ['https://www.poetryfoundation.org/poetrymagazine/poems/26838/2-for-theodore-roethke',
#      'https://www.poetryfoundation.org/poetrymagazine/poems/29416/mad-sonnet-we-shall-be-free',
#      'https://www.poetryfoundation.org/poetrymagazine/poems/29415/mad-sonnet-when-spirit-has-no-edge',
#      'https://www.poetryfoundation.org/poetrymagazine/poems/29414/the-child'])},
#   {'https://www.poetryfoundation.org/poets/kenneth-patchen': (['https://www.poetryfoundation.org/poems/46342/the-cloth-of-the-tempest',
#      'https://www.poetryfoundation.org/poems/46343/eve-of-st-agony-or-the-middleclass-was-sitting-on-its-fat',
#      'https://www.poetryfoundation.org/poems/46341/my-generation-reading-the-newspapers',
#      'https://www.poetryfoundation.org/poems/49267/as-we-are-so-wonderfully-done-with-each-other',
#      'https://www.poetryfoundation.org/poems/55969/at-the-new-year',
#      'https://www.poetryfoundation.org/poems/46346/the-murder-of-two-men-by-a-young-kid-wearing-lemon-colored-gloves',
#      'https://www.poetryfoundation.org/poems/46339/the-snow-is-deep-on-the-ground',
#      'https://www.poetryfoundation.org/poems/46340/the-rites-of-darkness',
#      'https://www.poetryfoundation.org/poems/46345/be-music-night',
#      'https://www.poetryfoundation.org/poems/46347/in-order-to'],
#     ['https://www.poetryfoundation.org/poetrymagazine/poems
],
#     [])},
#   {'https://www.poetryfoundation.org/poets/mari-evans': ([], [])},
#   {'https://www.poetryfoundation.org/poets/sarah-webster-fabio': ([], [])},
#   {'https://www.poetryfoundation.org/poets/nikki-giovanni': (['https://www.poetryfoundation.org/poems/48231/a-poem-on-the-assassination-of-robert-f-kennedy',
#      'https://www.poetryfoundation.org/poems/48229/they-clapped',
#      'https://www.poetryfoundation.org/poems/48228/mothers',
#      'https://www.poetryfoundation.org/poems/90179/blk-history-month',
#      'https://www.poetryfoundation.org/poems/90181/no-complaints',
#      'https://www.poetryfoundation.org/poems/48221/the-great-pax-whitie',
#      'https://www.poetryfoundation.org/poems/48224/dreams-56d229494e255',
#      'https://www.poetryfoundation.org/poems/48226/poem-for-a-lady-whose-voice-i-like',
#      'https://www.poetryfoundation.org/poems/48216/a-historical-footnote-to-consider-only-when-all-else-fails',
#      'https://www.poetryfoundation.org/poems/90180/rosa-parks',
#      'https://www.poetryfoundation.org/poems/90182/the-song-of-the-feet',
#      'https://www.poetryfoundation.org/poems/48219/nikki-rosa',
#      'https://www.poetryfoundation.org/poems/48230/the-laws-of-motion',
#      'https://www.poetryfoundation.org/poems/48227/legacies',
#      'https://www.poetryfoundation.org/poems/48225/walking-down-park'],
#     [])},
#   {'https://www.poetryfoundation.org/poets/bell-hooks': (['https://www.poetryfoundation.org/poems/148751/appalachian-elegy-1-6'],
#     [])},
#   {'https://www.poetryfoundation.org/poets/etheridge-knight': (['https://www.poetryfoundation.org/poems/48752/feeling-fucked-up',
#      'https://www.poetryfoundation.org/poems/51373/last-words-by-slick',
#      'https://www.poetryfoundation.org/poems/47593/haiku',
#      'https://www.poetryfoundation.org/poems/51367/hard-rock-returns-to-prison-from-the-hospital-for-the-criminal-insane',
#      'https://www.poetryfoundation.org/poems/49934/the-idea-of-ancestry',
#      'https://www.poetryfoundation.org/poems/51372/apology-for-apostasy',
#      'https://www.poetryfoundation.org/poems/147809/he-sees-through-stone',
#      'https://www.poetryfoundation.org/poems/54239/the-sun-came',
#      'https://www.poetryfoundation.org/poems/147810/the-violent-space-or-when-your-sister-sleeps-around-for-money',
#      'https://www.poetryfoundation.org/poems/51368/a-wasp-woman-visits-a-black-junkie-in-prison',
#      'https://www.poetryfoundation.org/poems/51369/for-freckle-faced-gerald',
#      'https://www.poetryfoundation.org/poems/51371/a-fable-56d22f0fa5920',
#      'https://www.poetryfoundation.org/poems/51370/for-malcolm-a-year-after',
#      'https://www.poetryfoundation.org/poems/51374/at-a-va-hospital-in-the-middle-of-the-united-states-of-america-an-act-in-a-play'],
#     [])},
#   {'https://www.poetryfoundation.org/poets/audre-lorde': (['https://www.poetryfoundation.org/poems/42578/from-the-house-of-yemanja',
#      'https://www.poetryfoundation.org/poems/42587/who-said-it-was-simple',
#      'https://www.poetryfoundation.org/poems/42582/afterimages',
#      'https://www.poetryfoundation.org/poems/42583/a-woman-speaks',
#      'https://www.poetryfoundation.org/poems/42584/never-to-dream-of-spiders',
#      'https://www.poetryfoundation.org/poems/42581/movement-song',
#      'https://www.poetryfoundation.org/poems/42588/sisters-in-arms',
#      'https://www.poetryfoundation.org/poems/42580/hanging-fire',
#      'https://www.poetryfoundation.org/poems/147275/a-litany-for-survival',
#      'https://www.poetryfoundation.org/poems/42577/coal',
#      'https://www.poetryfoundation.org/poems/53918/power-56d233adafeb3',
#      'https://www.poetryfoundation.org/poems/42579/recreation'],
#     [])},
#   {'https://www.poetryfoundation.org/poets/haki-madhubuti': (['https://www.poetryfoundation.org/poems/51277/quality-gwendolyn-brooks-at-73',
#      'https://www.poetryfoundation.org/poems/51275/for-the-consideration-of-poets',
#      'https://www.poetryfoundation.org/poems/51276/rwanda-where-tears-have-no-power',
#      'https://www.poetryfoundation.org/poems/50782/gwendolyn-brooks'],
#     ['https://www.poetryfoundation.org/poetrymagazine/poems/141965/gwendolyn-brooks-america-in-the-wintertime'])},
#   {'https://www.poetryfoundation.org/poets/larry-neal': (['https://www.poetryfoundation.org/poems/148634/holy-days'],
#     [])},
#   {'https://www.poetryfoundation.org/poets/sonia-sanchez': ([],
#     ['https://www.poetryfoundation.org/poetrymagazine/poems/146231/haiku-and-tanka-for-harriet-tubman'])},
#   {'https://www.poetryfoundation.org/poets/gil-scott-heron': ([], [])},
#   {'https://www.poetryfoundation.org/poets/ntozake-shange': (['https://www.poetryfoundation.org/poems/149660/lady-in-brown-de-library-waz-right-down-from-de-trolly-tracks',
#      'https://www.poetryfoundation.org/poems/148925/its-happenin-but-you-dont-know-abt-it',
#      'https://www.poetryfoundation.org/poems/149661/lady-in-red-at-430-am',
#      'https://www.poetryfoundation.org/poems/148924/nappy-edges-a-cross-country-sojourn',
#      'https://www.poetryfoundation.org/poems/148919/even-tho-yr-sampler-broke-down-on-you',
#      'https://www.poetryfoundation.org/poems/149662/lady-in-red-there-was-no-air-the-sheets-made-ripples-under-his',
#      'https://www.poetryfoundation.org/poems/148920/i-mood-indigo',
#      'https://www.poetryfoundation.org/poems/148922/senses-of-heritage',
#      'https://www.poetryfoundation.org/poems/148921/for-my-dead-loved-ones',
#      'https://www.poetryfoundation.org/poems/148923/who-am-i-thinkin-of'],
#     [])},
#   {'https://www.poetryfoundation.org/poets/lorenzo-thomas': (['https://www.poetryfoundation.org/poems/53348/mmdccxiii-1-2',
#      'https://www.poetryfoundation.org/poems/53346/inauguration',
#      'https://www.poetryfoundation.org/poems/53345/my-office',
#      'https://www.poetryfoundation.org/poems/53347/the-leopard'],
#     [])},
#   {'https://www.poetryfoundation.org/poets/quincy-troupe': (['https://www.poetryfoundation.org/poems/55712/poem-for-my-father'],
#     [])},
#   {'https://www.poetryfoundation.org/poets/alice-walker': ([], [])},
#   {'https://www.poetryfoundation.org/poets/jay-wright': (['https://www.poetryfoundation.org/poems/42751/boleros-14',
#      'https://www.poetryfoundation.org/poems/42737/benjamin-banneker-sends-his-almanac-to-thomas-jefferson',
#      'https://www.poetryfoundation.org/poems/42739/the-cradle-logic-of-autumn',
#      'https://www.poetryfoundation.org/poems/42743/meta-a-and-the-a-of-absolutes',
#      'https://www.poetryfoundation.org/poems/42742/homecoming-56d2215d7dd6f',
#      'https://www.poetryfoundation.org/poems/42738/journey-to-the-place-of-ghosts',
#      'https://www.poetryfoundation.org/poems/42744/the-lake-in-central-park',
#      'https://www.poetryfoundation.org/poems/42741/the-end-of-an-ethnic-dream',
#      'https://www.poetryfoundation.org/poems/42735/the-homecoming-singer',
#      'https://www.poetryfoundation.org/poems/42749/love-in-the-weathers-bells',
#      'https://www.poetryfoundation.org/poems/42740/the-healing-improvisation-of-hair',
#      'https://www.poetryfoundation.org/poems/42745/desires-persistence',
#      'https://www.poetryfoundation.org/poems/42736/benjamin-banneker-helps-to-build-a-city'],
#     [])}],
#  'black_mountain': [{'https://www.poetryfoundation.org/poets/paul-blackburn': (['https://www.poetryfoundation.org/poems/55512/7th-game-1960-series',
#      'https://www.poetryfoundation.org/poems/55511/brooklyn-narcissus',
#      'https://www.poetryfoundation.org/poems/55514/ritual-x-the-evening-pair-of-ales',
#      'https://www.poetryfoundation.org/poems/55515/journal-april-19-the-southern-tier',
#      'https://www.poetryfoundation.org/poems/55513/the-cafe-filtre'],
#     ['https://www.poetryfoundation.org/poetrymagazine/poems
],
#     [])},
#   {'https://www.poetryfoundation.org/poets/william-makepeace-thackeray': (['https://www.poetryfoundation.org/poems/52711/the-cane-bottomd-chair'],
#     [])},
#   {'https://www.poetryfoundation.org/poets/mark-twain': (['https://www.poetryfoundation.org/poems/45419/ode-to-stephen-dowling-bots-decd',
#      'https://www.poetryfoundation.org/poems/46037/warm-summer-sun'],
#     [])},
#   {'https://www.poetryfoundation.org/poets/katharine-tynan': (['https://www.poetryfoundation.org/poems/57291/joining-the-colours',
#      'https://www.poetryfoundation.org/poems/57349/a-lament-56d23ac7ae84a'],
#     [])},
#   {'https://www.poetryfoundation.org/poets/john-greenleaf-whittier': (['https://www.poetryfoundation.org/poems/53105/the-pumpkin',
#      'https://www.poetryfoundation.org/poems/45488/my-triumph',
#      'https://www.poetryfoundation.org/poems/45490/snow-bound-a-winter-idyl',
#      'https://www.poetryfoundation.org/poems/45486/ichabod',
#      'https://www.poetryfoundation.org/poems/45492/what-the-birds-said',
#      'https://www.poetryfoundation.org/poems/45482/an-autograph',
#      'https://www.poetryfoundation.org/poems/45484/the-barefoot-boy',
#      'https://www.poetryfoundation.org/poems/45491/telling-the-bees',
#      'https://www.poetryfoundation.org/poems/45485/burning-drift-wood',
#      'https://www.poetryfoundation.org/poems/45487/in-school-days',
#      'https://www.poetryfoundation.org/poems/45483/barbara-frietchie',
#      'https://www.poetryfoundation.org/poems/45489/skipper-iresons-ride',
#      'https://www.poetryfoundation.org/poems/45493/the-worship-of-nature'],
#     [])},
#   {'https://www.poetryfoundation.org/poets/oscar-wilde': (['https://www.poetryfoundation.org/poems/45495/the-ballad-of-reading-gaol'],
#     [])}]}

# %%
poet_poems_url_dict['augustan']
# Out:
# [{'https://www.poetryfoundation.org/poets/mary-barber': (['https://www.poetryfoundation.org/poems/50523/advice-to-her-son-on-marriage'],
#    [])},
#  {'https://www.poetryfoundation.org/poets/susanna-blamire': (['https://www.poetryfoundation.org/poems/50534/auld-robin-forbes',
#     'https://www.poetryfoundation.org/poems/50532/the-siller-croun',
#     'https://www.poetryfoundation.org/poems/50533/o-donald-ye-are-just-the-man'],
#    [])},
#  {'https://www.poetryfoundation.org/poets/henry-carey': (['https://www.poetryfoundation.org/poems/43884/the-ballad-of-sally-in-our-alley'],
#    [])},
#  {'https://www.poetryfoundation.org/poets/thomas-chatterton': (['https://www.poetryfoundation.org/poems/43925/an-excelente-balade-of-charitie',
#     'https://www.poetryfoundation.org/poems/43924/aella-a-tragical-interlude'],
#    [])},
#  {'https://www.poetryfoundation.org/poets/william-collins': (['https://www.poetryfoundation.org/poems/44003/ode-to-evening',
#     'https://www.poetryfoundation.org/poems/44002/an-ode-on-the-popular-superstitions-of-the-highlands-of-scotland-considered-as-the-subject-of-poetry',
#     'https://www.poetryfoundation.org/poems/52293/eclogue-the-second-hassan-or-the-camel-driver',
#     'https://www.poetryfoundation.org/poems/44001/ode-on-the-poetical-character'],
#    [])},
#  {'https://www.poetryfoundation.org/poets/william-cowper': (['https://www.poetryfoundation.org/poems/44035/the-task-book-i-the-sofa',
#     'https://www.poetryfoundation.org/poems/44034/sonnet-to-william-wilberforce-esq',
#     'https://www.poetryfoundation.org/poems/50600/hatred-and-vengeance-my-eternal-portion',
#     'https://www.poetryfoundation.org/poems/44029/on-the-loss-of-the-royal-george',
#     'https://www.poetryfoundation.org/poems/44028/light-shining-out-of-darkness',
],
#    [])},
#  {'https://www.poetryfoundation.org/poets/matthew-prior': (['https://www.poetryfoundation.org/poems/50473/a-true-maid',
#     'https://www.poetryfoundation.org/poems/50576/a-fable-56d22dc4b0597',
#     'https://www.poetryfoundation.org/poems/50577/an-ode-56d22dc5157c1'],
#    [])},
#  {'https://www.poetryfoundation.org/poets/richard-brinsley-sheridan': (['https://www.poetryfoundation.org/poems/50472/the-geranium-56d22d9c2a79a'],
#    [])},
#  {'https://www.poetryfoundation.org/poets/jonathan-swift': (['https://www.poetryfoundation.org/poems/50578/a-description-of-a-city-shower',
#     'https://www.poetryfoundation.org/poems/45270/stellas-birthday-march-13-1727',
#     'https://www.poetryfoundation.org/poems/45265/the-beasts-confession',
#     'https://www.poetryfoundation.org/poems/45272/verses-on-the-death-of-dr-swift-dspd',
#     'https://www.poetryfoundation.org/poems/50390/market-womens-cries',
#     'https://www.poetryfoundation.org/poems/50579/the-ladys-dressing-room',
#     'https://www.poetryfoundation.org/poems/45269/on-stellas-birth-day',
#     'https://www.poetryfoundation.org/poems/45264/advice-to-the-grub-street-verse-writers',
#     'https://www.poetryfoundation.org/poems/50580/a-beautiful-young-nymph-going-to-bed',
#     'https://www.poetryfoundation.org/poems/45267/to-quilca-a-country-house-not-in-good-repair',
#     'https://www.poetryfoundation.org/poems/45268/a-satirical-elegy-on-the-death-of-a-late-famous-general',
#     'https://www.poetryfoundation.org/poems/45266/a-description-of-the-morning'],
#    [])},
#  {'https://www.poetryfoundation.org/poets/james-thomson': (['https://www.poetryfoundation.org/poems/45406/the-seasons-winter',
#     'https://www.poetryfoundation.org/poems/45404/rule-britannia',
#     'https://www.poetryfoundation.org/poems/52409/the-seasons-spring'],
#    [])},
#  {'https://www.poetryfoundation.org/poets/isaac-watts': (['https://www.poetryfoundation.org/poems/50585/psalm-114',
#     'https://www.poetryfoundation.org/poems/50583/our-god-our-help',
#     'https://www.poetryfoundation.org/poems/50582/a-prospect-of-heaven-makes-death-easy',
#     'https://www.poetryfoundation.org/poems/50584/psalm-58',
#     'https://www.poetryfoundation.org/poems/50581/the-day-of-judgment'],
#    [])},
#  {'https://www.poetryfoundation.org/poets/john-wesley': (['https://www.poetryfoundation.org/poems/45463/hymn-thou-hidden-love-of-god'],
#    [])}]

# %%
test = {genre:{'text_urls':[],'scan_urls':[]} for genre in poet_poems_url_dict}
for genre,poets in poet_poems_url_dict.items():
    for poet in poets:
        for poet_url, poems in poet.items():
            test[genre]['text_urls'].extend(poems[0])
            test[genre]['scan_urls'].extend(poems[1])
            
test
# Out:
# {'augustan': {'text_urls': ['https://www.poetryfoundation.org/poems/50523/advice-to-her-son-on-marriage',
#    'https://www.poetryfoundation.org/poems/50534/auld-robin-forbes',
#    'https://www.poetryfoundation.org/poems/50532/the-siller-croun',
#    'https://www.poetryfoundation.org/poems/50533/o-donald-ye-are-just-the-man',
#    'https://www.poetryfoundation.org/poems/43884/the-ballad-of-sally-in-our-alley',
#    'https://www.poetryfoundation.org/poems/43925/an-excelente-balade-of-charitie',
#    'https://www.poetryfoundation.org/poems/43924/aella-a-tragical-interlude',
#    'https://www.poetryfoundation.org/poems/44003/ode-to-evening',
#    'https://www.poetryfoundation.org/poems/44002/an-ode-on-the-popular-superstitions-of-the-highlands-of-scotland-considered-as-the-subject-of-poetry',
#    'https://www.poetryfoundation.org/poems/52293/eclogue-the-second-hassan-or-the-camel-driver',
#    'https://www.poetryfoundation.org/poems/44001/ode-on-the-poetical-character',
#    'https://www.poetryfoundation.org/poems/44035/the-task-book-i-the-sofa',
#    'https://www.poetryfoundation.org/poems/44034/sonnet-to-william-wilberforce-esq',
#    'https://www.poetryfoundation.org/poems/50600/hatred-and-vengeance-my-eternal-portion',
#    'https://www.poetryfoundation.org/poems/44029/on-the-loss-of-the-royal-george',
#    'https://www.poetryfoundation.org/poems/44028/light-shining-out-of-darkness',
#    'https://www.poetryfoundation.org/poems/50599/epitaph-on-a-hare',
#    'https://www.poetryfoundation.org/poems/44036/the-task-book-ii-the-time-piece',
#    'https://www.poetryfoundation.org/poems/44031/on-receipt-of-my-mothers-picture',
#    'https://www.poetryfoundation.org/poems/44033/the-shrubbery',
#    'https://www.poetryfoundation.org/poems/44039/the-task-book-vi-the-winter-walk-at-noon',
#    'https://www.poetryfoundation.org/poems/44027/the-castaway',
#    'https://www.poetryfoundation.org/poems/44037/the-task-book-iv-the-winter-evening',
#    'https://www.poetryfoundation.org/poems/44038/the-task-book-v-the-winter-morning-walk',
#    'https://www.poetryfoundation.org/poems/44081/the-true-born-englishman',
#    'https://www.poetryfoundation.org/poems/50574/the-answer-56d22dc3e6ea0',
#    'https://www.poetryfoundation.org/poems/50566/adam-posed-56d22dc0cdf52',
#    'https://www.poetryfoundation.org/poems/50575/on-myself',
#    'https://www.poetryfoundation.org/poems/50564/the-introduction',
#    'https://www.poetryfoundation.org/poems/50560/a-song-56d22dbe9ef8e',
#    'https://www.poetryfoundation.org/poems/47656/to-the-nightingale',
#    'https://www.poetryfoundation.org/poems/50565/the-spleen',
#    'https://www.poetryfoundation.org/poems/50567/to-death-56d22dc12ea67',
#    'https://www.poetryfoundation.org/poems/50573/a-nocturnal-reverie',
#    'https://www.poetryfoundation.org/poems/44243/the-tree-56d223423328c',
#    'https://www.poetryfoundation.org/poems/50561/a-letter-to-daphnis',
#    'https://www.poetryfoundation.org/poems/50572/friendship-between-ephelia-and-ardelia',
#    'https://www.poetryfoundation.org/poems/50490/to-a-young-lady-with-some-lampreys',
#    'https://www.poetryfoundation.org/poems/50587/songs-from-the-beggars-opera-air-xvi-over-the-hills-and-far-away',
#    'https://www.poetryfoundation.org/poems/50588/songs-from-the-beggars-opera-air-iv-cotillion',
#    'https://www.poetryfoundation.org/poems/50589/songs-from-the-beggars-opera-air-xxvii-green-sleeves',
#    'https://www.poetryfoundation.org/poems/50586/songs-from-the-beggars-opera-air-x-thomas-i-cannot',
#    'https://www.poetryfoundation.org/poems/45613/when-lovely-woman-stoops-to-folly',
#    'https://www.poetryfoundation.org/poems/44292/the-deserted-village',
#    'https://www.poetryfoundation.org/poems/44302/ode-on-the-death-of-a-favourite-cat-drowned-in-a-tub-of-goldfishes',
#    'https://www.poetryfoundation.org/poems/44298/the-bard-a-pindaric-ode',
#    'https://www.poetryfoundation.org/poems/44306/the-progress-of-poesy-a-pindaric-ode',
#    'https://www.poetryfoundation.org/poems/44304/ode-on-the-spring',
#    'https://www.poetryfoundation.org/poems/44300/the-fatal-sisters-an-ode',
#    'https://www.poetryfoundation.org/poems/44299/elegy-written-in-a-country-churchyard',
#    'https://www.poetryfoundation.org/poems/46372/writ-on-the-steps-of-puerto-rican-harlem',
#    'https://www.poetryfoundation.org/poems/46373/writ-on-the-eve-of-my-32nd-birthday',
#    'https://www.poetryfoundation.org/poems/46376/the-whole-mess-almost',
#    'https://www.poetryfoundation.org/poems/46375/america-politica-historia-in-spontaneity',
#    'https://www.poetryfoundation.org/poems/54975/an-exercise-in-love',
#    'https://www.poetryfoundation.org/poems/54971/song-for-baby-o-unborn',
#    'https://www.poetryfoundation.org/poems/54973/first-snow-kerhonkson',
#    'https://www.poetryfoundation.org/poems/54976/paracelsus',
#    'https://www.poetryfoundation.org/poems/54972/the-window-56d235f7b6c36',
#    'https://www.poetryfoundation.org/poems/54974/buddhist-new-year-song',
#    'https://www.poetryfoundation.org/poems/42869/i-am-waiting-56d22183d718a',
#    'https://www.poetryfoundation.org/poems/42865/queens-cemetery-setting-sun',
#    'https://www.poetryfoundation.org/poems/42862/dont-let-that-horse-',
#    'https://www.poetryfoundation.org/poems/42863/in-golden-gate-park-that-day-',
#    'https://www.poetryfoundation.org/poems/42858/retired-ballerinas-central-park-west',
#    'https://www.poetryfoundation.org/poems/42867/away-above-a-harborful-',
#    'https://www.poetryfoundation.org/poems/42860/sometime-during-eternity-',
#    'https://www.poetryfoundation.org/poems/52319/constantly-risking-absurdity-15',
#    'https://www.poetryfoundation.org/poems/42861/in-goyas-greatest-scenes-we-seem-to-see-',
#    'https://www.poetryfoundation.org/poems/42871/underwear',
#    'https://www.poetryfoundation.org/poems/42868/london-crossfigured',
#    'https://www.poetryfoundation.org/poems/42859/people-getting-divorced',
#    'https://www.poetryfoundation.org/poems/42870/autobiography-56d221842ab9d',
#    'https://www.poetryfoundation.org/poems/42866/the-canticle-of-jack-kerouac',
#    'https://www.poetryfoundation.org/poems/53076/dog-56d2320f90631',
#    'https://www.poetryfoundation.org/poems/42864/i-genitori-perduti',
#    'https://www.poetryfoundation.org/poems/49303/howl',
#    'https://www.poetryfoundation.org/poems/49304/sunflower-sutra',
#    'https://www.poetryfoundation.org/poems/49313/kaddish',
#    'https://www.poetryfoundation.org/poems/47660/a-supermarket-in-california',
#    'https://www.poetryfoundation.org/poems/49310/mugging-i',
#    'https://www.poetryfoundation.org/poems/50123/new-stanzas-for-amazing-grace',
#    'https://www.poetryfoundation.org/poems/54163/footnote-to-howl',
#    'https://www.poetryfoundation.org/poems/49305/america-56d22b41f119f',
#    'https://www.poetryfoundation.org/poems/49307/my-sad-self',
#    'https://www.poetryfoundation.org/poems/49311/homework-56d22b44cb0bd',
#    'https://www.poetryfoundation.org/poems/55714/believe-believe',
#    'https://www.poetryfoundation.org/poems/55713/a-terror-is-more-certain-',
#    'https://www.poetryfoundation.org/poems/55967/the-night-that-lorca-comes',
#    'https://www.poetryfoundation.org/poems/55966/walking-parker-home',
#    'https://www.poetryfoundation.org/poems/55715/o-jazz-o-war-memoir-jazz-dont-listen-to-it-at-your-own-risk',
#    'https://www.poetryfoundation.org/poems/54613/dream-the-night-of-december-23rd-',
#    'https://www.poetryfoundation.org/poems/54612/the-chamber',
#    'https://www.poetryfoundation.org/poems/54614/mexico-seen-from-the-moving-car-',
#    'https://www.poetryfoundation.org/poems/54611/the-mystery-of-the-hunt',
#    'https://www.poetryfoundation.org/poems/46342/the-cloth-of-the-tempest',
#    'https://www.poetryfoundation.org/poems/46343/eve-of-st-agony-or-the-middleclass-was-sitting-on-its-fat',
#    'https://www.poetryfoundation.org/poems/46341/my-generation-reading-the-newspapers',
#    'https://www.poetryfoundation.org/poems/49267/as-we-are-so-wonderfully-done-with-each-other',
#    'https://www.poetryfoundation.org/poems/55969/at-the-new-year',
#    'https://www.poetryfoundation.org/poems/46346/the-murder-of-two-men-by-a-young-kid-wearing-lemon-colored-gloves',
#    'https://www.poetryfoundation.org/poems/46339/the-snow-is-deep-on-the-ground',
#    'https://www.poetryfoundation.org/poems/46340/the-rites-of-darkness',
#    'https://www.poetryfoundation.org/poems/46345/be-music-night',
#    'https://www.poetryfoundation.org/poems/46347/in-order-to',
#    'https://www.poetryfoundation.org/poems/49303/howl',
#    'https://www.poetryfoundation.org/poems/42811/discrimination',
#    'https://www.poetryfoundation.org/poems/42802/vitamins-and-roughage',
#    'https://www.poetryfoundation.org/poems/42805/the-wheel-revolves',
#    'https://www.poetryfoundation.org/poems/42806/lyells-hypothesis-again',
#    'https://www.poetryfoundation.org/poems/54452/on-what-planet',
#    'https://www.poetryfoundation.org/poems/54457/doubled-mirrors',
#    'https://www.poetryfoundation.org/poems/42804/prousts-madeleine',
#    'https://www.poetryfoundation.org/poems/54453/falling-leaves-and-early-snow',
#    'https://www.poetryfoundation.org/poems/42810/climbing-milestone-mountain-august-22-1937',
#    'https://www.poetryfoundation.org/poems/42808/toward-an-organic-philosophy',
#    'https://www.poetryfoundation.org/poems/54455/delia-rexroth',
#    'https://www.poetryfoundation.org/poems/42803/the-bad-old-days',
#    'https://www.poetryfoundation.org/poems/46662/dancing-on-the-grave-of-a-son-of-a-bitch',
#    'https://www.poetryfoundation.org/poems/46661/thanking-my-mother-for-piano-lessons',
#    'https://www.poetryfoundation.org/poems/46659/belly-dancer',
#    'https://www.poetryfoundation.org/poems/46658/inside-out',
#    'https://www.poetryfoundation.org/poems/46663/blue-monday-56d2269d7b489',
#    'https://www.poetryfoundation.org/poems/46664/the-photos',
#    'https://www.poetryfoundation.org/poems/46657/uneasy-rider',
#    'https://www.poetryfoundation.org/poems/46660/the-father-of-my-country',
#    'https://www.poetryfoundation.org/poems/55778/wobbly-rock',
#    'https://www.poetryfoundation.org/poems/55777/circle-poems',
#    'https://www.poetryfoundation.org/poems/55780/springtime-in-the-rockies-lichen',
#    'https://www.poetryfoundation.org/poems/55779/i-saw-myself',
#    'https://www.poetryfoundation.org/poems/55776/chicago-poem'],
#   'scan_urls': ['https://www.poetryfoundation.org/poetrymagazine/poems/31338/wood',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/56423/a-boat-56d238e754f45',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/21675/we-in-the-fields',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/21676/dust-and-the-glory',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/58150/beatitudes-visuales-mexicanas',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/36505/written-in-my-dream-by-w-c-williams',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/30162/the-baseball-poem',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/29383/from-one-finger-from-the-seasons',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/26838/2-for-theodore-roethke',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/29416/mad-sonnet-we-shall-be-free',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/29415/mad-sonnet-when-spirit-has-no-edge',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/29414/the-child',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/26192/the-unanswering-correspondences',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/20314/empty-dwelling-places',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/26191/beautiful-you-are',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/23496/egypt-56d20e2477a7a',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/26193/all-is-safe',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/
#    'https://www.poetryfoundation.org/poems/149661/lady-in-red-at-430-am',
#    'https://www.poetryfoundation.org/poems/148924/nappy-edges-a-cross-country-sojourn',
#    'https://www.poetryfoundation.org/poems/148919/even-tho-yr-sampler-broke-down-on-you',
#    'https://www.poetryfoundation.org/poems/149662/lady-in-red-there-was-no-air-the-sheets-made-ripples-under-his',
#    'https://www.poetryfoundation.org/poems/148920/i-mood-indigo',
#    'https://www.poetryfoundation.org/poems/148922/senses-of-heritage',
#    'https://www.poetryfoundation.org/poems/148921/for-my-dead-loved-ones',
#    'https://www.poetryfoundation.org/poems/148923/who-am-i-thinkin-of',
#    'https://www.poetryfoundation.org/poems/53348/mmdccxiii-1-2',
#    'https://www.poetryfoundation.org/poems/53346/inauguration',
#    'https://www.poetryfoundation.org/poems/53345/my-office',
#    'https://www.poetryfoundation.org/poems/53347/the-leopard',
#    'https://www.poetryfoundation.org/poems/55712/poem-for-my-father',
#    'https://www.poetryfoundation.org/poems/42751/boleros-14',
#    'https://www.poetryfoundation.org/poems/42737/benjamin-banneker-sends-his-almanac-to-thomas-jefferson',
#    'https://www.poetryfoundation.org/poems/42739/the-cradle-logic-of-autumn',
#    'https://www.poetryfoundation.org/poems/42743/meta-a-and-the-a-of-absolutes',
#    'https://www.poetryfoundation.org/poems/42742/homecoming-56d2215d7dd6f',
#    'https://www.poetryfoundation.org/poems/42738/journey-to-the-place-of-ghosts',
#    'https://www.poetryfoundation.org/poems/42744/the-lake-in-central-park',
#    'https://www.poetryfoundation.org/poems/42741/the-end-of-an-ethnic-dream',
#    'https://www.poetryfoundation.org/poems/42735/the-homecoming-singer',
#    'https://www.poetryfoundation.org/poems/42749/love-in-the-weathers-bells',
#    'https://www.poetryfoundation.org/poems/42740/the-healing-improvisation-of-hair',
#    'https://www.poetryfoundation.org/poems/42745/desires-persistence',
#    'https://www.poetryfoundation.org/poems/42736/benjamin-banneker-helps-to-build-a-city'],
#   'scan_urls': ['https://www.poetryfoundation.org/poetrymagazine/poems/28989/as-a-possible-lover',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/29929/like-rousseau',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/29577/valery-as-dictator',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/28988/balboa-the-entertainer',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/29579/snake-eyes',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/57883/tender-arrivals',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/29578/the-liar-56d2131c60523',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/29930/history-as-process',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/23988/gay-chaps-at-the-bar',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/28112/we-real-cool',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/25174/the-children-of-the-poor',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/28111/old-mary',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/23989/still-do-i-keep-my-look-my-identity',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/28110/the-bean-eaters',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/28113/strong-men-riding-horses',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/31364/henry-rago',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/25175/a-light-and-diplomatic-bird',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/36859/winnie',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/141965/gwendolyn-brooks-america-in-the-wintertime',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/146231/haiku-and-tanka-for-harriet-tubman']},
#  'black_mountain': {'text_urls': ['https://www.poetryfoundation.org/poems/55512/7th-game-1960-series',
#    'https://www.poetryfoundation.org/poems/55511/brooklyn-narcissus',
#    'https://www.poetryfoundation.org/poems/55514/ritual-x-the-evening-pair-of-ales',
#    'https://www.poetryfoundation.org/poems/55515/journal-april-19-the-southern-tier',
#    'https://www.poetryfoundation.org/poems/55513/the-cafe-filtre',
#    'https://www.poetryfoundation.org/poems/42842/a-wicker-basket',
#    'https://www.poetryfoundation.org/poems/54524/the-rain-56d234f78f810',
#    'https://www.poetryfoundation.org/poems/54508/one-day-56d234ece07b2',
#    'https://www.poetryfoundation.org/poems/42843/somewhere',
#    'https://www.poetryfoundation.org/poems/42841/a-marriage-56d2217b6b5d0',
#    'https://www.poetryfoundation.org/poems/42849/credo-56d2217de000e',
#    'https://www.poetryfoundation.org/poems/42840/the-rescue-56d2217b24ec4',
#    'https://www.poetryfoundation.org/poems/54522/the-whip-56d234f509455',
#    'https://www.poetryfoundation.org/poems/42848/gnomic-verses',
#    'https://www.poetryfoundation.org/poems/42845/for-no-clear-reason',
#    'https://www.poetryfoundation.org/poems/54523/the-tunnel-56d234f71846c',
#    'https://www.poetryfoundation.org/poems/49023/a-token',
#    'https://www.poetryfoundation.org/poems/42839/i-know-a-man',
#    'https://www.poetryfoundation.org/poems/49024/the-language-56d22abc283f2',
#    'https://www.poetryfoundation.org/poems/42838/the-pool-56d2217a96939',
#    'https://www.poetryfoundation.org/poems/49022/the-warning',
#    'https://www.poetryfoundation.org/poems/52504/the-end-56d2310542b95',
#    'https://www.poetryfoundation.org/poems/42851/yesterdays',
#    'https://www.poetryfoundation.org/poems/49025/the-measure-56d22abc822a2',
#    'https://www.poetryfoundation.org/poems/42847/after-frost',
#    'https://www.poetryfoundation.org/poems/42850/inside-my-head',
#    'https://www.poetryfoundation.org/poems/42844/self-portrait-56d2217c5e3ef',
#    'https://www.poetryfoundation.org/poems/42846/helsinki-window',
#    'https://www.poetryfoundation.org/poems/52505/if-it-should-ever-come',
#    'https://www.poetryfoundation.org/poems/50844/ode-on-the-facelifting-of-the-statue-of-liberty',
#    'https://www.poetryfoundation.org/poems/50843/the-price-is-right-a-torture-wheel-of-fortune',
#    'https://www.poetryfoundation.org/poems/50842/theres-only-one-natural-death-and-even-thats-bedcide-for-the-post-mortem-amusement-of-richard-brautigan',
#    'https://www.poetryfoundation.org/poems/46319/passage-over-water',
#    'https://www.poetryfoundation.org/poems/46324/such-is-the-sickness-of-many-a-good-thing',
#    'https://www.poetryfoundation.org/poems/46322/a-little-language',
#    'https://www.poetryfoundation.org/poems/46321/childhoods-retreat',
#    'https://www.poetryfoundation.org/poems/53073/my-mother-would-be-a-falconress',
#    'https://www.poetryfoundation.org/poems/55968/this-place-rumord-to-have-been-sodom',
#    'https://www.poetryfoundation.org/poems/53077/from-dante-etudes-book-three-in-my-youth-not-unstaind',
#    'https://www.poetryfoundation.org/poems/46320/what-i-saw',
#    'https://www.poetryfoundation.org/poems/53074/structure-of-rime-xxviii-in-memoriam-wallace-stevens',
#    'https://www.poetryfoundation.org/poems/46316/a-poem-beginning-with-a-line-by-pindar',
#    'https://www.poetryfoundation.org/poems/46681/an-african-elegy',
#    'https://www.poetryfoundation.org/poems/46381/rites-of-passage',
#    'https://www.poetryfoundation.org/poems/53075/from-dante-etudes-book-one-we-will-endeavor',
#    'https://www.poetryfoundation.org/poems/46323/styx',
#    'https://www.poetryfoundation.org/poems/46318/poetry-a-natural-thing',

#    'https://www.poetryfoundation.org/poetrymagazine/poems/27956/a-storm-of-white',
# ...
#    'https://www.poetryfoundation.org/poems/146804/in-an-artist39s-studio',
#    'https://www.poetryfoundation.org/poems/43199/color-56d221e6ec8fc',
#    'https://www.poetryfoundation.org/poems/146805/a-triad',
#    'https://www.poetryfoundation.org/poems/56587/mix-a-pancake',
#    'https://www.poetryfoundation.org/poems/53216/in-the-bleak-midwinter',
#    'https://www.poetryfoundation.org/poems/50291/a-dirge-56d22d42029d3',
#    'https://www.poetryfoundation.org/poems/50508/many-in-aftertimes-will-say-of-you',
#    'https://www.poetryfoundation.org/poems/146808/no-thank-you-john',
#    'https://www.poetryfoundation.org/poems/50504/somewhere-or-other',
#    'https://www.poetryfoundation.org/poems/146809/a-study-a-soul',
#    'https://www.poetryfoundation.org/poems/146806/from-the-antique',
#    'https://www.poetryfoundation.org/poems/44996/goblin-market',
#    'https://www.poetryfoundation.org/poems/44995/dream-land',
#    'https://www.poetryfoundation.org/poems/50289/echo-56d22d3f77136',
#    'https://www.poetryfoundation.org/poems/45003/when-i-am-dead-my-dearest',
#    'https://www.poetryfoundation.org/poems/44994/de-profundis',
#    'https://www.poetryfoundation.org/poems/50497/after-death',
#    'https://www.poetryfoundation.org/poems/44993/a-daughter-of-eve',
#    'https://www.poetryfoundation.org/poems/45002/up-hill',
#    'https://www.poetryfoundation.org/poems/146807/winter-my-secret',
#    'https://www.poetryfoundation.org/poems/50507/i-loved-you-first-but-afterwards-your-love',
#    'https://www.poetryfoundation.org/poems/45001/the-three-enemies',
#    'https://www.poetryfoundation.org/poems/44998/passing-away-saith-the-world',
#    'https://www.poetryfoundation.org/poems/52643/song-56d2314775fcc',
#    'https://www.poetryfoundation.org/poems/53532/crying-my-little-one-footsore-and-weary',
#    'https://www.poetryfoundation.org/poems/45024/sister-helen',
#    'https://www.poetryfoundation.org/poems/45017/the-house-of-life-97-a-superscription',
#    'https://www.poetryfoundation.org/poems/50352/sonnet-upon-a-day-came-sorrow-in-to-me',
#    'https://www.poetryfoundation.org/poems/45018/insomnia-56d22457b8d28',
#    'https://www.poetryfoundation.org/poems/50358/sestina-of-the-lady-pietra-degli-scrovigni',
#    'https://www.poetryfoundation.org/poems/45020/loves-nocturn',
#    'https://www.poetryfoundation.org/poems/45013/the-house-of-life-66-the-heart-of-the-night',
#    'https://www.poetryfoundation.org/poems/45010/the-house-of-life-22-hearts-haven',
#    'https://www.poetryfoundation.org/poems/45019/love-lily',
#    'https://www.poetryfoundation.org/poems/45016/the-house-of-life-73-the-choice-iii',
#    'https://www.poetryfoundation.org/poems/45025/the-streams-secret',
#    'https://www.poetryfoundation.org/poems/45011/the-house-of-life-36-life-in-love',
#    'https://www.poetryfoundation.org/poems/45012/the-house-of-life-41-through-death-to-love',
#    'https://www.poetryfoundation.org/poems/52332/jenny',
#    'https://www.poetryfoundation.org/poems/45015/the-house-of-life-72-the-choice-ii',
#    'https://www.poetryfoundation.org/poems/50343/one-girl',
#    'https://www.poetryfoundation.org/poems/45026/sudden-light',
#    'https://www.poetryfoundation.org/poems/45009/the-house-of-life-19-silent-noon',
#    'https://www.poetryfoundation.org/poems/45005/autumn-song-56d22452505f6',
#    'https://www.poetryfoundation.org/poems/45007/the-cloud-confines',
#    'https://www.poetryfoundation.org/poems/45487/in-school-days',
#    'https://www.poetryfoundation.org/poems/45483/barbara-frietchie',
#    'https://www.poetryfoundation.org/poems/45489/skipper-iresons-ride',
#    'https://www.poetryfoundation.org/poems/45493/the-worship-of-nature',
#    'https://www.poetryfoundation.org/poems/45495/the-ballad-of-reading-gaol'],
#   'scan_urls': ['https://www.poetryfoundation.org/poetrymagazine/poems/55409/to-my-comrade-moses-j-jackson-scoffer-at-this-scholarship',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/12659/maternity']}}

# %%
# %%time

poem_dicts = []
error_poems = []
for genre,poets in poet_poems_url_dict.items():
    for poet in poets:
        for poet_url, poems in poet.items():
            for text_url in poems[0]:
                poem = text_poem_scraper(text_url)
                poem['genre'] = genre
                poem['poem_url'] = text_url
                poem_dicts.append(poem)
            
            if poems[1]:
                for scan_url in poems[1]:
                    try:
                        poem = text_poem_scraper(scan_url)
                        poem['genre'] = genre
                        poem['poem_url'] = scan_url
                        poem_dicts.append(poem)
                        poems[0].append(scan_url)
                        poems[1].remove(scan_url)
                    except:
                        try:
                            poem = scan_poem_scraper(scan_url)
                            poem['genre'] = genre
                            poem['poet_url'] = scan_url
                            poem_dicts.append(poem)
                        except:
                            error_poems.append(scan_url)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/Documents/flatiron/projects/mod5/poetry_genre_classifier/functions_webscraping.py in text_poem_scraper(poem_url)
#      90
#      91     # load a page and soupify it
# ---> 92     page = rq.get(poem_url)
#      93     soup = bs(page.content, 'html.parser')
#      94
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py in getresponse(self)
#    1344         try:
#    1345             try:
# -> 1346                 response.begin()
#    1347             except ConnectionError:
#    1348                 self.close()
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     311     def recv_into(self, *args, **kwargs):
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#     315             if self.suppress_ragged_eofs and e.args == (-1, "Unexpected EOF"):
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:

# %%
'https://www.poetryfoundation.org/poetrymagazine/poems/13056/the-pool' in image_urls
# Out:
# True

# %%
text_poem_scraper('https://www.poetryfoundation.org/poetrymagazine/poems/13056/the-pool')
# Out:
# {'poet': 'H. D.',
#  'poem_url': 'https://www.poetryfoundation.org/poetrymagazine/poems/13056/the-pool',
#  'title': 'The Pool',
#  'poem_lines': ['Are you alive?',
#   'I touch you.',
#   'You quiver like a sea-fish.',
#   'I cover you with my net.',
#   'What are you—banded one?'],
#  'poem_string': 'Are you alive?\nI touch you.\nYou quiver like a sea-fish.\nI cover you with my net.\nWhat are you—banded one?'}

# %%
poet_poems_url_dict['imagist'][1]
# Out:
# {'https://www.poetryfoundation.org/poets/h-d': (['https://www.poetryfoundation.org/poems/47927/leda-56d228c3a5948',
#    'https://www.poetryfoundation.org/poems/51856/evening-56d22fe15dc07',
#    'https://www.poetryfoundation.org/poems/44133/cassandra-56d2231be6015',
#    'https://www.poetryfoundation.org/poems/48186/oread',
#    'https://www.poetryfoundation.org/poems/48187/sea-poppies',
#    'https://www.poetryfoundation.org/poems/46541/helen-56d22674d6e41',
#    'https://www.poetryfoundation.org/poems/48189/sheltered-garden',
#    'https://www.poetryfoundation.org/poems/44134/cities',
#    'https://www.poetryfoundation.org/poems/48188/sea-rose',
#    'https://www.poetryfoundation.org/poems/53970/sea-heroes',
#    'https://www.poetryfoundation.org/poems/51870/sea-iris',
#    'https://www.poetryfoundation.org/poems/51869/eurydice-56d22fe6d049d',
#    'https://www.poetryfoundation.org/poems/48190/wash-of-cold-river'],
#   ['https://www.poetryfoundation.org/poetrymagazine/poems/13056/the-pool',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/18187/birds-in-snow',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/13057/garden',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/13055/storm',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/12628/epigram',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/28005/regents-of-the-night',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/20665/elegy-and-choros-from-electra-orestes',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/27498/nails-for-petals',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/16971/leucadian-artemis',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/27499/sometimes-and-after',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/12823/acon',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/14645/hymen',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/20007/his-ecstasy',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/25619/last-winter',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/15345/fragment-xxxvi-i-know-not-what',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/22021/sigel-xv',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/15347/at-baia',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/27497/in-time-of-gold',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/20006/his-presence',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/35052/delphi-56d2187162bd6',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/22022/from-episode-i',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/15346/song-you-are-as-gold',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/16970/all-mountains',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/13054/the-wind-sleepers',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/16026/thetis',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/12626/hermes-of-the-ways',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/18188/triplex',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/20005/his-song',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/17593/halcyon',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/12627/priapus',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/12822/hermonax',
#    'https://www.poetryfoundation.org/poetrymagazine/poems/13058/moonrise'])}

# %%
len(image_urls)
# Out:
# 2221

# %%
text_poems = pd.DataFrame(poem_dicts)
text_poems.shape
# Out:
# (3084, 7)

# %%
text_poems = text_poems[text_poems.poem_string == '']
# Out:
#                poet  \
# 1321   Dylan Thomas
# 1433  Barbara Guest
#
#                                                                            poem_url  \
# 1321  https://www.poetryfoundation.org/poems/26804/poem-on-his-birthday-facs-drafts
# 1433                     https://www.poetryfoundation.org/poems/49367/imagined-room
#
#                                     title poem_lines poem_string  \
# 1321  Poem on His Birthday [Facs. drafts]         []
# 1433                        Imagined Room         []
#
#                 genre
# 1321           modern
# 1433  new_york_school

# %%
poem_url = 'https://www.poetryfoundation.org/poems/51653/to-a-poor-old-woman'

# load a page and soupify it
page = rq.get(poem_url)
soup = bs(page.content, 'html.parser')

# most frequent formatting
lines_raw = soup.find_all('div', {'style': 'text-indent: -1em; padding-left: 1em;'})
# normalize text (from unicode)
lines = [normalize('NFKD', str(line.contents[0])) for line in lines_raw if line.contents]
# remove some hanging html
lines = [line.replace('<br/>', '') for line in lines]
line_pattern = '>(.*?)<'
lines = [re.search(line_pattern, line, re.I).group(1) if '<' in line else line for line in lines]
# scrape poem
# lines_raw = soup.find('div', {'data-view': 'PoemView'}).strings
# lines = [line.strip() for line in lines_raw if line.strip()]

# if not lines:
#     lines_raw = soup.find_all('div', {'style': 'text-indent: -1em; padding-left: 1em;'})
#     lines = [line.get_text().strip() for line in lines_raw if line.get_text().strip()]

# # create string version of poem
# poem_string = '\n'.join(lines)

# info = {'poet': poet,
#         'poem_url': poem_url,
#         'title': title,
#         'poem_lines': lines,
#         'poem_string': poem_string}

lines
# Out:
# ['munching a plum on   ',
#  '\r the street a paper bag',
#  '\r of them in her hand',
#  '',
#  '\r They taste good to her',
#  '\r They taste good   ',
#  '\r to her. They taste',
#  '\r good to her',
#  '',
#  '\r You can see it by',
#  '\r the way she gives herself',
#  '\r to the one half',
#  '\r sucked out in her hand',
#  '',
#  'Comforted',
#  '\r a solace of ripe plums',
#  '\r seeming to fill the air',
#  '\r They taste good to her',
#  '']

# %%
lines_raw
# Out:
# [<div style="text-indent: -1em; padding-left: 1em;">munching a plum on   <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">
#   the street a paper bag<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">
#   of them in her hand<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;"><br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">
#   They taste good to her<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">
#   They taste good   <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">
#   to her. They taste<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">
#   good to her<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;"><br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">
#   You can see it by<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">
#   the way she gives herself<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">
#   to the one half<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">
#   sucked out in her hand<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;"><br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;"><span class="annotation" id="annotation-1">Comforted</span><span id="annotation-1-text" style="display: none;"><strong>Comforted</strong> When originally published in the journal <em>Smoke</em> (Autumn 1934), the line read: “Comforted, Relieved—”</span><br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">
#   a solace of ripe plums<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">
#   seeming to fill the air<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">
#   They taste good to her<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;"><br/></div>]

# %%
lines2 = [str(line) for line in lines_raw]
lines2
# Out:
# ['\n',
#  '\n',
#  '\n',
#  '\n',
#  'Highlight Actions',
#  '\n',
#  'Enable or disable annotations',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  'munching a plum on\xa0\xa0\xa0',
#  '\r the street a paper bag',
#  '\r of them in her hand',
#  '\r They taste good to her',
#  '\r They taste good\xa0\xa0\xa0',
#  '\r to her. They taste',
#  '\r good to her',
#  '\r You can see it by',
#  '\r the way she gives herself',
#  '\r to the one half',
#  '\r sucked out in her hand',
#  'Comforted',
#  'Comforted',
#  ' When originally published in the journal ',
#  'Smoke',
#  ' (Autumn 1934), the line read: “Comforted, Relieved—”',
#  '\r a solace of ripe plums',
#  '\r seeming to fill the air',
#  '\r They taste good to her',
#  '\n']

# %%
[line.strip() for line in lines2 if line.strip()]
# Out:
# ['Highlight Actions',
#  'Enable or disable annotations',
#  'munching a plum on',
#  'the street a paper bag',
#  'of them in her hand',
#  'They taste good to her',
#  'They taste good',
#  'to her. They taste',
#  'good to her',
#  'You can see it by',
#  'the way she gives herself',
#  'to the one half',
#  'sucked out in her hand',
#  'Comforted',
#  'Comforted',
#  'When originally published in the journal',
#  'Smoke',
#  '(Autumn 1934), the line read: “Comforted, Relieved—”',
#  'a solace of ripe plums',
#  'seeming to fill the air',
#  'They taste good to her']

# %%
pd.read_csv('data/text_poems.csv', index_col=0)
# Out:
#                          poet  \
# 0                 Mary Barber
# 1             Susanna Blamire
# 2             Susanna Blamire
# 3             Susanna Blamire
# 4                 Henry Carey
# ...                       ...
# 3079  John Greenleaf Whittier
# 3080  John Greenleaf Whittier
# 3081  John Greenleaf Whittier
# 3082  John Greenleaf Whittier
# 3083              Oscar Wilde
#
#                                                                            poem_url  \
# 0        https://www.poetryfoundation.org/poems/50523/advice-to-her-son-on-marriage
# 1                    https://www.poetryfoundation.org/poems/50534/auld-robin-forbes
# 2                     https://www.poetryfoundation.org/poems/50532/the-siller-croun
# 3         https://www.poetryfoundation.org/poems/50533/o-donald-ye-are-just-the-man
# 4     https://www.poetryfoundation.org/poems/43884/the-ballad-of-sally-in-our-alley
# ...                                                                             ...
# 3079                    https://www.poetryfoundation.org/poems/45487/in-school-days
# 3080                 https://www.poetryfoundation.org/poems/45483/barbara-frietchie
# 3081              https://www.poetryfoundation.org/poems/45489/skipper-iresons-ride
# 3082             https://www.poetryfoundation.org/poems/45493/the-worship-of-nature
# 3083        https://www.poetryfoundation.org/poems/45495/the-ballad-of-reading-gaol
#
#                                  title  \
# 0        Advice to Her Son on Marriage
# 1                    Auld Robin Forbes
# 2                     The Siller Croun
# 3        O Donald! Ye Are Just the Man
# 4     The Ballad of Sally in our Alley
# ...                                ...
# 3079                    In School-days
# 3080                 Barbara Frietchie
# 3081             Skipper Ireson’s Ride
# 3082             The Worship of Nature
# 3083        The Ballad of Reading Gaol
#
#                                                                                                                                                  poem_lines  \
# 0                                                                                                                                                        []
# 1     ['And auld Robin Forbes hes gien tem a dance,', 'I pat on my speckets to see them aw prance;', 'I thout o’ the days when I was but fifteen,', 'And...
# 2     ['And ye shall walk in silk attire,', 'And siller hae to spare,', 'Gin ye’ll consent to be his bride,', 'Nor think o’ Donald mair.', 'O wha wad bu...
# 3     ['O Donald! ye are just the man', 'Who, when he’s got a wife,', 'Begins to fratch— nae notice ta’en—', 'They’re strangers a’ their life.', 'The fa...
# 4     ['The ARGUMENT.  A Vulgar Error having long prevailed among many Persons, who imagine Sally Salisbury the Subject of this Ballad, the Author begs ...
# ...                                                                                                                                                     ...
# 3079  ['Still sits the school-house by the road, \xa0\xa0\xa0A ragged beggar sleeping; Around it still the sumachs grow, \xa0\xa0\xa0And blackberry-vine...
# 3080  ['Up from the meadows rich with corn,', 'Clear in the cool September morn,', 'The clustered spires of Frederick stand', 'Green-walled by the hills...
# 3081  ['Of all the rides since the birth of time,', 'Told in story or sung in rhyme, —', 'On Apuleius’s Golden Ass,', 'Or one-eyed Calender’s horse of b...
# 3082  ['The harp at Nature’s advent strung \xa0\xa0\xa0\xa0\xa0\xa0Has never ceased to play; The song the stars of morning sung \xa0\xa0\xa0\xa0\xa0\xa0...
# 3083  ['I He did not wear his scarlet coat,', 'For blood and wine are red,', 'And blood and wine were on his hands', 'When they found him with the dead,...
#
#                                                                                                                                                 poem_string  \
# 0                                                                                                                                                       NaN
# 1     And auld Robin Forbes hes gien tem a dance,\nI pat on my speckets to see them aw prance;\nI thout o’ the days when I was but fifteen,\nAnd skipp’d...
# 2     And ye shall walk in silk attire,\nAnd siller hae to spare,\nGin ye’ll consent to be his bride,\nNor think o’ Donald mair.\nO wha wad buy a silken...
# 3     O Donald! ye are just the man\nWho, when he’s got a wife,\nBegins to fratch— nae notice ta’en—\nThey’re strangers a’ their life.\nThe fan may drop...
# 4     The ARGUMENT.  A Vulgar Error having long prevailed among many Persons, who imagine Sally Salisbury the Subject of this Ballad, the Author begs le...
# ...                                                                                                                                                     ...
# 3079  Still sits the school-house by the road,    A ragged beggar sleeping; Around it still the sumachs grow,    And blackberry-vines are creeping. With...
# 3080  Up from the meadows rich with corn,\nClear in the cool September morn,\nThe clustered spires of Frederick stand\nGreen-walled by the hills of Mary...
# 3081  Of all the rides since the birth of time,\nTold in story or sung in rhyme, —\nOn Apuleius’s Golden Ass,\nOr one-eyed Calender’s horse of brass,\nW...
# 3082  The harp at Nature’s advent strung       Has never ceased to play; The song the stars of morning sung       Has never died away. And prayer is mad...
# 3083  I He did not wear his scarlet coat,\nFor blood and wine are red,\nAnd blood and wine were on his hands\nWhen they found him with the dead,\nThe po...
#
#           genre
# 0      augustan
# 1      augustan
# 2      augustan
# 3      augustan
# 4      augustan
# ...         ...
# 3079  victorian
# 3080  victorian
# 3081  victorian
# 3082  victorian
# 3083  victorian
#
# [3084 rows x 6 columns]

# %%
# uncomment to save
with gzip.open('data/text_poems.pkl', 'wb') as goodbye:
    pickle.dump(text_poems, goodbye, protocol=pickle.HIGHEST_PROTOCOL)

# uncomment to load
with gzip.open('data/text_poems.pkl', 'rb') as hello:
    df = pickle.load(hello)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-110-ffaf44ae5e94> in <module>
#       1 # uncomment to save
#       2 with gzip.open('data/text_poems.pkl', 'wb') as goodbye:
# ----> 3     pickle.dump(text_poems, goodbye, protocol=pickle.HIGHEST_PROTOCOL)
#       4
#       5 # uncomment to load
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/bs4/element.py in __getnewargs__(self)
#     633
#     634     def __getnewargs__(self):
# --> 635         return (str(self),)
#     636
#     637     def __getattr__(self, attr):
#
# RecursionError: maximum recursion depth exceeded while getting the str of an object

# %%
page = rq.get(list(poet_urls_dict['augustan'][10].values())[0][0][0])
soup = bs(page.content, 'html.parser')

# %%
poet = soup.find('a', href=re.compile('.*/poets/.*')).contents[0]
title = soup.find('h1').contents[-1].strip()
poet,title
# Out:
# ('Thomas Gray', 'On the Death of Richard West')

# %%
pd.DataFrame(text_poem_scraper(list(poet_poems_url_dict['black_mountain'][1].values())[0][0][0]))
# Out:
#                                                                                                                                                        0
# 0                                                                                                                                         Robert Creeley
# 1                                                                                                                                            After Frost
# 2  [He comes here, by whatever way he can,, not too late,, not too soon., He sits, waiting., He doesn’t know, why he should, have such a patience., H...
# 3  He comes here\nby whatever way he can,\nnot too late,\nnot too soon.\nHe sits, waiting.\nHe doesn’t know\nwhy he should\nhave such a patience.\nHe...

# %%
# most frequent formatting
lines_raw = soup.find_all('div', {'style': 'text-indent: -1em; padding-left: 1em;'})
lines_raw
# Out:
# [<div style="text-indent: -1em; padding-left: 1em;">In vain to me the smiling Mornings shine,
#  <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">    And reddening Phœbus lifts his golden fire;
#  <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">The birds in vain their amorous descant join;
#  <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">    Or cheerful fields resume their green attire;
#  <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">These ears, alas! for other notes repine,
#  <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">    A different object do these eyes require;
#  <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">My lonely anguish melts no heart but mine;
#  <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">    And in my breast the imperfect joys expire.
#  <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">Yet Morning smiles the busy race to cheer,
#  <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">    And new-born pleasure brings to happier men;
#  <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">The fields to all their wonted tribute bear;
#  <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">    To warm their little loves the birds complain;
#  <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">I fruitless mourn to him that cannot hear,
#  <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">    And weep the more because I weep in vain.
#  <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;"><br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;"><br/></div>]

# %%
# if 'text-align' is justified
lines_raw = soup.find_all('div', {'style': 'text-align: justify;'})
lines_raw
# Out:
# []

# %%
lines_raw
# Out:
# ['\n',
#  <div style="text-indent: -1em; padding-left: 1em;">In vain to me the smiling Mornings shine,
#  <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">    And reddening Phœbus lifts his golden fire;
#  <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">The birds in vain their amorous descant join;
#  <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">    Or cheerful fields resume their green attire;
#  <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">These ears, alas! for other notes repine,
#  <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">    A different object do these eyes require;
#  <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">My lonely anguish melts no heart but mine;
#  <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">    And in my breast the imperfect joys expire.
#  <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">Yet Morning smiles the busy race to cheer,
#  <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">    And new-born pleasure brings to happier men;
#  <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">The fields to all their wonted tribute bear;
#  <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">    To warm their little loves the birds complain;
#  <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">I fruitless mourn to him that cannot hear,
#  <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">    And weep the more because I weep in vain.
#  <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;"><br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;"><br/></div>,
#  '\n']

# %%
lines_raw = soup.find('div', {'data-view': 'PoemView'}).get_text().split('\r')
lines = [line.strip() for line in lines_raw if line.strip()]
lines
# Out:
# ['In vain to me the smiling Mornings shine,',
#  'And reddening Phœbus lifts his golden fire;',
#  'The birds in vain their amorous descant join;',
#  'Or cheerful fields resume their green attire;',
#  'These ears, alas! for other notes repine,',
#  'A different object do these eyes require;',
#  'My lonely anguish melts no heart but mine;',
#  'And in my breast the imperfect joys expire.',
#  'Yet Morning smiles the busy race to cheer,',
#  'And new-born pleasure brings to happier men;',
#  'The fields to all their wonted tribute bear;',
#  'To warm their little loves the birds complain;',
#  'I fruitless mourn to him that cannot hear,',
#  'And weep the more because I weep in vain.']

# %%
lines_raw
# Out:
# ['\nIn vain to me the smiling Mornings shine,',
#  '    And reddening Phœbus lifts his golden fire;',
#  'The birds in vain their amorous descant join;',
#  '    Or cheerful fields resume their green attire;',
#  'These ears, alas! for other notes repine,',
#  '    A different object do these eyes require;',
#  'My lonely anguish melts no heart but mine;',
#  '    And in my breast the imperfect joys expire.',
#  'Yet Morning smiles the busy race to cheer,',
#  '    And new-born pleasure brings to happier men;',
#  'The fields to all their wonted tribute bear;',
#  '    To warm their little loves the birds complain;',
#  'I fruitless mourn to him that cannot hear,',
#  '    And weep the more because I weep in vain.',
#  '\n']

# %%
# scrape 'PoemView' html type
lines_raw = soup.find('div', {'data-view': 'PoemView'})

line_pattern = '>(.*?)<'
lines = [re.search(line_pattern, line, re.I).group(1) if '<' in line else line for line in lines]

# normalize text (from unicode)
lines = [normalize('NFKD', str(line)) for line in lines_raw if line]

# lines = [line.replace('<br/>', '') for line in lines]
lines = [line.strip() for line in lines if line]
lines
# Out:
# ['',
#  '<div style="text-indent: -1em; padding-left: 1em;">In vain to me the smiling Mornings shine,\r<br/></div>',
#  '<div style="text-indent: -1em; padding-left: 1em;">    And reddening Phœbus lifts his golden fire;\r<br/></div>',
#  '<div style="text-indent: -1em; padding-left: 1em;">The birds in vain their amorous descant join;\r<br/></div>',
#  '<div style="text-indent: -1em; padding-left: 1em;">    Or cheerful fields resume their green attire;\r<br/></div>',
#  '<div style="text-indent: -1em; padding-left: 1em;">These ears, alas! for other notes repine,\r<br/></div>',
#  '<div style="text-indent: -1em; padding-left: 1em;">    A different object do these eyes require;\r<br/></div>',
#  '<div style="text-indent: -1em; padding-left: 1em;">My lonely anguish melts no heart but mine;\r<br/></div>',
#  '<div style="text-indent: -1em; padding-left: 1em;">    And in my breast the imperfect joys expire.\r<br/></div>',
#  '<div style="text-indent: -1em; padding-left: 1em;">Yet Morning smiles the busy race to cheer,\r<br/></div>',
#  '<div style="text-indent: -1em; padding-left: 1em;">    And new-born pleasure brings to happier men;\r<br/></div>',
#  '<div style="text-indent: -1em; padding-left: 1em;">The fields to all their wonted tribute bear;\r<br/></div>',
#  '<div style="text-indent: -1em; padding-left: 1em;">    To warm their little loves the birds complain;\r<br/></div>',
#  '<div style="text-indent: -1em; padding-left: 1em;">I fruitless mourn to him that cannot hear,\r<br/></div>',
#  '<div style="text-indent: -1em; padding-left: 1em;">    And weep the more because I weep in vain.\r<br/></div>',
#  '<div style="text-indent: -1em; padding-left: 1em;"><br/></div>',
#  '<div style="text-indent: -1em; padding-left: 1em;"><br/></div>',
#  '']

# %% [markdown]
# - **Check for duplicate values**

# %%
# create dataframe from poet_urls_dict
poet_df = pd.DataFrame([(genre,v) for genre in poet_urls_dict.keys() for v in poet_urls_dict[genre]])

# check if any URLs appear more than once
pd.concat(g for _, g in poet_df.groupby(1) if len(g) > 1)
# Out:
#            0                                                         1
# 126  imagist         https://www.poetryfoundation.org/poets/ezra-pound
# 186   modern         https://www.poetryfoundation.org/poets/ezra-pound
# 122  imagist  https://www.poetryfoundation.org/poets/richard-aldington
# 150   modern  https://www.poetryfoundation.org/poets/richard-aldington

# %% [markdown]
# - **I'll give those poets to the imagist genre, since it has so few already.**

# %%
# list of duplicate URLs
dups = [value for value in poet_df[poet_df.duplicated(1)][1]]
dups
# Out:
# ['https://www.poetryfoundation.org/poets/richard-aldington',
#  'https://www.poetryfoundation.org/poets/ezra-pound']

# %%
# number of modern poets before
len(poet_urls_dict['modern'])
# Out:
# 54

# %%
# re-listify the modernist URLs without Pound and Aldington
poet_urls_dict['modern'] = [url for url in poet_urls_dict['modern'] if url not in dups]

# number of modern poets after
len(poet_urls_dict['modern'])
# Out:
# 52

# %% [markdown]
# ## Build a dataframe
# - **Scrape poems and other info.**

# %%
# %%time

# instantiate an empty dataframe
df = pd.DataFrame()

# loop over each genre, create dataframe with desired information,
# concat to original dataframe, then save it before looping again
for genre in list(poet_urls_dict.keys()):
    genre_df = pf_scraper(poet_urls_dict, genre, 0.5)
    df = pd.concat([df, genre_df])
    df.to_csv('data/poetry_foundation_raw.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/Documents/flatiron/projects/mod5/poetry_genre_classifier/functions.py in pf_scraper(poet_urls_dict, genre)
#     169         for poem_url in poem_text_urls:
#     170             info = [poet_url, genre, poem_url]
# --> 171             info.extend(poem_scraper(poem_url))
#     172             ultra_list.append(info)
#     173
#
# ~/Documents/flatiron/projects/mod5/poetry_genre_classifier/functions.py in poem_scraper(poem_url)
#      90
#      91     # load a page and soupify it
# ---> 92     page = rq.get(poem_url)
#      93     soup = bs(page.content, 'html.parser')
#      94
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py in getresponse(self)
#    1344         try:
#    1345             try:
# -> 1346                 response.begin()
#    1347             except ConnectionError:
#    1348                 self.close()
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     311     def recv_into(self, *args, **kwargs):
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#     315             if self.suppress_ragged_eofs and e.args == (-1, "Unexpected EOF"):
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:

# %% [markdown]
# ### Save/load dataframe

# %%
# # uncomment to save
# df.to_csv('data/poetry_foundation_raw.csv')

# # uncomment to load
# df = pd.read_csv('data/poetry_foundation_raw.csv', index_col=0)

# %%
# rename the columns
df.columns = ['poet_url', 'genre', 'poem_url', 'poet', 'title', 'year', 'poem_lines', 'poem_string']
df.head()
# Out:
#                                                  poet_url     genre  \
# 0      https://www.poetryfoundation.org/poets/mary-barber  augustan
# 1  https://www.poetryfoundation.org/poets/susanna-blamire  augustan
# 2  https://www.poetryfoundation.org/poets/susanna-blamire  augustan
# 3  https://www.poetryfoundation.org/poets/susanna-blamire  augustan
# 4      https://www.poetryfoundation.org/poets/henry-carey  augustan
#
#                                                                         poem_url  \
# 0     https://www.poetryfoundation.org/poems/50523/advice-to-her-son-on-marriage
# 1                 https://www.poetryfoundation.org/poems/50534/auld-robin-forbes
# 2      https://www.poetryfoundation.org/poems/50533/o-donald-ye-are-just-the-man
# 3                  https://www.poetryfoundation.org/poems/50532/the-siller-croun
# 4  https://www.poetryfoundation.org/poems/43884/the-ballad-of-sally-in-our-alley
#
#               poet                             title  year  \
# 0      Mary Barber     Advice to Her Son on Marriage   NaN
# 1  Susanna Blamire                 Auld Robin Forbes   NaN
# 2  Susanna Blamire     O Donald! Ye Are Just the Man   NaN
# 3  Susanna Blamire                  The Siller Croun   NaN
# 4      Henry Carey  The Ballad of Sally in our Alley   NaN
#
#                                                                                                                                               poem_lines  \
# 0  ['When you gain her Affection, take care to preserve it;\r', 'Lest others persuade her, you do not deserve it.\r', 'Still study to heighten the Jo...
# 1  ['And auld Robin Forbes hes gien tem a dance,\r', 'I pat on my speckets to see them aw prance;\r', 'I thout o’ the days when I was but fifteen,\r'...
# 2  ['O Donald! ye are just the man\r', '  Who, when he’s got a wife,\r', 'Begins to fratch— nae notice ta’en—\r', '  They’re strangers a’ their life....
# 3  ['And ye shall walk in silk attire,\r', '   And siller hae to spare,\r', 'Gin ye’ll consent to be his bride,\r', '    Nor think o’ Donald mair.\r'...
# 4  ['Of all the Girls that are so smart\r', '     There’s none like pretty SALLY,\r', 'She is the Darling of my Heart,\r', '     And she lives in our...
#
#                                                                                                                                              poem_string
# 0  When you gain her Affection, take care to preserve it;\r\nLest others persuade her, you do not deserve it.\r\nStill study to heighten the Joys of ...
# 1  And auld Robin Forbes hes gien tem a dance,\r\nI pat on my speckets to see them aw prance;\r\nI thout o’ the days when I was but fifteen,\r\nAnd s...
# 2  O Donald! ye are just the man\r\n  Who, when he’s got a wife,\r\nBegins to fratch— nae notice ta’en—\r\n  They’re strangers a’ their life.\r\n\nTh...
# 3  And ye shall walk in silk attire,\r\n   And siller hae to spare,\r\nGin ye’ll consent to be his bride,\r\n    Nor think o’ Donald mair.\r\nO wha w...
# 4  Of all the Girls that are so smart\r\n     There’s none like pretty SALLY,\r\nShe is the Darling of my Heart,\r\n     And she lives in our Alley.\...

# %% [markdown]
# - **Explore how the data looks.**

# %%
df.shape
# Out:
# (5295, 8)

# %%
df.genre.unique()
# Out:
# array(['augustan', 'beat', 'black_arts_movement', 'black_mountain',
#        'confessional', 'fugitive', 'georgian', 'harlem_renaissance',
#        'imagist', 'language_poetry', 'middle_english', 'modern',
#        'new_york_school', 'new_york_school_2nd_generation', 'objectivist',
#        'renaissance', 'romantic', 'victorian'], dtype=object)

# %%
df.genre.value_counts()
# Out:
# modern                            1324
# victorian                          674
# renaissance                        430
# romantic                           407
# imagist                            370
# new_york_school                    265
# black_mountain                     257
# new_york_school_2nd_generation     193
# language_poetry                    192
# confessional                       176
# georgian                           167
# black_arts_movement                165
# objectivist                        159
# harlem_renaissance                 148
# beat                               147
# augustan                           121
# fugitive                            90
# middle_english                      10
# Name: genre, dtype: int64

# %% [markdown]
# - **Check for duplicate values across multiple columns and drop those rows.**

# %%
df.duplicated(subset=['poet_url', 'genre', 'poem_url', 'poet', 'title', 'year', 'poem_string'], keep='last').sum()
# Out:
# 98

# %%
# drop duplicates
df.drop_duplicates(subset=['poet_url', 'genre', 'poem_url', 'poet', 'title', 'year', 'poem_string'],
                   keep='last',
                   inplace=True)

# reset index
df.reset_index(drop=True, inplace=True)

# %%
# check changes
df.shape
# Out:
# (5197, 8)

# %%
df.genre.value_counts()
# Out:
# modern                            1284
# victorian                          643
# renaissance                        427
# romantic                           398
# imagist                            370
# new_york_school                    265
# black_mountain                     257
# new_york_school_2nd_generation     192
# language_poetry                    192
# confessional                       176
# black_arts_movement                165
# georgian                           160
# objectivist                        159
# harlem_renaissance                 148
# beat                               147
# augustan                           114
# fugitive                            90
# middle_english                      10
# Name: genre, dtype: int64

# %% [markdown]
# - **Looks like the poem_lines column converted to a list inside of a string while saving to CSV.**
# - **I'll wait to convert it until I can fill some missing values for that column, a process I found to be more easily done as a list inside of a string.**

# %%
df.loc[0,'poem_lines']
# Out:
# "['When you gain her Affection, take care to preserve it;\\r', 'Lest others persuade her, you do not deserve it.\\r', 'Still study to heighten the Joys of her Life;\\r', 'Not treat her the worse, for her being your Wife.\\r', 'If in Judgment she errs, set her right, without Pride:\\r', '’Tis the Province of insolent Fools, to deride.\\r', 'A Husband’s first Praise, is a ', 'Then change not these Titles, for ', 'Let your Person be neat, unaffectedly clean,\\r', 'Tho’ alone with your wife the whole Day you remain.\\r', 'Chuse Books, for her study, to fashion her Mind,\\r', 'To emulate those who excell’d of her Kind.\\r', 'Be Religion the principal Care of your Life,\\r', 'As you hope to be blest in your Children and Wife:\\r', 'So you, in your Marriage, shall gain its true End;\\r', 'And find, in your Wife, a ', '', '']"

# %% [markdown]
# - **Check for missing values.**

# %%
df.isna().sum()
# Out:
# poet_url          0
# genre             0
# poem_url          0
# poet             13
# title           215
# year           1649
# poem_lines      410
# poem_string     412
# dtype: int64

# %%
df[df.poet.isna()]
# Out:
#                                                   poet_url         genre  \
# 858   https://www.poetryfoundation.org/poets/w-d-snodgrass  confessional
# 1409     https://www.poetryfoundation.org/poets/amy-lowell       imagist
# 1410     https://www.poetryfoundation.org/poets/amy-lowell       imagist
# 1411     https://www.poetryfoundation.org/poets/amy-lowell       imagist
# 1412     https://www.poetryfoundation.org/poets/amy-lowell       imagist
# 1413     https://www.poetryfoundation.org/poets/amy-lowell       imagist
# 1414     https://www.poetryfoundation.org/poets/amy-lowell       imagist
# 1415     https://www.poetryfoundation.org/poets/amy-lowell       imagist
# 1416     https://www.poetryfoundation.org/poets/amy-lowell       imagist
# 1417     https://www.poetryfoundation.org/poets/amy-lowell       imagist
# 1418     https://www.poetryfoundation.org/poets/amy-lowell       imagist
# 1419     https://www.poetryfoundation.org/poets/amy-lowell       imagist
# 3919     https://www.poetryfoundation.org/poets/ben-jonson   renaissance
#
#                                                                                                                                                 poem_url  \
# 858                                                                       https://www.poetryfoundation.org/poetrymagazine/poems/48292/road-56d22969928f0
# 1409                             https://www.poetryfoundation.org/poetrymagazine/poems/14311/after-how-many-years-tr-by-amy-lowell-and-florence-ayscough
# 1410                                      https://www.poetryfoundation.org/poetrymagazine/poems/14312/calligraphy-tr-by-amy-lowell-and-florence-ayscough
# 1411  https://www.poetryfoundation.org/poetrymagazine/poems/14322/the-emperors-return-from-a-journey-to-the-south-tr-by-amy-lowell-and-florence-ayscough
# 1412                               https://www.poetryfoundation.org/poetrymagazine/poems/14310/an-evening-meeting-tr-by-amy-lowell-and-florence-ayscough
# 1413         https://www.poetryfoundation.org/poetrymagazine/poems/14314/from-the-straw-hut-among-the-seven-peaks-tr-by-amy-lowell-and-florence-ayscough
# 1414                      https://www.poetryfoundation.org/poetrymagazine/poems/14321/the-inn-at-the-western-lake-tr-by-amy-lowell-and-florence-ayscough
# 1415  https://www.poetryfoundation.org/poetrymagazine/poems/14296/on-seeing-the-portrait-of-a-beautiful-concubine-tr-by-amy-lowell-and-florence-ayscough
# 1416              https://www.poetryfoundation.org/poetrymagazine/poems/14316/on-the-classic-of-the-hills-and-sea-tr-by-amy-lowell-and-florence-ayscough
# 1417                               https://www.poetryfoundation.org/poetrymagazine/poems/14313/one-goes-a-journey-tr-by-amy-lowell-and-florence-ayscough
# 1418                              https://www.poetryfoundation.org/poetrymagazine/poems/14315/the-palace-blossoms-tr-by-amy-lowell-and-florence-ayscough
# 1419                                        https://www.poetryfoundation.org/poetrymagazine/poems/14320/a-recluse-tr-by-amy-lowell-and-florence-ayscough
# 3919                                           https://www.poetryfoundation.org/poetrymagazine/poems/28076/brucio-e-limminenza-lombra-che-sale-riconosco
#
#      poet  \
# 858   NaN
# 1409  NaN
# 1410  NaN
# 1411  NaN
# 1412  NaN
# 1413  NaN
# 1414  NaN
# 1415  NaN
# 1416  NaN
# 1417  NaN
# 1418  NaN
# 1419  NaN
# 3919  NaN
#
#                                                                                        title  \
# 858                                                                                      NaN
# 1409                             After How Many Years Tr By Amy Lowell And Florence Ayscough
# 1410                                      Calligraphy Tr By Amy Lowell And Florence Ayscough
# 1411  The Emperors Return From A Journey To The South Tr By Amy Lowell And Florence Ayscough
# 1412                               An Evening Meeting Tr By Amy Lowell And Florence Ayscough
# 1413         From The Straw Hut Among The Seven Peaks Tr By Amy Lowell And Florence Ayscough
# 1414                      The Inn At The Western Lake Tr By Amy Lowell And Florence Ayscough
# 1415  On Seeing The Portrait Of A Beautiful Concubine Tr By Amy Lowell And Florence Ayscough
# 1416              On The Classic Of The Hills And Sea Tr By Amy Lowell And Florence Ayscough
# 1417                               One Goes A Journey Tr By Amy Lowell And Florence Ayscough
# 1418                              The Palace Blossoms Tr By Amy Lowell And Florence Ayscough
# 1419                                        A Recluse Tr By Amy Lowell And Florence Ayscough
# 3919                                           Brucio E Limminenza Lombra Che Sale Riconosco
#
#         year  \
# 858   2006.0
# 1409  1919.0
# 1410  1919.0
# 1411  1919.0
# 1412  1919.0
# 1413  1919.0
# 1414  1919.0
# 1415  1919.0
# 1416  1919.0
# 1417  1919.0
# 1418  1919.0
# 1419  1919.0
# 3919  1959.0
#
#                                                                                                                                                  poem_lines  \
# 858   ['ILEANA MALANCIOIU', '', 'Road', '', 'I walk on a dark road so that I won’t see', '', 'The way my young oxen limp so much;', '', 'The horseshoes ...
# 1409                                                                                                                                                    NaN
# 1410                                                                                                                                                    NaN
# 1411                                                                                                                                                    NaN
# 1412                                                                                                                                                    NaN
# 1413                                                                                                                                                    NaN
# 1414                                                                                                                                                    NaN
# 1415                                                                                                                                                    NaN
# 1416                                                                                                                                                    NaN
# 1417                                                                                                                                                    NaN
# 1418                                                                                                                                                    NaN
# 1419                                                                                                                                                    NaN
# 3919                                                                                                                                                    NaN
#
#                                                                                                                                                 poem_string
# 858   ILEANA MALANCIOIU\n\nRoad\n\nI walk on a dark road so that I won’t see\n\nThe way my young oxen limp so much;\n\nThe horseshoes gouging into their...
# 1409                                                                                                                                                    NaN
# 1410                                                                                                                                                    NaN
# 1411                                                                                                                                                    NaN
# 1412                                                                                                                                                    NaN
# 1413                                                                                                                                                    NaN
# 1414                                                                                                                                                    NaN
# 1415                                                                                                                                                    NaN
# 1416                                                                                                                                                    NaN
# 1417                                                                                                                                                    NaN
# 1418                                                                                                                                                    NaN
# 1419                                                                                                                                                    NaN
# 3919                                                                                                                                                    NaN

# %% [markdown]
# - **The Amy Lowell and Ben Jonson entries appear unuseable, so I'll drop those rows.**
# - **I'll go ahead and fill in the missing info for the Snodgrass poem (which is actually a translation of another poet, but a Confessional translator will probably produce a Confessional work).**

# %%
# manually load in information to the poet and title column
df.loc[858,'poet'] = 'ILEANA MALANCIOIU'.title()
df.loc[858,'title'] = 'Road'
df[df.index == 858]
# Out:
#                                                  poet_url         genre  \
# 858  https://www.poetryfoundation.org/poets/w-d-snodgrass  confessional
#
#                                                                            poem_url  \
# 858  https://www.poetryfoundation.org/poetrymagazine/poems/48292/road-56d22969928f0
#
#                   poet title    year  \
# 858  Ileana Malancioiu  Road  2006.0
#
#                                                                                                                                                 poem_lines  \
# 858  ['ILEANA MALANCIOIU', '', 'Road', '', 'I walk on a dark road so that I won’t see', '', 'The way my young oxen limp so much;', '', 'The horseshoes ...
#
#                                                                                                                                                poem_string
# 858  ILEANA MALANCIOIU\n\nRoad\n\nI walk on a dark road so that I won’t see\n\nThe way my young oxen limp so much;\n\nThe horseshoes gouging into their...

# %%
# drop the rows with missing values in the poet column
df.dropna(subset=['poet'], inplace=True)

# %%
df.isna().sum()
# Out:
# poet_url          0
# genre             0
# poem_url          0
# poet              0
# title           214
# year           1649
# poem_lines      398
# poem_string     400
# dtype: int64

# %% [markdown]
# ## Rescraping
# - **After reworking the scraping function a bit, I can try to fill in some missing poem_lines and poem_string values.**

# %% [markdown]
# ### Round 1

# %%
# create a list of index numbers with NaN values in the poem_lines column
lookups = list(df[df.poem_lines.isna()].index)
lookups
# Out:
# [158,
#  168,
#  169,
#  171,
#  175,
#  183,
#  184,
#  200,
#  203,
#  210,
#  229,
#  254,
#  283,
#  324,
#  325,
#  336,
#  351,
#  354,
#  361,
#  458,
#  466,
#  482,
#  484,
#  487,
#  490,
#  503,
#  511,
#  512,
#  513,
#  531,
#  532,
#  542,
#  558,
#  568,
#  576,
#  578,
#  624,
#  626,
#  648,
#  660,
#  661,
#  663,
#  664,
#  694,
#  701,
#  702,
#  703,
#  704,
#  705,
#  707,
#  708,
#  711,
#  714,
#  715,
#  716,
#  717,
#  719,
#  727,
#  736,
#  749,
#  751,
#  753,
#  769,
#  770,
#  817,
#  834,
#  853,
#  872,
#  881,
#  885,
#  886,
#  892,
#  897,
#  900,
#  917,
#  921,
#  940,
#  942,
#  943,
#  944,
#  945,
#  946,
#  947,
#  1004,
#  1025,
#  1123,
#  1163,
#  1169,
#  1171,
#  1184,
#  1186,
#  1192,
#  1234,
#  1297,
#  1299,
#  1319,
#  1326,
#  1345,
#  1348,
#  1363,
#  1367,
#  1371,
#  1379,
#  1383,
#  1392,
#  1395,
#  1404,
#  1440,
#  1446,
#  1452,
#  1456,
#  1467,
#  1468,
#  1477,
#  1482,
#  1489,
#  1495,
#  1496,
#  1498,
#  1500,
#  1502,
#  1503,
#  1505,
#  1515,
#  1516,
#  1517,
#  1518,
#  1519,
#  1551,
#  1552,
#  1553,
#  1554,
#  1555,
#  1556,
#  1560,
#  1565,
#  1566,
#  1587,
#  1591,
#  1594,
#  1602,
#  1604,
#  1617,
#  1618,
#  1623,
#  1631,
#  1711,
#  1731,
#  1732,
#  1743,
#  1748,
#  1770,
#  1786,
#  1815,
#  1816,
#  1834,
#  1836,
#  1837,
#  1839,
#  1844,
#  1865,
#  1867,
#  1870,
#  1875,
#  1876,
#  1877,
#  1906,
#  1914,
#  1915,
#  1940,
#  1965,
#  1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  1993,
#  1994,
#  1997,
#  1999,
#  2000,
#  2003,
#  2004,
#  2005,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2013,
#  2019,
#  2021,
#  2022,
#  2023,
#  2024,
#  2025,
#  2026,
#  2027,
#  2031,
#  2032,
#  2037,
#  2041,
#  2042,
#  2044,
#  2045,
#  2046,
#  2047,
#  2049,
#  2050,
#  2055,
#  2077,
#  2089,
#  2091,
#  2092,
#  2093,
#  2109,
#  2112,
#  2117,
#  2120,
#  2122,
#  2123,
#  2156,
#  2158,
#  2163,
#  2165,
#  2171,
#  2180,
#  2193,
#  2195,
#  2206,
#  2208,
#  2213,
#  2240,
#  2249,
#  2268,
#  2276,
#  2288,
#  2293,
#  2307,
#  2310,
#  2336,
#  2338,
#  2349,
#  2355,
#  2356,
#  2401,
#  2412,
#  2417,
#  2421,
#  2424,
#  2425,
#  2434,
#  2444,
#  2451,
#  2452,
#  2457,
#  2458,
#  2461,
#  2464,
#  2488,
#  2492,
#  2528,
#  2546,
#  2572,
#  2580,
#  2593,
#  2642,
#  2647,
#  2648,
#  2649,
#  2650,
#  2652,
#  2655,
#  2657,
#  2658,
#  2668,
#  2669,
#  2723,
#  2728,
#  2730,
#  2744,
#  2746,
#  2775,
#  2776,
#  2787,
#  2801,
#  2803,
#  2819,
#  2827,
#  2829,
#  2851,
#  2866,
#  2867,
#  2869,
#  2877,
#  2880,
#  2912,
#  2932,
#  2933,
#  2947,
#  2949,
#  2954,
#  2959,
#  2960,
#  3000,
#  3001,
#  3004,
#  3005,
#  3020,
#  3073,
#  3088,
#  3110,
#  3124,
#  3159,
#  3166,
#  3180,
#  3181,
#  3195,
#  3205,
#  3214,
#  3215,
#  3217,
#  3218,
#  3254,
#  3258,
#  3264,
#  3288,
#  3315,
#  3320,
#  3322,
#  3326,
#  3327,
#  3329,
#  3330,
#  3331,
#  3333,
#  3334,
#  3335,
#  3336,
#  3337,
#  3345,
#  3367,
#  3371,
#  3419,
#  3434,
#  3438,
#  3444,
#  3445,
#  3446,
#  3450,
#  3452,
#  3479,
#  3509,
#  3523,
#  3525,
#  3530,
#  3538,
#  3540,
#  3541,
#  3542,
#  3565,
#  3566,
#  3590,
#  3591,
#  3596,
#  3597,
#  3600,
#  3601,
#  3602,
#  3604,
#  3625,
#  3627,
#  3631,
#  3633,
#  3637,
#  3646,
#  3649,
#  3673,
#  3699,
#  3701,
#  3706,
#  3710,
#  3711,
#  3712,
#  3713,
#  3716,
#  3717,
#  3725,
#  3728,
#  3767,
#  3793,
#  4017,
#  4303,
#  4309,
#  4312,
#  4317,
#  4685,
#  4831]

# %%
# %%time

# iterate over the list, attempting to re-scrape the lines and string
# NOTE: I was getting a 'ValueError: Must have equal len keys and value when setting with an iterable', but converting
# the list to a string first seemed to make that go away. I have to convert this entire column anyway next.
for i in lookups:
    info = poem_scraper(df.loc[i, 'poem_url'])
    try:
        df.loc[i,'poem_lines'] = str(info[3])
        df.loc[i,'poem_string'] = info[4]
        print(f'Success -- {i}')
    except:
        print(f'Failure -- {i}')
        continue
# Out:
# Success --
# Success -- 3625
# Success -- 3627
# Success -- 3631
# Success -- 3633
# Success -- 3637
# Success -- 3646
# Success -- 3649
# Success -- 3673
# Success -- 3699
# Success -- 3701
# Success -- 3706
# Success -- 3710
# Success -- 3711
# Success -- 3712
# Success -- 3713
# Success -- 3716
# Success -- 3717
# Success -- 3725
# Success -- 3728
# Success -- 3767
# Success -- 3793
# Success -- 4017
# Success -- 4303
# Success -- 4309
# Success -- 4312
# Success -- 4317
# Success -- 4685
# Success -- 4831
# CPU times: user 59.9 s, sys: 5.84 s, total: 1min 5s
# Wall time: 24min 25s

# %% [markdown]
# - **Looks like the loop was somewhat successful though it did turn NaN values into the string 'nan'.**
# - **I'll look first for other NaNs I may want to get rid of.**

# %%
df['poem_lines'] = df['poem_lines'].apply(destringify)

# %%
df.loc[0,'poem_lines']
# Out:
# ['When you gain her Affection, take care to preserve it;\r',
#  'Lest others persuade her, you do not deserve it.\r',
#  'Still study to heighten the Joys of her Life;\r',
#  'Not treat her the worse, for her being your Wife.\r',
#  'If in Judgment she errs, set her right, without Pride:\r',
#  '’Tis the Province of insolent Fools, to deride.\r',
#  'A Husband’s first Praise, is a ',
#  'Then change not these Titles, for ',
#  'Let your Person be neat, unaffectedly clean,\r',
#  'Tho’ alone with your wife the whole Day you remain.\r',
#  'Chuse Books, for her study, to fashion her Mind,\r',
#  'To emulate those who excell’d of her Kind.\r',
#  'Be Religion the principal Care of your Life,\r',
#  'As you hope to be blest in your Children and Wife:\r',
#  'So you, in your Marriage, shall gain its true End;\r',
#  'And find, in your Wife, a ',
#  '',
#  '']

# %%
# convert the string 'nan' back to NaN value
df['poem_lines'] = np.where(df['poem_lines'] == 'nan', np.nan, df['poem_lines'])

# check
df.loc[169,'poem_lines']
# Out:
# nan

# %%
df.isna().sum()
# Out:
# poet_url          0
# genre             0
# poem_url          0
# poet              0
# title           214
# year           1649
# poem_lines      344
# poem_string     346
# dtype: int64

# %% [markdown]
# ### Round 2

# %%
# again, create a list of index numbers with NaN values in the poem_lines column
lookups2 = list(df[df.poem_lines.isna()].index)
lookups2
# Out:
# [169,
#  171,
#  183,
#  184,
#  200,
#  203,
#  210,
#  229,
#  254,
#  283,
#  324,
#  325,
#  458,
#  466,
#  482,
#  484,
#  487,
#  490,
#  503,
#  511,
#  512,
#  513,
#  531,
#  532,
#  558,
#  568,
#  576,
#  578,
#  624,
#  626,
#  648,
#  660,
#  661,
#  663,
#  664,
#  694,
#  701,
#  702,
#  703,
#  704,
#  705,
#  707,
#  708,
#  711,
#  714,
#  715,
#  716,
#  717,
#  719,
#  727,
#  736,
#  749,
#  751,
#  753,
#  769,
#  770,
#  834,
#  853,
#  872,
#  881,
#  885,
#  886,
#  892,
#  897,
#  900,
#  917,
#  921,
#  940,
#  942,
#  943,
#  944,
#  945,
#  946,
#  947,
#  1004,
#  1025,
#  1163,
#  1169,
#  1171,
#  1184,
#  1186,
#  1234,
#  1297,
#  1299,
#  1319,
#  1363,
#  1367,
#  1371,
#  1379,
#  1383,
#  1392,
#  1395,
#  1404,
#  1440,
#  1446,
#  1452,
#  1456,
#  1467,
#  1468,
#  1477,
#  1482,
#  1489,
#  1495,
#  1496,
#  1498,
#  1500,
#  1502,
#  1503,
#  1505,
#  1551,
#  1552,
#  1553,
#  1554,
#  1555,
#  1556,
#  1560,
#  1565,
#  1566,
#  1587,
#  1591,
#  1594,
#  1602,
#  1604,
#  1617,
#  1618,
#  1623,
#  1711,
#  1834,
#  1836,
#  1837,
#  1839,
#  1844,
#  1865,
#  1867,
#  1870,
#  1875,
#  1876,
#  1877,
#  1906,
#  1914,
#  1915,
#  1940,
#  1965,
#  1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  1993,
#  1994,
#  1997,
#  1999,
#  2000,
#  2003,
#  2004,
#  2005,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2013,
#  2019,
#  2021,
#  2022,
#  2023,
#  2024,
#  2025,
#  2026,
#  2027,
#  2031,
#  2032,
#  2037,
#  2041,
#  2042,
#  2044,
#  2045,
#  2046,
#  2047,
#  2049,
#  2050,
#  2055,
#  2089,
#  2091,
#  2092,
#  2093,
#  2109,
#  2112,
#  2117,
#  2120,
#  2122,
#  2123,
#  2156,
#  2158,
#  2163,
#  2165,
#  2171,
#  2180,
#  2193,
#  2195,
#  2206,
#  2208,
#  2213,
#  2240,
#  2249,
#  2276,
#  2288,
#  2293,
#  2307,
#  2310,
#  2336,
#  2349,
#  2355,
#  2356,
#  2401,
#  2412,
#  2417,
#  2421,
#  2424,
#  2425,
#  2434,
#  2444,
#  2451,
#  2452,
#  2457,
#  2458,
#  2461,
#  2464,
#  2488,
#  2492,
#  2528,
#  2546,
#  2572,
#  2580,
#  2593,
#  2642,
#  2647,
#  2648,
#  2649,
#  2723,
#  2728,
#  2730,
#  2744,
#  2746,
#  2775,
#  2776,
#  2787,
#  2801,
#  2803,
#  2819,
#  2827,
#  2829,
#  2851,
#  2866,
#  2867,
#  2869,
#  2877,
#  2880,
#  2912,
#  2932,
#  2933,
#  2947,
#  2949,
#  2954,
#  2959,
#  2960,
#  3000,
#  3001,
#  3004,
#  3005,
#  3020,
#  3073,
#  3088,
#  3110,
#  3159,
#  3166,
#  3180,
#  3181,
#  3195,
#  3205,
#  3254,
#  3258,
#  3264,
#  3288,
#  3315,
#  3322,
#  3326,
#  3327,
#  3329,
#  3330,
#  3331,
#  3333,
#  3334,
#  3335,
#  3336,
#  3337,
#  3345,
#  3367,
#  3371,
#  3434,
#  3438,
#  3444,
#  3445,
#  3446,
#  3450,
#  3452,
#  3523,
#  3525,
#  3530,
#  3538,
#  3540,
#  3541,
#  3542,
#  3566,
#  3590,
#  3591,
#  3596,
#  3597,
#  3600,
#  3601,
#  3602,
#  3604,
#  3625,
#  3627,
#  3631,
#  3633,
#  3637,
#  3646,
#  3649,
#  3673,
#  3699,
#  3701,
#  3706,
#  3710,
#  3711,
#  3712,
#  3713,
#  3716,
#  3717,
#  3725,
#  3728,
#  3767,
#  3793,
#  4309]

# %%
# %%time

# iterate over the list, attempting to re-scrape the lines and string
# NOTE: I was getting a 'ValueError: Must have equal len keys and value when setting with an iterable', but converting
# the list to a string first seemed to make that go away. I have to convert this entire column anyway next.
for i in lookups2:
    try:
        info = image_rescraper_poet(df.loc[i, 'poem_url'], df.loc[i, 'poet'])
        df.loc[i,'poem_lines'] = str(info[0])
        df.loc[i,'poem_string'] = info[1]
        print(f'Success -- {i}')
    except:
        print(f'Failure -- {i}')
        continue
# Out:
# Success --
# Success -- 2047
# Success -- 2049
# Failure -- 2050
# Failure -- 2055
# Success -- 2089
# Failure -- 2091
# Failure -- 2092
# Failure -- 2093
# Success -- 2109
# Success -- 2112
# Failure -- 2117
# Success -- 2120
# Failure -- 2122
# Failure -- 2123
# Failure -- 2156
# Success -- 2158
# Failure -- 2163
# Failure -- 2165
# Failure -- 2171
# Success -- 2180
# Failure -- 2193
# Success -- 2195
# Failure -- 2206
# Success -- 2208
# Success -- 2213
# Failure -- 2240
# Failure -- 2249
# Success -- 2276
# Success -- 2288
# Failure -- 2293
# Failure -- 2307
# Failure -- 2310
# Failure -- 2336
# Failure -- 2349
# Success -- 2355
# Success -- 2356
# Success -- 2401
# Failure -- 2412
# Failure -- 2417
# Failure -- 2421
# Failure -- 2424
# Failure -- 2425
# Failure -- 2434
# Failure -- 2444
# Failure -- 2451
# Failure -- 2452
# Failure -- 2457
# Failure -- 2458
# Failure -- 2461
# Failure -- 2464
# Failure -- 2488
# Failure -- 2492
# Failure -- 2528
# Failure -- 2546
# Failure -- 2572
# Success -- 2580
# Success -- 2593
# Success -- 2642
# Failure -- 2647
# Failure -- 2648
# Failure -- 2649
# Success -- 2723
# Failure -- 2728
# Failure -- 2730
# Failure -- 2744
# Failure -- 2746
# Success -- 2775
# Failure -- 2776
# Failure -- 2787
# Success -- 2801
# Failure -- 2803
# Success -- 2819
# Success -- 2827
# Failure -- 2829
# Failure -- 2851
# Success -- 2866
# Success -- 2867
# Failure -- 2869
# Failure -- 2877
# Failure -- 2880
# Success -- 2912
# Success -- 2932
# Failure -- 2933
# Failure -- 2947
# Success -- 2949
# Failure -- 2954
# Failure -- 2959
# Success -- 2960
# Failure -- 3000
# Success -- 3001
# Failure -- 3004
# Failure -- 3005
# Success -- 3020
# Success -- 3073
# Success -- 3088
# Success -- 3110
# Success -- 3159
# Success -- 3166
# Success -- 3180
# Success -- 3181
# Success -- 3195
# Success -- 3205
# Success -- 3254
# Success -- 3258
# Failure -- 3264
# Success -- 3288
# Success -- 3315
# Failure -- 3322
# Failure -- 3326
# Failure -- 3327
# Failure -- 3329
# Success -- 3330
# Failure -- 3331
# Failure -- 3333
# Success -- 3334
# Failure -- 3335
# Failure -- 3336
# Failure -- 3337
# Success -- 3345
# Success -- 3367
# Success -- 3371
# Failure -- 3434
# Success -- 3438
# Success -- 3444
# Failure -- 3445
# Failure -- 3446
# Success -- 3450
# Failure -- 3452
# Success -- 3523
# Failure -- 3525
# Success -- 3530
# Success -- 3538
# Failure -- 3540
# Success -- 3541
# Failure -- 3542
# Success -- 3566
# Success -- 3590
# Success -- 3591
# Success -- 3596
# Success -- 3597
# Success -- 3600
# Success -- 3601
# Success -- 3602
# Success -- 3604
# Success -- 3625
# Success -- 3627
# Success -- 3631
# Success -- 3633
# Success -- 3637
# Success -- 3646
# Failure -- 3649
# Failure -- 3673
# Failure -- 3699
# Failure -- 3701
# Success -- 3706
# Success -- 3710
# Success -- 3711
# Success -- 3712
# Success -- 3713
# Success -- 3716
# Success -- 3717
# Failure -- 3725
# Success -- 3728
# Success -- 3767
# Failure -- 3793
# Failure -- 4309
# CPU times: user 39.9 s, sys: 5.18 s, total: 45.1 s
# Wall time: 8min 17s

# %% [markdown]
# ### Round 3

# %%
# again, create a list of index numbers with NaN values in the poem_lines column
lookups3 = list(df[df.poem_lines.isna()].index)
lookups3
# Out:
# [183,
#  184,
#  200,
#  203,
#  229,
#  254,
#  283,
#  324,
#  325,
#  513,
#  576,
#  578,
#  648,
#  704,
#  707,
#  715,
#  717,
#  751,
#  753,
#  769,
#  770,
#  881,
#  892,
#  900,
#  917,
#  940,
#  943,
#  945,
#  946,
#  947,
#  1025,
#  1163,
#  1169,
#  1184,
#  1234,
#  1297,
#  1299,
#  1319,
#  1363,
#  1367,
#  1371,
#  1383,
#  1392,
#  1404,
#  1440,
#  1446,
#  1456,
#  1467,
#  1468,
#  1477,
#  1482,
#  1489,
#  1495,
#  1496,
#  1498,
#  1500,
#  1502,
#  1503,
#  1505,
#  1552,
#  1554,
#  1587,
#  1594,
#  1604,
#  1617,
#  1618,
#  1623,
#  1711,
#  1834,
#  1836,
#  1837,
#  1839,
#  1865,
#  1870,
#  1915,
#  1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  1993,
#  1997,
#  2003,
#  2008,
#  2011,
#  2013,
#  2019,
#  2021,
#  2023,
#  2026,
#  2032,
#  2037,
#  2042,
#  2044,
#  2050,
#  2055,
#  2091,
#  2092,
#  2093,
#  2117,
#  2122,
#  2123,
#  2156,
#  2163,
#  2165,
#  2171,
#  2193,
#  2206,
#  2240,
#  2249,
#  2293,
#  2307,
#  2310,
#  2336,
#  2349,
#  2412,
#  2417,
#  2421,
#  2424,
#  2425,
#  2434,
#  2444,
#  2451,
#  2452,
#  2457,
#  2458,
#  2461,
#  2464,
#  2488,
#  2492,
#  2528,
#  2546,
#  2572,
#  2647,
#  2648,
#  2649,
#  2728,
#  2730,
#  2744,
#  2746,
#  2776,
#  2787,
#  2803,
#  2829,
#  2851,
#  2869,
#  2877,
#  2880,
#  2933,
#  2947,
#  2954,
#  2959,
#  3000,
#  3004,
#  3005,
#  3264,
#  3322,
#  3326,
#  3327,
#  3329,
#  3331,
#  3333,
#  3335,
#  3336,
#  3337,
#  3434,
#  3445,
#  3446,
#  3452,
#  3525,
#  3540,
#  3542,
#  3649,
#  3673,
#  3699,
#  3701,
#  3725,
#  3793,
#  4309]

# %%
# %%time

# iterate over the list, attempting to re-scrape the lines and string
# NOTE: I was getting a 'ValueError: Must have equal len keys and value when setting with an iterable', but converting
# the list to a string first seemed to make that go away. I have to convert this entire column anyway next.
for i in lookups3:
    try:
        info = image_rescraper_POETRY(df.loc[i, 'poem_url'])
        df.loc[i,'poem_lines'] = str(info[0])
        df.loc[i,'poem_string'] = info[1]
        print(f'Success -- {i}')
    except:
        print(f'Failure -- {i}')
        continue
# Out:
# Failure -- 183
# Failure -- 184
# Success -- 200
# Success -- 203
# Success -- 229
# Success -- 254
# Failure -- 283
# Success -- 324
# Success -- 325
# Success -- 513
# Success -- 576
# Success -- 578
# Success -- 648
# Success -- 704
# Success -- 707
# Success -- 715
# Success -- 717
# Success -- 751
# Success -- 753
# Success -- 769
# Success -- 770
# Success -- 881
# Failure -- 892
# Success -- 900
# "['© SHE IS AS LOVELY-OFTEN', 'And tallness stood upon the sky like a sparkling mane', 'O she is as lovely-often as every day; the day', 'following the day . . the day of our lives, the brief day.', 'Within this moving room, this shadowy often-', 'ness of days where the little hurry of our lives is said. .', 'O as lovely-often as the moving wing of a bird.', 'But ah, alas, sooner or later each of us must', 'stand before that Roman Court, and be judged free of', 'even such lies as I told about the imperishable beauty of', 'her hair. But that time is not now, and even such lies as', 'I said about the enduring wonder of her grace, are lies', 'that contain within them the only truth by which a', 'man may live in this world.', 'she is as lovely-often as every day; the day', 'following the little day . . the day of our lives, ah, alas,', 'the brief day.', 'FIRST CAME THE LION-RIDER', 'First came the Lion-Rider, across the green', 'fields of the morning, holding golden in his golden', 'hands a thing of great wonder and loveliness—and it', 'had your name.']"

# %% [markdown]
# ### Round 4

# %%
# again, create a list of index numbers with NaN values in the poem_lines column
lookups4 = list(df[df.poem_lines.isna()].index)
lookups4
# Out:
# [183,
#  184,
#  283,
#  892,
#  945,
#  1297,
#  1363,
#  1371,
#  1383,
#  1392,
#  1440,
#  1446,
#  1482,
#  1489,
#  1495,
#  1496,
#  1500,
#  1552,
#  1617,
#  1836,
#  1839,
#  1865,
#  1870,
#  1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  2003,
#  2013,
#  2050,
#  2093,
#  2122,
#  2123,
#  2412,
#  2424,
#  2434,
#  2451,
#  2452,
#  2457,
#  2458,
#  2546,
#  2572,
#  2728,
#  2776,
#  2933,
#  3004,
#  3327,
#  3335,
#  3336,
#  3452,
#  4309]

# %%
# %%time

# iterate over the list, attempting to re-scrape the lines and string
# NOTE: I reworked the image_rescraper_poet function from earlier, so I'm running that again
for i in lookups4:
    try:
        info = image_rescraper_poet(df.loc[i, 'poem_url'], df.loc[i, 'poet'])
        df.loc[i,'poem_lines'] = str(info[0])
        df.loc[i,'poem_string'] = info[1]
        print(f'Success -- {i}')
    except:
        print(f'Failure -- {i}')
        continue
# Out:
# Success -- 183
# Success -- 184
# Failure -- 283
# Failure -- 892
# Failure -- 945
# Success -- 1297
# Failure -- 1363
# Failure -- 1371
# Failure -- 1383
# Failure -- 1392
# Failure -- 1440
# Failure -- 1446
# Failure -- 1482
# Failure -- 1489
# Failure -- 1495
# Failure -- 1496
# Failure -- 1500
# Failure -- 1552
# Failure -- 1617
# Failure -- 1836
# Failure -- 1839
# Failure -- 1865
# Failure -- 1870
# Failure -- 1975
# Failure -- 1976
# Failure -- 1977
# Failure -- 1978
# Failure -- 1979
# Success -- 2003
# Success -- 2013
# Failure -- 2050
# Success -- 2093
# Failure -- 2122
# Failure -- 2123
# Failure -- 2412
# Failure -- 2424
# Success -- 2434
# Failure -- 2451
# Failure -- 2452
# Failure -- 2457
# Failure -- 2458
# Failure -- 2546
# Failure -- 2572
# Failure -- 2728
# Failure -- 2776
# Failure -- 2933
# Failure -- 3004
# Success -- 3327
# Success -- 3335
# Success -- 3336
# Failure -- 3452
# Failure -- 4309
# CPU times: user 5.96 s, sys: 798 ms, total: 6.75 s
# Wall time: 1min 13s

# %% [markdown]
# ### Round 5

# %%
# again, create a list of index numbers with NaN values in the poem_lines column
lookups5 = list(df[df.poem_lines.isna()].index)
lookups5
# Out:
# [283,
#  892,
#  945,
#  1363,
#  1371,
#  1383,
#  1392,
#  1440,
#  1446,
#  1482,
#  1489,
#  1495,
#  1496,
#  1500,
#  1552,
#  1617,
#  1836,
#  1839,
#  1865,
#  1870,
#  1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  2050,
#  2122,
#  2123,
#  2412,
#  2424,
#  2451,
#  2452,
#  2457,
#  2458,
#  2546,
#  2572,
#  2728,
#  2776,
#  2933,
#  3004,
#  3452,
#  4309]

# %%
# %%time

# iterate over the list, attempting to re-scrape the lines and string
# NOTE: I reworked the image_rescraper_poet function from earlier, so am running that again
for i in lookups5:
    try:
        info = image_rescraper_title(df.loc[i, 'poem_url'], df.loc[i, 'title'])
        df.loc[i,'poem_lines'] = str(info[0])
        df.loc[i,'poem_string'] = info[1]
        print(f'Success -- {i}')
    except:
        print(f'Failure -- {i}')
        continue
# Out:
# Success -- 283
# Success -- 892
# Success -- 945
# Success -- 1363
# Success -- 1371
# Success -- 1383
# Success -- 1392
# Failure -- 1440
# Success -- 1446
# Failure -- 1482
# Success -- 1489
# Failure -- 1495
# Success -- 1496
# Failure -- 1500
# Success -- 1552
# Failure -- 1617
# Success -- 1836
# Failure -- 1839
# Success -- 1865
# Success -- 1870
# Failure -- 1975
# Failure -- 1976
# Success -- 1977
# Failure -- 1978
# Failure -- 1979
# Failure -- 2050
# Success -- 2122
# Failure -- 2123
# Failure -- 2412
# Success -- 2424
# Failure -- 2451
# Success -- 2452
# Success -- 2457
# Failure -- 2458
# Success -- 2546
# Success -- 2572
# Success -- 2728
# Failure -- 2776
# Success -- 2933
# Success -- 3004
# Success -- 3452
# Success -- 4309
# CPU times: user 4.89 s, sys: 663 ms, total: 5.56 s
# Wall time: 58.8 s

# %% [markdown]
# ### A little excessive, but not bad!

# %%
df.isna().sum()
# Out:
# poet_url          0
# genre             0
# poem_url          0
# poet              0
# title           214
# year           1649
# poem_lines        7
# poem_string       9
# dtype: int64

# %% [markdown]
# - **I'll drop the remaining rows with missing poem_lines values.**

# %%
# drop the rows with missing values in the poem_lines column
df.dropna(subset=['poem_lines'], inplace=True)

# %%
df.isna().sum()
# Out:
# poet_url          0
# genre             0
# poem_url          0
# poet              0
# title           214
# year           1649
# poem_lines        0
# poem_string       2
# dtype: int64

# %% [markdown]
# - **The pages for the rows with missing poem_string values appear to be blank so I'll drop those.**

# %%
df[df.poem_string.isna()]
# Out:
#                                                   poet_url            genre  \
# 2941   https://www.poetryfoundation.org/poets/dylan-thomas           modern
# 3230  https://www.poetryfoundation.org/poets/barbara-guest  new_york_school
#
#                                                                            poem_url  \
# 2941  https://www.poetryfoundation.org/poems/26804/poem-on-his-birthday-facs-drafts
# 3230                     https://www.poetryfoundation.org/poems/49367/imagined-room
#
#                poet                                title  year poem_lines  \
# 2941   Dylan Thomas  Poem on His Birthday [Facs. drafts]   NaN         []
# 3230  Barbara Guest                        Imagined Room   NaN         []
#
#      poem_string
# 2941         NaN
# 3230         NaN

# %%
# drop the rows with missing values in the poem_string column, the pages for which do appear blank
df.dropna(subset=['poem_string'], inplace=True)

# %% [markdown]
# - **I'll try to fill in the title column using Regex.**

# %%
# create a list of index numbers with NaN values in the title column
lookups_title = list(df[df.title.isna()].index)
lookups_title
# Out:
# [166,
#  251,
#  275,
#  285,
#  306,
#  459,
#  460,
#  462,
#  463,
#  469,
#  470,
#  471,
#  472,
#  514,
#  517,
#  521,
#  522,
#  523,
#  552,
#  556,
#  557,
#  559,
#  561,
#  563,
#  567,
#  619,
#  631,
#  639,
#  641,
#  642,
#  696,
#  710,
#  779,
#  780,
#  830,
#  831,
#  906,
#  908,
#  922,
#  924,
#  986,
#  999,
#  1012,
#  1046,
#  1112,
#  1136,
#  1143,
#  1164,
#  1174,
#  1261,
#  1262,
#  1296,
#  1349,
#  1455,
#  1539,
#  1540,
#  1586,
#  1588,
#  1596,
#  1599,
#  1609,
#  1757,
#  1842,
#  1848,
#  1849,
#  1903,
#  1907,
#  1908,
#  1930,
#  1935,
#  1946,
#  1947,
#  1955,
#  2028,
#  2034,
#  2118,
#  2159,
#  2160,
#  2167,
#  2177,
#  2182,
#  2188,
#  2198,
#  2210,
#  2211,
#  2212,
#  2219,
#  2223,
#  2291,
#  2363,
#  2415,
#  2426,
#  2428,
#  2460,
#  2466,
#  2493,
#  2494,
#  2522,
#  2757,
#  2758,
#  2760,
#  2767,
#  2778,
#  2781,
#  2796,
#  2806,
#  2816,
#  2820,
#  2830,
#  2845,
#  2847,
#  2858,
#  2862,
#  2864,
#  2871,
#  2953,
#  2955,
#  2969,
#  2996,
#  2997,
#  3002,
#  3008,
#  3167,
#  3271,
#  3309,
#  3346,
#  3360,
#  3369,
#  3380,
#  3381,
#  3390,
#  3430,
#  3431,
#  3433,
#  3449,
#  3456,
#  3533,
#  3592,
#  3593,
#  3641,
#  3644,
#  3677,
#  3696,
#  3704,
#  3705,
#  3707,
#  3708,
#  3709,
#  3714,
#  3715,
#  3731,
#  3732,
#  3733,
#  3736,
#  3741,
#  3749,
#  3776,
#  3777,
#  3780,
#  3782,
#  3783,
#  3784,
#  3785,
#  3786,
#  3787,
#  3788,
#  3870,
#  3895,
#  3903,
#  3904,
#  3907,
#  3939,
#  3947,
#  3948,
#  3949,
#  3950,
#  3952,
#  3954,
#  3955,
#  3959,
#  3960,
#  3961,
#  3962,
#  4008,
#  4030,
#  4034,
#  4035,
#  4036,
#  4038,
#  4039,
#  4040,
#  4041,
#  4042,
#  4043,
#  4044,
#  4045,
#  4046,
#  4047,
#  4048,
#  4049,
#  4051,
#  4052,
#  4053,
#  4054,
#  4055,
#  4056,
#  4057,
#  4058,
#  4059,
#  4066,
#  4327,
#  4419,
#  4420,
#  4618]

# %%
# %%time

# create regex pattern to capture the ending of the url
title_pattern = '.+/([a-z\-]*).*$'

# iterate over the list, attempting to fill in the title with re-stylized url ending
for i in lookups_title:
    title = re.search(title_pattern, df.loc[i,'poem_url'], re.I).group(1).replace('-', ' ').title()
    try:
        df.loc[i,'title'] = title
        print(f'Success -- {i}')
    except:
        print(f'Failure -- {i}')
        continue
# Out:
# Success -- 166
# Success -- 251
# Success -- 275
# Success -- 285
# Success -- 306
# Success -- 459
# Success -- 460
# Success -- 462
# Success -- 463
# Success -- 469
# Success -- 470
# Success -- 471
# Success -- 472
# Success -- 514
# Success -- 517
# Success -- 521
# Success -- 522
# Success -- 523
# Success -- 552
# Success -- 556
# Success -- 557
# Success -- 559
# Success -- 561
# Success -- 563
# Success -- 567
# Success -- 619
# Success -- 631
# Success -- 639
# Success -- 641
# Success -- 642
# Success -- 696
# Success -- 710
# Success -- 779
# Success -- 780
# Success -- 830
# Success -- 831
# Success -- 906
# Success -- 908
# Success -- 922
# Success -- 924
# Success -- 986
# Success -- 999
# Success -- 1012
# Success -- 1046
# Success -- 1112
# %%
df.isna().sum()
# Out:
# poet_url          0
# genre             0
# poem_url          0
# poet              0
# title             0
# year           1647
# poem_lines        0
# poem_string       0
# dtype: int64

# %% [markdown]
# - **I'll drop the year column, as that didn't seem to be too successful.**

# %%
df.drop(columns='year', inplace=True)
df.isna().sum()
# Out:
# poet_url       0
# genre          0
# poem_url       0
# poet           0
# title          0
# poem_lines     0
# poem_string    0
# dtype: int64

# %%
df.shape
# Out:
# (5176, 7)

# %% [markdown]
# ### Save a copy

# %%
df.to_csv('data/poetry_foundation_raw_rescrape.csv')

# %% [markdown]
# - **I'll look at a breakdown of genres and see if there are any I should get rid of.**
# - **My initial thoughts are to limit it in time period, so as to remove any language barriers, so to speak (between, say, Shakespearean English and modern English).**

# %%
df.genre.value_counts()
# Out:
# modern                            1279
# victorian                          643
# renaissance                        426
# romantic                           398
# imagist                            356
# new_york_school                    264
# black_mountain                     257
# new_york_school_2nd_generation     192
# language_poetry                    192
# confessional                       176
# black_arts_movement                165
# georgian                           160
# objectivist                        159
# harlem_renaissance                 148
# beat                               147
# augustan                           114
# fugitive                            90
# middle_english                      10
# Name: genre, dtype: int64

# %%
# check a sample Middle English poem
print(df[df.genre == 'middle_english'].iloc[0,-1])
# Out:
# Whan that Aprille with his shour
# The droghte of March hath perc
# And bath
# Of which vertú engendr
# Whan Zephirus eek with his swet
# Inspir
# The tendr
# Hath in the Ram his half
# And smal
# That slepen al the nyght with open y
# So priketh hem Natúre in hir corag
# Thanne longen folk to goon on pilgrimag
# And palmeres for to seken straung
# To fern
# And specially, from every shir
# Of Eng
# The hooly blisful martir for to sek
# That hem hath holpen whan that they were seek
#
# Bifil that in that seson on a day,
# In Southwerk at the Tabard as I lay,
# Redy to wenden on my pilgrymag
# To Caunterbury with ful devout corag
# At nyght were come into that hostelry
# Wel nyne and twenty in a compaigny
# Of sondry folk, by áventure y-fall
# In felaweshipe, and pilgrimes were they all
# That toward Caunterbury wolden ryd
# The chambr
# And wel we weren es
# And shortly, whan the sonn
# So hadde I spoken with hem everychon,
# That I was of hir felaweshipe anon,
# And mad
# To take oure wey, ther as I yow devys
#
# But nath
# Er that I ferther in this tal
# Me thynketh it acordaunt to resoun
# To tell
# Of ech of hem, so as it sem
# And whiche they weren and of what degree,
# And eek in what array that they were inn
# And at a Knyght than wol I first bigynn
#
# A Knyght ther was, and that a worthy man,
# That fro the tym
# To riden out, he lov
# Trouthe and honóur, fredom and curteisi
# Ful worthy was he in his lord
# And thereto hadde he riden, no man ferr
# As wel in cristendom as in heth
# And evere honóur
# At Alisaundre he was whan it was wonn
# Ful oft
# Aboven all
# In Lettow hadde he reys
# No cristen man so ofte of his degree.
# In Gernade at the seege eek hadde he be
# Of Algezir, and riden in Belmary
# At Lyeys was he, and at Sataly
# Whan they were wonne; and in the Gret
# At many a noble armee hadde he be.
#
# At mortal batailles hadde he been fiften
# And foughten for oure feith at Tramyssen
# In lyst
# This ilk
# Somtym
# Agayn another hethen in Turky
# And evermoore he hadde a sovereyn prys.
# And though that he were worthy, he was wys,
# Withouten any lenger taryyng
#
# Amorw
# Up roos oure Hoost and was oure aller cok,
# And gadrede us togidre alle in a flok;
# And forth we riden, a litel moore than paas,
# Unto the wateryng of Seint Thomas;
# And there oure Hoost bigan his hors arest
# And seyd
# Ye woot youre foreward and I it yow record
# If even-song and morw
# Lat se now who shal telle the first
# As ever mote I drynk
# Whoso be rebel to my jugg
# Shal paye for all that by the wey is spent.
# Now draweth cut, er that we ferrer twynn
# He which that hath the shorteste shal bigynn
# Sire Knyght," quod he, "my mayster and my lord
# Now draweth cut, for that is myn accord.
# Cometh neer," quod he, "my lady Prioress
# And ye, sire Clerk, lat be your shamefastness
# Ne studieth noght. Ley hond to, every man."
#
# Anon to drawen every wight bigan,
# And, shortly for to tellen as it was,
# Were it by áventúre, or sort, or cas,
# The sothe is this, the cut fil to the Knyght,
# Of which ful blithe and glad was every wyght;
# And telle he moste his tale, as was resoun,
# By foreward and by composic
# As ye han herd; what nedeth word
# And whan this goode man saugh that it was so,
# As he that wys was and obedient
# To kepe his foreward by his free assent,
# He seyd
# What, welcome be the cut, a Godd
# Now lat us ryde, and herkneth what I sey
# And with that word we ryden forth oure wey
# And he bigan with right a myrie cheer
# His tale anon, and seyde in this manér

# %% [markdown]
# - **Indeed, Middle English is definitely out.**

# %%
df = df[df.genre != 'middle_english']
df.shape
# Out:
# (5166, 7)

# %%
# check a sample Renaissance poem
print(df[df.genre == 'renaissance'].iloc[0,-1])
# Out:
# Long have I long’d to see my love againe,
#    Still have I wisht, but never could obtaine it;
#    Rather than all the world (if I might gaine it)
# Would I desire my love’s sweet precious gaine.
# Yet in my soule I see him everie day,
#    See him, and see his still sterne countenaunce,
#    But (ah) what is of long continuance,
# Where majestie and beautie beares the sway?
# Sometimes, when I imagine that I see him,
#    (As love is full of foolish fantasies)
#    Weening to kisse his lips, as my love’s fees,
# I feele but aire: nothing but aire to bee him.
#    Thus with Ixion, kisse I clouds in vaine:
#    Thus with Ixion, feele I endles paine.

# %%
# check a sample Augustan poem
print(df[df.genre == 'augustan'].iloc[1,-1])
# Out:
# And auld Robin Forbes hes gien tem a dance,
# I pat on my speckets to see them aw prance;
# I thout o’ the days when I was but fifteen,
# And skipp’d wi’ the best upon Forbes’s green.
# Of aw things that is I think thout is meast queer,
# It brings that that’s by-past and sets it down here;
# I see Willy as plain as I dui this bit leace,
# When he tuik his cwoat lappet and deeghted his feace.
#
# The lasses aw wonder’d what Willy cud see
# In yen that was dark and hard featur’d leyke me;
# And they wonder’d ay mair when they talk’d o’ my wit,
# And slily telt Willy that cudn’t be it:
# But Willy he laugh’d, and he meade me his weyfe,
# And whea was mair happy thro’ aw his lang leyfe?
# It’s e’en my great comfort, now Willy is geane,
# The he offen said— nae place was leyke his awn heame!
#
# I mind when I carried my wark to yon steyle
# Where Willy was deykin, the time to beguile,
# He wad fling me a daisy to put i’ my breast,
# And I hammer’d my noddle to mek out a jest.
# But merry or grave, Willy often wad tell
# There was nin o’ the leave that was leyke my awn sel;
# And he spak what he thout, for I’d hardly a plack
# When we married, and nobbet ae gown to my back.
#
# When the clock had struck eight I expected him heame,
# And wheyles went to meet him as far as Dumleane;
# Of aw hours it telt
# But now when it streykes there’s a tear i’ my ee.
# O Willy! dear Willy! it never can be
# That age, time, or death, can divide thee and me!
# For that spot on earth that’s aye dearest to me,
# Is the turf that has cover’d my Willy frae me!

# %% [markdown]
# - **According to Poetry Foundation's website, Renaissance and Augustan poems are from the years 1500 - 1780, and the differences in the English are fairly clear.**
# - **For now, I'll drop these.**

# %%
df_trim = df[df.genre != 'renaissance']
df_trim = df_trim[df_trim.genre != 'augustan']
df_trim.shape
# Out:
# (4626, 7)

# %%
# check a sample Victorian poem
print(df[df.genre == 'victorian'].iloc[1,-1])
# Out:
# I
# The evening comes, the fields are still.
# The tinkle of the thirsty rill,
# Unheard all day, ascends again;
# Deserted is the half-mown plain,
# Silent the swaths! the ringing wain,
# The mower's cry, the dog's alarms,
# All housed within the sleeping farms!
# The business of the day is done,
# The last-left haymaker is gone.
# And from the thyme upon the height,
# And from the elder-blossom white
# And pale dog-roses in the hedge,
# And from the mint-plant in the sedge,
# In puffs of balm the night-air blows
# The perfume which the day forgoes.
# And on the pure horizon far,
# See, pulsing with the first-born star,
# The liquid sky above the hill!
# The evening comes, the fields are still.
#
#        Loitering and leaping,
#        With saunter, with bounds—
#        Flickering and circling
#        In files and in rounds—
#        Gaily their pine-staff green
#        Tossing in air,
#        Loose o'er their shoulders white
#        Showering their hair—
#        See! the wild Maenads
#        Break from the wood,
#        Youth and Iacchus
#        Maddening their blood.
#
#        See! through the quiet land
#        Rioting they pass—
#        Fling the fresh heaps about,
#        Trample the grass.
#        Tear from the rifled hedge
#        Garlands, their prize;
#        Fill with their sports the field,
#        Fill with their cries.
#
#        Shepherd, what ails thee, then?
#        Shepherd, why mute?
#        Forth with thy joyous song!
#        Forth with thy flute!
#        Tempts not the revel blithe?
#        Lure not their cries?
#        Glow not their shoulders smooth?
#        Melt not their eyes?
#        Is not, on cheeks like those,
#        Lovely the flush?
#
#
#
# II
# The epoch ends, the world is still.
# The age has talk'd and work'd its fill—
# The famous orators have shone,
# The famous poets sung and gone,
# The famous men of war have fought,
# The famous speculators thought,
# The famous players, sculptors, wrought,
# The famous painters fill'd their wall,
# The famous critics judged it all.
# The combatants are parted now—
# Uphung the spear, unbent the bow,
# The puissant crown'd, the weak laid low.
# And in the after-silence sweet,
# Now strifes are hush'd, our ears doth meet,
# Ascending pure, the bell-like fame
# Of this or that down-trodden name,
# Delicate spirits, push'd away
# In the hot press of the noon-day.
# And o'er the plain, where the dead age
# Did its now silent warfare wage—
# O'er that wide plain, now wrapt in gloom,
# Where many a splendour finds its tomb,
# Many spent fames and fallen mights—
# The one or two immortal lights
# Rise slowly up into the sky
# To shine there everlastingly,
# Like stars over the bounding hill.
# The epoch ends, the world is still.
#
#        Thundering and bursting
#        In torrents, in waves—
#        Carolling and shouting
#        Over tombs, amid graves—
#        See! on the cumber'd plain
#        Clearing a stage,
#        Scattering the past about,
#        Comes the new age.
#        Bards make new poems,
#        Thinkers new schools,
#        Statesmen new systems,
#        Critics new rules.
#        All things begin again;
#        Life is their prize;
#        Earth with their deeds they fill,
#        Fill with their cries.
#
#        Poet, what ails thee, then?
#        Say, why so mute?
#        Forth with thy praising voice!
#        Forth with thy flute!
#        Loiterer! why sittest thou
#        Sunk in thy dream?
#        Tempts not the bright new age?
#        Shines not its stream?
#        Look, ah, what genius,
#        Art, science, wit!
#        Soldiers like Caesar,
#        Statesmen like Pitt!
#        Sculptors like Phidias,
#        Raphaels in shoals,
#        Poets like Shakespeare—
#        Beautiful souls!
#        See, on their glowing cheeks
#        Heavenly the flush!
#
#
#
# The world but feels the present's spell,
# The poet feels the past as well;
# Whatever men have done, might do,
# Whatever thought, might think it too.

# %%
# check a sample Romantic poem
print(df[df.genre == 'romantic'].iloc[1,-1])
# Out:
# Now in thy dazzling half-oped eye,
# Thy curled nose and lip awry,
# Uphoisted arms and noddling head,
# And little chin with crystal spread,
# Poor helpless thing! what do I see,
# That I should sing of thee?
#
# From thy poor tongue no accents come,
# Which can but rub thy toothless gum:
# Small understanding boasts thy face,
# Thy shapeless limbs nor step nor grace:
# A few short words thy feats may tell,
# And yet I love thee well.
#
# When wakes the sudden bitter shriek,
# And redder swells thy little cheek
# When rattled keys thy woes beguile,
# And through thine eyelids gleams the smile,
# Still for thy weakly self is spent
# Thy little silly plaint.
#
# But when thy friends are in distress.
# Thou’lt laugh and chuckle n’ertheless,
# Nor with kind sympathy be smitten,
# Though all are sad but thee and kitten;
# Yet puny varlet that thou art,
# Thou twitchest at the heart.
#
# Thy smooth round cheek so soft and warm;
# Thy pinky hand and dimpled arm;
# Thy silken locks that scantly peep,
# With gold tipped ends, where circle deep,
# Around thy neck in harmless grace,
# So soft and sleekly hold their place,
# Might harder hearts with kindness fill,
# And gain our right goodwill.
#
# Each passing clown bestows his blessing,
# Thy mouth is worn with old wives’ kissing;
# E’en lighter looks the gloomy eye
# Of surly sense when thou art by;
# And yet, I think, whoe’er they be,
# They love thee not like me.
#
# Perhaps when time shall add a few
# Short years to thee, thou’lt love me too;
# And after that, through life’s long way,
# Become my sure and cheering stay;
# Wilt care for me and be my hold,
# When I am weak and old.
#
# Thou’lt listen to my lengthened tale,
# And pity me when I am frail —
# But see, the sweepy spinning fly
# Upon the window takes thine eye.
# Go to thy little senseless play;
# Thou dost not heed my lay.

# %% [markdown]
# - **Romantic and Victorian poems are from 1781-1900, but the language seems fairly similar.**
# - **Plus, these are some very formative genres for poetry in English. For now, I'll keep these.**
#
# - **All other genres are from after 1900.**

# %%
# let's reindex
df_trim.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## Rescraping (again)
# - **Look more closely at how the scraping went.**
# - **Eventually, I'll want to create some new features, like number of lines and average line length.**
#     - **Since I can't divide by zero, this is a good opportunity to look for any unsuccessful scrapes--those where 0 or too few lines were scraped.**
#     - **NOTE: I'm checking if length of poem_lines is less than or equal to 1 because that yielded the desired results, whereas seeing if length equaled 0 did not.**

# %%
df_trim[df_trim['poem_lines'].map(lambda x: len(x)) <= 1]
# Out:
# 1938  As she laughed I was aware of becoming involved in her laughter and being part of it, until her teeth were only accidental stars with a talent for...
# 2509  A kind in glass and a cousin, a spectacle and nothing strange a single hurt color and an arrangement in a system to pointing. All this and not ord...
# 2514
# 2517
# 3275  The god of war assured King Arsounas, “Do not be fooled by words. No life is taken. Know that no one was ever born, nor does anyone die.” In the v...
# 3418                                                                                                              I'm coming up out of the tomb, Men of War
# 3421  All writing around the sides the persons a galaxy all writing resounds a hot history. All writing is in fact cut-ups history will decide games hea...
# 4217
# 4611

# %% [markdown]
# - **After building out some specific rescraping functions, I can replace the poem_lines and poem_string values.**

# %%
# rescrape poem based on index from above 
df_trim.loc[428,'poem_lines'] = str(PoemView_rescraper(df_trim.loc[428,'poem_url'])[0])
df_trim.loc[428,'poem_string'] = PoemView_rescraper(df_trim.loc[428,'poem_url'])[1]

df_trim.loc[703,'poem_lines'] = str(PoemView_rescraper(df_trim.loc[703,'poem_url'])[0])
df_trim.loc[703,'poem_string'] = PoemView_rescraper(df_trim.loc[703,'poem_url'])[1]

df_trim.loc[952,'poem_lines'] = str(poempara_rescraper(df_trim.loc[952,'poem_url'])[0])
df_trim.loc[952,'poem_string'] = poempara_rescraper(df_trim.loc[952,'poem_url'])[1]

df_trim.loc[953,'poem_lines'] = str(modified_regular_rescraper(df_trim.loc[953,'poem_url'])[0])
df_trim.loc[953,'poem_string'] = modified_regular_rescraper(df_trim.loc[953,'poem_url'])[1]

df_trim.loc[1231,'poem_lines'] = str(justify_rescraper(df_trim.loc[1231,'poem_url'])[0])
df_trim.loc[1231,'poem_string'] = justify_rescraper(df_trim.loc[1231,'poem_url'])[1]

df_trim.loc[1234,'poem_lines'] = str(justify_rescraper(df_trim.loc[1234,'poem_url'])[0])
df_trim.loc[1234,'poem_string'] = justify_rescraper(df_trim.loc[1234,'poem_url'])[1]

df_trim.loc[1389,'poem_lines'] = str(PoemView_rescraper(df_trim.loc[1389,'poem_url'])[0])
df_trim.loc[1389,'poem_string'] = PoemView_rescraper(df_trim.loc[1389,'poem_url'])[1]

df_trim.loc[1603,'poem_lines'] = str(PoemView_rescraper(df_trim.loc[1603,'poem_url'])[0])
df_trim.loc[1603,'poem_string'] = PoemView_rescraper(df_trim.loc[1603,'poem_url'])[1]

df_trim.loc[2514,'poem_lines'] = str(PoemView_rescraper(df_trim.loc[2514,'poem_url'])[0])
df_trim.loc[2514,'poem_string'] = PoemView_rescraper(df_trim.loc[2514,'poem_url'])[1]

df_trim.loc[2517,'poem_lines'] = str(PoemView_rescraper(df_trim.loc[2517,'poem_url'])[0])
df_trim.loc[2517,'poem_string'] = PoemView_rescraper(df_trim.loc[2517,'poem_url'])[1]

df_trim.loc[3335,'poem_lines'] = str(ranged_rescraper(df_trim.loc[3335,'poem_url'])[0])
df_trim.loc[3335,'poem_string'] = ranged_rescraper(df_trim.loc[3335,'poem_url'])[1]

df_trim.loc[3418,'poem_lines'] = str(center_rescraper(df_trim.loc[3418,'poem_url'])[0])
df_trim.loc[3418,'poem_string'] = center_rescraper(df_trim.loc[3418,'poem_url'])[1]

df_trim.loc[3421,'poem_lines'] = str(justify_rescraper(df_trim.loc[3421,'poem_url'])[0])
df_trim.loc[3421,'poem_string'] = justify_rescraper(df_trim.loc[3421,'poem_url'])[1]

df_trim.loc[4217,'poem_lines'] = str(poempara_rescraper(df_trim.loc[4217,'poem_url'])[0])
df_trim.loc[4217,'poem_string'] = poempara_rescraper(df_trim.loc[4217,'poem_url'])[1]

df_trim.loc[4611,'poem_lines'] = str(poempara_rescraper(df_trim.loc[4611,'poem_url'])[0])
df_trim.loc[4611,'poem_string'] = poempara_rescraper(df_trim.loc[4611,'poem_url'])[1]

# %%
# found some more...
df_trim.loc[1388,'poem_lines'] = str(PoemView_rescraper(df_trim.loc[1388,'poem_url'])[0])
df_trim.loc[1388,'poem_string'] = PoemView_rescraper(df_trim.loc[1388,'poem_url'])[1]

df_trim.loc[1390,'poem_lines'] = str(PoemView_rescraper(df_trim.loc[1390,'poem_url'])[0])
df_trim.loc[1390,'poem_string'] = PoemView_rescraper(df_trim.loc[1390,'poem_url'])[1]

df_trim.loc[1391,'poem_lines'] = str(PoemView_rescraper(df_trim.loc[1391,'poem_url'])[0])
df_trim.loc[1391,'poem_string'] = PoemView_rescraper(df_trim.loc[1391,'poem_url'])[1]

df_trim.loc[1392,'poem_lines'] = str(PoemView_rescraper(df_trim.loc[1392,'poem_url'])[0])
df_trim.loc[1392,'poem_string'] = PoemView_rescraper(df_trim.loc[1392,'poem_url'])[1]

# %%
# another one...
df_trim.loc[3399,'poem_lines'] = str(image_rescraper(df_trim.loc[3399,'poem_url'])[0])
df_trim.loc[3399,'poem_string'] = image_rescraper(df_trim.loc[3399,'poem_url'])[1]

# %% [markdown]
# - **Some scrapings contain only BeautifulSoup garbage, so I'll try to re-scrape those.**

# %%
# check if html tags are in the string
df_trim[df_trim.poem_string.str.contains('<div')]
# Out:
#                                                    poet_url  \
# 237   https://www.poetryfoundation.org/poets/nikki-giovanni
# 1687    https://www.poetryfoundation.org/poets/ron-silliman
# 1688    https://www.poetryfoundation.org/poets/ron-silliman
# 4260    https://www.poetryfoundation.org/poets/emma-lazarus
#
#                     genre  \
# 237   black_arts_movement
# 1687      language_poetry
# 1688      language_poetry
# 4260            victorian
#
#                                                                    poem_url  \
# 237              https://www.poetryfoundation.org/poems/90181/no-complaints
# 1687                https://www.poetryfoundation.org/poems/55563/you-part-i
# 1688              https://www.poetryfoundation.org/poems/55564/you-part-xii
# 4260  https://www.poetryfoundation.org/poems/46791/by-the-waters-of-babylon
#
#                 poet                     title  \
# 237   Nikki Giovanni             No Complaints
# 1687    Ron Silliman               You, part I
# 1688    Ron Silliman             You, part XII
# 4260    Emma Lazarus  By the Waters of Babylon
#
#                                                                                                                                                  poem_lines  \
# 237   [, <div class="c-epigraph">\n<p>\n<div style="font-style:italic;"><p><span style="font-style:normal">(For Gwendolyn Brooks, 1917—2001)</span></p><...
# 1687  [, <div class="c-epigraph">\n<p>\n<div style="font-style:italic;"><p><span style="font-style:normal">for Pat Silliman</span></p></div>\n</p>\n</di...
# 1688  [, <div class="c-epigraph">\n<p>\n<div style="font-style:italic;"><p><span style="font-style:normal">for Pat Silliman</span></p></div>\n</p>\n</di...
# 4260               [, <div class="c-epigraph">\n<p>\n<div style="font-style:italic;"><div align="center">Little Poems in Prose</div></div>\n</p>\n</div>, ]
#
#                                                                                                                                                 poem_string
# 237   \n<div class="c-epigraph">\n<p>\n<div style="font-style:italic;"><p><span style="font-style:normal">(For Gwendolyn Brooks, 1917—2001)</span></p></...
# 1687  \n<div class="c-epigraph">\n<p>\n<div style="font-style:italic;"><p><span style="font-style:normal">for Pat Silliman</span></p></div>\n</p>\n</div>\n
# 1688  \n<div class="c-epigraph">\n<p>\n<div style="font-style:italic;"><p><span style="font-style:normal">for Pat Silliman</span></p></div>\n</p>\n</div>\n
# 4260                 \n<div class="c-epigraph">\n<p>\n<div style="font-style:italic;"><div align="center">Little Poems in Prose</div></div>\n</p>\n</div>\n

# %%
# rescrape poem based on index from above 
df_trim.loc[237,'poem_lines'] = str(PoemView_rescraper_2(df_trim.loc[237,'poem_url'])[0])
df_trim.loc[237,'poem_string'] = PoemView_rescraper_2(df_trim.loc[237,'poem_url'])[1]

df_trim.loc[1687,'poem_lines'] = str(PoemView_rescraper(df_trim.loc[1687,'poem_url'])[0])
df_trim.loc[1687,'poem_string'] = PoemView_rescraper(df_trim.loc[1687,'poem_url'])[1]

df_trim.loc[1688,'poem_lines'] = str(PoemView_rescraper(df_trim.loc[1688,'poem_url'])[0])
df_trim.loc[1688,'poem_string'] = PoemView_rescraper(df_trim.loc[1688,'poem_url'])[1]

df_trim.loc[4260,'poem_lines'] = str(PoemView_rescraper(df_trim.loc[4260,'poem_url'])[0])
df_trim.loc[4260,'poem_string'] = PoemView_rescraper(df_trim.loc[4260,'poem_url'])[1]

# %%
# re-run the destringify function
df_trim['poem_lines'] = df_trim['poem_lines'].apply(destringify)

# %% [markdown]
# - **Re-check for any missing poem_lines values that aren't NaNs.**

# %%
df_trim[df_trim['poem_lines'].map(lambda d: len(d)) == 0]
# Out:
#                                                             poet_url  \
# 783           https://www.poetryfoundation.org/poets/randall-jarrell
# 1326               https://www.poetryfoundation.org/poets/ezra-pound
# 1433  https://www.poetryfoundation.org/poets/william-carlos-williams
# 1438  https://www.poetryfoundation.org/poets/william-carlos-williams
# 1736                https://www.poetryfoundation.org/poets/w-h-auden
# 1738                https://www.poetryfoundation.org/poets/w-h-auden
# 1775             https://www.poetryfoundation.org/poets/louise-bogan
# 1826               https://www.poetryfoundation.org/poets/hart-crane
# 2056                https://www.poetryfoundation.org/poets/a-m-klein
# 2582          https://www.poetryfoundation.org/poets/wallace-stevens
# 2685           https://www.poetryfoundation.org/poets/marion-strobel
# 2790            https://www.poetryfoundation.org/poets/sara-teasdale
# 2817    https://www.poetryfoundation.org/poets/jean-starr-untermeyer
# 3191              https://www.poetryfoundation.org/poets/frank-ohara
#
#                 genre  \
# 783          fugitive
# 1326          imagist
# 1433          imagist
# 1438          imagist
# 1736           modern
# 1738           modern
# 1775           modern
# 1826           modern
# 2056           modern
# 2582           modern
# 2685           modern
# 2790           modern
# 2817           modern
# 3191  new_york_school
#
#                                                                                                                                         poem_url  \
# 783                                           https://www.poetryfoundation.org/poetrymagazine/poems/25237/goodbye-wendover-goodbye-mountain-home
# 1326  https://www.poetryfoundation.org/poetrymagazine/poems/13071/dogmatic-statement-concerning-the-game-of-chess-theme-for-a-series-of-pictures
# 1433                                                                     https://www.poetryfoundation.org/poetrymagazine/poems/20226/a-foot-note
# 1438                                                                https://www.poetryfoundation.org/poetrymagazine/poems/24855/paterson-book-ii
# 1736                                                    https://www.poetryfoundation.org/poetrymagazine/poems/22702/poem-he-watched-with-all-his
# 1738                                     https://www.poetryfoundation.org/poetrymagazine/poems/21500/poem-o-who-can-ever-praise-enough-the-price
# 1775                                                    https://www.poetryfoundation.org/poetrymagazine/poems/21807/untitled-tender-and-insolent
# 1826                                                               https://www.poetryfoundation.org/poetrymagazine/poems/17345/at-melvilles-tomb
# 2056                                                           https://www.poetryfoundation.org/poetrymagazine/poems/23448/come-two-like-shadows
# 2582                                                              https://www.poetryfoundation.org/poetrymagazine/poems/19837/good-man-bad-woman
# 2685                                                       https://www.poetryfoundation.org/poetrymagazine/poems/20561/man-in-blue-shirt-sleeves
# 2790                                                        https://www.poetryfoundation.org/poetrymagazine/poems/14542/song-let-it-be-forgotten
# 2817                                                                   https://www.poetryfoundation.org/poetrymagazine/poems/21991/kristins-song
# 3191                                                             https://www.poetryfoundation.org/poetrymagazine/poems/26906/radio-56d210d8c79fe
#
#                          poet  \
# 783           Randall Jarrell
# 1326               Ezra Pound
# 1433  William Carlos Williams
# 1438  William Carlos Williams
# 1736              W. H. Auden
# 1738              W. H. Auden
# 1775             Louise Bogan
# 1826               Hart Crane
# 2056              A. M. Klein
# 2582          Wallace Stevens
# 2685           Marion Strobel
# 2790            Sara Teasdale
# 2817    Jean Starr Untermeyer
# 3191             Frank O'Hara
#
#                                                                                title  \
# 783                                           Goodbye Wendover Goodbye Mountain Home
# 1326  Dogmatic Statement Concerning The Game Of Chess Theme For A Series Of Pictures
# 1433                                                                     A Foot Note
# 1438                                                                Paterson Book Ii
# 1736                                                    Poem He Watched With All His
# 1738                                     Poem O Who Can Ever Praise Enough The Price
# 1775                                                    Untitled Tender And Insolent
# 1826                                                               At Melvilles Tomb
# 2056                                                           Come Two Like Shadows
# 2582                                                              Good Man Bad Woman
# 2685                                                       Man In Blue Shirt Sleeves
# 2790                                                        Song Let It Be Forgotten
# 2817                                                                   Kristins Song
# 3191                                                                              Fe
#
#      poem_lines poem_string
# 783          []
# 1326         []
# 1433         []
# 1438         []
# 1736         []
# 1738         []
# 1775         []
# 1826         []
# 2056         []
# 2582         []
# 2685         []
# 2790         []
# 2817         []
# 3191         []

# %%
# create a list of indices
lookups6 = list(df_trim[df_trim['poem_lines'].map(lambda d: len(d)) == 0].index)
lookups6
# Out:
# [783,
#  1326,
#  1433,
#  1438,
#  1736,
#  1738,
#  1775,
#  1826,
#  2056,
#  2582,
#  2685,
#  2790,
#  2817,
#  3191]

# %%
# %%time

# iterate over the list, attempting to re-scrape the lines and string
# NOTE: I reworked the image_rescraper_poet function from earlier, so I'm running that again
for i in lookups6:
    try:
        info = image_rescraper_title(df_trim.loc[i, 'poem_url'], df_trim.loc[i, 'title'])
        df_trim.loc[i,'poem_lines'] = str(info[0])
        df_trim.loc[i,'poem_string'] = info[1]
        print(f'Success -- {i}')
    except:
        print(f'Failure -- {i}')
        continue
# Out:
# Success -- 783
# Success -- 1326
# Success -- 1433
# Success -- 1438
# Success -- 1736
# Success -- 1738
# Success -- 1775
# Success -- 1826
# Success -- 2056
# Success -- 2582
# Success -- 2685
# Success -- 2790
# Success -- 2817
# Failure -- 3191
# CPU times: user 1.58 s, sys: 214 ms, total: 1.79 s
# Wall time: 51.6 s

# %%
# one final one to redo
df_trim.loc[3191,'title'] = 'Radio'
info = image_rescraper_title(df_trim.loc[3191, 'poem_url'], df_trim.loc[3191, 'title'])
df_trim.loc[3191,'poem_lines'] = str(info[0])
df_trim.loc[3191,'poem_string'] = info[1]

# %%
# re-run destringify
df_trim['poem_lines'] = df_trim['poem_lines'].apply(destringify)

# %% [markdown]
# ## SAVE IT!

# %%
df_trim.to_csv('data/poetry_foundation_raw_rescrape.csv')
