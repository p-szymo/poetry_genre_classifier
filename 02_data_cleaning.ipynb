# %% [markdown]
# # Predicting Poetic Movements
#
# ## Data Cleaning
#
# - In this notebook, I look at the data I scraped from [PoetryFoundation.org](https://www.poetryfoundation.org/) in the previous [notebook](01_webscraping.ipynb).
# - I check for and rectify duplicate (or near-duplicate) entries, NaN values, and poorly scraped poems.
#
# #### Important note
# As in the [previous notebook](01_webscraping.ipynb), due to the imperfection and idiosyncracies of scraping text from images, a lot of rescraping was necessary. Sometimes this had to be done in a manner that is best described, rather unfortunately, as nonprogrammatic. As a result, this notebook is at times messy, which is not a reflection on the other notebooks for this project.
#
# Thank you for understanding :)
#
# ## Table of contents
#
# 1. [Load packages and data](#Load-packages-and-data)
# 2. [Check for duplicates](#Check-for-duplicates)
#
#     - [Drop duplicates](#Drop-duplicates)
#     - [Scrape extra pages](#Scrape-extra_pages)
#     - [Add titles](#Add-titles)
#
#
# 3. [Check for NaN values](#Check-for-NaN-values)
# 4. [Check for other bad scrapes](#Check-for-other-bad-scrapes)
#
#     - [Finishing touches](#Finishing-touches)
#     - [💾 Save DataFrame](#💾-Save-DataFrame)
#
#
# 5. [Drop certain genres](#Drop-certain-genres)
#
#     - [💾 Save/Load Trimmed DataFrame](#💾-Save/Load-Trimmed-DataFrame)
#
#
# ## Load packages and data
#
# [[go back to the top](#Data-Cleaning)]

# %%
# custom functions for webscraping
from functions_webscraping import *
from functions import destringify

# standard dataframe packages
import pandas as pd
import numpy as np

# timekeeping/progress packages
import time
from tqdm import tqdm

# saving packages
import gzip
import pickle

# reload functions/libraries when edited
# %load_ext autoreload
# %autoreload 2

# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# increase column width of dataframe
pd.set_option('max_colwidth', 150)

# %%
df = pd.read_csv('data/poems_df_pre_clean.csv', index_col=0)
df.shape
# Out:
# (5168, 6)

# %%
df.head()
# Out:
#              poet  \
# 0  Alexander Pope
# 1  Alexander Pope
# 2  Alexander Pope
# 3  Alexander Pope
# 4  Alexander Pope
#
#                                                                     poem_url  \
# 0  https://www.poetryfoundation.org/poems/44896/an-essay-on-criticism-part-1
# 1  https://www.poetryfoundation.org/poems/44897/an-essay-on-criticism-part-2
# 2  https://www.poetryfoundation.org/poems/44898/an-essay-on-criticism-part-3
# 3     https://www.poetryfoundation.org/poems/44899/an-essay-on-man-epistle-i
# 4    https://www.poetryfoundation.org/poems/44900/an-essay-on-man-epistle-ii
#
#                            title  \
# 0  An Essay on Criticism: Part 1
# 1  An Essay on Criticism: Part 2
# 2  An Essay on Criticism: Part 3
# 3     An Essay on Man: Epistle I
# 4    An Essay on Man: Epistle II
#
#                                                                                                                                               poem_lines  \
# 0  ['PART 1', "'Tis hard to say, if greater want of skill", 'Appear in writing or in judging ill;', "But, of the two, less dang'rous is th' offence",...
# 1  ['Of all the causes which conspire to blind', "Man's erring judgment, and misguide the mind,", 'What the weak head with strongest bias rules,', 'I...
# 2  ['Learn then what morals critics ought to show,', "For 'tis but half a judge's task, to know.", "'Tis not enough, taste, judgment, learning, join;...
# 3  ['Awake, my St. John! leave all meaner things', 'To low ambition, and the pride of kings.', 'Let us (since life can little more supply', 'Than jus...
# 4  ['I.', 'Know then thyself, presume not God to scan;', 'The proper study of mankind is man.', "Plac'd on this isthmus of a middle state,", 'A being...
#
#                                                                                                                                              poem_string  \
# 0  PART 1\n'Tis hard to say, if greater want of skill\nAppear in writing or in judging ill;\nBut, of the two, less dang'rous is th' offence\nTo tire ...
# 1  Of all the causes which conspire to blind\nMan's erring judgment, and misguide the mind,\nWhat the weak head with strongest bias rules,\nIs pride,...
# 2  Learn then what morals critics ought to show,\nFor 'tis but half a judge's task, to know.\n'Tis not enough, taste, judgment, learning, join;\nIn a...
# 3  Awake, my St. John! leave all meaner things\nTo low ambition, and the pride of kings.\nLet us (since life can little more supply\nThan just to loo...
# 4  I.\nKnow then thyself, presume not God to scan;\nThe proper study of mankind is man.\nPlac'd on this isthmus of a middle state,\nA being darkly wi...
#
#       genre
# 0  augustan
# 1  augustan
# 2  augustan
# 3  augustan
# 4  augustan

# %% [markdown]
# - Saving to CSV converts the list of poem_lines to a string, so I'll use my destringify function.

# %%
df['poem_lines'] = df['poem_lines'].apply(destringify)

# %% [markdown]
# ## Check for duplicates
#
# [[go back to the top](#Data-Cleaning)]
#
# - First check if any poems were scraped twice.
# - Then look for poems that are the same, but may have been scraped slightly differently.

# %%
len(df[df.duplicated(subset=['poet', 'poem_string'])])
# Out:
# 21

# %%
df[df.duplicated(subset=['poet', 'poem_string'], keep=False)]
# Out:
#                             poet  \
# 119               Allen Ginsberg
# 120               Allen Ginsberg
# 249            Richard Brautigan
# 250            Richard Brautigan
# 613               Robert Creeley
# 614               Robert Creeley
# 738                John Berryman
# 741                John Berryman
# 852              W. D. Snodgrass
# 1845            Alfred Kreymborg
# 1867            Alfred Kreymborg
# 2195           Edgar Lee Masters
# 2236           Edgar Lee Masters
# 2333       Guillaume Apollinaire
# 2335       Guillaume Apollinaire
# 2337       Guillaume Apollinaire
# 2338       Guillaume Apollinaire
# 2355                  Hart Crane
# 2356                  Hart Crane
# 2357                  Hart Crane
# 2358                  Hart Crane
# 2359                  Hart Crane
# 2360                  Hart Crane
# 2367  Henry Wadsworth Longfellow
# 2567              Marianne Moore
# 2571              Marianne Moore
# 2575              Marianne Moore
# 2931             Wallace Stevens
# 2932             Wallace Stevens
# 2995             Wallace Stevens
# 2996             Wallace Stevens
# 3454       Guillaume Apollinaire
# 3455       Guillaume Apollinaire
# 3642            Lorine Niedecker
# 3666            Lorine Niedecker
# 4480          William Wordsworth
# 4481          William Wordsworth
# 4891  Henry Wadsworth Longfellow
# 5159             W. D. Snodgrass
#
#                                                                                                                                                    poem_url  \
# 119                                                                                                       https://www.poetryfoundation.org/poems/49303/howl
# 120                                                                                                       https://www.poetryfoundation.org/poems/49303/howl
# 249                                                                                                     https://www.poetryfoundation.org/poems/48576/a-boat
# 250                                                                        https://www.poetryfoundation.org/poetrymagazine/poems/56423/a-boat-56d238e754f45
# 613                                                                                   https://www.poetryfoundation.org/poems/42840/the-rescue-56d2217b24ec4
# 614                                                                                  https://www.poetryfoundation.org/poetrymagazine/poems/28665/the-rescue
# 738                                                                            https://www.poetryfoundation.org/poetrymagazine/poems/29165/four-dream-songs
# 741                                                                      https://www.poetryfoundation.org/poetrymagazine/poems/29167/henrys-pelt-was-put-on
# 852                                                                                         https://www.poetryfoundation.org/poems/52643/song-56d2314775fc
# 3642  are at their highest thoughts\nof leaving\nMiddle life said nothing—\ngrounde\nto a livelihood\nOld age—a high gabbling gathering\nbefore goodbye\...
# 3666  are at their highest thoughts\nof leaving\nMiddle life said nothing—\ngrounde\nto a livelihood\nOld age—a high gabbling gathering\nbefore goodbye\...
# 4480  Five years have past; five summers, with the length\nOf five long winters! and again I hear\nThese waters, rolling from their mountain-springs\nWi...
# 4481  Five years have past; five summers, with the length\nOf five long winters! and again I hear\nThese waters, rolling from their mountain-springs\nWi...
# 4891  Listen, my children, and you shall hear\nOf the midnight ride of Paul Revere,\nOn the eighteenth of April, in Seventy-five;\nHardly a man is now a...
# 5159  Sweet beast, I have gone prowling,\na proud rejected man\nwho lived along the edges\ncatch as catch can;\nin darkness and in hedges\nI sang my sou...
#
#                                genre
# 119                             beat
# 120                             beat
# 249                             beat
# 250                             beat
# 613                   black_mountain
# 614                   black_mountain
# 738                     confessional
# 741                     confessional
# 852                     confessional
# 1845                          modern
# 1867                          modern
# 2195                          modern
# 2236                          modern
# 2333                          modern
# 2335                          modern
# 2337                          modern
# 2338                          modern
# 2355                          modern
# 2356                          modern
# 2357                          modern
# 2358                          modern
# 2359                          modern
# 2360                          modern
# 2367                          modern
# 2567                          modern
# 2571                          modern
# 2575                          modern
# 2931                          modern
# 2932                          modern
# 2995                          modern
# 2996                          modern
# 3454  new_york_school_2nd_generation
# 3455  new_york_school_2nd_generation
# 3642                     objectivist
# 3666                     objectivist
# 4480                        romantic
# 4481                        romantic
# 4891                       victorian
# 5159                       victorian

# %% [markdown]
# - I'm actually somewhat happy about this because it shows that my image scraper worked pretty darn well, if the strings are exactly the same.
# - That said, it may also mean that there are even more near-duplicates, but I can check for duplicates across poet and title next.

# %%
# drop duplicates
to_drop = [120, 250, 614, 2338, 2358, 2367, 2931, 2995, 3454, 3455, 3642, 4481, 5159]
df.drop(index=to_drop, inplace=True)

# confirm
df.shape
# Out:
# (5155, 6)

# %% [markdown]
# - With some poems that have multiple parts, my scraper scraped all the parts for each row, so those need a more nuanced fix, as conducted below.

# %%
df.loc[738, 'poem_lines'] = df.loc[738, 'poem_lines'][:-4]
df.loc[738, 'poem_string'] = '\n'.join(df.loc[738, 'poem_lines'])

df.loc[741, 'poem_lines'] = df.loc[741, 'poem_lines'][-3:]
df.loc[741, 'poem_string'] = '\n'.join(df.loc[741, 'poem_lines'])

# %%
df.loc[1845, 'poem_lines'] = df.loc[1845, 'poem_lines'][:19]
df.loc[1845, 'poem_string'] = '\n'.join(df.loc[1845, 'poem_lines'])

df.loc[1867, 'poem_lines'] = df.loc[1867, 'poem_lines'][20:]
df.loc[1867, 'poem_string'] = '\n'.join(df.loc[1867, 'poem_lines'])

# %%
df.loc[2195, 'poem_lines'] = df.loc[2195, 'poem_lines'][:12]
df.loc[2195, 'poem_string'] = '\n'.join(df.loc[2195, 'poem_lines'])

df.loc[2236, 'poem_lines'] = df.loc[2236, 'poem_lines'][12:51]
df.loc[2236, 'poem_string'] = '\n'.join(df.loc[2236, 'poem_lines'])

# %%
df.loc[2571, 'poem_lines'] = df.loc[2571, 'poem_lines'][:-1]
df.loc[2571, 'poem_string'] = '\n'.join(df.loc[2571, 'poem_lines'])

# %% [markdown]
# - A couple of total rescrapes, because the URL went to the wrong page.

# %%
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=83&issue=6&page=2'
url = df.loc[2567, 'poem_url']
rescrape = scan_poem_scraper(actual_url, input_poet=df.loc[2567, 'poet'], input_title=df.loc[2567, 'title'])
rescrape['poem_url'] = url
rescrape['genre'] = df.loc[2567, 'genre']
df.loc[2567, 'poem_lines'] = rescrape['poem_lines']
df.loc[2567, 'poem_string'] = rescrape['poem_string']

# %%
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=83&issue=6&page=3'
url = df.loc[2575, 'poem_url']
rescrape = scan_poem_scraper(actual_url, input_poet=df.loc[2575, 'poet'], input_title=df.loc[2575, 'title'])
rescrape['poem_url'] = url
rescrape['genre'] = df.loc[2575, 'genre']
df.loc[2575, 'poem_lines'] = rescrape['poem_lines']
df.loc[2575, 'poem_string'] = rescrape['poem_string']

# %% [markdown]
# - A slight title adjustment so all the words in the first line will be accounted for.

# %%
df.loc[3666, 'title'] = 'Young in Fall I said: the birds'

# %% [markdown]
# - Check for duplicates again.

# %%
df[df.duplicated(subset=['poet', 'poem_string'], keep=False)]
# Out:
#             poet  \
# 2355  Hart Crane
# 2356  Hart Crane
# 2359  Hart Crane
# 2360  Hart Crane
#
#                                                                                        poem_url  \
# 2355  https://www.poetryfoundation.org/poetrymagazine/poems/19926/the-urn-enrich-my-resignation
# 2356             https://www.poetryfoundation.org/poetrymagazine/poems/19916/the-urn-purgatorio
# 2359                  https://www.poetryfoundation.org/poetrymagazine/poems/19922/the-urn-reply
# 2360         https://www.poetryfoundation.org/poetrymagazine/poems/19920/the-urn-the-sad-indian
#
#                               title poem_lines poem_string   genre
# 2355  The Urn Enrich My Resignation         []         NaN  modern
# 2356             The Urn Purgatorio         []         NaN  modern
# 2359                  The Urn Reply         []         NaN  modern
# 2360         The Urn The Sad Indian         []         NaN  modern

# %% [markdown]
# - I know I scraped these in the [rescrape](01_webscraping.ipynb#Rescrape) portion of the previous notebook, so I'll confirm those are somewhere in the DataFrame.

# %%
df[df.poet == 'Hart Crane']
# Out:
#             poet  \
# 2341  Hart Crane
# 2342  Hart Crane
# 2343  Hart Crane
# 2344  Hart Crane
# 2345  Hart Crane
# 2346  Hart Crane
# 2347  Hart Crane
# 2348  Hart Crane
# 2349  Hart Crane
# 2350  Hart Crane
# 2351  Hart Crane
# 2352  Hart Crane
# 2353  Hart Crane
# 2354  Hart Crane
# 2355  Hart Crane
# 2356  Hart Crane
# 2357  Hart Crane
# 2359  Hart Crane
# 2360  Hart Crane
# 2361  Hart Crane
# 2362  Hart Crane
# 2363  Hart Crane
# 2364  Hart Crane
# 2365  Hart Crane
# 2366  Hart Crane
#
#                                                                                        poem_url  \
# 2341                   https://www.poetryfoundation.org/poetrymagazine/poems/19925/a-postscript
# 2342              https://www.poetryfoundation.org/poetrymagazine/poems/17345/at-melvilles-tomb
# 2343               https://www.poetryfoundation.org/poems/43260/at-melvilles-tomb-56d221f8f2f82
# 2344                  https://www.poetryfoundation.org/poetrymagazine/poems/19923/by-nilus-once
# 2345                                  https://www.poetryfoundation.org/poems/43257/chaplinesque
# 2346          https://www.poetryfoundation.org/poetrymagazine/poems/17746/the-bridge-cutty-sark
# 2347                       https://www.poetryfoundation.org/poetrymagazine/poems/18754/eldorado
# 2348                    https://www.poetryfoundation.org/poetrymagazine/poems/19919/havana-rose
# 2351  So dream thy sails, O phantom bark,\nThat I thy drowned men may speak again\nPerhaps as once Will Collins spoke the lark,\nAnd leave me half adrea...
# 2352  This tuft that thrives on saline nothingness,\nInverted octopus with heavenward arms\nThrust parching from a palm-bole hard by the cove⎯\nA bird a...
# 2353  How many dawns, chill from his rippling rest\nThe seagull’s wings shall dip and pivot him,\nShedding white rings of tumult, building high\nOver th...
# 2354  To Xochipilli\nThe anointed stone, the coruscated crown,\nThe drastic throne, the\nDesperate sweet eyepit-basins of a bloody foreign clown—\nCouch...
# 2355                                                                                                                                                    NaN
# 2356                                                                                                                                                    NaN
# 2357  ENDERNESS and resolution!\nWhat is our life without a sudden pillow,\nWhat is death without a ditch?\nThe harvest laugh of bright Apollo\nAnd the ...
# 2359                                                                                                                                                    NaN
# 2360                                                                                                                                                    NaN
# 2361  Enrich my resignation as I usurp those far\nFeints of control, hear rifles blown out on the stag\nBelow the aeroplane, and see the fox’s brush\nWh...
# 2362  My country, O my land, my friends—\nAm I apart—here from you in a land\nWhere all your gas-lights, faces, sputum gleam\nLike something left, forsa...
# 2363  Thou canst read nothing except through appetite,\nAnd here we join eyes in that sanctity\nWhere brother passes brother without sight,\nBut finally...
# 2364  Sad heart, the gymnast of inertia, does not count\nHours, days—and scarcely sun and moon.\nThe warp is in his woof, and his keen vision\nSpells wh...
# 2365  To E. O.\nYes, I being\nThe terrible puppet of my dreams, shall\nLavish this on you—\nThe dense mine of the orchid, split in two.\nAnd the finger-...
# 2366  I\nAbove the fresh ruffles of the surf\nBright striped urchins flay each other with sand.\nThey have contrived a conquest for shell shucks,\nAnd t...
#
#        genre
# 2341  modern
# 2342  modern
# 2343  modern
# 2344  modern
# 2345  modern
# 2346  modern
# 2347  modern
# 2348  modern
# 2349  modern
# 2350  modern
# 2351  modern
# 2352  modern
# 2353  modern
# 2354  modern
# 2355  modern
# 2356  modern
# 2357  modern
# 2359  modern
# 2360  modern
# 2361  modern
# 2362  modern
# 2363  modern
# 2364  modern
# 2365  modern
# 2366  modern

# %% [markdown]
# - Found them! And interestingly, I found a duplicate for which my image-text scraper must not have scraped entirely properly.
# - I'll go ahead a drop all those now.

# %%
# drop duplicates
to_drop = [2342, 2355, 2356, 2359, 2360]
df.drop(index=to_drop, inplace=True)

# confirm
df.shape
# Out:
# (5150, 6)

# %% [markdown]
# - Check for poems with same poet and title, which may mean there are differently scraped duplicate poems.
# - Since there were so many, I did these in batches of 40, using the code in the following cell.
# - The subsequent cells detail my process for fixing any legitimate duplicates, by either dropping, rescraping, adding titles, etc.

# %%
df[df.duplicated(subset=['poet', 'title'], keep=False)].head(40)
# Out:
#                          poet  \
# 176           Kenneth Patchen
# 177           Kenneth Patchen
# 461           Denise Levertov
# 462           Denise Levertov
# 546            Robert Creeley
# 547            Robert Creeley
# 603            Robert Creeley
# 604            Robert Creeley
# 622            Robert Creeley
# 623            Robert Creeley
# 624            Robert Creeley
# 625            Robert Creeley
# 736             John Berryman
# 737             John Berryman
# 802              Sylvia Plath
# 803              Sylvia Plath
# 823                Ted Hughes
# 824                Ted Hughes
# 851           W. D. Snodgrass
# 852           W. D. Snodgrass
# 929           Randall Jarrell
# 929             fugitive
# 930             fugitive
# 938             fugitive
# 939             fugitive
# 1019            georgian
# 1020            georgian
# 1167  harlem_renaissance
# 1168  harlem_renaissance
# 1266             imagist
# 1267             imagist
# 1505             imagist
# 1506             imagist
# 1532             imagist
# 1533             imagist
# 1556             imagist
# 1557             imagist
# 1930              modern
# 1931              modern
# 1935              modern
# 1936              modern

# %% [markdown]
# ### Drop duplicates
#
# [[go back to the top](#Data-Cleaning)]
#
# - Drop duplicate values.

# %%
# drop duplicates
to_drop = [176, 461, 547, 603, 737, 803, 823, 930, 939, 1267, 1506, 1556, 1930, 1936]
df.drop(index=to_drop, inplace=True)

# confirm
df.shape
# Out:
# (5136, 6)

# %%
# drop duplicates
to_drop = [2010, 2052, 2119, 2236, 2315, 2397, 2504, 2505, 2574, 2831, 2863, 2866, 2900]
df.drop(index=to_drop, inplace=True)

# confirm
df.shape
# Out:
# (5123, 6)

# %%
# drop duplicates
to_drop = [2903, 2914, 2969, 3238, 3264, 3287, 3902]
df.drop(index=to_drop, inplace=True)

# confirm
df.shape
# Out:
# (5116, 6)

# %%
# drop duplicates
to_drop = [4041]
df.drop(index=to_drop, inplace=True)

# confirm
df.shape
# Out:
# (5115, 6)

# %% [markdown]
# ### Scrape extra pages
#
# [[go back to the top](#Data-Cleaning)]
#
# - I noticed some poems that were incomplete, so I'll rescrape post-first pages and add those on.

# %%
temp_rescrape = scan_poem_scraper('https://www.poetryfoundation.org/poetrymagazine/browse?volume=88&issue=5&page=10',
                  input_poet=df.loc[824, 'poet'], input_title='Tailfever was a bawdreur good')
temp_rescrape_lines = [temp_rescrape['title']]
temp_rescrape_lines.extend(temp_rescrape['poem_lines'])

# %%
temp_rescrape2 = scan_poem_scraper('https://www.poetryfoundation.org/poetrymagazine/browse?volume=88&issue=5&page=11',
                  input_poet=df.loc[824, 'poet'], input_title='They caught each other by the body')
temp_rescrape_lines2 = [temp_rescrape2['title']]
temp_rescrape_lines2.extend(temp_rescrape2['poem_lines'])

# %%
temp_lines = df.loc[824, 'poem_lines'].copy()
temp_lines.extend(temp_rescrape_lines)
temp_lines.extend(temp_rescrape_lines2)
temp_string = '\n'.join(temp_lines)

# %%
df.loc[824, 'poem_lines'] = temp_lines
df.loc[824, 'poem_string'] = temp_string

# %%
temp_rescrape = scan_poem_scraper('https://www.poetryfoundation.org/poetrymagazine/browse?volume=55&issue=5&page=4',
                  input_poet='Gertrude Stein', input_title='Before')
temp_rescrape_lines = [temp_rescrape['title']]
temp_rescrape_lines.extend(temp_rescrape['poem_lines'])

# %%
temp_lines = df.loc[2316, 'poem_lines'].copy()
temp_lines.extend(temp_rescrape_lines[:-1])
temp_string = '\n'.join(temp_lines)

# %%
df.loc[2316, 'poem_lines'] = temp_lines
df.loc[2316, 'poem_string'] = temp_string

# %% [markdown]
# ### Add titles
#
# [[go back to the top](#Data-Cleaning)]
#
# - Some titles are mysteriously difficult to scrape, so I'll impute those here.

# %%
df.loc[1167, 'title'] = "Lady’s Boogie"
df.loc[1168, 'title'] = 'Flatted Fifths'

# %%
df.loc[3416, 'title'] = 'Christmas Eve'
df.loc[3417, 'title'] = 'The Obvious Tradition'
df.loc[3568, 'title'] = 'Deerfield:1703'
df.loc[3569, 'title'] = 'Slave Sale: New Orleans'
df.loc[3702, 'title'] = 'Song: to Celia [Come, my Celia, let us prove]'
df.loc[3703, 'title'] = 'Song: to Celia [“Drink to me only with thine eyes”]'
df.loc[3704, 'title'] = '“Though I am young, and cannot tell”'
df.loc[3705, 'title'] = 'Ode to Himself [“Come leave the loathéd stage”]'
df.loc[3900, 'title'] = 'Delia 36: But love whilst that thou mayst be loved again'
df.loc[3901, 'title'] = 'Delia 2: Go wailing verse, the infants of my love'
df.loc[3903, 'title'] = 'Delia 53: Unhappy pen and ill accepted papers'

# %%
df.loc[3904, 'title'] = 'Delia 47: Read in my face a volume of despairs'
df.loc[3905, 'title'] = 'Delia 1: Unto the boundless Ocean of thy beauty'
df.loc[3906, 'title'] = "Delia 6: Fair is my love, and cruel as she's fair"
df.loc[3907, 'title'] = 'Delia 46: Let others sing of knights and paladins'
df.loc[3908, 'title'] = 'Delia 37: When men shall find thy flower, thy glory pass'
df.loc[3909, 'title'] = 'Delia 45: Care-charmer Sleep, son of the sable Night'
df.loc[3917, 'title'] = 'Astrophil and Stella 3: Let dainty wits cry on the sisters nine'
df.loc[3918, 'title'] = 'Astrophil and Stella 41: Having this day my horse, my hand, my lance '
df.loc[3919, 'title'] = 'Astrophil and Stella 63: O Grammar rules, O now your virtues show'
df.loc[3920, 'title'] = 'Astrophil and Stella 64: No more, my dear, no more these counsels try'
df.loc[3921, 'title'] = 'Astrophil and Stella 52: A strife is grown between Virtue and Love'
df.loc[3922, 'title'] = 'Astrophil and Stella 21: Your words my friend (right healthful caustics) blame'
df.loc[3923, 'title'] = 'Astrophil and Stella 15: You that do search for every purling spring'
df.loc[3924, 'title'] = 'Astrophil and Stella 72: Desire, though thou my old companion art'
df.loc[3925, 'title'] = 'Astrophil and Stella 90: Stella, think not that I by verse seek fame'
df.loc[3926, 'title'] = 'Astrophil and Stella 92: Be your words made, good sir, of Indian ware'
df.loc[3927, 'title'] = 'Astrophil and Stella 49: I on my horse, and Love on me, doth try '
df.loc[3928, 'title'] = 'Astrophil and Stella 47: What, have I thus betrayed my liberty?'
df.loc[3929, 'title'] = 'Astrophil and Stella 107: Stella, since thou so right a princess art'
df.loc[3930, 'title'] = 'Astrophil and Stella 20: Fly, fly, my friends, I have my death wound, fly'
df.loc[3931, 'title'] = 'Astrophil and Stella 23: The curious wits, seeing dull pensiveness'
df.loc[3932, 'title'] = 'Astrophil and Stella 25: The wisest scholar of the wight most wise'
df.loc[3933, 'title'] = 'Astrophil and Stella 48: Soul’s joy, bend not those morning stars from me'
df.loc[3934, 'title'] = 'Astrophil and Stella 71: Who will in fairest book of nature know'

# %%
df.loc[3935, 'title'] = 'Astrophil and Stella 84: Highway, since you my chief Parnassus be'
df.loc[3936, 'title'] = "Astrophil and Stella 31: With how sad steps, O Moon, thou climb'st the skies"
df.loc[3937, 'title'] = 'Astrophil and Stella 33: I might!—unhappy word—O me, I might'
df.loc[3938, 'title'] = 'Astrophil and Stella 1: Loving in truth, and fain in verse my love to show'
df.loc[3939, 'title'] = "Astrophil and Stella 7: When Nature made her chief work, Stella's eyes"
df.loc[3940, 'title'] = 'Astrophil and Stella 14: Alas, have I not pain enough, my friend'
df.loc[3941, 'title'] = 'Song from Arcadia: “My True Love Hath My Heart”'
df.loc[3942, 'title'] = 'Astrophil and Stella 39: Come Sleep! O Sleep, the certain knot of peace'
df.loc[3997, 'title'] = 'Book 1, Epigram 39: Ad librum suum.'
df.loc[3998, 'title'] = 'Book 1, Epigram 5: Ad lectorem de subjecto operis sui.'
df.loc[3999, 'title'] = 'Book 7, Epigram 9: De senectute & iuuentute.'
df.loc[4000, 'title'] = 'Book 2, Epigram 4: Ad Henricum Wottonum.'
df.loc[4001, 'title'] = 'Book 5, Epigram 20: In Misum & Mopsam.'
df.loc[4002, 'title'] = 'Book 1, Epigram 34: Ad. Thomam Freake armig. de veris adventu.'
df.loc[4009, 'title'] = 'Book 6, Epigram 17: In Sextum.'
df.loc[4010, 'title'] = 'Book 2, Epigram 21: In Momum.'
df.loc[4011, 'title'] = 'Book 6, Epigram 7: In prophanationem nominis Dei.'
df.loc[4012, 'title'] = 'Book 7, Epigram 36: De puero balbutiente.'
df.loc[4013, 'title'] = 'Book 7, Epigram 47: De Hominis Ortu & Sepultura.'
df.loc[4014, 'title'] = 'Book 2, Epigram 40: De libro suo.'
df.loc[4015, 'title'] = 'Book 6, Epigram 14: De Piscatione.'
df.loc[4042, 'title'] = 'Song: “Come away, come away, death”'
df.loc[4043, 'title'] = 'Song: “Where the bee sucks, there suck I”'

# %%
df.loc[4044, 'title'] = 'Song: “When daisies pied and violets blue”'
df.loc[4045, 'title'] = 'Song: “Sigh no more, ladies, sigh no more”'
df.loc[4046, 'title'] = 'Song: “Orpheus with his lute made trees”'
df.loc[4047, 'title'] = 'Song: “Fear no more the heat o’ the sun”'
df.loc[4048, 'title'] = 'Sonnet 135: Whoever hath her wish, thou hast thy Will'
df.loc[4049, 'title'] = 'Song: “O Mistress mine where are you roaming?”'
df.loc[4050, 'title'] = 'Song: “Who is Silvia? what is she”'
df.loc[4051, 'title'] = 'Song: “When that I was and a little tiny boy (With hey, ho, the wind and the rain)”'
df.loc[4052, 'title'] = "Song: “Hark, hark! the lark at heaven's gate sings”"
df.loc[4113, 'title'] = 'Speech: “O Romeo, Romeo, wherefore art thou Romeo?”'
df.loc[4114, 'title'] = 'Speech: “Is this a dagger which I see before me”'
df.loc[4115, 'title'] = 'Speech: “No matter where; of comfort no man speak”'
df.loc[4116, 'title'] = 'Speech: “To be, or not to be, that is the question”'
df.loc[4117, 'title'] = 'Speech: “This day is called the feast of Crispian”'
df.loc[4118, 'title'] = 'Speech: “Friends, Romans, countrymen, lend me your ears”'
df.loc[4119, 'title'] = 'Speech: “Once more unto the breach, dear friends, once more”'
df.loc[4120, 'title'] = 'Speech: “Tomorrow, and tomorrow, and tomorrow”'
df.loc[4121, 'title'] = 'Speech: “The raven himself is hoarse”'
df.loc[4122, 'title'] = 'Song: “Take, oh take those lips away”'
df.loc[4123, 'title'] = 'Speech: “Time hath, my lord, a wallet at his back”'
df.loc[4124, 'title'] = 'Song: “It was a lover and his lass”'
df.loc[4125, 'title'] = "Speech: All the world's a stage."
df.loc[4126, 'title'] = 'Song: Blow blow though winter wind'

# %%
df.loc[4139, 'title'] = "Sonnet 92: Behold that tree, in Autumn’s dim decay"
df.loc[4140, 'title'] = 'Sonnet 91: On the fleet streams, the Sun, that late arose'

# %% [markdown]
# #### Miscellaneous (remove extra scrape)

# %%
df.loc[1931, 'poem_lines'] = df.loc[1931, 'poem_lines'][:4]

# %% [markdown]
# ## Check for NaN values
#
# [[go back to the top](#Data-Cleaning)]
#
# - Check for NaN values.
# - Impute, rescrape, or drop as necessary.

# %%
df.isna().sum()
# Out:
# poet           0
# poem_url       0
# title          9
# poem_lines     0
# poem_string    8
# genre          0
# dtype: int64

# %%
df[df.title.isna()]
# Out:
#                                           poet  \
# 114                             Allen Ginsberg
# 264                               Amiri Baraka
# 306                           Gwendolyn Brooks
# 1045                         Walter de La Mare
# 2186                         Edgar Lee Masters
# 3874  Mary Sidney Herbert Countess of Pembroke
# 3985                         Sir Walter Ralegh
# 4216                                John Keats
# 4766                Elizabeth Barrett Browning
#
#                                                                                                                poem_url  \
# 114                                          https://www.poetryfoundation.org/poems/50123/new-stanzas-for-amazing-grace
# 264                                                        https://www.poetryfoundation.org/poems/52777/an-agony-as-now
# 306                                                     https://www.poetryfoundation.org/poems/58377/riot-56d23cb395a01
# 1045                                                          https://www.poetryfoundation.org/poems/48215/gloria-mundi
# 2186                                                      https://www.poetryfoundation.org/poems/56348/archibald-higbie
# 3874                                                       https://www.poetryfoundation.org/poems/55249/o-56d2369e67a1d
# 3985                                                 https://www.poetryfoundation.org/poems/57130/on-the-cards-and-dice
# 4216                         https://www.poetryfoundation.org/poems/44468/bright-star-would-i-were-stedfast-as-thou-art
# 4766  https://www.poetryfoundation.org/poems/43733/sonnets-from-the-portuguese-1-i-thought-once-how-theocritus-had-sung
#
#      title  \
# 114    NaN
# 264    NaN
# 306    NaN
# 1045   NaN
# 2186   NaN
# 3874   NaN
# 3985   NaN
# 4216   NaN
# 4766   NaN
#
#                                                                                                                                                  poem_lines  \
# 114   [I dreamed I dwelled in a homeless place, Where I was lost alone, Folk looked right through me into space, And passed with eyes of stone, O homele...
# 264   [I am inside someone, who hates me. I look, out from his eyes. Smell, what fouled tunes come in, to his breath. Love his, wretched women., Slits i...
# 306   [A Poem in Three Parts,               , John Cabot, out of Wilma, once a Wycliffe, , Because the “Negroes” were coming down the street. , Because ...
# 1045  [Upon a bank, easeless with knobs of gold,, Beneath a canopy of noonday smoke,, I saw a measureless Beast, morose and bold,, With eyes like one fr...
# 2186  [I loathed you, Spoon River. I tried to rise above you,, I was ashamed of you. I despised you, As the place of my nativity., And there in Rome, am...
# 3874  [Oh, what a lantern, what a lamp of light, Is thy pure word to me, To clear my paths and guide my goings right!, I swore and swear again,, I of th...
# 3985  [Before the sixth day of the next new year,, Strange wonders in this kingdom shall appear:, Four kings shall be assembled in this isle,, Where the...
# 4216  [Bright star, would I were stedfast as thou art—, Not in lone splendour hung aloft the night, And watching, with eternal lids apart,, Like nature'...
# 4766  [I thought once how Theocritus had sung, Of the sweet years, the dear and wished for years,, Who each one in a gracious hand appears, To bear a gi...
#
#                                                                                                                                                 poem_string  \
# 114   I dreamed I dwelled in a homeless place\nWhere I was lost alone\nFolk looked right through me into space\nAnd passed with eyes of stone\nO homeles...
# 264   I am inside someone\nwho hates me. I look\nout from his eyes. Smell\nwhat fouled tunes come in\nto his breath. Love his\nwretched women.\nSlits in...
# 306   A Poem in Three Parts\n              \nJohn Cabot, out of Wilma, once a Wycliffe, \nBecause the “Negroes” were coming down the street. \nBecause t...
# 1045  Upon a bank, easeless with knobs of gold,\nBeneath a canopy of noonday smoke,\nI saw a measureless Beast, morose and bold,\nWith eyes like one fro...
# 2186  I loathed you, Spoon River. I tried to rise above you,\nI was ashamed of you. I despised you\nAs the place of my nativity.\nAnd there in Rome, amo...
# 3874  Oh, what a lantern, what a lamp of light\nIs thy pure word to me\nTo clear my paths and guide my goings right!\nI swore and swear again,\nI of the...
# 3985  Before the sixth day of the next new year,\nStrange wonders in this kingdom shall appear:\nFour kings shall be assembled in this isle,\nWhere they...
# 4216  Bright star, would I were stedfast as thou art—\nNot in lone splendour hung aloft the night\nAnd watching, with eternal lids apart,\nLike nature's...
# 4766  I thought once how Theocritus had sung\nOf the sweet years, the dear and wished for years,\nWho each one in a gracious hand appears\nTo bear a gif...
#
#                     genre
# 114                  beat
# 264   black_arts_movement
# 306   black_arts_movement
# 1045             georgian
# 2186               modern
# 3874          renaissance
# 3985          renaissance
# 4216             romantic
# 4766            victorian

# %% [markdown]
# - Impute titles.

# %%
df.loc[114, 'title'] = 'New Stanzas for Amazing Grace'
df.loc[264, 'title'] = 'An Agony. As Now.'
df.loc[306, 'title'] = 'RIOT'
df.loc[1045, 'title'] = 'Gloria Mundi'
df.loc[2186, 'title'] = 'Archibald Higbie'
df.loc[3874, 'title'] = 'O'
df.loc[3985, 'title'] = 'On the Cards and Dice'
df.loc[4216, 'title'] = '“Bright star, would I were stedfast as thou art”'
df.loc[4766, 'title'] = 'Sonnets from the Portuguese 1: I thought once how Theocritus had sung'

# %%
df[df.poem_string.isna()]
# Out:
#                        poet  \
# 239         Michael McClure
# 2339  Guillaume Apollinaire
# 2526         Malcolm Cowley
# 2886        Stephen Spender
# 3007   William Butler Yeats
# 3143           Frank O'Hara
# 3386           Anne Waldman
# 3516              Tom Clark
#
#                                                                                              poem_url  \
# 239                https://www.poetryfoundation.org/poetrymagazine/poems/26838/2-for-theodore-roethke
# 2339  https://www.poetryfoundation.org/poetrymagazine/poems/25655/toward-the-south-tr-by-harry-duncan
# 2526              https://www.poetryfoundation.org/poetrymagazine/poems/30954/a-countryside-1918-1968
# 2886             https://www.poetryfoundation.org/poetrymagazine/poems/22310/poem-after-the-wrestling
# 3007                 https://www.poetryfoundation.org/poetrymagazine/poems/20737/a-full-moon-in-march
# 3143            https://www.poetryfoundation.org/poetrymagazine/poems/31123/places-for-oscar-salvador
# 3386                  https://www.poetryfoundation.org/poetrymagazine/poems/56845/history-will-decide
# 3516                                https://www.poetryfoundation.org/poetrymagazine/poems/30773/fig-1
#
#                                     title poem_lines poem_string  \
# 239                2 For Theodore Roethke         []         NaN
# 2339  Toward The South Tr By Harry Duncan         []         NaN
# 2526              A Countryside 1918 1968         []         NaN
# 2886             Poem After The Wrestling         []         NaN
# 3007                 A Full Moon In March         []         NaN
# 3143            Places For Oscar Salvador         []         NaN
# 3386                  History Will Decide         []         NaN
# 3516                                Fig 1         []         NaN
#
#                                genre
# 239                             beat
# 2339                          modern
# 2526                          modern
# 2886                          modern
# 3007                          modern
# 3143                 new_york_school
# 3386  new_york_school_2nd_generation
# 3516  new_york_school_2nd_generation

# %% [markdown]
# - Some of these poems have already been rescraped, so I can drop those below.
# - The rest I will re-scrape.

# %%
# drop already re-scraped poems
to_drop = [239, 2339, 2526, 3007, 3143]
df.drop(index=to_drop, inplace=True)

# confirm
df.shape
# Out:
# (5110, 6)

# %% [markdown]
# #### Rescrapes

# %%
actual_url = 'https://www.poetryfoundation.org/poetrymagazine/browse?volume=54&issue=1&page=17'
url = df.loc[2886, 'poem_url']
rescrape = scan_poem_scraper(actual_url, input_poet=df.loc[2886, 'poet'], input_title='Poem')
rescrape['poem_url'] = url
rescrape['genre'] = df.loc[2886, 'genre']
df.loc[2886, 'poem_lines'] = rescrape['poem_lines']
df.loc[2886, 'poem_string'] = rescrape['poem_string']

# %%
df.loc[3386, 'poem_lines']
# Out:
# ['After the wrestling, when our mouths',
#  'Had kissed to heal their wounds,',
#  'And both sides victory gained, then peace was signed',
#  'And on my burning body you drew',
#  'With grateful hands the shining folds',
#  'Of a cloth stretching from head to heel,',
#  'Invisible lineaments I wear,',
#  'Pressing my face against my arm',
#  'To touch and smell your body there.']

# %%
rescrape = rescraper(df.loc[3386, 'poem_url'], 'justify')
df.loc[3386, 'poem_lines'] = rescrape[0]
df.loc[3386, 'poem_string'] = rescrape[1]

# %%
# rescrape (NOTE: only grabs first page)
url = df.loc[3516, 'poem_url']
rescrape = scan_poem_scraper(url, input_poet=df.loc[3516, 'poet'], input_title='FIG. 1: Weakly cuddling the telephone as a last')
rescrape['poem_url'] = url
rescrape['genre'] = df.loc[3516, 'genre']

# %%
# scrape second page
temp_rescrape = scan_poem_scraper('https://www.poetryfoundation.org/poetrymagazine/browse?volume=111&issue=3&page=6',
                  input_poet='Tom Clark', input_title='POETRY')
temp_rescrape_lines = temp_rescrape['poem_lines']

# %%
# combine pages
rescrape['poem_lines'].extend(temp_rescrape_lines)
rescrape['poem_string'] = '\n'.join(rescrape['poem_lines'])
df.loc[3516, 'poem_lines'] = rescrape['poem_lines']
df.loc[3516, 'poem_string'] = rescrape['poem_string']

# %% [markdown]
# - Re-check for NaN values.

# %%
df.isna().sum()
# Out:
# poet           0
# poem_url       0
# title          0
# poem_lines     0
# poem_string    0
# genre          0
# dtype: int64

# %% [markdown]
# - Re-sort and reset indicies.

# %%
# sort dataframe
df.sort_values(by=['genre', 'poet', 'title'], inplace=True)

# reset indices
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# #### 💾 Save a copy

# %%
df.to_csv('data/poems_df_cleaner.csv')

# %% [markdown]
# ## Check for other bad scrapes
#
# [[go back to the top](#Data-Cleaning)]
#
# - I'll look for any poems that seem suspiciusly short.
# - Impute, rescrape, or drop as necessary.

# %%
# length of poem string
df['temp_len'] = df.poem_string.apply(lambda x: len(x))

# take a look at the numbers
df.temp_len.describe()
# Out:
# count     5110.000000
# mean      1487.130920
# std       2715.646359
# min          1.000000
# 25%        475.000000
# 50%        715.000000
# 75%       1405.500000
# max      53241.000000
# Name: temp_len, dtype: float64

# %%
# if string fewer than 10 characters
df[df.temp_len <= 10]
# Out:
#                          poet  \
# 1072             Wilfred Owen
# 1473  William Carlos Williams
# 2731              Paul Valéry
# 2844          Stephen Spender
# 3308             Alice Notley
# 3347             Aram Saroyan
# 3544  Gaius Valerius Catullus
# 4474            A. E. Housman
# 4876          Katharine Tynan
#
#                                                                                                              poem_url  \
# 1072                                                        https://www.poetryfoundation.org/poems/57369/the-send-off
# 1473                                            https://www.poetryfoundation.org/poetrymagazine/poems/28309/3-stances
# 2731  https://www.poetryfoundation.org/poetrymagazine/poems/27998/to-the-plane-tree-tr-by-louise-bogan-and-may-sarton
# 2844                                       https://www.poetryfoundation.org/poetrymagazine/poems/29238/journal-leaves
# 3308                                                  https://www.poetryfoundation.org/poems/58243/gift-56d23c725d4d9
# 3347                                           https://www.poetryfoundation.org/poetrymagazine/poems/30722/cham-pagne
# 3544                  https://www.poetryfoundation.org/poetrymagazine/poems/31271/peliaco-quondam-with-celia-zukofsky
# 4474                     https://www.poetryfoundation.org/poems/58269/a-shropshire-lad-52-far-in-a-western-brookland-
# 4876                                              https://www.poetryfoundation.org/poems/57349/a-lament-56d23ac7ae84a
#
#                                                     title poem_lines  \
# 1072                                         The Send-Off        [ ]
# 1473                                            3 Stances        [I]
# 2731  To The Plane Tree Tr By Louise Bogan And May Sarton        [ ]
# 2844                                       Journal Leaves        [I]
# 3308                                                 Gift       [, ]
# 3347                                           Cham Pagne    [cham.]
# 3544                  Peliaco Quondam With Celia Zukofsky        [ ]
# 4474      A Shropshire Lad 52: Far in a western brookland        [ ]
# 4876                                             A Lament        [ ]
#
#      poem_string                           genre  temp_len
# 1072                                    georgian         1
# 1473           I                         imagist         1
# 2731                                      modern         1
# 2844           I                          modern         1
# 3308          \n  new_york_school_2nd_generation         1
# 3347       cham.  new_york_school_2nd_generation         5
# 3544                                 objectivist         1
# 4474                                   victorian         1
# 4876                                   victorian         1

# %%
# drop already re-scraped poems
to_drop = [1473, 2731, 3544]
df.drop(index=to_drop, inplace=True)

# confirm
df.shape
# Out:
# (5107, 7)

# %% [markdown]
# #### Rescrapes
#
# - Due to a mysterious length error, the list of lines have to be imputed as a string.

# %%
url = df.loc[1072, 'poem_url']
rescrape = rescraper(url, 'poempara')
df.loc[1072, 'poem_lines'] = str(rescrape[0])
df.loc[1072, 'poem_string'] = rescrape[1]

# %%
url = df.loc[4474, 'poem_url']
rescrape = rescraper(url, 'poempara')
df.loc[4474, 'poem_lines'] = str(rescrape[0])
df.loc[4474, 'poem_string'] = rescrape[1]

# %%
url = df.loc[4876, 'poem_url']
rescrape = rescraper(url, 'poempara')
df.loc[4876, 'poem_lines'] = str(rescrape[0])
df.loc[4876, 'poem_string'] = rescrape[1]

# %%
url = df.loc[2844, 'poem_url']
rescrape = scan_poem_scraper(url, 
                             input_poet='Stephen Spender',
                             first_pattern='.*((?:\r?\n.*)*)',
                             next_pattern='\n((?:\r?\n(?!CHARLES TOMLINSON).*)*)')
rescrape['poem_url'] = url
rescrape['genre'] = 'modern'

# %%
temp_rescrape = scan_poem_scraper('https://www.poetryfoundation.org/poetrymagazine/browse?volume=101&issue=1&page=169',
                  input_poet='Stephen Spender', input_title='Lothar lit a log fire in the yard', 
                                  first_pattern='.*((?:\r?\n.*)*)',
                             next_pattern='\n((?:\r?\n(?!CHARLES TOMLINSON).*)*)')
temp_rescrape_lines = [temp_rescrape['title']]
temp_rescrape_lines.extend(temp_rescrape['poem_lines'])

# %%
rescrape['poem_lines'].extend(temp_rescrape_lines)
rescrape['poem_string'] = '\n'.join(rescrape['poem_lines'])
df.loc[2844, 'poem_lines'] = str(rescrape['poem_lines'])
df.loc[2844, 'poem_string'] = rescrape['poem_string']

# %%
url = df.loc[3308, 'poem_url']
rescrape = rescraper(url, 'p_all')
df.loc[3308, 'poem_lines'] = str(rescrape[0])
df.loc[3308, 'poem_string'] = rescrape[1]

# %% [markdown]
# #### Re-check for bad scrapes
#
# - This time for anything less than 50 characters.

# %%
df['temp_len'] = df.poem_string.apply(lambda x: len(x))
df[df.temp_len <= 50]
# Out:
#                          poet  \
# 188           Kenneth Rexroth
# 571            Robert Creeley
# 996            Robert Nichols
# 1068             Wilfred Owen
# 1221         Melvin B. Tolson
# 1223         Melvin B. Tolson
# 1588  William Carlos Williams
# 2266          Ford Madox Ford
# 2285           Gertrude Stein
# 2308    Guillaume Apollinaire
# 2352              Ivor Gurney
# 3270             Kenneth Koch
# 3342             Anne Waldman
# 3347             Aram Saroyan
# 3351             Aram Saroyan
# 3356             Aram Saroyan
# 3357             Aram Saroyan
# 3358             Aram Saroyan
# 3359             Aram Saroyan
# 3361             Aram Saroyan
# 3363             Aram Saroyan
# 3364             Aram Saroyan
# 3594         Lorine Niedecker
# 3633           Louis Zukofsky
# 3639           Louis Zukofsky
# 3963           Thomas Campion
# 4132           Heinrich Heine
#
#                                                                                                              poem_url  \
# 188                                        https://www.poetryfoundation.org/poetrymagazine/poems/29229/air-and-angels
# 571                                                https://www.poetryfoundation.org/poems/54508/one-day-56d234ece07b2
# 996                                      https://www.poetryfoundation.org/poetrymagazine/poems/14477/modern-love-song
# 1068                                                   https://www.poetryfoundation.org/poems/57347/smile-smile-smile
# 1221                                                               https://www.poetryfoundation.org/poems/56036/delta
# 1223                                                                 https://www.poetryfoundation.org/poems/56037/eta
# 1588                                         https://www.poetryfoundation.org/poetrymagazine/poems/21822/weasel-snout
# 2266                                         https://www.poetryfoundation.org/poetrymagazine/poems/19554/buckshee-i-v
# 2285                                                      https://www.poetryfoundation.org/poems/51213/a-white-hunter
# 2308                  https://www.poetryfoundation.org/poetrymagazine/poems/25652/le-pont-mirabeau-tr-by-harry-duncan
# 2352                                            https://www.poetryfoundation.org/poems/57256/i-saw-england-july-night
# 3270                                    https://www.poetryfoundation.org/poetrymagazine/poems/33016/the-art-of-poetry
# 3342                                              https://www.poetryfoundation.org/poems/56750/to-the-censorious-ones
# 3347                                           https://www.poetryfoundation.org/poetrymagazine/poems/30722/cham-pagne
# 3351                                              https://www.poetryfoundation.org/poetrymagazine/poems/30720/i-crazy
# 3356                                             https://www.poetryfoundation.org/poetrymagazine/poems/57985/paradise
# 3357                               https://www.poetryfoundation.org/poetrymagazine/poems/30962/poem-night-night-night
# 3358                                             https://www.poetryfoundation.org/poetrymagazine/poems/30721/room-now
# 3359                                             https://www.poetryfoundation.org/poetrymagazine/poems/30725/seek-air
# 3361                                       https://www.poetryfoundation.org/poetrymagazine/poems/29724/talking-to-you
# 3363                                 https://www.poetryfoundation.org/poetrymagazine/poems/30723/jungle-56d21432117a5
# 3364                                             https://www.poetryfoundation.org/poetrymagazine/poems/30726/wind-oil
# 3594                                  https://www.poetryfoundation.org/poetrymagazine/poems/30139/march-56d213a2b802b
# 3633                            https://www.poetryfoundation.org/poetrymagazine/poems/31003/a-21-rudens-acts-i-and-ii
# 3639                           https://www.poetryfoundation.org/poetrymagazine/poems/28542/from-bottom-on-shakespeare
# 3963  https://www.poetryfoundation.org/poetrymagazine/poems/33656/epigrammatum-liber-secundus-tr-by-stephen-ratcliffe
# 4132        https://www.poetryfoundation.org/poetrymagazine/poems/25286/leaning-against-the-mast-tr-by-vernon-watkins
# 3363                                            j;u;n;g;l;e
# 3364                                          blows out sea
# 3594                  Bird feeder’s\nsnow-cap\nsliding\noff
# 3633                                            AUGUST 1968
# 3639         PART TWO—AN ALPHABET OF SUBJECTS\nTwo Excerpts
# 3963                                      \nTHOMAS CAMPION:
# 4132                                       two translations
#
#                                genre  temp_len
# 188                             beat        22
# 571                   black_mountain        45
# 996                         georgian        12
# 1068                        georgian        48
# 1221              harlem_renaissance        26
# 1223              harlem_renaissance        39
# 1588                         imagist        38
# 2266                          modern        27
# 2285                          modern        31
# 2308                          modern        41
# 2352                          modern        37
# 3270                 new_york_school        14
# 3342  new_york_school_2nd_generation        41
# 3347  new_york_school_2nd_generation         5
# 3351  new_york_school_2nd_generation        41
# 3356  new_york_school_2nd_generation        50
# 3357  new_york_school_2nd_generation        11
# 3358  new_york_school_2nd_generation        32
# 3359  new_york_school_2nd_generation        40
# 3361  new_york_school_2nd_generation        20
# 3363  new_york_school_2nd_generation        11
# 3364  new_york_school_2nd_generation        13
# 3594                     objectivist        34
# 3633                     objectivist        11
# 3639                     objectivist        45
# 3963                     renaissance        17
# 4132                        romantic        16

# %%
# drop already re-scraped poems and un-scrapables
to_drop = [996, 1068, 2308, 2352, 3361, 3633, 3639, 3963, 4132]
df.drop(index=to_drop, inplace=True)

# confirm
df.shape
# Out:
# (5098, 7)

# %% [markdown]
# #### Rescrapes

# %%
url = df.loc[188, 'poem_url']
rescrape = scan_poem_scraper(url, 
                             input_poet='Kenneth Rexroth',
                             first_pattern='.*((?:\r?\n.*)*)',
                             next_pattern='\n((?:\r?\n(?!MURIEL RUKEYSER).*)*)')
rescrape['poem_url'] = url
rescrape['genre'] = 'beat'

# %%
temp_rescrape = scan_poem_scraper('https://www.poetryfoundation.org/poetrymagazine/browse?volume=101&issue=1&page=147',
                  input_poet='Kenneth Rexroth', input_title='An Easy Song', 
                                  first_pattern='.*((?:\r?\n.*)*)',
                             next_pattern='\n((?:\r?\n(?!MURIEL RUKEYSER).*)*)')
temp_rescrape_lines = [temp_rescrape['title']]
temp_rescrape_lines.extend(temp_rescrape['poem_lines'])

# %%
temp_rescrape2 = scan_poem_scraper('https://www.poetryfoundation.org/poetrymagazine/browse?volume=101&issue=1&page=148',
                  input_poet='Kenneth Rexroth', input_title='Coming', 
                                  first_pattern='.*((?:\r?\n.*)*)',
                             next_pattern='\n((?:\r?\n(?!MURIEL RUKEYSER).*)*)')
temp_rescrape_lines2 = [temp_rescrape2['title']]
temp_rescrape_lines2.extend(temp_rescrape2['poem_lines'])

# %%
rescrape['poem_lines'].extend(temp_rescrape_lines)
rescrape['poem_lines'].extend(temp_rescrape_lines2)
rescrape['poem_string'] = '\n'.join(rescrape['poem_lines'])
df.loc[188, 'poem_lines'] = str(rescrape['poem_lines'])
df.loc[188, 'poem_string'] = rescrape['poem_string']

# %%
url = df.loc[1221, 'poem_url']
rescrape = rescraper(url, 'p_all')
df.loc[1221, 'poem_lines'] = str(rescrape[0])
df.loc[1221, 'poem_string'] = rescrape[1]

# %%
url = df.loc[1223, 'poem_url']
rescrape = rescraper(url, 'p_all')
df.loc[1223, 'poem_lines'] = str(rescrape[0])
df.loc[1223, 'poem_string'] = rescrape[1]

# %%
temp_rescrape = scan_poem_scraper('https://www.poetryfoundation.org/poetrymagazine/browse?volume=51&issue=1&page=20',
                  input_poet=df.loc[1588, 'poet'], input_title='to daintiness')
temp_rescrape_lines = [temp_rescrape['title']]
temp_rescrape_lines.extend(temp_rescrape['poem_lines'])

# %%
df.loc[1588, 'poem_lines'].extend(temp_rescrape_lines[:-1])
df.loc[1588, 'poem_string'] = '\n'.join(df.loc[1588, 'poem_lines'])

# %%
url = df.loc[2266, 'poem_url']
rescrape = scan_poem_scraper(url, input_poet=df.loc[2266, 'poet'], input_title='Buckshee')
rescrape['poem_url'] = url
rescrape['genre'] = df.loc[2266, 'genre']

# %%
df.loc[2266, 'poem_lines'] = str(rescrape['poem_lines'])
df.loc[2266, 'poem_string'] = rescrape['poem_string']

# %%
url = df.loc[3270, 'poem_url']
rescrape = scan_poem_scraper(url, input_poet=df.loc[3270, 'poet'], input_title='The Art of')
rescrape['poem_url'] = url
rescrape['genre'] = df.loc[3270, 'genre']

# %%
temp_rescrape = scan_poem_scraper('https://www.poetryfoundation.org/poetrymagazine/browse?volume=125&issue=4&page=10',
                  input_poet=df.loc[3270, 'poet'], input_title='(More about this a little later) 6) Is it in my own')
temp_rescrape_lines = [temp_rescrape['title']]
temp_rescrape_lines.extend(temp_rescrape['poem_lines'])

# %%
temp_rescrape2 = scan_poem_scraper('https://www.poetryfoundation.org/poetrymagazine/browse?volume=125&issue=4&page=11',
                  input_poet=df.loc[3270, 'poet'], input_title='Indeed. For the original "inspration" is not there. Some')
temp_rescrape_lines2 = [temp_rescrape2['title']]
temp_rescrape_lines2.extend(temp_rescrape2['poem_lines'])

# %%
temp_rescrape3 = scan_poem_scraper('https://www.poetryfoundation.org/poetrymagazine/browse?volume=125&issue=4&page=19',
                  input_poet=df.loc[3270, 'poet'], input_title='Total absorption in poetry is one of the finest things in')
temp_rescrape_lines3 = [temp_rescrape3['title']]
temp_rescrape_lines3.extend(temp_rescrape3['poem_lines'])

# %%
temp_rescrape4 = scan_poem_scraper('https://www.poetryfoundation.org/poetrymagazine/browse?volume=125&issue=4&page=20',
                  input_poet=df.loc[3270, 'poet'], 
                  input_title='Natural part of writing. Your poetry, if possible')
temp_rescrape_lines4 = [temp_rescrape4['title']]
temp_rescrape_lines4.extend(temp_rescrape4['poem_lines'])

# %%
temp_rescrape5 = scan_poem_scraper('https://www.poetryfoundation.org/poetrymagazine/browse?volume=125&issue=4&page=21',
                  input_poet=df.loc[3270, 'poet'], 
                  input_title='Or "almost" being friends with someone, or hanging')
temp_rescrape_lines5 = [temp_rescrape5['title']]
temp_rescrape_lines5.extend(temp_rescrape5['poem_lines'])

# %%
rescrape['poem_lines'].extend(temp_rescrape_lines)
rescrape['poem_lines'].extend(temp_rescrape_lines2)
rescrape['poem_lines'].extend(temp_rescrape_lines3)
rescrape['poem_lines'].extend(temp_rescrape_lines4)
rescrape['poem_lines'].extend(temp_rescrape_lines5)

# %%
df.loc[3270, 'poem_lines'] = str(rescrape['poem_lines'])
df.loc[3270, 'poem_string'] = '\n'.join(rescrape['poem_lines'])

# %%
url = df.loc[3342, 'poem_url']
rescrape = rescraper(url, 'center')
df.loc[3342, 'poem_lines'] = str(rescrape[0])
df.loc[3342, 'poem_string'] = rescrape[1]

# %%
df.loc[3347, 'poem_lines'] = str(df.loc[3351, 'poem_lines'][-2:])
df.loc[3347, 'poem_string'] = 'pagne\nchamp'

# %%
df.loc[3351, 'poem_lines'] = ['I crazy.']
df.loc[3351, 'poem_string'] = 'I crazy.'

# %%
df.loc[3357, 'title'] = 'Untitled'
df.loc[3357, 'poem_lines'] = ['night night night night night night night night night night night night night night night']
df.loc[3357, 'poem_string'] = 'night night night night night night night night night night night night night night night'

# %%
df.loc[3358, 'poem_lines'] = str(['room now', 'door Humphrey', 'Bogart'])
df.loc[3358, 'poem_string'] = 'room now\ndoor Humphrey\nBogart'

# %%
df.loc[3359, 'poem_lines'] = str(df.loc[3359, 'poem_lines'][:2])
df.loc[3359, 'poem_string'] = 'tragedy\nbodies'

# %% [markdown]
# #### Re-check for bad scrapes
#
# - This time for anything less than 100 characters.

# %%
df['temp_len'] = df.poem_string.apply(lambda x: len(x))
df[df.temp_len <= 100].tail(50)
# Out:
#                          poet  \
# 1624        Charles Bernstein
# 1682           Michael Palmer
# 1683           Michael Palmer
# 1685           Michael Palmer
# 1687           Michael Palmer
# 1695           Michael Palmer
# 1703           Rae Armantrout
# 1798              A. M. Klein
# 1808              A. M. Klein
# 1838         Alfred Kreymborg
# 1940            Carl Sandburg
# 2106           E. E. Cummings
# 2132           E. E. Cummings
# 2157           E. E. Cummings
# 2259      Ernest M. Hemingway
# 2285           Gertrude Stein
# 3430  new_york_school_2nd_generation        98
# 3568                     objectivist       100
# 3594                     objectivist        34
# 3595                     objectivist        69
# 3599                     objectivist        79
# 3601                     objectivist        73
# 3608                     objectivist        90
# 3620                     objectivist        76
# 3623                     objectivist        85
# 3628                     objectivist        82
# 3671                     renaissance        85
# 3679                     renaissance        91
# 3757                     renaissance        77
# 3835                     renaissance        85
# 3841                     renaissance        70
# 3960                     renaissance        70
# 4311                        romantic        98
# 4639                       victorian        92

# %%
url = df.loc[1682, 'poem_url']
rescrape = rescraper(url, 'p_all')
df.loc[1682, 'poem_lines'] = str(rescrape[0])
df.loc[1682, 'poem_string'] = rescrape[1]

# %%
url = df.loc[1683, 'poem_url']
rescrape = rescraper(url, 'p_all')
df.loc[1683, 'poem_lines'] = str(rescrape[0])
df.loc[1683, 'poem_string'] = rescrape[1]

# %%
url = df.loc[1685, 'poem_url']
rescrape = rescraper(url, 'p_all')
df.loc[1685, 'poem_lines'] = str(rescrape[0])
df.loc[1685, 'poem_string'] = rescrape[1]

# %%
url = df.loc[1687, 'poem_url']
rescrape = rescraper(url, 'p_all')
df.loc[1687, 'poem_lines'] = str(rescrape[0])
df.loc[1687, 'poem_string'] = rescrape[1]

# %%
url = df.loc[1695, 'poem_url']
rescrape = rescraper(url, 'p_all')
# grab first line
rescrape2 = [rescraper(url, 'PoemView')[0][0]]
# add other lines
rescrape2.extend(rescrape[0])
temp_string = '\n'.join(rescrape2)
df.loc[1695, 'poem_lines'] = str(rescrape2)
df.loc[1695, 'poem_string'] = temp_string

# %%
url = df.loc[1940, 'poem_url']
rescrape = scan_poem_scraper(url, input_poet=df.loc[1940, 'poet'], input_title='Joy: Let a joy keep you')
rescrape['poem_url'] = url
rescrape['genre'] = df.loc[1940, 'genre']
df.loc[1940, 'poem_lines'] = str(rescrape['poem_lines'])
df.loc[1940, 'poem_string'] = rescrape['poem_string']

# %%
url = df.loc[2106, 'poem_url']
rescrape = scan_poem_scraper(url, 
                             input_poet=df.loc[2106, 'poet'],
                             first_pattern='.*((?:\r?\n.*)*)',
                             next_pattern='\n((?:\r?\n(?!POETRY).*)*)')
rescrape['poem_url'] = url
rescrape['genre'] = df.loc[2106, 'genre']
df.loc[2106, 'poem_lines'] = str(rescrape['poem_lines'])
df.loc[2106, 'poem_string'] = rescrape['poem_string']

# %%
url = df.loc[2536, 'poem_url']
rescrape = scan_poem_scraper(url, 
                             input_poet=df.loc[2536, 'poet'],
                             first_pattern='.*((?:\r?\n.*)*)',
                             next_pattern='\n((?:\r?\n(?!THE HERO).*)*)')
rescrape['poem_url'] = url
rescrape['genre'] = df.loc[2536, 'genre']

# %%
temp_rescrape = scan_poem_scraper('https://www.poetryfoundation.org/poetrymagazine/browse?volume=40&issue=3&page=6',
                  input_poet=df.loc[2536, 'poet'],
                    input_title='says, "but the French do not think that all can have it', 
                    first_pattern='.*((?:\r?\n.*)*)',
                    next_pattern='\n((?:\r?\n(?!THE HERO).*)*)')
temp_rescrape_lines = [temp_rescrape['title']]
temp_rescrape_lines.extend(temp_rescrape['poem_lines'])

# %%
temp_rescrape2 = scan_poem_scraper('https://www.poetryfoundation.org/poetrymagazine/browse?volume=40&issue=3&page=8',
                  input_poet=df.loc[2536, 'poet'],
                  input_title='of the eye showing; or as sea-lions keep going round and', 
                  first_pattern='.*((?:\r?\n.*)*)',
                  next_pattern='\n((?:\r?\n(?!THE HERO).*)*)')
temp_rescrape_lines2 = [temp_rescrape2['title']]
temp_rescrape_lines2.extend(temp_rescrape2['poem_lines'])

# %%
rescrape['poem_lines'].extend(temp_rescrape_lines)
rescrape['poem_lines'].extend(temp_rescrape_lines2)
rescrape['poem_string'] = '\n'.join(rescrape['poem_lines'])
df.loc[2536, 'poem_lines'] = str(rescrape['poem_lines'])
df.loc[2536, 'poem_string'] = rescrape['poem_string']

# %%
url = df.loc[2586, 'poem_url']
rescrape = scan_poem_scraper(url, 
                             input_poet=df.loc[2586, 'poet'],
                             first_pattern='.*((?:\r?\n.*)*)',
                             next_pattern='\n((?:\r?\n(?!MUSICIAN).*)*)')
rescrape['poem_url'] = url
rescrape['genre'] = df.loc[2586, 'genre']
df.loc[2586, 'poem_lines'] = str(rescrape['poem_lines'])
df.loc[2586, 'poem_string'] = rescrape['poem_string']

# %%
df.loc[3343, 'poem_string'] = '\n'.join(df.loc[3343, 'poem_lines'][:2])
df.loc[3343, 'poem_lines'] = str(df.loc[3343, 'poem_lines'][:2])

df.loc[3346, 'poem_string'] = '\n'.join(df.loc[3346, 'poem_lines'][:2])
df.loc[3346, 'poem_lines'] = str(df.loc[3346, 'poem_lines'][:2])

df.loc[3360, 'poem_string'] = '\n'.join(df.loc[3360, 'poem_lines'][:2])
df.loc[3360, 'poem_lines'] = str(df.loc[3360, 'poem_lines'][:2])

# %%
url = df.loc[3568, 'poem_url']
rescrape = scan_poem_scraper(url, 
                             input_poet=df.loc[3568, 'poet'],
                             first_pattern='.*((?:\r?\n.*)*)',
                             next_pattern="\n((?:\r?\n(?!GIOVANNI'S RAPE OF THE SABINE).*)*)")
rescrape['poem_url'] = url
rescrape['genre'] = df.loc[3568, 'genre']

# %%
temp_rescrape = scan_poem_scraper('https://www.poetryfoundation.org/poetrymagazine/browse?volume=104&issue=2&page=16',
                  input_poet=df.loc[3568, 'poet'],
                    input_title='beach Curves to a bay. Here the dug-out is hauled', 
                    first_pattern=".*((?:\r?\n(?!Crying\.).*)*)",
                    next_pattern="\n((?:\r?\n(?!GIOVANNI'S RAPE OF THE SABINE).*)*)")
temp_rescrape_lines = [temp_rescrape['title']]
temp_rescrape_lines.extend(temp_rescrape['poem_lines'])
temp_rescrape_lines.extend(['Crying.'])

# %%
rescrape['poem_lines'].extend(temp_rescrape_lines)
rescrape['poem_string'] = '\n'.join(rescrape['poem_lines'])
df.loc[3568, 'poem_lines'] = str(rescrape['poem_lines'])
df.loc[3568, 'poem_string'] = rescrape['poem_string']

# %% [markdown]
# #### Re-check for bad scrapes
#
# - Again, I'll look at anything less than 100 characters.

# %%
df['temp_len'] = df.poem_string.apply(lambda x: len(x))
df[df.temp_len <= 100].head(50)
# Out:
#                          poet  \
# 179           Kenneth Patchen
# 249         Richard Brautigan
# 256         Richard Brautigan
# 543            Robert Creeley
# 560            Robert Creeley
# 571            Robert Creeley
# 604            Robert Creeley
# 1107             Claude McKay
# 1157          Langston Hughes
# 1158          Langston Hughes
# 1180          Langston Hughes
# 1201          Langston Hughes
# 1246               Amy Lowell
# 1262               Amy Lowell
# 1317               Amy Lowell
# 1345               Ezra Pound
# 1357               Ezra Pound
# 1398               Ezra Pound
# 1420                    H. D.
# 1484  William Carlos Williams
# 1516  William Carlos Williams
# 1520  William Carlos Williams
# 1544  William Carlos Williams
# 1570  William Carlos Williams
# 1583  William Carlos Williams
# 1624        Charles Bernstein
# 1703           Rae Armantrout
# 1798              A. M. Klein
# 1808              A. M. Klein
# 1838         Alfred Kreymborg
# 2132           E. E. Cummings
# 2157           E. E. Cummings
# 2259      Ernest M. Hemingway
# 2285           Gertrude Stein
# 2288           Gertrude Stein
# 3343             Aram Saroyan
# 3346             Aram Saroyan
# 3347             Aram Saroyan
# 3348             Aram Saroyan
# 3351             Aram Saroyan
# 3355             Aram Saroyan
# 3356             Aram Saroyan
# 3357             Aram Saroyan
# 2132  ly this\n(merely and whose\nnot\nnumerable leaves are\nfall\ni\nng)he\n* Copyright 1961 by E. E. Cummings.
# 2157               do\nyou(rouNd\ner\nthan roUnd ) float;\nwho\nlly &(rOunder than)\ngo\n:Idenly (Round\nest)\n?
# 2259                                                    The Lord is my shepherd, I shall not\nwant him for long.
# 2285                                                                             A white hunter is nearly crazy.
# 2288                                            The story of how she bowed to her brother.\nWho has whom as his.
# 3343                                                                                           of Irish\nsetters
# 3346                                                                                    injures 11;\ndriver held
# 3347                                                                                                pagne\nchamp
# 3348       Tell me anything\nI knew it\nWhat a coincidence\nit always is\nI recognized you\nthe minute I saw you
# 3351                                                                                                    I crazy.
# 3355              lose me\nor I them\ntoday I didn’t speak to anyone\nan occasional world, be-\ntween the words.
# 3356                                                       Look\nthe moon.\nNuts look like wood\nbut taste good.
# 3357                   night night night night night night night night night night night night night night night
# 3358                                                                             room now\ndoor Humphrey\nBogart
# 3359                                                                                             tragedy\nbodies
# 3360                                                                                                  every\nday
# 3363                                                                                                 j;u;n;g;l;e
# 3364                                                                                               blows out sea
# 3430   The pines are\nstately\nstill\nreflecting\nupon themselves\nwithout knowing it\nin eternity\nupside down.
# 3594                                                                       Bird feeder’s\nsnow-cap\nsliding\noff
#
#                                genre  temp_len
# 179                             beat        85
# 249                             beat        64
# 256                             beat        96
# 543                   black_mountain        92
# 560                   black_mountain        61
# 571                   black_mountain        45
# 604                   black_mountain        59
# 1107              harlem_renaissance        85
# 1157              harlem_renaissance        69
# 1158              harlem_renaissance        79
# 1180              harlem_renaissance        85
# 1201              harlem_renaissance        53
# 1246                         imagist        84
# 1262                         imagist        99
# 1317                         imagist        79
# 1345                         imagist        63
# 1357                         imagist        73
# 1398                         imagist        95
# 1420                         imagist        93
# 1484                         imagist        89
# 1516                         imagist        53
# 1520                         imagist        67
# 1544                         imagist        54
# 1570                         imagist        88
# 1583                         imagist        96
# 1624                 language_poetry        74
# 1703                 language_poetry        63
# 1798                          modern        90
# 1808                          modern        79
# 1838                          modern        99
# 2132                          modern        99
# 2157                          modern        84
# 2259                          modern        55
# 2285                          modern        31
# 2288                          modern        63
# 3343  new_york_school_2nd_generation        16
# 3346  new_york_school_2nd_generation        23
# 3347  new_york_school_2nd_generation        11
# 3348  new_york_school_2nd_generation        96
# 3351  new_york_school_2nd_generation         8
# 3355  new_york_school_2nd_generation        90
# 3356  new_york_school_2nd_generation        50
# 3357  new_york_school_2nd_generation        89
# 3358  new_york_school_2nd_generation        29
# 3359  new_york_school_2nd_generation        14
# 3360  new_york_school_2nd_generation         9
# 3363  new_york_school_2nd_generation        11
# 3364  new_york_school_2nd_generation        13
# 3430  new_york_school_2nd_generation        98
# 3594                     objectivist        34

# %% [markdown]
# - Looking perhaps as good as it's going to get!
# - One last check for duplicates.

# %%
df[df.duplicated(subset=['poem_string'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [poet, poem_url, title, poem_lines, poem_string, genre, temp_len]
# Index: []

# %% [markdown]
# ### Finishing touches
#
# [[go back to the top](#Data-Cleaning)]
#
# - Drop ```temp_len``` column.
# - Sort and reset indices.
# - Convert ```poem_lines``` back to lists from string.

# %%
# drop temp_len column
df.drop(columns='temp_len', inplace=True)

# confirm
df.shape
# Out:
# (5098, 6)

# %%
# sort dataframe
df.sort_values(by=['genre', 'poet', 'title'], inplace=True)

# reset indices
df.reset_index(drop=True, inplace=True)

# %%
# destringify
df['poem_lines'] = df['poem_lines'].apply(destringify)

# %% [markdown]
# ### 💾 Save DataFrame
#
# [[go back to the top](#Data-Cleaning)]

# %%
# # uncomment to save
# with gzip.open('data/poems_df_clean_all.pkl', 'wb') as goodbye:
#     pickle.dump(df, goodbye, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# # uncomment to save as csv
# df.to_csv('data/poems_df_cleaned_all.csv')

# %%
df.columns
# Out:
# Index(['poet', 'poem_url', 'title', 'poem_lines', 'poem_string', 'genre'], dtype='object')

# %% [markdown]
# ## Drop certain genres
#
# - I'll look at a breakdown of genres and see if there are any I should get rid of.
# - My initial thoughts are to limit it by time period, so as to remove any language barriers, so to speak, between old English and modern English.

# %%
# # uncomment to load
# with gzip.open('data/poems_df_clean_all.pkl', 'rb') as hello:
#     df = pickle.load(hello)

# %%
df.shape
# Out:
# (5098, 6)

# %%
# look at quantity within each genre
df.genre.value_counts()
# Out:
# modern                            1244
# victorian                          642
# renaissance                        423
# romantic                           395
# imagist                            350
# new_york_school                    259
# black_mountain                     256
# language_poetry                    194
# new_york_school_2nd_generation     188
# confessional                       172
# black_arts_movement                159
# georgian                           158
# objectivist                        155
# harlem_renaissance                 147
# beat                               146
# augustan                           114
# fugitive                            86
# middle_english                      10
# Name: genre, dtype: int64

# %%
# check a sample Middle English poem
print(df[df.genre == 'middle_english'].iloc[0, -2])
# Out:
# Whan that Aprille with his shour
# The droghte of March hath perc
# And bath
# Of which vertú engendr
# Whan Zephirus eek with his swet
# Inspir
# The tendr
# Hath in the Ram his half
# And smal
# That slepen al the nyght with open y
# So priketh hem Natúre in hir corag
# Thanne longen folk to goon on pilgrimag
# And palmeres for to seken straung
# To fern
# And specially, from every shir
# Of Eng
# The hooly blisful martir for to sek
# That hem hath holpen whan that they were seek
# Bifil that in that seson on a day,
# In Southwerk at the Tabard as I lay,
# Redy to wenden on my pilgrymag
# To Caunterbury with ful devout corag
# At nyght were come into that hostelry
# Wel nyne and twenty in a compaigny
# Of sondry folk, by áventure y-fall
# In felaweshipe, and pilgrimes were they all
# That toward Caunterbury wolden ryd
# The chambr
# And wel we weren es
# And shortly, whan the sonn
# So hadde I spoken with hem everychon,
# That I was of hir felaweshipe anon,
# And mad
# To take oure wey, ther as I yow devys
# But nath
# Er that I ferther in this tal
# Me thynketh it acordaunt to resoun
# To tell
# Of ech of hem, so as it sem
# And whiche they weren and of what degree,
# And eek in what array that they were inn
# And at a Knyght than wol I first bigynn
# A Knyght ther was, and that a worthy man,
# That fro the tym
# To riden out, he lov
# Trouthe and honóur, fredom and curteisi
# Ful worthy was he in his lord
# And thereto hadde he riden, no man ferr
# As wel in cristendom as in heth
# And evere honóur
# Tel me anon, withouten word
# And I wol erly shap
# This thyng was graunted, and oure oth
# With ful glad herte, and preyden hym also
# That he wolde vouch
# And that he wolde been oure governour,
# And of our tal
# And sette a soper at a certeyn pris;
# And we wol reul
# In heigh and lough; and thus, by oon assent,
# We been acorded to his jugg
# And therupon the wyn was fet anon;
# We dronken, and to rest
# Withouten any lenger taryyng
# Amorw
# Up roos oure Hoost and was oure aller cok,
# And gadrede us togidre alle in a flok;
# And forth we riden, a litel moore than paas,
# Unto the wateryng of Seint Thomas;
# And there oure Hoost bigan his hors arest
# And seyd
# Ye woot youre foreward and I it yow record
# If even-song and morw
# Lat se now who shal telle the first
# As ever mote I drynk
# Whoso be rebel to my jugg
# Shal paye for all that by the wey is spent.
# Now draweth cut, er that we ferrer twynn
# He which that hath the shorteste shal bigynn
# Sire Knyght," quod he, "my mayster and my lord
# Now draweth cut, for that is myn accord.
# Cometh neer," quod he, "my lady Prioress
# And ye, sire Clerk, lat be your shamefastness
# Ne studieth noght. Ley hond to, every man."
# Anon to drawen every wight bigan,
# And, shortly for to tellen as it was,
# Were it by áventúre, or sort, or cas,
# The sothe is this, the cut fil to the Knyght,
# Of which ful blithe and glad was every wyght;
# And telle he moste his tale, as was resoun,
# By foreward and by composic
# As ye han herd; what nedeth word
# And whan this goode man saugh that it was so,
# As he that wys was and obedient
# To kepe his foreward by his free assent,
# He seyd
# What, welcome be the cut, a Godd
# Now lat us ryde, and herkneth what I sey
# And with that word we ryden forth oure wey
# And he bigan with right a myrie cheer
# His tale anon, and seyde in this manér

# %% [markdown]
# - Indeed, Middle English is definitely out.

# %%
# drop genre
df = df[df.genre != 'middle_english']

# confirm
df.shape
# Out:
# (5088, 6)

# %%
# check a sample Renaissance poem
print(df[df.genre == 'renaissance'].iloc[1, -2])
# Out:
# See the chariot at hand here of Love,
# Wherein my lady rideth!
# Each that draws is a swan or a dove,
# And well the car Love guideth.
# As she goes, all hearts do duty
# Unto her beauty;
# And enamour'd, do wish, so they might
# But enjoy such a sight,
# That they still were to run by her side,
# Through swords, through seas, whither she would ride.
# Do but look on her eyes, they do light
# All that Love's world compriseth!
# Do but look on her hair, it is bright
# As Love's star when it riseth!
# Do but mark, her forehead's smoother
# Than words that soothe her;
# And from her arched brows, such a grace
# Sheds itself through the face
# As alone there triumphs to the life
# All the gain, all the good, of the elements' strife.
# Have you seen but a bright lily grow,
# Before rude hands have touch'd it?
# Ha' you mark'd but the fall o' the snow
# Before the soil hath smutch'd it?
# Ha' you felt the wool o' the beaver?
# Or swan's down ever?
# Or have smelt o' the bud o' the briar?
# Or the nard in the fire?
# Or have tasted the bag of the bee?
# Oh so white! Oh so soft! Oh so sweet is she!

# %%
# check a sample Augustan poem
print(df[df.genre == 'augustan'].iloc[2, -2])
# Out:
# Learn then what morals critics ought to show,
# For 'tis but half a judge's task, to know.
# 'Tis not enough, taste, judgment, learning, join;
# In all you speak, let truth and candour shine:
# That not alone what to your sense is due,
# All may allow; but seek your friendship too.
# Be silent always when you doubt your sense;
# And speak, though sure, with seeming diffidence:
# Some positive, persisting fops we know,
# Who, if once wrong, will needs be always so;
# But you, with pleasure own your errors past,
# And make each day a critic on the last.
# 'Tis not enough, your counsel still be true;
# Blunt truths more mischief than nice falsehoods do;
# Men must be taught as if you taught them not;
# And things unknown proposed as things forgot.
# Without good breeding, truth is disapprov'd;
# That only makes superior sense belov'd.
# Be niggards of advice on no pretence;
# For the worst avarice is that of sense.
# With mean complacence ne'er betray your trust,
# Nor be so civil as to prove unjust.
# Fear not the anger of the wise to raise;
# Those best can bear reproof, who merit praise.
# 'Twere well might critics still this freedom take,
# But Appius reddens at each word you speak,
# And stares,
# Like some fierce tyrant in old tapestry!
# Fear most to tax an honourable fool,
# Whose right it is, uncensur'd, to be dull;
# Such, without wit, are poets when they please,
# As without learning they can take degrees.
# Leave dangerous truths to unsuccessful satires,
# And flattery to fulsome dedicators,
# Whom, when they praise, the world believes no more,
# Than when they promise to give scribbling o'er.
# 'Tis best sometimes your censure to restrain,
# And charitably let the dull be vain:
# Your silence there is better than your spite,
# For who can rail so long as they can write?
# Still humming on, their drowsy course they keep,
# And lash'd so long, like tops, are lash'd asleep.
# False steps but help them to renew the race,
# As after stumbling, jades will mend their pace.
# What crowds of these, impenitently bold,
# In sounds and jingling syllables grown old,
# Still run on poets, in a raging vein,
# Even to the dregs and squeezings of the brain,
# Strain out the last, dull droppings of their sense,
# And rhyme with all the rage of impotence!
# Such shameless bards we have; and yet 'tis true,
# There are as mad, abandon'd critics too.
# The bookful blockhead, ignorantly read,
# With loads of learned lumber in his head,
# With his own tongue still edifies his ears,
# And always list'ning to himself appears.
# All books he reads, and all he reads assails,
# From Dryden's Fables down to Durfey's Tales.
# With him, most authors steal their works, or buy;
# Garth did not write his own
# Name a new play, and he's the poet's friend,
# Nay show'd his faults—but when would poets mend?
# No place so sacred from such fops is barr'd,
# Nor is Paul's church more safe than Paul's churchyard:
# Nay, fly to altars; there they'll talk you dead:
# For fools rush in where angels fear to tread.
# Distrustful sense with modest caution speaks;
# It still looks home, and short excursions makes;
# But rattling nonsense in full volleys breaks;
# And never shock'd, and never turn'd aside,
# Bursts out, resistless, with a thund'ring tide.
# But where's the man, who counsel can bestow,
# Still pleas'd to teach, and yet not proud to know?
# Unbias'd, or by favour or by spite;
# Not dully prepossess'd, nor blindly right;
# Though learn'd, well-bred; and though well-bred, sincere;
# Modestly bold, and humanly severe?
# Who to a friend his faults can freely show,
# And gladly praise the merit of a foe?
# Blest with a taste exact, yet unconfin'd;
# A knowledge both of books and human kind;
# Gen'rous converse; a soul exempt from pride;
# And love to praise, with reason on his side?
# Such once were critics; such the happy few,
# Athens and Rome in better ages knew.
# The mighty Stagirite first left the shore,
# Spread all his sails, and durst the deeps explore:
# He steer'd securely, and discover'd far,
# Led by the light of the Mæonian Star.
# Poets, a race long unconfin'd and free,
# Still fond and proud of savage liberty,
# Receiv'd his laws; and stood convinc'd 'twas fit,
# Who conquer'd nature, should preside o'er wit.
# Horace still charms with graceful negligence,
# And without methods talks us into sense,
# Will, like a friend, familiarly convey
# The truest notions in the easiest way.
# He, who supreme in judgment, as in wit,
# Might boldly censure, as he boldly writ,
# Yet judg'd with coolness, though he sung with fire;
# His precepts teach but what his works inspire.
# Our critics take a contrary extreme,
# They judge with fury, but they write with fle'me:
# Nor suffers Horace more in wrong translations
# By wits, than critics in as wrong quotations.
# See Dionysius Homer's thoughts refine,
# And call new beauties forth from ev'ry line!
# Fancy and art in gay Petronius please,
# The scholar's learning, with the courtier's ease.
# In grave Quintilian's copious work we find
# The justest rules, and clearest method join'd;
# Thus useful arms in magazines we place,
# All rang'd in order, and dispos'd with grace,
# But less to please the eye, than arm the hand,
# Still fit for use, and ready at command.
# Thee, bold Longinus! all the Nine inspire,
# And bless their critic with a poet's fire.
# An ardent judge, who zealous in his trust,
# With warmth gives sentence, yet is always just;
# Whose own example strengthens all his laws;
# And is himself that great sublime he draws.
# Thus long succeeding critics justly reign'd,
# Licence repress'd, and useful laws ordain'd;
# Learning and Rome alike in empire grew,
# And arts still follow'd where her eagles flew;
# From the same foes, at last, both felt their doom,
# And the same age saw learning fall, and Rome.
# With tyranny, then superstition join'd,
# As that the body, this enslav'd the mind;
# Much was believ'd, but little understood,
# And to be dull was constru'd to be good;
# A second deluge learning thus o'er-run,
# And the monks finish'd what the Goths begun.
# At length Erasmus, that great, injur'd name,
# (The glory of the priesthood, and the shame!)
# Stemm'd the wild torrent of a barb'rous age,
# And drove those holy Vandals off the stage.
# But see! each Muse, in Leo's golden days,
# Starts from her trance, and trims her wither'd bays!
# Rome's ancient genius, o'er its ruins spread,
# Shakes off the dust, and rears his rev'rend head!
# Then sculpture and her sister-arts revive;
# Stones leap'd to form, and rocks began to live;
# With sweeter notes each rising temple rung;
# A Raphael painted, and a Vida sung.
# Immortal Vida! on whose honour'd brow
# The poet's bays and critic's ivy grow:
# Cremona now shall ever boast thy name,
# As next in place to Mantua, next in fame!
# But soon by impious arms from Latium chas'd,
# Their ancient bounds the banished Muses pass'd;
# Thence arts o'er all the northern world advance;
# But critic-learning flourish'd most in France.
# The rules a nation born to serve, obeys,
# And Boileau still in right of Horace sways.
# But we, brave Britons, foreign laws despis'd,
# And kept unconquer'd, and uncivilis'd,
# Fierce for the liberties of wit, and bold,
# We still defied the Romans, as of old.
# Yet some there were, among the sounder few
# Of those who less presum'd, and better knew,
# Who durst assert the juster ancient cause,
# And here restor'd wit's fundamental laws.
# Such was the Muse, whose rules and practice tell
# "Nature's chief master-piece is writing well."
# Such was Roscommon—not more learn'd than good,
# With manners gen'rous as his noble blood;
# To him the wit of Greece and Rome was known,
# And ev'ry author's merit, but his own.
# Such late was Walsh—the Muse's judge and friend,
# Who justly knew to blame or to commend;
# To failings mild, but zealous for desert;
# The clearest head, and the sincerest heart.
# This humble praise, lamented shade! receive,
# This praise at least a grateful Muse may give:
# The Muse, whose early voice you taught to sing,
# Prescrib'd her heights, and prun'd her tender wing,
# (Her guide now lost) no more attempts to rise,
# But in low numbers short excursions tries:
# Content, if hence th' unlearn'd their wants may view,
# The learn'd reflect on what before they knew:
# Careless of censure, nor too fond of fame,
# Still pleas'd to praise, yet not afraid to blame,
# Averse alike to flatter, or offend,
# Not free from faults, nor yet too vain to mend.

# %% [markdown]
# - According to Poetry Foundation's website, Renaissance and Augustan poems are from the years 1500 - 1780, and the differences in the English are fairly clear.
# - I'm going to go ahead and drop these.

# %%
# drop genres
df_trim = df[df.genre != 'renaissance']
df_trim = df_trim[df_trim.genre != 'augustan']

# confirm
df_trim.shape
# Out:
# (4551, 6)

# %%
# check a sample Victorian poem
print(df[df.genre == 'victorian'].iloc[1,-2])
# Out:
# The time you won your town the race
# We chaired you through the market-place;
# Man and boy stood cheering by,
# And home we brought you shoulder-high.
# To-day, the road all runners come,
# Shoulder-high we bring you home,
# And set you at your threshold down,
# Townsman of a stiller town.
# Smart lad, to slip betimes away
# From fields where glory does not stay
# And early though the laurel grows
# It withers quicker than the rose.
# Eyes the shady night has shut
# Cannot see the record cut,
# And silence sounds no worse than cheers
# After earth has stopped the ears:
# Now you will not swell the rout
# Of lads that wore their honours out,
# Runners whom renown outran
# And the name died before the man.
# So set, before its echoes fade,
# The fleet foot on the sill of shade,
# And hold to the low lintel up
# The still-defended challenge-cup.
# And round that early-laurelled head
# Will flock to gaze the strengthless dead,
# And find unwithered on its curls
# The garland briefer than a girl's.

# %%
# check a sample Romantic poem
print(df[df.genre == 'romantic'].iloc[1,-2])
# Out:
# I once rejoiced, sweet evening gale,
# To see thy breath the poplar wave;
# But now it makes my cheek turn pale,
# It waves the grass o’er Henry’s grave.
# Ah! setting sun! how changed I seem!
# I to thy rays prefer deep gloom, —
# Since now, alas! I see them beam
# Upon my Henry’s lonely tomb.
# Sweet evening gale, howe’er I seem,
# I wish thee o’er my sod to wave;
# Ah! setting sun! soon mayst thou beam
# On mine, as well as Henry’s grave!

# %% [markdown]
# - Romantic and Victorian poems are from 1781-1900, but the language seems fairly similar.
# - Plus, these are some very formative genres for poetry in English. I'll keep these.
# - All other genres are from after 1900.
# - I'd never heard of the genres Georgian and Fugitive, however, and after doing some research, I've decided to drop them, due to some associations with white supremacy.

# %%
# drop genres
df_trim = df_trim[df_trim.genre != 'georgian']
df_trim = df_trim[df_trim.genre != 'fugitive']

# confirm
df_trim.shape
# Out:
# (4307, 6)

# %% [markdown]
# - Reset indices and save.

# %%
# reindex
df_trim.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### 💾 Save/Load Trimmed DataFrame
#
# [[go back to the top](#Data-Cleaning)]

# %%
# # uncomment to save
# with gzip.open('data/poems_df_clean_trim.pkl', 'wb') as goodbye:
#     pickle.dump(df_trim, goodbye, protocol=pickle.HIGHEST_PROTOCOL)

# # uncomment to load
# with gzip.open('data/poems_df_clean_trim.pkl', 'rb') as hello:
#     df = pickle.load(hello)

# %%
# # uncomment to save
# df_trim.to_csv('data/poems_df_cleaned_trim.csv')

# %% [markdown]
# ## Next notebook: [NLP, Feature Engineering, and EDA](03_nlp_features_eda.ipynb)
#
# [[go back to the top](#Data-Cleaning)]
#
# - The next notebook includes natural language processing, engineering of features, exploring data, and analyzing data.
