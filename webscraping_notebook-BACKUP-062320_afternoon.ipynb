# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns; sns.set_style('ticks')

import re
from unicodedata import normalize
from ast import literal_eval

import requests as rq
from bs4 import BeautifulSoup as bs
from selenium import webdriver


import time
import pickle

from functions import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pd.set_option('max_colwidth', 150)

# %% [markdown]
# ##### Manually create dictionary with url codes for each genre.

# %%
genre_codes = {
    'augustan': 149,
    'beat': 150,
    'black_arts_movement': 304,
    'black_mountain': 151,
    'confessional': 152,
    'fugitive': 153,
    'georgian': 154,
    'harlem_renaissance': 155,
    'imagist': 156,
    'language_poetry': 157,
    'middle_english': 158,
    'modern': 159,
    'new_york_school': 160,
    'new_york_school_2nd_generation': 161,
    'objectivist': 162,
    'renaissance': 163,
    'romantic': 164,
    'victorian': 165
}

# %% [markdown]
# ##### Run function in a loop to create dictionary of poet urls.

# %%
poet_urls = {genre:poet_urls_by_genre(genre_code, 3) for genre,genre_code in genre_codes.items()}
poet_urls['augustan']
# Out:
# ['https://www.poetryfoundation.org/poets/mary-barber',
#  'https://www.poetryfoundation.org/poets/susanna-blamire',
#  'https://www.poetryfoundation.org/poets/henry-carey',
#  'https://www.poetryfoundation.org/poets/thomas-chatterton',
#  'https://www.poetryfoundation.org/poets/william-collins',
#  'https://www.poetryfoundation.org/poets/william-cowper',
#  'https://www.poetryfoundation.org/poets/daniel-defoe',
#  'https://www.poetryfoundation.org/poets/anne-finch',
#  'https://www.poetryfoundation.org/poets/john-gay',
#  'https://www.poetryfoundation.org/poets/oliver-goldsmith',
#  'https://www.poetryfoundation.org/poets/thomas-gray',
#  'https://www.poetryfoundation.org/poets/matthew-green',
#  'https://www.poetryfoundation.org/poets/warren-hastings',
#  'https://www.poetryfoundation.org/poets/samuel-johnson',
#  'https://www.poetryfoundation.org/poets/mary-jones',
#  'https://www.poetryfoundation.org/poets/lady-mary-wortley-montagu',
#  'https://www.poetryfoundation.org/poets/alexander-pope',
#  'https://www.poetryfoundation.org/poets/matthew-prior',
#  'https://www.poetryfoundation.org/poets/richard-brinsley-sheridan',
#  'https://www.poetryfoundation.org/poets/jonathan-swift',
#  'https://www.poetryfoundation.org/poets/james-thomson',
#  'https://www.poetryfoundation.org/poets/isaac-watts',
#  'https://www.poetryfoundation.org/poets/john-wesley']

# %% [markdown]
# ##### The loop only partially worked, so let's re-run sections in which some urls are missing.

# %%
poet_urls['black_arts_movement'] = poet_urls_by_genre(genre_codes['black_arts_movement'])

# %%
poet_urls['modern'] = poet_urls_by_genre(genre_codes['modern'])

# %%
poet_urls['renaissance'] = poet_urls_by_genre(genre_codes['renaissance'])

# %%
poet_urls['romantic'] = poet_urls_by_genre(genre_codes['romantic'])

# %%
poet_urls['victorian'] = poet_urls_by_genre(genre_codes['victorian'])

# %%
# confirm all urls have been grabbed
url_lens = {k:len(v) for k,v in poet_urls.items()}
url_lens
# Out:
# {'augustan': 23,
#  'beat': 13,
#  'black_arts_movement': 23,
#  'black_mountain': 10,
#  'confessional': 7,
#  'fugitive': 7,
#  'georgian': 22,
#  'harlem_renaissance': 17,
#  'imagist': 6,
#  'language_poetry': 18,
#  'middle_english': 3,
#  'modern': 54,
#  'new_york_school': 9,
#  'new_york_school_2nd_generation': 16,
#  'objectivist': 5,
#  'renaissance': 41,
#  'romantic': 51,
#  'victorian': 55}

# %% [markdown]
# ##### Pickle it! uncomment to save/load

# %%
# with open('poet_urls_dict.pickle', 'wb') as w:
#     pickle.dump(poet_urls, w, protocol=pickle.HIGHEST_PROTOCOL)

# with open('poet_urls_dict.pickle', 'rb') as r:
#     poet_urls_dict = pickle.load(r)

# %% [markdown]
# ##### Check for duplicate values

# %%
poet_df = pd.DataFrame([(genre,v) for genre in poet_urls_dict.keys() for v in poet_urls_dict[genre]])
pd.concat(g for _, g in poet_df.groupby(1) if len(g) > 1)
# Out:
#            0                                                         1
# 126  imagist         https://www.poetryfoundation.org/poets/ezra-pound
# 186   modern         https://www.poetryfoundation.org/poets/ezra-pound
# 122  imagist  https://www.poetryfoundation.org/poets/richard-aldington
# 150   modern  https://www.poetryfoundation.org/poets/richard-aldington

# %% [markdown]
# ##### We'll give those poets to the imagist genre, since it has so few already

# %%
dups = [value for value in poet_df[poet_df.duplicated(1)][1]]
dups
# Out:
# ['https://www.poetryfoundation.org/poets/richard-aldington',
#  'https://www.poetryfoundation.org/poets/ezra-pound']

# %%
len(poet_urls_dict['modern'])
# Out:
# 54

# %%
# re-listify the modernist urls without pound and aldington
poet_urls_dict['modern'] = [url for url in poet_urls_dict['modern'] if url not in dups]
len(poet_urls_dict['modern'])
# Out:
# 52

# %% [markdown]
# ##### Instantiate an empty dataframe, then loop over each genre in our poet urls dictionary, create a dataframe for each genre and add that to the original dataframe, saving it after each concatenation

# %%
# %%time

# instantiate an empty dataframe
df = pd.DataFrame()

# loop over each genre, create dataframe with desired information,
# concat to original dataframe, then save it before looping again
for genre in list(poet_urls_dict.keys()):
    genre_df = pf_scraper(poet_urls_dict, genre, 0.5)
    df = pd.concat([df, genre_df])
    df.to_csv('data/poetry_foundation_raw.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/Documents/flatiron/projects/mod5/poetry_genre_classifier/functions.py in pf_scraper(poet_urls_dict, genre)
#     169         for poem_url in poem_text_urls:
#     170             info = [poet_url, genre, poem_url]
# --> 171             info.extend(poem_scraper(poem_url))
#     172             ultra_list.append(info)
#     173
#
# ~/Documents/flatiron/projects/mod5/poetry_genre_classifier/functions.py in poem_scraper(poem_url)
#      90
#      91     # load a page and soupify it
# ---> 92     page = rq.get(poem_url)
#      93     soup = bs(page.content, 'html.parser')
#      94
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py in getresponse(self)
#    1344         try:
#    1345             try:
# -> 1346                 response.begin()
#    1347             except ConnectionError:
#    1348                 self.close()
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     311     def recv_into(self, *args, **kwargs):
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#     315             if self.suppress_ragged_eofs and e.args == (-1, "Unexpected EOF"):
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:

# %% [markdown]
# ##### Uncomment to save/load dataframe

# %%
# TO SAVE
# df.to_csv('data/poetry_foundation_raw.csv')

# TO LOAD
# df = pd.read_csv('data/poetry_foundation_raw.csv', index_col=0)

# %%
# rename the columns
df.columns = ['poet_url', 'genre', 'poem_url', 'poet', 'title', 'year', 'poem_lines', 'poem_string']
df.head()
# Out:
#                                                  poet_url     genre  \
# 0      https://www.poetryfoundation.org/poets/mary-barber  augustan
# 1  https://www.poetryfoundation.org/poets/susanna-blamire  augustan
# 2  https://www.poetryfoundation.org/poets/susanna-blamire  augustan
# 3  https://www.poetryfoundation.org/poets/susanna-blamire  augustan
# 4      https://www.poetryfoundation.org/poets/henry-carey  augustan
#
#                                                                         poem_url  \
# 0     https://www.poetryfoundation.org/poems/50523/advice-to-her-son-on-marriage
# 1                 https://www.poetryfoundation.org/poems/50534/auld-robin-forbes
# 2      https://www.poetryfoundation.org/poems/50533/o-donald-ye-are-just-the-man
# 3                  https://www.poetryfoundation.org/poems/50532/the-siller-croun
# 4  https://www.poetryfoundation.org/poems/43884/the-ballad-of-sally-in-our-alley
#
#               poet                             title  year  \
# 0      Mary Barber     Advice to Her Son on Marriage   NaN
# 1  Susanna Blamire                 Auld Robin Forbes   NaN
# 2  Susanna Blamire     O Donald! Ye Are Just the Man   NaN
# 3  Susanna Blamire                  The Siller Croun   NaN
# 4      Henry Carey  The Ballad of Sally in our Alley   NaN
#
#                                                                                                                                               poem_lines  \
# 0  ['When you gain her Affection, take care to preserve it;\r', 'Lest others persuade her, you do not deserve it.\r', 'Still study to heighten the Jo...
# 1  ['And auld Robin Forbes hes gien tem a dance,\r', 'I pat on my speckets to see them aw prance;\r', 'I thout o’ the days when I was but fifteen,\r'...
# 2  ['O Donald! ye are just the man\r', '  Who, when he’s got a wife,\r', 'Begins to fratch— nae notice ta’en—\r', '  They’re strangers a’ their life....
# 3  ['And ye shall walk in silk attire,\r', '   And siller hae to spare,\r', 'Gin ye’ll consent to be his bride,\r', '    Nor think o’ Donald mair.\r'...
# 4  ['Of all the Girls that are so smart\r', '     There’s none like pretty SALLY,\r', 'She is the Darling of my Heart,\r', '     And she lives in our...
#
#                                                                                                                                              poem_string
# 0  When you gain her Affection, take care to preserve it;\r\nLest others persuade her, you do not deserve it.\r\nStill study to heighten the Joys of ...
# 1  And auld Robin Forbes hes gien tem a dance,\r\nI pat on my speckets to see them aw prance;\r\nI thout o’ the days when I was but fifteen,\r\nAnd s...
# 2  O Donald! ye are just the man\r\n  Who, when he’s got a wife,\r\nBegins to fratch— nae notice ta’en—\r\n  They’re strangers a’ their life.\r\n\nTh...
# 3  And ye shall walk in silk attire,\r\n   And siller hae to spare,\r\nGin ye’ll consent to be his bride,\r\n    Nor think o’ Donald mair.\r\nO wha w...
# 4  Of all the Girls that are so smart\r\n     There’s none like pretty SALLY,\r\nShe is the Darling of my Heart,\r\n     And she lives in our Alley.\...

# %% [markdown]
# ##### Explore to see how the data looks

# %%
df.shape
# Out:
# (5295, 8)

# %%
df.genre.unique()
# Out:
# array(['augustan', 'beat', 'black_arts_movement', 'black_mountain',
#        'confessional', 'fugitive', 'georgian', 'harlem_renaissance',
#        'imagist', 'language_poetry', 'middle_english', 'modern',
#        'new_york_school', 'new_york_school_2nd_generation', 'objectivist',
#        'renaissance', 'romantic', 'victorian'], dtype=object)

# %%
df.genre.value_counts()
# Out:
# modern                            1324
# victorian                          674
# renaissance                        430
# romantic                           407
# imagist                            370
# new_york_school                    265
# black_mountain                     257
# new_york_school_2nd_generation     193
# language_poetry                    192
# confessional                       176
# georgian                           167
# black_arts_movement                165
# objectivist                        159
# harlem_renaissance                 148
# beat                               147
# augustan                           121
# fugitive                            90
# middle_english                      10
# Name: genre, dtype: int64

# %% [markdown]
# ##### Check for duplicate values across multiple columns and drop those rows

# %%
df.duplicated(subset=['poet_url', 'genre', 'poem_url', 'poet', 'title', 'year', 'poem_string'], keep='last').sum()
# Out:
# 98

# %%
df.drop_duplicates(subset=['poet_url', 'genre', 'poem_url', 'poet', 'title', 'year', 'poem_string'],
                   keep='last',
                   inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.shape
# Out:
# (5197, 8)

# %%
df.genre.value_counts()
# Out:
# modern                            1284
# victorian                          643
# renaissance                        427
# romantic                           398
# imagist                            370
# new_york_school                    265
# black_mountain                     257
# new_york_school_2nd_generation     192
# language_poetry                    192
# confessional                       176
# black_arts_movement                165
# georgian                           160
# objectivist                        159
# harlem_renaissance                 148
# beat                               147
# augustan                           114
# fugitive                            90
# middle_english                      10
# Name: genre, dtype: int64

# %% [markdown]
# ##### Looks like the poem_lines column converted to a list inside of a string while saving to CSV. We'll wait to convert it until we can fill some missing values for that column, a process I found to be more easily done as a list inside of a string.

# %%
df.loc[0,'poem_lines']
# Out:
# "['When you gain her Affection, take care to preserve it;\\r', 'Lest others persuade her, you do not deserve it.\\r', 'Still study to heighten the Joys of her Life;\\r', 'Not treat her the worse, for her being your Wife.\\r', 'If in Judgment she errs, set her right, without Pride:\\r', '’Tis the Province of insolent Fools, to deride.\\r', 'A Husband’s first Praise, is a ', 'Then change not these Titles, for ', 'Let your Person be neat, unaffectedly clean,\\r', 'Tho’ alone with your wife the whole Day you remain.\\r', 'Chuse Books, for her study, to fashion her Mind,\\r', 'To emulate those who excell’d of her Kind.\\r', 'Be Religion the principal Care of your Life,\\r', 'As you hope to be blest in your Children and Wife:\\r', 'So you, in your Marriage, shall gain its true End;\\r', 'And find, in your Wife, a ', '', '']"

# %% [markdown]
# ##### Check for missing values

# %%
df.isna().sum()
# Out:
# poet_url          0
# genre             0
# poem_url          0
# poet             13
# title           215
# year           1649
# poem_lines      410
# poem_string     412
# dtype: int64

# %%
df[df.poet.isna()]
# Out:
#                                                   poet_url         genre  \
# 858   https://www.poetryfoundation.org/poets/w-d-snodgrass  confessional
# 1409     https://www.poetryfoundation.org/poets/amy-lowell       imagist
# 1410     https://www.poetryfoundation.org/poets/amy-lowell       imagist
# 1411     https://www.poetryfoundation.org/poets/amy-lowell       imagist
# 1412     https://www.poetryfoundation.org/poets/amy-lowell       imagist
# 1413     https://www.poetryfoundation.org/poets/amy-lowell       imagist
# 1414     https://www.poetryfoundation.org/poets/amy-lowell       imagist
# 1415     https://www.poetryfoundation.org/poets/amy-lowell       imagist
# 1416     https://www.poetryfoundation.org/poets/amy-lowell       imagist
# 1417     https://www.poetryfoundation.org/poets/amy-lowell       imagist
# 1418     https://www.poetryfoundation.org/poets/amy-lowell       imagist
# 1419     https://www.poetryfoundation.org/poets/amy-lowell       imagist
# 3919     https://www.poetryfoundation.org/poets/ben-jonson   renaissance
#
#                                                                                                                                                 poem_url  \
# 858                                                                       https://www.poetryfoundation.org/poetrymagazine/poems/48292/road-56d22969928f0
# 1409                             https://www.poetryfoundation.org/poetrymagazine/poems/14311/after-how-many-years-tr-by-amy-lowell-and-florence-ayscough
# 1410                                      https://www.poetryfoundation.org/poetrymagazine/poems/14312/calligraphy-tr-by-amy-lowell-and-florence-ayscough
# 1411  https://www.poetryfoundation.org/poetrymagazine/poems/14322/the-emperors-return-from-a-journey-to-the-south-tr-by-amy-lowell-and-florence-ayscough
# 1412                               https://www.poetryfoundation.org/poetrymagazine/poems/14310/an-evening-meeting-tr-by-amy-lowell-and-florence-ayscough
# 1413         https://www.poetryfoundation.org/poetrymagazine/poems/14314/from-the-straw-hut-among-the-seven-peaks-tr-by-amy-lowell-and-florence-ayscough
# 1414                      https://www.poetryfoundation.org/poetrymagazine/poems/14321/the-inn-at-the-western-lake-tr-by-amy-lowell-and-florence-ayscough
# 1415  https://www.poetryfoundation.org/poetrymagazine/poems/14296/on-seeing-the-portrait-of-a-beautiful-concubine-tr-by-amy-lowell-and-florence-ayscough
# 1416              https://www.poetryfoundation.org/poetrymagazine/poems/14316/on-the-classic-of-the-hills-and-sea-tr-by-amy-lowell-and-florence-ayscough
# 1415                                                                                                                                                    NaN
# 1416                                                                                                                                                    NaN
# 1417                                                                                                                                                    NaN
# 1418                                                                                                                                                    NaN
# 1419                                                                                                                                                    NaN
# 3919                                                                                                                                                    NaN

# %% [markdown]
# ##### The Amy Lowell and Ben Jonson entries appear unuseable, so we'll drop those rows, but since we're here, let's go ahead and fill in the missing info for the Snodgrass poem (which is actually a translation of another poet, but a confessional translator will probably produce a confessional work).

# %%
# manually load in information to the poet and title column
df.loc[858,'poet'] = 'ILEANA MALANCIOIU'.title()
df.loc[858,'title'] = 'Road'
df[df.index == 858]
# Out:
#                                                  poet_url         genre  \
# 858  https://www.poetryfoundation.org/poets/w-d-snodgrass  confessional
#
#                                                                            poem_url  \
# 858  https://www.poetryfoundation.org/poetrymagazine/poems/48292/road-56d22969928f0
#
#                   poet title    year  \
# 858  Ileana Malancioiu  Road  2006.0
#
#                                                                                                                                                 poem_lines  \
# 858  ['ILEANA MALANCIOIU', '', 'Road', '', 'I walk on a dark road so that I won’t see', '', 'The way my young oxen limp so much;', '', 'The horseshoes ...
#
#                                                                                                                                                poem_string
# 858  ILEANA MALANCIOIU\n\nRoad\n\nI walk on a dark road so that I won’t see\n\nThe way my young oxen limp so much;\n\nThe horseshoes gouging into their...

# %%
# drop the rows with missing values in the poet column
df.dropna(subset=['poet'], inplace=True)

# %%
df.isna().sum()
# Out:
# poet_url          0
# genre             0
# poem_url          0
# poet              0
# title           214
# year           1649
# poem_lines      398
# poem_string     400
# dtype: int64

# %% [markdown]
# ##### After reworking the scraping function a bit, we can try to fill in some missing poem_lines and poem_string values.

# %%
# create a list of index numbers with NaN values in the poem_lines column
lookups = list(df[df.poem_lines.isna()].index)
lookups
# Out:
# [158,
#  168,
#  169,
#  171,
#  175,
#  183,
#  184,
#  200,
#  203,
#  210,
#  229,
#  254,
#  283,
#  324,
#  325,
#  336,
#  351,
#  354,
#  361,
#  458,
#  466,
#  482,
#  484,
#  487,
#  490,
#  503,
#  511,
#  512,
#  513,
#  531,
#  532,
#  542,
#  558,
#  568,
#  576,
#  578,
#  624,
#  626,
#  648,
#  660,
#  661,
#  663,
#  664,
#  694,
#  701,
#  702,
#  703,
#  704,
#  705,
#  707,
#  708,
#  711,
#  714,
#  715,
#  716,
#  717,
#  719,
#  727,
#  736,
#  749,
#  751,
#  753,
#  769,
#  770,
#  817,
#  834,
#  853,
#  872,
#  881,
#  885,
#  886,
#  892,
#  897,
#  900,
#  917,
#  921,
#  940,
#  942,
#  943,
#  944,
#  945,
#  946,
#  947,
#  1004,
#  1025,
#  1123,
#  1163,
#  1169,
#  1171,
#  1184,
#  1186,
#  1192,
#  1234,
#  1297,
#  1299,
#  1319,
#  1326,
#  1345,
#  1348,
#  1363,
#  1367,
#  1371,
#  1379,
#  1383,
#  1392,
#  1395,
#  1404,
#  1440,
#  1446,
#  1452,
#  1456,
#  1467,
#  1468,
#  1477,
#  1482,
#  1489,
#  1495,
#  1496,
#  1498,
#  1500,
#  1502,
#  1503,
#  1505,
#  1515,
#  1516,
#  1517,
#  1518,
#  1519,
#  1551,
#  1552,
#  1553,
#  1554,
#  1555,
#  1556,
#  1560,
#  1565,
#  1566,
#  1587,
#  1591,
#  1594,
#  1602,
#  1604,
#  1617,
#  1618,
#  1623,
#  1631,
#  1711,
#  1731,
#  1732,
#  1743,
#  1748,
#  1770,
#  1786,
#  1815,
#  1816,
#  1834,
#  1836,
#  1837,
#  1839,
#  1844,
#  1865,
#  1867,
#  1870,
#  1875,
#  1876,
#  1877,
#  1906,
#  1914,
#  1915,
#  1940,
#  1965,
#  1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  1993,
#  1994,
#  1997,
#  1999,
#  2000,
#  2003,
#  2004,
#  2005,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2013,
#  2019,
#  2021,
#  2022,
#  2023,
#  2024,
#  2025,
#  2026,
#  2027,
#  2031,
#  2032,
#  2037,
#  2041,
#  2042,
#  2044,
#  2045,
#  2046,
#  2047,
#  2049,
#  2050,
#  2055,
#  2077,
#  2089,
#  2091,
#  2092,
#  2093,
#  2109,
#  2112,
#  2117,
#  2120,
#  2122,
#  2123,
#  2156,
#  2158,
#  2163,
#  2165,
#  2171,
#  2180,
#  2193,
#  2195,
#  2206,
#  2208,
#  2213,
#  2240,
#  2249,
#  2268,
#  2276,
#  2288,
#  2293,
#  2307,
#  2310,
#  2336,
#  2338,
#  2349,
#  2355,
#  2356,
#  2401,
#  2412,
#  2417,
#  2421,
#  2424,
#  2425,
#  2434,
#  2444,
#  2451,
#  2452,
#  2457,
#  2458,
#  2461,
#  2464,
#  2488,
#  2492,
#  2528,
#  2546,
#  2572,
#  2580,
#  2593,
#  2642,
#  2647,
#  2648,
#  2649,
#  2650,
#  2652,
#  2655,
#  2657,
#  2658,
#  2668,
#  2669,
#  2723,
#  2728,
#  2730,
#  2744,
#  2746,
#  2775,
#  2776,
#  2787,
#  2801,
#  2803,
#  2819,
#  2827,
#  2829,
#  2851,
#  2866,
#  2867,
#  2869,
#  2877,
#  2880,
#  2912,
#  2932,
#  2933,
#  2947,
#  2949,
#  2954,
#  2959,
#  2960,
#  3000,
#  3001,
#  3004,
#  3005,
#  3020,
#  3073,
#  3088,
#  3110,
#  3124,
#  3159,
#  3166,
#  3180,
#  3181,
#  3195,
#  3205,
#  3214,
#  3215,
#  3217,
#  3218,
#  3254,
#  3258,
#  3264,
#  3288,
#  3315,
#  3320,
#  3322,
#  3326,
#  3327,
#  3329,
#  3330,
#  3331,
#  3333,
#  3334,
#  3335,
#  3336,
#  3337,
#  3345,
#  3367,
#  3371,
#  3419,
#  3434,
#  3438,
#  3444,
#  3445,
#  3446,
#  3450,
#  3452,
#  3479,
#  3509,
#  3523,
#  3525,
#  3530,
#  3538,
#  3540,
#  3541,
#  3542,
#  3565,
#  3566,
#  3590,
#  3591,
#  3596,
#  3597,
#  3600,
#  3601,
#  3602,
#  3604,
#  3625,
#  3627,
#  3631,
#  3633,
#  3637,
#  3646,
#  3649,
#  3673,
#  3699,
#  3701,
#  3706,
#  3710,
#  3711,
#  3712,
#  3713,
#  3716,
#  3717,
#  3725,
#  3728,
#  3767,
#  3793,
#  4017,
#  4303,
#  4309,
#  4312,
#  4317,
#  4685,
#  4831]

# %%
# %%time

# iterate over the list, attempting to re-scrape the lines and string
# NOTE: I was getting a 'ValueError: Must have equal len keys and value when setting with an iterable', but converting
# the list to a string first seemed to make that go away. We have to convert this entire column anyway next.
for i in lookups:
    info = poem_scraper(df.loc[i, 'poem_url'])
    try:
        df.loc[i,'poem_lines'] = str(info[3])
        df.loc[i,'poem_string'] = info[4]
        print(f'Success -- {i}')
    except:
        print(f'Failure -- {i}')
        continue
# Out:
# Success --
# 168   1984.0
# 169   1986.0
# 171   1963.0
# 175   1996.0
# ...      ...
# 4309  1949.0
# 4312  2009.0
# 4317  1950.0
# 4685     NaN
# 4831  2002.0
#
#                                                                                                                                                  poem_lines  \
# 158   ['Autobus on Paseo de la Reforma with destination signs:', 'A boy and three burros run across a stubble field, away from the white mountain. He ho...
# 168   ['What thoughts I have of you tonight, Walt Whitman, for I walked down the sidestreets under the trees with a headache self-conscious looking at t...
# 169                                                                                                                                                     nan
# 171                                                                                                                                                     nan
# 175   ['A terror is more certain than all the rare desirable popular songs I', 'know, than even now when all of my myths have become . . . , & walk', 'a...
# ...                                                                                                                                                     ...
# 4309                                                                                                                                                    nan
# 4312  ['Like the stamen inside a flower', 'The steeple stands in lovely blue', 'And the day unfolds around its needle;', 'The flock of swallows that cir...
# 4317  ['There is a silence where hath been no sound,', 'There is a silence where no sound may be,', 'In the cold grave—under the deep deep sea,', 'Or in...
# 4685  ['Oh, but to fade, and live we know not where,', 'To be a cold obstruction and to groan!', 'This sensible, warm woman to become', 'A prudish clod;...
# 4831         ['', '<div class="c-epigraph">\n<p>\n<div style="font-style:italic;"><div align="center">Little Poems in Prose</div></div>\n</p>\n</div>', '']
#
#                                                                                                                                                 poem_string
# 158   Autobus on Paseo de la Reforma with destination signs:\nA boy and three burros run across a stubble field, away from the white mountain. He holds ...
# 168   What thoughts I have of you tonight, Walt Whitman, for I walked down the sidestreets under the trees with a headache self-conscious looking at the...
# 169                                                                                                                                                     NaN
# 171                                                                                                                                                     NaN
# 175   A terror is more certain than all the rare desirable popular songs I\nknow, than even now when all of my myths have become . . . , & walk\naround ...
# ...                                                                                                                                                     ...
# 4309                                                                                                                                                    NaN
# 4312  Like the stamen inside a flower\nThe steeple stands in lovely blue\nAnd the day unfolds around its needle;\nThe flock of swallows that circles the...
# 4317  There is a silence where hath been no sound,\nThere is a silence where no sound may be,\nIn the cold grave—under the deep deep sea,\nOr in the wid...
# 4685  Oh, but to fade, and live we know not where,\nTo be a cold obstruction and to groan!\nThis sensible, warm woman to become\nA prudish clod; and the...
# 4831                 \n<div class="c-epigraph">\n<p>\n<div style="font-style:italic;"><div align="center">Little Poems in Prose</div></div>\n</p>\n</div>\n
#
# [398 rows x 8 columns]

# %%
df.to_csv('data/poetry_foundation_cleaner_temp.csv')

# %% [markdown]
# ##### Looks like the loop was fairly successful though it did turn NaN values into the string 'nan'. Let's look first for other NaNs we may want to get rid of

# %%
df['poem_lines'] = df['poem_lines'].apply(destringify)

# %%
df.loc[0,'poem_lines']
# Out:
# ['When you gain her Affection, take care to preserve it;\r',
#  'Lest others persuade her, you do not deserve it.\r',
#  'Still study to heighten the Joys of her Life;\r',
#  'Not treat her the worse, for her being your Wife.\r',
#  'If in Judgment she errs, set her right, without Pride:\r',
#  '’Tis the Province of insolent Fools, to deride.\r',
#  'A Husband’s first Praise, is a ',
#  'Then change not these Titles, for ',
#  'Let your Person be neat, unaffectedly clean,\r',
#  'Tho’ alone with your wife the whole Day you remain.\r',
#  'Chuse Books, for her study, to fashion her Mind,\r',
#  'To emulate those who excell’d of her Kind.\r',
#  'Be Religion the principal Care of your Life,\r',
#  'As you hope to be blest in your Children and Wife:\r',
#  'So you, in your Marriage, shall gain its true End;\r',
#  'And find, in your Wife, a ',
#  '',
#  '']

# %%
df['poem_lines'] = np.where(df['poem_lines'] == 'nan', np.nan, df['poem_lines'])

# %%
df.loc[169,'poem_lines']
# Out:
# nan

# %%
df.isna().sum()
# Out:
# poet_url          0
# genre             0
# poem_url          0
# poet              0
# title           214
# year           1649
# poem_lines      344
# poem_string     346
# dtype: int64

# %% [markdown]
# ##### Looks like it may be time to drop rows with missing poem_lines values

# %%
# drop the rows with missing values in the poem_lines column
df.dropna(subset=['poem_lines'], inplace=True)

# %%
df.isna().sum()
# Out:
# poet_url          0
# genre             0
# poem_url          0
# poet              0
# title           214
# year           1649
# poem_lines        0
# poem_string       2
# dtype: int64

# %%
df[df.poem_string.isna()]
# Out:
#                                                   poet_url            genre  \
# 2941   https://www.poetryfoundation.org/poets/dylan-thomas           modern
# 3230  https://www.poetryfoundation.org/poets/barbara-guest  new_york_school
#
#                                                                            poem_url  \
# 2941  https://www.poetryfoundation.org/poems/26804/poem-on-his-birthday-facs-drafts
# 3230                     https://www.poetryfoundation.org/poems/49367/imagined-room
#
#                poet                                title  year poem_lines  \
# 2941   Dylan Thomas  Poem on His Birthday [Facs. drafts]   NaN         []
# 3230  Barbara Guest                        Imagined Room   NaN         []
#
#      poem_string
# 2941         NaN
# 3230         NaN

# %%
# drop the rows with missing values in the poem_string column, the pages for which do appear blank
df.dropna(subset=['poem_string'], inplace=True)

# %%
df[df.title.isna()]
# Out:
#                                                                poet_url  \
# 166               https://www.poetryfoundation.org/poets/allen-ginsberg
# 251                https://www.poetryfoundation.org/poets/diane-wakoski
# 275                 https://www.poetryfoundation.org/poets/amiri-baraka
# 285                 https://www.poetryfoundation.org/poets/amiri-baraka
# 306             https://www.poetryfoundation.org/poets/gwendolyn-brooks
# ...                                                                 ...
# 4066               https://www.poetryfoundation.org/poets/philip-sidney
# 4327                  https://www.poetryfoundation.org/poets/john-keats
# 4419                 https://www.poetryfoundation.org/poets/anna-seward
# 4420                 https://www.poetryfoundation.org/poets/anna-seward
# 4618  https://www.poetryfoundation.org/poets/elizabeth-barrett-browning
#
#                     genre  \
# 166                  beat
# 251                  beat
# 275   black_arts_movement
# 285   black_arts_movement
# 306   black_arts_movement
# ...                   ...
# 4066          renaissance
# 4327             romantic
# 4419             romantic
# 4420             romantic
# 4618            victorian
#
#                                                                                                                poem_url  \
# 166                                          https://www.poetryfoundation.org/poems/50123/new-stanzas-for-amazing-grace
# 251                                  https://www.poetryfoundation.org/poetrymagazine/poems/33706/the-ring-56d21729d7aa4
# 275                                                        https://www.poetryfoundation.org/poems/52777/an-agony-as-now
# 285                                  https://www.poetryfoundation.org/poetrymagazine/poems/29578/the-liar-56d2131c60523
# 306                                                     https://www.poetryfoundation.org/poems/58377/riot-56d23cb395a
# 4327  Bright star, would I were stedfast as thou art— \n         Not in lone splendour hung aloft the night \nAnd watching, with eternal lids apart, \n ...
# 4419  On the fleet streams, the Sun, that late arose, \n   In amber radiance plays; the tall young grass \n   No foot hath bruised; clear morning, as I ...
# 4420  Behold that tree, in Autumn’s dim decay, \n   Stripped by the frequent, chill, and eddying wind; \n   Where yet some yellow, lonely leaves we find...
# 4618  I thought once how Theocritus had sung \nOf the sweet years, the dear and wished for years, \nWho each one in a gracious hand appears \nTo bear a ...
#
# [214 rows x 8 columns]

# %% [markdown]
# ##### Let's try to fill in the title column using Regex

# %%
# create a list of index numbers with NaN values in the title column
lookups = list(df[df.title.isna()].index)
lookups
# Out:
# [166,
#  251,
#  275,
#  285,
#  306,
#  459,
#  460,
#  462,
#  463,
#  469,
#  470,
#  471,
#  472,
#  514,
#  517,
#  521,
#  522,
#  523,
#  552,
#  556,
#  557,
#  559,
#  561,
#  563,
#  567,
#  619,
#  631,
#  639,
#  641,
#  642,
#  696,
#  710,
#  779,
#  780,
#  830,
#  831,
#  906,
#  908,
#  922,
#  924,
#  986,
#  999,
#  1012,
#  1046,
#  1112,
#  1136,
#  1143,
#  1164,
#  1174,
#  1261,
#  1262,
#  1296,
#  1349,
#  1455,
#  1539,
#  1540,
#  1586,
#  1588,
#  1596,
#  1599,
#  1609,
#  1757,
#  1842,
#  1848,
#  1849,
#  1903,
#  1907,
#  1908,
#  1930,
#  1935,
#  1946,
#  1947,
#  1955,
#  2028,
#  2034,
#  2118,
#  2159,
#  2160,
#  2167,
#  2177,
#  2182,
#  2188,
#  2198,
#  2210,
#  2211,
#  2212,
#  2219,
#  2223,
#  2291,
#  2363,
#  2415,
#  2426,
#  2428,
#  2460,
#  2466,
#  2493,
#  2494,
#  2522,
#  2757,
#  2758,
#  2760,
#  2767,
#  2778,
#  2781,
#  2796,
#  2806,
#  2816,
#  2820,
#  2830,
#  2845,
#  2847,
#  2858,
#  2862,
#  2864,
#  2871,
#  2953,
#  2955,
#  2969,
#  2996,
#  2997,
#  3002,
#  3008,
#  3167,
#  3271,
#  3309,
#  3346,
#  3360,
#  3369,
#  3380,
#  3381,
#  3390,
#  3430,
#  3431,
#  3433,
#  3449,
#  3456,
#  3533,
#  3592,
#  3593,
#  3641,
#  3644,
#  3677,
#  3696,
#  3704,
#  3705,
#  3707,
#  3708,
#  3709,
#  3714,
#  3715,
#  3731,
#  3732,
#  3733,
#  3736,
#  3741,
#  3749,
#  3776,
#  3777,
#  3780,
#  3782,
#  3783,
#  3784,
#  3785,
#  3786,
#  3787,
#  3788,
#  3870,
#  3895,
#  3903,
#  3904,
#  3907,
#  3939,
#  3947,
#  3948,
#  3949,
#  3950,
#  3952,
#  3954,
#  3955,
#  3959,
#  3960,
#  3961,
#  3962,
#  4008,
#  4030,
#  4034,
#  4035,
#  4036,
#  4038,
#  4039,
#  4040,
#  4041,
#  4042,
#  4043,
#  4044,
#  4045,
#  4046,
#  4047,
#  4048,
#  4049,
#  4051,
#  4052,
#  4053,
#  4054,
#  4055,
#  4056,
# 306   \nA Poem in Three Parts\n\n              \n              \n\n\nJohn Cabot, out of Wilma, once a Wycliffe, \nBecause the “Negroes” were coming down...
# ...                                                                                                                                                     ...
# 4066  My true-love hath my heart and I have his, \nBy just exchange one for the other given: \nI hold his dear, and mine he cannot miss; \nThere never w...
# 4327  Bright star, would I were stedfast as thou art— \n         Not in lone splendour hung aloft the night \nAnd watching, with eternal lids apart, \n ...
# 4419  On the fleet streams, the Sun, that late arose, \n   In amber radiance plays; the tall young grass \n   No foot hath bruised; clear morning, as I ...
# 4420  Behold that tree, in Autumn’s dim decay, \n   Stripped by the frequent, chill, and eddying wind; \n   Where yet some yellow, lonely leaves we find...
# 4618  I thought once how Theocritus had sung \nOf the sweet years, the dear and wished for years, \nWho each one in a gracious hand appears \nTo bear a ...
#
# [214 rows x 8 columns]

# %% [markdown]
# ##### Only thing left is to drop the year column, as that didn't seem to be too successful

# %%
df.drop(columns='year', inplace=True)
df.isna().sum()
# Out:
# poet_url       0
# genre          0
# poem_url       0
# poet           0
# title          0
# poem_lines     0
# poem_string    0
# dtype: int64

# %%
df.shape
# Out:
# (4839, 7)

# %% [markdown]
# ### SAVE IT!

# %%
df.to_csv('data/poetry_foundation_clean.csv')

# %%
info = poem_scraper(df.loc[158,'poem_url'])
info
# Out:
# ['Lawrence Ferlinghetti',
#  'Beatitudes Visuales Mexicanas',
#  2015,
#  ['Autobus on Paseo de la Reforma with destination signs:',
#   'A boy and three burros run across a stubble field, away from the white mountain. He holds a stick. There is no other way.',
#   'Deep yellow flowers in the dusk by the road, beds of them stretching away into darkness. A moon the same color comes up.',
#   'As the bus turns + turns down the winding hill, moon swings wildly from side to side. It has had too many pathetic phallusies written about it to stand still for one more.',
#   'In Xalapa I am a head taller than anyone else in town — A foot of flesh and two languages separate us.',
#   'At a stand in the park at the center of Xalapa I eat white corn on the cob with a stick in the end, sprinkled with salt, butter, grated cheese + hot sauce. The dark stone Indian who hands it to me has been standing there three thousand years.',
#   'I’m taking this trip from Mexico City to the Gulf of Mexico and back without any bag or person — only what I can carry in my pockets. The need for baggage is a form of insecurity.',
#   'Two hours in this town and I feel I might live forever (foreign places affect me that way). The tall church tower tolls its antique sign:',
#   'In early morning in the great garden of Xalapa, with its terraces and immense jacaranda trees, pines + palms, there are black birds with cries like bells, and others with hollow wooden voices like gourds knocked together. The great white volcano shimmers far off, unreached by the rising sun.',
#   'Brown men in white palmetto cowboy hats stand about the fountains in groups of three or four, their voices lost to the hollow-sounding birds. Along a sunlit white stone balustrade, student lovers are studying each other,',
#   'On the bus again to Veracruz, dropping down fast to flat coast. A tropical feeling — suddenly coffee plantation + palms — everything small except the landscape, horses the size of burros, small black avocados, small strong men with machetes — each still saying to himself'],
#  'Autobus on Paseo de la Reforma with destination signs:\nA boy and three burros run across a stubble field, away from the white mountain. He holds a stick. There is no other way.\nDeep yellow flowers in the dusk by the road, beds of them stretching away into darkness. A moon the same color comes up.\nAs the bus turns + turns down the winding hill, moon swings wildly from side to side. It has had too many pathetic phallusies written about it to stand still for one more.\nIn Xalapa I am a head taller than anyone else in town — A foot of flesh and two languages separate us.\nAt a stand in the park at the center of Xalapa I eat white corn on the cob with a stick in the end, sprinkled with salt, butter, grated cheese + hot sauce. The dark stone Indian who hands it to me has been standing there three thousand years.\nI’m taking this trip from Mexico City to the Gulf of Mexico and back without any bag or person — only what I can carry in my pockets. The need for baggage is a form of insecurity.\nTwo hours in this town and I feel I might live forever (foreign places affect me that way). The tall church tower tolls its antique sign:\nIn early morning in the great garden of Xalapa, with its terraces and immense jacaranda trees, pines + palms, there are black birds with cries like bells, and others with hollow wooden voices like gourds knocked together. The great white volcano shimmers far off, unreached by the rising sun.\nBrown men in white palmetto cowboy hats stand about the fountains in groups of three or four, their voices lost to the hollow-sounding birds. Along a sunlit white stone balustrade, student lovers are studying each other,\nOn the bus again to Veracruz, dropping down fast to flat coast. A tropical feeling — suddenly coffee plantation + palms — everything small except the landscape, horses the size of burros, small black avocados, small strong men with machetes — each still saying to himself']

# %%
df.loc[158, 'poem_lines'] = str(info[3])
df.loc[158, 'poem_string'] = info[4]
df.loc[158]
# Out:
# poet_url                                                                                                https://www.poetryfoundation.org/poets/lawrence-ferlinghetti
# genre                                                                                                                                                           beat
# poem_url                                                                   https://www.poetryfoundation.org/poetrymagazine/poems/58150/beatitudes-visuales-mexicanas
# poet                                                                                                                                           Lawrence Ferlinghetti
# title                                                                                                                                  Beatitudes Visuales Mexicanas
# year                                                                                                                                                            2015
# poem_lines     ['Autobus on Paseo de la Reforma with destination signs:', 'A boy and three burros run across a stubble field, away from the white mountain. He ho...
# poem_string    Autobus on Paseo de la Reforma with destination signs:\nA boy and three burros run across a stubble field, away from the white mountain. He holds ...
# Name: 158, dtype: object

# %%
info[3]
# Out:
# ['Autobus on Paseo de la Reforma with destination signs:',
#  'A boy and three burros run across a stubble field, away from the white mountain. He holds a stick. There is no other way.',
#  'Deep yellow flowers in the dusk by the road, beds of them stretching away into darkness. A moon the same color comes up.',
#  'As the bus turns + turns down the winding hill, moon swings wildly from side to side. It has had too many pathetic phallusies written about it to stand still for one more.',
#  'In Xalapa I am a head taller than anyone else in town — A foot of flesh and two languages separate us.',
#  'At a stand in the park at the center of Xalapa I eat white corn on the cob with a stick in the end, sprinkled with salt, butter, grated cheese + hot sauce. The dark stone Indian who hands it to me has been standing there three thousand years.',
#  'I’m taking this trip from Mexico City to the Gulf of Mexico and back without any bag or person — only what I can carry in my pockets. The need for baggage is a form of insecurity.',
#  'Two hours in this town and I feel I might live forever (foreign places affect me that way). The tall church tower tolls its antique sign:',
#  'In early morning in the great garden of Xalapa, with its terraces and immense jacaranda trees, pines + palms, there are black birds with cries like bells, and others with hollow wooden voices like gourds knocked together. The great white volcano shimmers far off, unreached by the rising sun.',
#  'Brown men in white palmetto cowboy hats stand about the fountains in groups of three or four, their voices lost to the hollow-sounding birds. Along a sunlit white stone balustrade, student lovers are studying each other,',
#  'On the bus again to Veracruz, dropping down fast to flat coast. A tropical feeling — suddenly coffee plantation + palms — everything small except the landscape, horses the size of burros, small black avocados, small strong men with machetes — each still saying to himself']

# %%
df[df.poem_lines.isna()]
# Out:
#                                                           poet_url      genre  \
# 158   https://www.poetryfoundation.org/poets/lawrence-ferlinghetti       beat
# 168          https://www.poetryfoundation.org/poets/allen-ginsberg       beat
# 169          https://www.poetryfoundation.org/poets/allen-ginsberg       beat
# 171          https://www.poetryfoundation.org/poets/jack-hirschman       beat
# 175             https://www.poetryfoundation.org/poets/bob-kaufman       beat
# ...                                                            ...        ...
# 4309         https://www.poetryfoundation.org/poets/heinrich-heine   romantic
# 4312    https://www.poetryfoundation.org/poets/friedrich-holderlin   romantic
# 4317            https://www.poetryfoundation.org/poets/thomas-hood   romantic
# 4685            https://www.poetryfoundation.org/poets/phoebe-cary  victorian
# 4831           https://www.poetryfoundation.org/poets/emma-lazarus  victorian
#
#                                                                                                        poem_url  \
# 158                   https://www.poetryfoundation.org/poetrymagazine/poems/58150/beatitudes-visuales-mexicanas
# 168                                    https://www.poetryfoundation.org/poems/47660/a-supermarket-in-california
# 169             https://www.poetryfoundation.org/poetrymagazine/poems/36505/written-in-my-dream-by-w-c-williams
# 171                https://www.poetryfoundation.org/poetrymagazine/poems/29383/from-one-finger-from-the-seasons
# 175                                      https://www.poetryfoundation.org/poems/55713/a-terror-is-more-certain-
# ...                                                                                                         ...
# 4309  https://www.poetryfoundation.org/poetrymagazine/poems/25286/leaning-against-the-mast-tr-by-vernon-watkins
# 4312                                 https://www.poetryfoundation.org/poetrymagazine/poems/52408/in-lovely-blue
# 4317                                         https://www.poetryfoundation.org/poems/52339/silence-56d230b89fd5e
# 4685                                         https://www.poetryfoundation.org/poems/43918/shakesperian-readings
# 4831                                      https://www.poetryfoundation.org/poems/46791/by-the-waters-of-babylon
#
#                        poet                                          title  \
# 158   Lawrence Ferlinghetti                  Beatitudes Visuales Mexicanas
# 168          Allen Ginsberg                    A Supermarket in California
# 169          Allen Ginsberg            Written In My Dream By W C Williams
# 171          Jack Hirschman               From One Finger From The Seasons
# 175             Bob Kaufman                 A Terror is More Certain . . .
# ...                     ...                                            ...
# 4309         Heinrich Heine  Leaning Against The Mast Tr By Vernon Watkins
# 4312    Friedrich Hölderlin                                 In Lovely Blue
# 4317            Thomas Hood                                        Silence
# 4685            Phoebe Cary                          Shakesperian Readings
# 4831           Emma Lazarus                       By the Waters of Babylon
#
#         year poem_lines poem_string
# 158   2015.0        NaN         NaN
# 168   1984.0        NaN         NaN
# 169   1986.0        NaN         NaN
# 171   1963.0        NaN         NaN
# 175   1996.0        NaN         NaN
# ...      ...        ...         ...
# 4309  1949.0        NaN         NaN
# 4312  2009.0        NaN         NaN
# 4317  1950.0        NaN         NaN
# 4685     NaN        NaN         NaN
# 4831  2002.0        NaN         NaN
#
# [397 rows x 8 columns]

# %%
df['poem_lines'] = df.poem_lines.apply(lambda x: literal_eval(x))
df.loc[0,'poem_lines']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-3ac49fecdd0d> in <module>
# ----> 1 df['poem_lines'] = df.poem_lines.apply(lambda x: literal_eval(x))
#       2 df.loc[0,'poem_lines']
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-53-3ac49fecdd0d> in <lambda>(x)
# ----> 1 df['poem_lines'] = df.poem_lines.apply(lambda x: literal_eval(x))
#       2 df.loc[0,'poem_lines']
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/ast.py in literal_eval(node_or_string)
#      83                     return left - right
#      84         raise ValueError('malformed node or string: ' + repr(node))
# ---> 85     return _convert(node_or_string)
#      86
#      87
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/ast.py in _convert(node)
#      82                 else:
#      83                     return left - right
# ---> 84         raise ValueError('malformed node or string: ' + repr(node))
#      85     return _convert(node_or_string)
#      86
#
# ValueError: malformed node or string: nan

# %%
page = rq.get('https://www.poetryfoundation.org/poetrymagazine/poems/58150/beatitudes-visuales-mexicanas')
soup = bs(page.content, 'html.parser')

# %%
lines_raw = soup.find_all('div', {'style': 'text-align: justify;'})
lines = [normalize('NFKD', str(line.contents[0])) for line in lines_raw if line.contents]
lines
# Out:
# ['Autobus on Paseo de la Reforma with destination signs: ',
#  '<br/>',
#  '<br/>',
#  '<br/>',
#  'A boy and three burros run across a stubble field, away from the white mountain. He holds a stick. There is no other way.',
#  'Deep yellow flowers in the dusk by the road, beds of them stretching away into darkness. A moon the same color comes up.',
#  'As the bus turns + turns down the winding hill, moon swings wildly from side to side. It has had too many pathetic phallusies written about it to stand still for one more.',
#  'In Xalapa I am a head taller than anyone else in town — A foot of flesh and two languages separate us.',
#  'At a stand in the park at the center of Xalapa I eat white corn on the cob with a stick in the end, sprinkled with salt, butter, grated cheese + hot sauce. The dark stone Indian who hands it to me has been standing there three thousand years.',
#  'I’m taking this trip from Mexico City to the Gulf of Mexico and back without any bag or person — only what I can carry in my pockets. The need for baggage is a form of insecurity.',
#  'Two hours in this town and I feel I might live forever (foreign places affect me that way). The tall church tower tolls its antique sign: ',
#  'In early morning in the great garden of Xalapa, with its terraces and immense jacaranda trees, pines + palms, there are black birds with cries like bells, and others with hollow wooden voices like gourds knocked together. The great white volcano shimmers far off, unreached by the rising sun.',
#  'Brown men in white palmetto cowboy hats stand about the fountains in groups of three or four, their voices lost to the hollow-sounding birds. Along a sunlit white stone balustrade, student lovers are studying each other, ',
#  'On the bus again to Veracruz, dropping down fast to flat coast. A tropical feeling — suddenly coffee plantation + palms — everything small except the landscape, horses the size of burros, small black avocados, small strong men with machetes — each still saying to himself ']

# %%
lines_raw = soup.find('div', {'data-view': 'PoemView'}).contents[1]
lines = [normalize('NFKD', str(line)) for line in lines_raw if line]
lines = [line.replace('<br/>', '') for line in lines]
lines = [line.strip() for line in lines if line]
lines
# Out:
# ['What thoughts I have of you tonight, Walt Whitman, for I walked down the sidestreets under the trees with a headache self-conscious looking at the full moon.',
#  'In my hungry fatigue, and shopping for images, I went into the neon fruit supermarket, dreaming of your enumerations!',
#  'What peaches and what penumbras! Whole families shopping at night! Aisles full of husbands! Wives in the avocados, babies in the tomatoes!—and you, Garcia Lorca, what were you doing down by the watermelons?',
#  'I saw you, Walt Whitman, childless, lonely old grubber, poking among the meats in the refrigerator and eyeing the grocery boys.',
#  'I heard you asking questions of each: Who killed the pork chops? What price bananas? Are you my Angel?',
#  'I wandered in and out of the brilliant stacks of cans following you, and followed in my imagination by the store detective.',
#  'We strode down the open corridors together in our solitary fancy tasting artichokes, possessing every frozen delicacy, and never passing the cashier.',
#  'Where are we going, Walt Whitman? The doors close in an hour. Which way does your beard point tonight?',
#  '(I touch your book and dream of our odyssey in the supermarket and feel absurd.)',
#  "Will we walk all night through solitary streets? The trees add shade to shade, lights out in the houses, we'll both be lonely.",
#  'Will we stroll dreaming of the lost America of love past blue automobiles in driveways, home to our silent cottage?',
#  'Ah, dear father, graybeard, lonely old courage-teacher, what America did you have when Charon quit poling his ferry and you got out on a smoking bank and stood watching the boat disappear on the black waters of Lethe?',
#  '']

# %%
lines_raw = soup.find_all('div', {'style': 'text-indent: -1em; padding-left: 1em;'})
lines = [normalize('NFKD', str(line.contents[0])) for line in lines_raw if line.contents]
lines = [line.replace('<br/>', '') for line in lines]
lines
# Out:
# []

# %%
line_pattern = '<.*>'
# re.search(line_pattern, line, re.I).group(1)

# %%
# line_pattern = '>(.*?)<'
lines_test = [re.sub(line_pattern, '', line) if '<' in line else line for line in lines]
lines_test
# Out:
# ['There is a silence where hath been no sound, ',
#  '   There is a silence where no sound may be, ',
#  '   In the cold grave—under the deep deep sea, ',
#  'Or in the wide desert where no life is found, ',
#  'Which hath been mute, and still must sleep profound; ',
#  '   No voice is hush’d—no life treads silently, ',
#  '   But clouds and cloudy shadows wander free, ',
#  'That never spoke, over the idle ground: ',
#  'But in green ruins, in the desolate walls ',
#  '   Of antique palaces, where Man hath been, ',
#  'Though the dun fox, or wild hyena, calls, ',
#  '   And owls, that flit continually between, ',
#  'Shriek to the echo, and the low winds moan, ',
#  'There the true Silence is, self-conscious and alone. ',
#  '',
#  '',
#  '']

# %%
poem_scraper('https://www.poetryfoundation.org/poems/52339/silence-56d230b89fd5e')[3]
# Out:
# ['There is a silence where hath been no sound,',
#  'There is a silence where no sound may be,',
#  'In the cold grave—under the deep deep sea,',
#  'Or in the wide desert where no life is found,',
#  'Which hath been mute, and still must sleep profound;',
#  'No voice is hush’d—no life treads silently,',
#  'But clouds and cloudy shadows wander free,',
#  'That never spoke, over the idle ground:',
#  'But in green ruins, in the desolate walls',
#  'Of antique palaces, where Man hath been,',
#  'Though the dun fox, or wild hyena, calls,',
#  'And owls, that flit continually between,',
#  'Shriek to the echo, and the low winds moan,',
#  'There the true Silence is, self-conscious and alone.']

# %%
df[df.poem_lines.isna()]
# Out:
#                                                           poet_url      genre  \
# 158   https://www.poetryfoundation.org/poets/lawrence-ferlinghetti       beat
# 168          https://www.poetryfoundation.org/poets/allen-ginsberg       beat
# 169          https://www.poetryfoundation.org/poets/allen-ginsberg       beat
# 171          https://www.poetryfoundation.org/poets/jack-hirschman       beat
# 175             https://www.poetryfoundation.org/poets/bob-kaufman       beat
# ...                                                            ...        ...
# 4309         https://www.poetryfoundation.org/poets/heinrich-heine   romantic
# 4312    https://www.poetryfoundation.org/poets/friedrich-holderlin   romantic
# 4317            https://www.poetryfoundation.org/poets/thomas-hood   romantic
# 4685            https://www.poetryfoundation.org/poets/phoebe-cary  victorian
# 4831           https://www.poetryfoundation.org/poets/emma-lazarus  victorian
#
#                                                                                                        poem_url  \
# 158                   https://www.poetryfoundation.org/poetrymagazine/poems/58150/beatitudes-visuales-mexicanas
# 168                                    https://www.poetryfoundation.org/poems/47660/a-supermarket-in-california
# 169             https://www.poetryfoundation.org/poetrymagazine/poems/36505/written-in-my-dream-by-w-c-williams
# 171                https://www.poetryfoundation.org/poetrymagazine/poems/29383/from-one-finger-from-the-seasons
# 175                                      https://www.poetryfoundation.org/poems/55713/a-terror-is-more-certain-
# ...                                                                                                         ...
# 4309  https://www.poetryfoundation.org/poetrymagazine/poems/25286/leaning-against-the-mast-tr-by-vernon-watkins
# 4312                                 https://www.poetryfoundation.org/poetrymagazine/poems/52408/in-lovely-blue
# 4317                                         https://www.poetryfoundation.org/poems/52339/silence-56d230b89fd5e
# 4685                                         https://www.poetryfoundation.org/poems/43918/shakesperian-readings
# 4831                                      https://www.poetryfoundation.org/poems/46791/by-the-waters-of-babylon
#
#                        poet                                          title  \
# 158   Lawrence Ferlinghetti                  Beatitudes Visuales Mexicanas
# 168          Allen Ginsberg                    A Supermarket in California
# 169          Allen Ginsberg            Written In My Dream By W C Williams
# 171          Jack Hirschman               From One Finger From The Seasons
# 175             Bob Kaufman                 A Terror is More Certain . . .
# ...                     ...                                            ...
# 4309         Heinrich Heine  Leaning Against The Mast Tr By Vernon Watkins
# 4312    Friedrich Hölderlin                                 In Lovely Blue
# 4317            Thomas Hood                                        Silence
# 4685            Phoebe Cary                          Shakesperian Readings
# 4831           Emma Lazarus                       By the Waters of Babylon
#
#         year poem_lines poem_string
# 158   2015.0        NaN         NaN
# 168   1984.0        NaN         NaN
# 169   1986.0        NaN         NaN
# 171   1963.0        NaN         NaN
# 175   1996.0        NaN         NaN
# ...      ...        ...         ...
# 4309  1949.0        NaN         NaN
# 4312  2009.0        NaN         NaN
# 4317  1950.0        NaN         NaN
# 4685     NaN        NaN         NaN
# 4831  2002.0        NaN         NaN
#
# [410 rows x 8 columns]

# %%
df[df.poem_lines.isna()]
# Out:
#                                                               poet_url  \
# 65    https://www.poetryfoundation.org/poets/lady-mary-wortley-montagu
# 306            https://www.poetryfoundation.org/poets/gwendolyn-brooks
# 408                  https://www.poetryfoundation.org/poets/jay-wright
# 500              https://www.poetryfoundation.org/poets/robert-creeley
# 799            https://www.poetryfoundation.org/poets/frederick-seidel
# 949              https://www.poetryfoundation.org/poets/hilaire-belloc
# 1087          https://www.poetryfoundation.org/poets/siegfried-sassoon
# 1165            https://www.poetryfoundation.org/poets/langston-hughes
# 1211               https://www.poetryfoundation.org/poets/claude-mckay
# 1430                 https://www.poetryfoundation.org/poets/ezra-pound
# 1431                 https://www.poetryfoundation.org/poets/ezra-pound
# 1646             https://www.poetryfoundation.org/poets/rae-armantrout
# 1751                 https://www.poetryfoundation.org/poets/fanny-howe
# 1755                 https://www.poetryfoundation.org/poets/fanny-howe
# 1759                 https://www.poetryfoundation.org/poets/fanny-howe
# 1818               https://www.poetryfoundation.org/poets/ron-silliman
# 2084                  https://www.poetryfoundation.org/poets/t-s-eliot
# 2137                https://www.poetryfoundation.org/poets/ivor-gurney
# 2138                https://www.poetryfoundation.org/poets/ivor-gurney
# 2143                https://www.poetryfoundation.org/poets/ivor-gurney
# 3949        https://www.poetryfoundation.org/poets/william-shakespeare
# 3958        https://www.poetryfoundation.org/poets/william-shakespeare
# 4238                 https://www.poetryfoundation.org/poets/lord-byron
# 4239                 https://www.poetryfoundation.org/poets/lord-byron
# 4240                 https://www.poetryfoundation.org/poets/lord-byron
# 4295    https://www.poetryfoundation.org/poets/samuel-taylor-coleridge
# 4303             https://www.poetryfoundation.org/poets/erasmus-darwin
# 4438       https://www.poetryfoundation.org/poets/percy-bysshe-shelley
# 4777                          https://www.poetryfoundation.org/poems/44403/the-wreck-of-the-deutschland
# 4812                                   https://www.poetryfoundation.org/poems/57409/epitaphs-of-the-war
#
#                             poet  \
# 65     Lady Mary Wortley Montagu
# 306             Gwendolyn Brooks
# 408                   Jay Wright
# 500               Robert Creeley
# 799             Frederick Seidel
# 949               Hilaire Belloc
# 1087           Siegfried Sassoon
# 1165             Langston Hughes
# 1211                Claude McKay
# 1430                  Ezra Pound
# 1431                  Ezra Pound
# 1646              Rae Armantrout
# 1751                  Fanny Howe
# 1755                  Fanny Howe
# 1759                  Fanny Howe
# 1818                Ron Silliman
# 2084                 T. S. Eliot
# 2137                 Ivor Gurney
# 2138                 Ivor Gurney
# 2143                 Ivor Gurney
# 3949         William Shakespeare
# 3958         William Shakespeare
# 4238  Lord Byron (George Gordon)
# 4239  Lord Byron (George Gordon)
# 4240  Lord Byron (George Gordon)
# 4295     Samuel Taylor Coleridge
# 4303              Erasmus Darwin
# 4438        Percy Bysshe Shelley
# 4777       Gerard Manley Hopkins
# 4812             Rudyard Kipling
#
#                                                          title    year  \
# 65                 Town Eclogues: Thursday; the Bassette-Table     NaN
# 306                                                        NaN     NaN
# 408                    Benjamin Banneker Helps to Build a City  2000.0
# 500                                                   A Prayer  1982.0
# 799                                                       Snow  2012.0
# 949                               Ballade of Modest Confession  1970.0
# 1087                                               'Blighters'  1917.0
# 1165                                                       God  1994.0
# 1211                                              The Lynching  1922.0
# 1430                            Hugh Selwyn Mauberley [Part I]     NaN
# 1431                           Hugh Selwyn Mauberley [Part II]     NaN
# 1646                                                    Advent  2009.0
# 1751                                              The Cenotaph  2011.0
# 1755                                                    A Hymn  2010.0
# 1759                                                    Oxford  2009.0
# 1818                                                 Revelator  2010.0
# 2084                                   Whispers of Immortality     NaN
# 2137              First Time In [“After the dread tales ... ”]     NaN
# 2138                                I Saw England — July Night     NaN
# 2143                                           Strange Service     NaN
# 3949                                                       NaN     NaN
# 3958                          Song: “Under the greenwood tree”     NaN
# 4238                                : Canto 1, Stanzas 217-221  1986.0
# 4239                                  : Canto 1, Stanzas 41-42  1986.0
# 4240                                  : Canto 1, Stanzas 47-48  1986.0
# 4295            The Rime of the Ancient Mariner (text of 1834)     NaN
# 4303  The Botanic Garden, “The Economy of Vegetation”: Canto I     NaN
# 4438     Laon and Cythna; or The Revolution of the Golden City  2002.0
# 4777                              The Wreck of the Deutschland  1950.0
# 4812                                       Epitaphs of the War  1919.0
#
#      poem_lines poem_string
# 65          NaN         NaN
# 306         NaN         NaN
# 408         NaN         NaN
# 500         NaN         NaN
# 799         NaN         NaN
# 949         NaN         NaN
# 1087        NaN         NaN
# 1165        NaN         NaN
# 1211        NaN         NaN
# 1430        NaN         NaN
# 1431        NaN         NaN
# 1646        NaN         NaN
# 1751        NaN         NaN
# 1755        NaN         NaN
# 1759        NaN         NaN
# 1818        NaN         NaN
# 2084        NaN         NaN
# 2137        NaN         NaN
# 2138        NaN         NaN
# 2143        NaN         NaN
# 3949        NaN         NaN
# 3958        NaN         NaN
# 4238        NaN         NaN
# 4239        NaN         NaN
# 4240        NaN         NaN
# 4295        NaN         NaN
# 4303        NaN         NaN
# 4438        NaN         NaN
# 4777        NaN         NaN
# 4812        NaN         NaN

# %%
df[df.poem_string.isna()]
# Out:
#                                                               poet_url  \
# 65    https://www.poetryfoundation.org/poets/lady-mary-wortley-montagu
# 126           https://www.poetryfoundation.org/poets/richard-brautigan
# 140             https://www.poetryfoundation.org/poets/william-everson
# 141             https://www.poetryfoundation.org/poets/william-everson
# 158       https://www.poetryfoundation.org/poets/lawrence-ferlinghetti
# ...                                                                ...
# 4438       https://www.poetryfoundation.org/poets/percy-bysshe-shelley
# 4777      https://www.poetryfoundation.org/poets/gerard-manley-hopkins
# 4812            https://www.poetryfoundation.org/poets/rudyard-kipling
# 4831               https://www.poetryfoundation.org/poets/emma-lazarus
# 4937              https://www.poetryfoundation.org/poets/alice-meynell
#
#           genre  \
# 65     augustan
# 126        beat
# 140        beat
# 141        beat
# 158        beat
# ...         ...
# 4438   romantic
# 4777  victorian
# 4812  victorian
# 4831  victorian
# 4937  victorian
#
#                                                                                                poem_url  \
# 65               https://www.poetryfoundation.org/poems/44765/town-eclogues-thursday-the-bassette-table
# 126                                    https://www.poetryfoundation.org/poetrymagazine/poems/31338/wood
# 140                      https://www.poetryfoundation.org/poetrymagazine/poems/21676/dust-and-the-glory
# 141                        https://www.poetryfoundation.org/poetrymagazine/poems/21675/we-in-the-fields
# 158           https://www.poetryfoundation.org/poetrymagazine/poems/58150/beatitudes-visuales-mexicanas
# ...                                                                                                 ...
# 4438  https://www.poetryfoundation.org/poems/56665/laon-and-cythna-or-the-revolution-of-the-golden-city
# 4777                          https://www.poetryfoundation.org/poems/44403/the-wreck-of-the-deutschland
# 4812                                   https://www.poetryfoundation.org/poems/57409/epitaphs-of-the-war
# 4831                              https://www.poetryfoundation.org/poems/46791/by-the-waters-of-babylon
# 4937                              https://www.poetryfoundation.org/poetrymagazine/poems/12659/maternity
#
#                            poet  \
# 65    Lady Mary Wortley Montagu
# 126                         NaN
# 140                         NaN
# 141                         NaN
# 158       Lawrence Ferlinghetti
# ...                         ...
# 4438       Percy Bysshe Shelley
# 4777      Gerard Manley Hopkins
# 4812            Rudyard Kipling
# 4831               Emma Lazarus
# 4937                        NaN
#
#                                                       title    year  \
# 65              Town Eclogues: Thursday; the Bassette-Table     NaN
# 126                                                     NaN     NaN
# 140                                                     NaN     NaN
# 141                                                     NaN     NaN
# 158                           Beatitudes Visuales Mexicanas  2015.0
# ...                                                     ...     ...
# 4438  Laon and Cythna; or The Revolution of the Golden City  2002.0
# 4777                           The Wreck of the Deutschland  1950.0
# 4812                                    Epitaphs of the War  1919.0
# 4831                               By the Waters of Babylon  2002.0
# 4937                                                    NaN     NaN
#
#      poem_lines poem_string
# 65          NaN         NaN
# 126          []         NaN
# 140          []         NaN
# 141          []         NaN
# 158          []         NaN
# ...         ...         ...
# 4438        NaN         NaN
# 4777        NaN         NaN
# 4812        NaN         NaN
# 4831         []         NaN
# 4937         []         NaN
#
# [1937 rows x 8 columns]

# %%
df.head()
# Out:
#                                                  poet_url     genre  \
# 0      https://www.poetryfoundation.org/poets/mary-barber  augustan
# 1  https://www.poetryfoundation.org/poets/susanna-blamire  augustan
# 2  https://www.poetryfoundation.org/poets/susanna-blamire  augustan
# 3  https://www.poetryfoundation.org/poets/susanna-blamire  augustan
# 4      https://www.poetryfoundation.org/poets/henry-carey  augustan
#
#                                                                         poem_url  \
# 0     https://www.poetryfoundation.org/poems/50523/advice-to-her-son-on-marriage
# 1                 https://www.poetryfoundation.org/poems/50534/auld-robin-forbes
# 2      https://www.poetryfoundation.org/poems/50533/o-donald-ye-are-just-the-man
# 3                  https://www.poetryfoundation.org/poems/50532/the-siller-croun
# 4  https://www.poetryfoundation.org/poems/43884/the-ballad-of-sally-in-our-alley
#
#               poet                             title  year  \
# 0      Mary Barber     Advice to Her Son on Marriage   NaN
# 1  Susanna Blamire                 Auld Robin Forbes   NaN
# 2  Susanna Blamire     O Donald! Ye Are Just the Man   NaN
# 3  Susanna Blamire                  The Siller Croun   NaN
# 4      Henry Carey  The Ballad of Sally in our Alley   NaN
#
#                                                                                                                                               poem_lines  \
# 0  ['When you gain her Affection, take care to preserve it;\r', 'Lest others persuade her, you do not deserve it.\r', 'Still study to heighten the Jo...
# 1  ['And auld Robin Forbes hes gien tem a dance,\r', 'I pat on my speckets to see them aw prance;\r', 'I thout o’ the days when I was but fifteen,\r'...
# 2  ['O Donald! ye are just the man\r', '  Who, when he’s got a wife,\r', 'Begins to fratch— nae notice ta’en—\r', '  They’re strangers a’ their life....
# 3  ['And ye shall walk in silk attire,\r', '   And siller hae to spare,\r', 'Gin ye’ll consent to be his bride,\r', '    Nor think o’ Donald mair.\r'...
# 4  ['Of all the Girls that are so smart\r', '     There’s none like pretty SALLY,\r', 'She is the Darling of my Heart,\r', '     And she lives in our...
#
#                                                                                                                                              poem_string
# 0  When you gain her Affection, take care to preserve it;\nLest others persuade her, you do not deserve it.\nStill study to heighten the Joys of her ...
# 1  And auld Robin Forbes hes gien tem a dance,\nI pat on my speckets to see them aw prance;\nI thout o’ the days when I was but fifteen,\nAnd skipp’d...
# 2  O Donald! ye are just the man\n  Who, when he’s got a wife,\nBegins to fratch— nae notice ta’en—\n  They’re strangers a’ their life.\n\nThe fan ma...
# 3  And ye shall walk in silk attire,\n   And siller hae to spare,\nGin ye’ll consent to be his bride,\n    Nor think o’ Donald mair.\nO wha wad buy a...
# 4  Of all the Girls that are so smart\n     There’s none like pretty SALLY,\nShe is the Darling of my Heart,\n     And she lives in our Alley.\nThere...

# %%
import urllib

# %%
def poem_scraper(poem_url):
    '''Scraper for PoetryFoundation.org--scrapes poet name, poem title, poem year, list of poem's lines,
       and the poem as a string.
       Input the url for a poem's page on PoetryFoundation.org.
       Output is a list.'''
    
    # load a page and soupify it
    page = rq.get(poem_url)
    soup = bs(page.content, 'html.parser')
    
    # series of try/except statements to scrape info or return NaN value if desired info cannot be scraped
    try:
        poet = soup.find('a', href=re.compile('.*/poets/.*')).contents[0]
    except:
        poet = np.nan
        
    try:
        title = soup.find('h1').contents[-1].strip()
    except:
        try:
            title_pattern = '[a-z\-]*$'
            title = re.search(title_pattern, poem_url, re.I).group().replace('-', ' ').title()
        except:
            title = np.nan
        
    try:
        lines_raw = soup.find_all('div', {'style': 'text-indent: -1em; padding-left: 1em;'})
        lines = [normalize('NFKD', str(line.contents[0])) for line in lines_raw if line.contents]
        lines = [line.replace('<br/>', '') for line in lines]
        line_pattern = '>(.*?)<'
        lines = [re.search(line_pattern, line, re.I).group(1) if '<' in line else line for line in lines]
        if lines == []:
            try:
                img_link = soup.find('img', src=re.compile('.*/jstor/.*'))['src']
                img_data = rq.get(img_link).content
                with open('poem_imgs/temp.png', 'wb') as handle:
                    handle.write(img_data)
                text = pytesseract.image_to_string('poem_imgs/temp.png')
                scan_pattern = fr'{title.upper()}\s*((.*\s.*)*)'
                lines = re.search(scan_pattern, text, re.I).group(1).splitlines()
            except:
                lines = np.nan
    except:
        lines = np.nan
        
    try:
        poem_string = '\n'.join(lines)
    except:
        poem_string = np.nan
        
    try:
        year_blurb = soup.find('span', {'class': 'c-txt c-txt_note c-txt_note_mini'}).contents[2]
        year_pattern = r'[12]\d{3}'
        year = int(re.search(year_pattern, year_blurb, re.I).group())
    except:
        try:
            year_blurb = soup.find_all('span', {'class': 'c-txt c-txt_note c-txt_note_mini'})[-1].contents[2]
            year_pattern = r'[12]\d{3}'
            year = int(re.search(year_pattern, year_blurb, re.I).group())
        except:
            year = np.nan
    
    info = [poet, title, year, lines, poem_string]
    
    return info

# %%
poem_scraper('https://www.poetryfoundation.org/poetrymagazine/poems/31338/wood')
# Out:
# ['Richard Brautigan',
#  'Wood',
#  1969,
#  ['We age in darkness like wood',
#   'and watch our phantoms change',
#   'eir clothes',
#   'of shingles and boards',
#   'for a purpose that can only be',
#   'described as wood.'],
#  'We age in darkness like wood\nand watch our phantoms change\neir clothes\nof shingles and boards\nfor a purpose that can only be\ndescribed as wood.']

# %%
img_link
# Out:
# 'https://static.poetryfoundation.org/jstor/i20599092/pages/36.png'

# %%
page = rq.get('https://www.poetryfoundation.org/poetrymagazine/poems/31338/wood')
soup = bs(page.content, 'html.parser')
img_link = soup.find('img', src=re.compile('.*/jstor/.*'))['src']

img_data = rq.get(img_link).content
with open('poem_imgs/temp.png', 'wb') as handle:
    handle.write(img_data)
# with open('poem_imgs/temp.png', 'wb') as handle:
#     response = rq.get(img_link, stream=True)
# text = pytesseract.image_to_string('poem_imgs/temp.png')
# scan_pattern = fr'{title.upper()}\s*((.*\s.*)*)'
# lines = re.search(scan_pattern, text, re.I).group(1).splitlines()

# %%
img_data = rq.get(img_link).content
with open('poem_imgs/temp.png', 'wb') as handle:
    handle.write(img_data)
text = pytesseract.image_to_string('poem_imgs/temp.png')
scan_pattern = fr'{title.upper()}\s*((.*\s.*)*)'
lines = re.search(scan_pattern, text, re.I).group(1).splitlines()

# %%
lines
# Out:
# ['We age in darkness like wood',
#  'and watch our phantoms change',
#  'eir clothes',
#  'of shingles and boards',
#  'for a purpose that can only be',
#  'described as wood.']

# %%
text
# Out:
# 'POETRY\n\nRICHARD BRAUTIGAN\n\n \n\nWOOD\n\nWe age in darkness like wood\nand watch our phantoms change\neir clothes\nof shingles and boards\nfor a purpose that can only be\ndescribed as wood.'

# %%
soup.find('img', src=re.compile('.*/jstor/.*'))['src']
# Out:
# 'https://static.poetryfoundation.org/jstor/i20599092/pages/36.png'

# %%
import pytesseract

text = pytesseract.image_to_string('poem_imgs/36.png')
text
# Out:
# 'POETRY\n\nRICHARD BRAUTIGAN\n\n \n\nWOOD\n\nWe age in darkness like wood\nand watch our phantoms change\neir clothes\nof shingles and boards\nfor a purpose that can only be\ndescribed as wood.'

# %%
title_test = 'Wood'.upper()
title_test
# Out:
# 'WOOD'

# %%
scan_pattern = fr'{title_test}\s*((.*\s.*)*)'
re.search(scan_pattern, text, re.I).group(1).splitlines()
# Out:
# ['We age in darkness like wood',
#  'and watch our phantoms change',
#  'eir clothes',
#  'of shingles and boards',
#  'for a purpose that can only be',
#  'described as wood.']

# %%
print(text)
# Out:
# POETRY
#
# RICHARD BRAUTIGAN
#
#
#
# WOOD
#
# We age in darkness like wood
# and watch our phantoms change
# eir clothes
# of shingles and boards
# for a purpose that can only be
# described as wood.

# %%
page = rq.get('https://www.poetryfoundation.org/poetrymagazine/poems/21676/dust-and-the-glory')
soup = bs(page.content, 'html.parser')
poet = soup.find('a', href=re.compile('.*/poets/.*')).contents[0]
title = soup.find('span', attrs={'class':'c-hdgSans c-hdgSans_7'}).contents[-1].strip()
print(poet)
print(title)
# Out:
# William Everson
# We in the Fields

# %%
url = 'https://www.poetryfoundation.org/poetrymagazine/poems/21676/dust-and-the-glory'
title_pattern = '[a-z\-]*$'
title = re.search(title_pattern, url, re.I).group().replace('-', ' ').title()
year_blurb = soup.find_all('span', {'class': 'c-txt c-txt_note c-txt_note_mini'})[-1].contents[2]
year_pattern = r'[12]\d{3}'
year = int(re.search(year_pattern, year_blurb, re.I).group())
year
# Out:
# 1937

# %%
nan_lines = {ind:row.poem_url for ind,row in df[df.poem_lines.isna()].iterrows()}
nan_lines
# Out:
# {65: 'https://www.poetryfoundation.org/poems/44765/town-eclogues-thursday-the-bassette-table',
#  306: 'https://www.poetryfoundation.org/poems/58377/riot-56d23cb395a01',
#  408: 'https://www.poetryfoundation.org/poems/42736/benjamin-banneker-helps-to-build-a-city',
#  500: 'https://www.poetryfoundation.org/poetrymagazine/poems/55314/a-prayer-56d236c6bb760',
#  799: 'https://www.poetryfoundation.org/poetrymagazine/poems/55728/snow-56d23797074a2',
#  949: 'https://www.poetryfoundation.org/poems/46684/ballade-of-modest-confession',
#  1087: 'https://www.poetryfoundation.org/poems/57215/blighters',
#  1165: 'https://www.poetryfoundation.org/poetrymagazine/poems/55313/god-56d236c65624c',
#  1211: 'https://www.poetryfoundation.org/poems/56983/the-lynching',
#  1430: 'https://www.poetryfoundation.org/poems/44915/hugh-selwyn-mauberley-part-i',
#  1431: 'https://www.poetryfoundation.org/poems/57353/hugh-selwyn-mauberley-part-ii',
#  1646: 'https://www.poetryfoundation.org/poetrymagazine/poems/52593/advent-56d231303d41f',
#  1751: 'https://www.poetryfoundation.org/poetrymagazine/poems/55209/the-cenotaph',
#  1755: 'https://www.poetryfoundation.org/poetrymagazine/poems/53206/a-hymn',
#  1759: 'https://www.poetryfoundation.org/poetrymagazine/poems/53072/oxford-56d2320d14703',
#  1818: 'https://www.poetryfoundation.org/poetrymagazine/poems/53579/revelator',
#  2084: 'https://www.poetryfoundation.org/poems/52563/whispers-of-immortality',
#  2137: 'https://www.poetryfoundation.org/poems/57257/first-time-in-after-the-dread-tales-',
#  2138: 'https://www.poetryfoundation.org/poems/57256/i-saw-england-july-night',
#  2143: 'https://www.poetryfoundation.org/poems/57238/strange-service',
#  3949: 'https://www.poetryfoundation.org/poems/47418/song-full-fathom-five-thy-father-lies-',
#  3958: 'https://www.poetryfoundation.org/poems/47423/song-under-the-greenwood-tree',
#  4238: 'https://www.poetryfoundation.org/poems/55816/don-juan-canto-1-stanzas-217-221',
#  4239: 'https://www.poetryfoundation.org/poems/55814/don-juan-canto-1-stanzas-41-42',
#  4240: 'https://www.poetryfoundation.org/poems/55815/don-juan-canto-1-stanzas-47-48',
#  4295: 'https://www.poetryfoundation.org/poems/43997/the-rime-of-the-ancient-mariner-text-of-1834',
#  4303: 'https://www.poetryfoundation.org/poems/52827/the-botanic-garden-the-economy-of-vegetation-canto-i',
#  4438: 'https://www.poetryfoundation.org/poems/56665/laon-and-cythna-or-the-revolution-of-the-golden-city',
#  4777: 'https://www.poetryfoundation.org/poems/44403/the-wreck-of-the-deutschland',
#  4812: 'https://www.poetryfoundation.org/poems/57409/epitaphs-of-the-war'}

# %%
for i,url in nan_lines.items():
    df[i]['poem_lines'] =

# %%
df.iloc[308]
# Out:
# poet_url                                                                                                     https://www.poetryfoundation.org/poets/gwendolyn-brooks
# genre                                                                                                                                            black_arts_movement
# poem_url                                                                                                 https://www.poetryfoundation.org/poems/43311/sadie-and-maud
# poet                                                                                                                                                Gwendolyn Brooks
# title                                                                                                                                                 Sadie and Maud
# year                                                                                                                                                             NaN
# poem_lines     ['Maud went to college.', '\r Sadie stayed at home.', '\r Sadie scraped life', '\r With a fine-tooth comb.', '<br/>', '\r She didn’t leave a tangl...
# poem_string    Maud went to college.\n Sadie stayed at home.\n Sadie scraped life\n With a fine-tooth comb.\n\n She didn’t leave a tangle in.\n Her comb found ev...
# Name: 308, dtype: object

# %%
def poem_scraper(poem_url):
    '''Scraper for PoetryFoundation.org--scrapes poet name, poem title, poem year, list of poem's lines,
       and the poem as a string.
       Input the url for a poem's page on PoetryFoundation.org.
       Output is a list.'''
    
    # load a page and soupify it
    page = rq.get(poem_url)
    soup = bs(page.content, 'html.parser')
    
    # series of try/except statements to scrape info or return NaN value if desired info cannot be scraped
    try:
        poet = soup.find('a', href=re.compile('.*/poets/.*'), attrs={'class': None}).contents[0]
    except:
        poet = np.nan
        
    try:
        title = soup.find('h1').contents[-1].strip()
    except:
        title = np.nan
        
    try:
        lines_raw = soup.find_all('div', {'style': 'text-indent: -1em; padding-left: 1em;'})
        lines = [normalize('NFKD', str(line.contents[0])) for line in lines_raw if line.contents]
        lines = [line.replace('<br/>', '') for line in lines]
    except:
        lines = np.nan
        
    try:
        poem_string = '\n'.join(lines)
    except:
        poem_string = np.nan
        
    try:
        year_blurb = soup.find('span', {'class': 'c-txt c-txt_note c-txt_note_mini'}).contents[2]
        year_pattern = r'[12]\d{3}'
        year = int(re.search(year_pattern, year_blurb, re.I).group())
    except:
        year = np.nan
    
    info = [poet, title, year, lines, poem_string]
    
    return info

# %%
infor = poem_scraper('https://www.poetryfoundation.org/poetrymagazine/poems/55209/the-cenotaph')
infor
# Out:
# ['Fanny Howe',
#  'The Cenotaph',
#  2011,
#  ['I want to leave this place',
#   'unremembered.',
#   'The gas stove is leaking',
#   'and the door of the refrigerator',
#   'stained with rust.',
#   'The mugs are ugly',
#   'and there are only two forks.',
#   'The walls are black',
#   'and soft, the bed a balloon',
#   'of night-clothing.',
#   'The stairwell sloped',
#   'to a dragger’s pace.',
#   '',
#   'There are big windows',
#   'with blind-slats dusty',
#   'and gray. Street life ',
#   'goes all night and at dawn',
#   'freedmen shout and ',
#   'laugh outside the kitchen.',
#   '',
#   'Where does life begin and end?',
#   'In the lamb or the cotton?',
#   'My pillow is my friend.',
#   ''],
#  'I want to leave this place\nunremembered.\nThe gas stove is leaking\nand the door of the refrigerator\nstained with rust.\nThe mugs are ugly\nand there are only two forks.\nThe walls are black\nand soft, the bed a balloon\nof night-clothing.\nThe stairwell sloped\nto a dragger’s pace.\n\nThere are big windows\nwith blind-slats dusty\nand gray. Street life \ngoes all night and at dawn\nfreedmen shout and \nlaugh outside the kitchen.\n\nWhere does life begin and end?\nIn the lamb or the cotton?\nMy pillow is my friend.\n']

# %%
page = rq.get('https://www.poetryfoundation.org/poetrymagazine/poems/55209/the-cenotaph')
soup = bs(page.content, 'html.parser')
lines_raw = soup.find_all('div', {'style': 'text-indent: -1em; padding-left: 1em;'})
lines = [normalize('NFKD', str(line.contents[0])) for line in lines_raw if line.contents]
lines = [line.replace('<br/>', '') for line in lines]
year_blurb = soup.find('span', {'class': 'c-txt c-txt_note c-txt_note_mini'})
year_blurb
# Out:
# <span class="c-txt c-txt_note c-txt_note_mini">
#                         Source:
#                         <em>Poetry</em>
#                                                                                                                                                                     (December 2011)
#                                             </span>

# %%
print('\n'.join(lines).replace('<br/>', '\n'))
# Out:
# I want to leave this place
# unremembered.
# The gas stove is leaking
# and the door of the refrigerator
# stained with rust.
# The mugs are ugly
# and there are only two forks.
# The walls are black
# and soft, the bed a balloon
# of night-clothing.
# The stairwell sloped
# to a dragger’s pace.
#
# There are big windows
# with blind-slats dusty
# and gray. Street life
# goes all night and at dawn
# freedmen shout and
# laugh outside the kitchen.
#
# Where does life begin and end?
# In the lamb or the cotton?
# My pillow is my friend.

# %%
poem_string = "\n".join(''.join(lines).splitlines()).replace('<br/>', '\n')
print(poem_string)
# Out:
# I want to leave this placeunremembered.The gas stove is leakingand the door of the refrigeratorstained with rust.The mugs are uglyand there are only two forks.The walls are blackand soft, the bed a balloonof night-clothing.The stairwell slopedto a dragger’s pace.
# There are big windowswith blind-slats dustyand gray. Street life goes all night and at dawnfreedmen shout and laugh outside the kitchen.
# Where does life begin and end?In the lamb or the cotton?My pillow is my friend.

# %%
poet = soup.find('a', href=re.compile('.*/poets/.*'), attrs={'class': None}).contents[0]
poet
# Out:
# 'Fanny Howe'

# %%
title = soup.find('h1').contents[-1].strip()
title
# Out:
# 'The Cenotaph'

# %%
lines_raw = soup.find_all('div', {'style': 'text-indent: -1em; padding-left: 1em;'})
lines_raw
# Out:
# [<div style="text-indent: -1em; padding-left: 1em;">I want to leave this place<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">unremembered.<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">The gas stove is leaking<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">and the door of the refrigerator<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">stained with rust.<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">The mugs are ugly<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">and there are only two forks.<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">The walls are black<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">and soft, the bed a balloon<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">of night-clothing.<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">The stairwell sloped<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">to a dragger’s pace.<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;"><br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">There are big windows<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">with blind-slats dusty<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">and gray. Street life <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">goes all night and at dawn<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">freedmen shout and <br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">laugh outside the kitchen.<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;"><br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">Where does life begin and end?<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">In the lamb or the cotton?<br/></div>,
#  <div style="text-indent: -1em; padding-left: 1em;">My pillow is my friend.<em><br/></em></div>,
#  <div style="text-indent: -1em; padding-left: 1em;"></div>,
#  <div style="text-indent: -1em; padding-left: 1em;"><br/></div>]

# %%
lines_raw[-2]
# Out:
# <div style="text-indent: -1em; padding-left: 1em;"></div>

# %%
lines_raw[-2].contents[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-129-33eb644260ed> in <module>
# ----> 1 lines_raw[-2].contents[0]
#
# IndexError: list index out of range

# %%
lines = [normalize('NFKD', str(line.contents[0])) for line in lines_raw if line.contents]
lines
# Out:
# ['I want to leave this place',
#  'unremembered.',
#  'The gas stove is leaking',
#  'and the door of the refrigerator',
#  'stained with rust.',
#  'The mugs are ugly',
#  'and there are only two forks.',
#  'The walls are black',
#  'and soft, the bed a balloon',
#  'of night-clothing.',
#  'The stairwell sloped',
#  'to a dragger’s pace.',
#  '<br/>',
#  'There are big windows',
#  'with blind-slats dusty',
#  'and gray. Street life ',
#  'goes all night and at dawn',
#  'freedmen shout and ',
#  'laugh outside the kitchen.',
#  '<br/>',
#  'Where does life begin and end?',
#  'In the lamb or the cotton?',
#  'My pillow is my friend.',
#  '<br/>']

# %%
    
    # series of try/except statements to scrape info or return NaN value if desired info cannot be scraped
    try:
        poet = soup.find('a', href=re.compile('.*/poets/.*'), attrs={'class': None}).contents[0]
    except:
        poet = np.nan
        
    try:
        title = soup.find('h1').contents[-1].strip()
    except:
        title = np.nan
        
    try:
        lines_raw = soup.find_all('div', {'style': 'text-indent: -1em; padding-left: 1em;'})
        lines = [normalize('NFKD', str(line.contents[0])) for line in lines_raw]
    except:
        lines = np.nan
        
    try:
        poem_string = "\n".join(''.join(lines).splitlines()).replace('<br/>', '\n') 
    except:
        poem_string = np.nan
        
    try:
        year_blurb = soup.find('span', {'class': 'c-txt c-txt_note c-txt_note_mini'}).contents[2]
        year_pattern = r'[12]\d{3}'
        year = int(re.search(year_pattern, year_blurb, re.I).group())
    except:
        year = np.nan
    
    info = [poet, title, year, lines, poem_string]
    
    return info

# %%
df.groupby('genre').sum()
# Out:
#                                     year
# genre
# augustan                         30930.0
# beat                            183660.0
# black_arts_movement             271883.0
# black_mountain                  194322.0
# confessional                    150867.0
# fugitive                         62157.0
# georgian                         56322.0
# harlem_renaissance              152419.0
# imagist                         122877.0
# language_poetry                 342601.0
# middle_english                    1891.0
# modern                          362902.0
# new_york_school                 206930.0
# new_york_school_2nd_generation  252821.0
# objectivist                     131376.0
# renaissance                      72151.0
# romantic                         90357.0
# victorian                       196698.0

# %%
df[df.genre == 'modern'].title.value_counts()
# Out:
# The Waste Land                         14
# The Love Song of J. Alfred Prufrock    10
# Gerontion                               6
# Rhapsody on a Windy Night               4
# Portrait of a Lady                      4
#                                        ..
# No Second Troy                          1
# Under Ben Bulben                        1
# The People, Yes                         1
# Leave-Taking                            1
# Fixed Ideas                             1
# Name: title, Length: 459, dtype: int64

# %%
df[df.title == 'The Waste Land']
# Out:
#                                              poet_url   genre  \
# 245  https://www.poetryfoundation.org/poets/t-s-eliot  modern
# 246  https://www.poetryfoundation.org/poets/t-s-eliot  modern
# 247  https://www.poetryfoundation.org/poets/t-s-eliot  modern
# 256  https://www.poetryfoundation.org/poets/t-s-eliot  modern
# 257  https://www.poetryfoundation.org/poets/t-s-eliot  modern
# 261  https://www.poetryfoundation.org/poets/t-s-eliot  modern
# 262  https://www.poetryfoundation.org/poets/t-s-eliot  modern
# 265  https://www.poetryfoundation.org/poets/t-s-eliot  modern
# 266  https://www.poetryfoundation.org/poets/t-s-eliot  modern
# 267  https://www.poetryfoundation.org/poets/t-s-eliot  modern
# 268  https://www.poetryfoundation.org/poets/t-s-eliot  modern
# 269  https://www.poetryfoundation.org/poets/t-s-eliot  modern
# 270  https://www.poetryfoundation.org/poets/t-s-eliot  modern
# 283  https://www.poetryfoundation.org/poets/t-s-eliot  modern
#
#                                                         poem_url         poet  \
# 245  https://www.poetryfoundation.org/poems/47311/the-waste-land  T. S. Eliot
# 246  https://www.poetryfoundation.org/poems/47311/the-waste-land  T. S. Eliot
# 247  https://www.poetryfoundation.org/poems/47311/the-waste-land  T. S. Eliot
# 256  https://www.poetryfoundation.org/poems/47311/the-waste-land  T. S. Eliot
# 257  https://www.poetryfoundation.org/poems/47311/the-waste-land  T. S. Eliot
# 261  https://www.poetryfoundation.org/poems/47311/the-waste-land  T. S. Eliot
# 262  https://www.poetryfoundation.org/poems/47311/the-waste-land  T. S. Eliot
# 265  https://www.poetryfoundation.org/poems/47311/the-waste-land  T. S. Eliot
# 266  https://www.poetryfoundation.org/poems/47311/the-waste-land  T. S. Eliot
# 267  https://www.poetryfoundation.org/poems/47311/the-waste-land  T. S. Eliot
# 268  https://www.poetryfoundation.org/poems/47311/the-waste-land  T. S. Eliot
# 269  https://www.poetryfoundation.org/poems/47311/the-waste-land  T. S. Eliot
# 270  https://www.poetryfoundation.org/poems/47311/the-waste-land  T. S. Eliot
# 283  https://www.poetryfoundation.org/poems/47311/the-waste-land  T. S. Eliot
#
#               title  year  \
# 245  The Waste Land   NaN
# 246  The Waste Land   NaN
# 247  The Waste Land   NaN
# 256  The Waste Land   NaN
# 257  The Waste Land   NaN
# 261  The Waste Land   NaN
# 262  The Waste Land   NaN
# 265  The Waste Land   NaN
# 266  The Waste Land   NaN
# 267  The Waste Land   NaN
# 268  The Waste Land   NaN
# 269  The Waste Land   NaN
# 270  The Waste Land   NaN
# 283  The Waste Land   NaN
#
#                                                                                                                                                 poem_lines  \
# 245  [             , <br/>, \r   April is the cruellest month, breeding, \r Lilacs out of the dead land, mixing, \r Memory and desire, stirring, \r Dul...
# 246  [             , <br/>, \r   April is the cruellest month, breeding, \r Lilacs out of the dead land, mixing, \r Memory and desire, stirring, \r Dul...
# 247  [             , <br/>, \r   April is the cruellest month, breeding, \r Lilacs out of the dead land, mixing, \r Memory and desire, stirring, \r Dul...
# 256  [             , <br/>, \r   April is the cruellest month, breeding, \r Lilacs out of the dead land, mixing, \r Memory and desire, stirring, \r Dul...
# 257  [             , <br/>, \r   April is the cruellest month, breeding, \r Lilacs out of the dead land, mixing, \r Memory and desire, stirring, \r Dul...
# 261  [             , <br/>, \r   April is the cruellest month, breeding, \r Lilacs out of the dead land, mixing, \r Memory and desire, stirring, \r Dul...
# 262  [             , <br/>, \r   April is the cruellest month, breeding, \r Lilacs out of the dead land, mixing, \r Memory and desire, stirring, \r Dul...
# 265  [             , <br/>, \r   April is the cruellest month, breeding, \r Lilacs out of the dead land, mixing, \r Memory and desire, stirring, \r Dul...
# 266  [             , <br/>, \r   April is the cruellest month, breeding, \r Lilacs out of the dead land, mixing, \r Memory and desire, stirring, \r Dul...
# 267  [             , <br/>, \r   April is the cruellest month, breeding, \r Lilacs out of the dead land, mixing, \r Memory and desire, stirring, \r Dul...
# 268  [             , <br/>, \r   April is the cruellest month, breeding, \r Lilacs out of the dead land, mixing, \r Memory and desire, stirring, \r Dul...
# 269  [             , <br/>, \r   April is the cruellest month, breeding, \r Lilacs out of the dead land, mixing, \r Memory and desire, stirring, \r Dul...
# 270  [             , <br/>, \r   April is the cruellest month, breeding, \r Lilacs out of the dead land, mixing, \r Memory and desire, stirring, \r Dul...
# 283  [             , <br/>, \r   April is the cruellest month, breeding, \r Lilacs out of the dead land, mixing, \r Memory and desire, stirring, \r Dul...
#
#                                                                                                                                                poem_string
# 245               \n\n   April is the cruellest month, breeding\n Lilacs out of the dead land, mixing\n Memory and desire, stirring\n Dull roots with s...
# 246               \n\n   April is the cruellest month, breeding\n Lilacs out of the dead land, mixing\n Memory and desire, stirring\n Dull roots with s...
# 247               \n\n   April is the cruellest month, breeding\n Lilacs out of the dead land, mixing\n Memory and desire, stirring\n Dull roots with s...
# 256               \n\n   April is the cruellest month, breeding\n Lilacs out of the dead land, mixing\n Memory and desire, stirring\n Dull roots with s...
# 257               \n\n   April is the cruellest month, breeding\n Lilacs out of the dead land, mixing\n Memory and desire, stirring\n Dull roots with s...
# 261               \n\n   April is the cruellest month, breeding\n Lilacs out of the dead land, mixing\n Memory and desire, stirring\n Dull roots with s...
# 262               \n\n   April is the cruellest month, breeding\n Lilacs out of the dead land, mixing\n Memory and desire, stirring\n Dull roots with s...
# 265               \n\n   April is the cruellest month, breeding\n Lilacs out of the dead land, mixing\n Memory and desire, stirring\n Dull roots with s...
# 266               \n\n   April is the cruellest month, breeding\n Lilacs out of the dead land, mixing\n Memory and desire, stirring\n Dull roots with s...
# 267               \n\n   April is the cruellest month, breeding\n Lilacs out of the dead land, mixing\n Memory and desire, stirring\n Dull roots with s...
# 268               \n\n   April is the cruellest month, breeding\n Lilacs out of the dead land, mixing\n Memory and desire, stirring\n Dull roots with s...
# 269               \n\n   April is the cruellest month, breeding\n Lilacs out of the dead land, mixing\n Memory and desire, stirring\n Dull roots with s...
# 270               \n\n   April is the cruellest month, breeding\n Lilacs out of the dead land, mixing\n Memory and desire, stirring\n Dull roots with s...
# 283               \n\n   April is the cruellest month, breeding\n Lilacs out of the dead land, mixing\n Memory and desire, stirring\n Dull roots with s...

# %%
df.genre.value_counts()
# Out:
# modern                            1324
# victorian                          674
# renaissance                        430
# romantic                           407
# imagist                            370
# beat                               294
# new_york_school                    265
# black_mountain                     257
# new_york_school_2nd_generation     193
# language_poetry                    192
# confessional                       176
# georgian                           167
# black_arts_movement                165
# objectivist                        159
# harlem_renaissance                 148
# augustan                           121
# fugitive                            90
# middle_english                      10
# Name: genre, dtype: int64

# %%
df[df.genre == 'middle_english']
# Out:
#                                                   poet_url           genre  \
# 0  https://www.poetryfoundation.org/poets/geoffrey-chaucer  middle_english
# 1  https://www.poetryfoundation.org/poets/geoffrey-chaucer  middle_english
# 2  https://www.poetryfoundation.org/poets/geoffrey-chaucer  middle_english
# 3  https://www.poetryfoundation.org/poets/geoffrey-chaucer  middle_english
# 4  https://www.poetryfoundation.org/poets/geoffrey-chaucer  middle_english
# 5  https://www.poetryfoundation.org/poets/geoffrey-chaucer  middle_english
# 6  https://www.poetryfoundation.org/poets/geoffrey-chaucer  middle_english
# 7  https://www.poetryfoundation.org/poets/geoffrey-chaucer  middle_english
# 8  https://www.poetryfoundation.org/poets/william-langland  middle_english
# 9      https://www.poetryfoundation.org/poets/john-lydgate  middle_english
#
#                                                                              poem_url  \
# 0  https://www.poetryfoundation.org/poems/43926/the-canterbury-tales-general-prologue
# 1                 https://www.poetryfoundation.org/poems/43936/the-parlement-of-fowls
# 2                 https://www.poetryfoundation.org/poems/45694/to-rosemounde-a-balade
# 3            https://www.poetryfoundation.org/poems/43937/troilus-and-criseyde-book-i
# 4           https://www.poetryfoundation.org/poems/43938/troilus-and-criseyde-book-ii
# 5            https://www.poetryfoundation.org/poems/43939/troilus-and-criseyde-book-v
# 6                    https://www.poetryfoundation.org/poems/43940/truth-56d222d5bf80c
# 7     https://www.poetryfoundation.org/poems/50383/if-no-love-is-o-god-what-fele-i-so
# 8             https://www.poetryfoundation.org/poems/47350/piers-plowman-the-prologue
# 9          https://www.poetryfoundation.org/poems/44660/the-testament-of-john-lydgate
#
#                poet                                    title    year  \
# 7  If no love is, O God, what fele I so?\n And if love is, what thing and which is he?\n If love be good, from whennes cometh my woo?\n If it be wikk...
# 8  \n\n In a somer sesun, whon softe was the sonne,\n I schop me into a shroud, as I a scheep were;\n In habite as an hermite unholy of werkes\n Went...
# 9  Beholde, o man! lyft up thyn eye and see       What mortall peyne I suffre for thi trespace. With pietous voys I crye and sey to the:       Behold...

# %% [markdown]
# # SCRAP HEAP

# %%
ultra_dict = {genre: [] for genre in poet_urls_dict.keys()}
ultra_dict
# Out:
# {'augustan': [],
#  'beat': [],
#  'black_arts_movement': [],
#  'black_mountain': [],
#  'confessional': [],
#  'fugitive': [],
#  'georgian': [],
#  'harlem_renaissance': [],
#  'imagist': [],
#  'language_poetry': [],
#  'middle_english': [],
#  'modern': [],
#  'new_york_school': [],
#  'new_york_school_2nd_generation': [],
#  'objectivist': [],
#  'renaissance': [],
#  'romantic': [],
#  'victorian': []}

# %%
s = rq.Session()
s.get(genre_urls[0])
# Out:
# <Response [200]>

# %% [markdown]
# ### SCRAPER ATTEMPT READ IMAGE

# %%
def poem_scraper(poem_url):
    '''Scraper for PoetryFoundation.org--scrapes poet name, poem title, poem year, list of poem's lines,
       and the poem as a string.
       Input the url for a poem's page on PoetryFoundation.org.
       Output is a list.'''
    
    # load a page and soupify it
    page = rq.get(poem_url)
    soup = bs(page.content, 'html.parser')
    
    # series of try/except statements to scrape info or return NaN value if desired info cannot be scraped
    try:
        poet = soup.find('a', href=re.compile('.*/poets/.*')).contents[0]
    except:
        poet = np.nan
        
    try:
        title = soup.find('h1').contents[-1].strip()
    except:
        try:
            title_pattern = '[a-z\-]*$'
            title = re.search(title_pattern, poem_url, re.I).group().replace('-', ' ').title()
        except:
            title = np.nan
        
    try:
        lines_raw = soup.find_all('div', {'style': 'text-indent: -1em; padding-left: 1em;'})
        lines = [normalize('NFKD', str(line.contents[0])) for line in lines_raw if line.contents]
        lines = [line.replace('<br/>', '') for line in lines]
        line_pattern = '>(.*?)<'
        lines = [re.search(line_pattern, line, re.I).group(1) if '<' in line else line for line in lines]
        if lines == []:
            try:
                img_link = soup.find('img', src=re.compile('.*/jstor/.*'))['src']
                resource = urlopen(img_link)
                output = open('poem_imgs/temp.png','wb')
                output.write(resource.read())
                text = pytesseract.image_to_string('poem_imgs/temp.png')
                scan_pattern = fr'{title.upper()}\s*((.*\s.*)*)'
                lines = re.search(scan_pattern, text, re.I).group(1).splitlines()
            except:
                lines = np.nan
    except:
        lines = np.nan
        
    try:
        poem_string = '\n'.join(lines)
    except:
        poem_string = np.nan
        
    try:
        year_blurb = soup.find('span', {'class': 'c-txt c-txt_note c-txt_note_mini'}).contents[2]
        year_pattern = r'[12]\d{3}'
        year = int(re.search(year_pattern, year_blurb, re.I).group())
    except:
        try:
            year_blurb = soup.find_all('span', {'class': 'c-txt c-txt_note c-txt_note_mini'})[-1].contents[2]
            year_pattern = r'[12]\d{3}'
            year = int(re.search(year_pattern, year_blurb, re.I).group())
        except:
            year = np.nan
    
    info = [poet, title, year, lines, poem_string]
    
    return info
